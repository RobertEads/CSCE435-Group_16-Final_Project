# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd
import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Weak Scaling for Random

# %%
tk = th.Thicket.from_caliperreader(glob("*-i0*.cali"))

# %%
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
tk.dataframe
# Out:
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'main_function', 'type': 'function'}     69778151         0.381760
#                                                   399177385        2.174373
#                                                   523387201        0.386522
#                                                   938112548        0.761398
#                                                   1066994924       8.057966
#                                                   1071674850      42.811338
#                                                   1091449174      31.972805
#                                                   1091677715       2.116284
#                                                   1193204644     128.390969
#                                                   1216137125       2.114890
#                                                   1364689108       1.038207
#                                                   1453497524     125.730707
#                                                   1459960355     185.574192
#                                                   1472059284       8.196782
#                                                   1567983953       0.467005
#                                                   1690623772       0.746155
#                                                   2006852609       2.421228
#                                                   2034263549       0.496085
#                                                   2117806238     142.570528
#                                                   2331711899       0.794167
#                                                   2407546354     126.923596
#                                                   2522125044       0.728784
#                                                   2598285721       1.054431
#                                                   2646206980       0.365640
#                                                   2759465296       0.383424
#                                                   2992502833      31.319518
#                                                   3185965169       0.769003
#                                                   3357991400       0.478986
#                                                   3425464094       8.894542
#                                                   3548853050       8.313851
#                                                   3606745995       2.477061
#                                                   3807311974       8.137852
#                                                   4007904565      34.959160
#                                                   4050545721      31.193742
#                                                   4256600727       0.762219
# {'name': 'comm', 'type': 'function'}              69778151         0.000310
#                                                   399177385        0.007964
#                                                   523387201        0.000308
#                                                   938112548        0.000730
#                                                   1066994924       0.029537
#                                                   1071674850       0.117640
#                                                   1091449174       0.117640
#                                                   1091677715       0.007953
#                                                   1193204644       0.468648
#                                                   1216137125       0.007917
#                                                   1364689108       0.002104
#                                                   1453497524       0.468051
#                                                   1459960355       0.470181
#                                                   1472059284       0.030135
#                                                   1567983953       0.000685
#                                                   1690623772       0.002032
#                                                   2006852609       0.008080
#                                                   2034263549       0.000304
#                                                   2117806238       0.456290
#                                                   2331711899       0.000755
#                                                   2407546354       0.471789
#                                                   2522125044       0.002008
#                                                   2598285721       0.002040
#                                                   2646206980       0.000304
#                                                   2759465296       0.000319
#                                                   2992502833       0.114071
#                                                   3185965169       0.000687
#                                                   3357991400       0.000687
#                                                   3425464094       0.029306
#                                                   3548853050       0.029124
#                                                   3606745995       0.007827
#                                                   3807311974       0.029784
#                                                   4007904565       0.116573
#                                                   4050545721       0.117513
#                                                   4256600727       0.002040
# {'name': 'comm_large', 'type': 'function'}        69778151         0.000252
#                                                   399177385        0.007901
#                                                   523387201        0.000248
#                                                   938112548        0.000675
#                                                   1066994924       0.029476
#                                                   1071674850       0.117576
#                                                   1091449174       0.117579
#                                                   1091677715       0.007890
#                                                   1193204644       0.468578
#                                                   1216137125       0.007856
#                                                   1364689108       0.002049
#                                                   1453497524       0.467984
#                                                   1459960355       0.470114
#                                                   1472059284       0.030072
#                                                   1567983953       0.000626
#                                                   1690623772       0.001971
#                                                   2006852609       0.008024
#                                                   2034263549       0.000244
#                                                   2117806238       0.456226
#                                                   2331711899       0.000695
#                                                   2407546354       0.471721
#                                                   2522125044       0.001948
#                                                   2598285721       0.001979
#                                                   2646206980       0.000244
#                                                   2759465296       0.000258
#                                                   2992502833       0.114011
#                                                   3185965169       0.000636
#                                                   3357991400       0.000628
#                                                   3425464094       0.029243
#                                                   3548853050       0.029066
#                                                   3606745995       0.007766
#                                                   3807311974       0.029723
#                                                   4007904565       0.116508
#                                                   4050545721       0.117449
#                                                   4256600727       0.001979
# {'name': 'cudaMemcpy', 'type': 'function'}        69778151         0.000221
#                                                   399177385        0.007854
#                                                   523387201        0.000214
#                                                   938112548        0.000631
#                                                   1066994924       0.029424
#                                                   1071674850       0.117525
#                                                   1091449174       0.117518
#                                                   1091677715       0.007839
#                                                   1193204644       0.468520
#                                                   1216137125       0.007810
#                                                   1364689108       0.002001
#                                                   1453497524       0.467931
#                                                   1459960355       0.470062
#                                                   1472059284       0.030013
#                                                   1567983953       0.000589
#                                                   1690623772       0.001926
#                                                   2006852609       0.007978
#                                                   2034263549       0.000211
#                                                   2117806238       0.456177
#                                                   2331711899       0.000649
#                                                   2407546354       0.471665
#                                                   2522125044       0.001899
#                                                   2598285721       0.001935
#                                                   2646206980       0.000210
#                                                   2759465296       0.000224
#                                                   2992502833       0.113961
#                                                   3185965169       0.000599
#                                                   3357991400       0.000591
#                                                   3425464094       0.029192
#                                                   3548853050       0.029021
#                                                   3606745995       0.007721
#                                                   3807311974       0.029672
#                                                   4007904565       0.116456
#                                                   4050545721       0.117396
#                                                   4256600727       0.001932
# {'name': 'comp', 'type': 'function'}              69778151         0.034069
#                                                   399177385        1.739836
#                                                   523387201        0.038543
#                                                   938112548        0.151529
#                                                   1066994924       7.304709
#                                                   1071674850      40.764169
#                                                   1091449174      29.887301
#                                                   1091677715       1.675189
#                                                   1193204644     121.244023
#                                                   1216137125       1.672067
#                                                   1364689108       0.426931
#                                                   1453497524     118.582767
#                                                   1459960355     178.411817
#                                                   1472059284       7.430029
#                                                   1567983953       0.122260
#                                                   1690623772       0.378768
#                                                   2006852609       1.732875
#                                                   2034263549       0.033042
#                                                   2117806238     135.432461
#                                                   2331711899       0.150510
#                                                   2407546354     119.761913
#                                                   2522125044       0.366756
#                                                   2598285721       0.426933
#                                                   2646206980       0.027857
#                                                   2759465296       0.033149
#                                                   2992502833      29.289125
#                                                   3185965169       0.147498
#                                                   3357991400       0.136183
#                                                   3425464094       8.134053
#                                                   3548853050       7.563479
#                                                   3606745995       1.766048
#                                                   3807311974       7.373369
#                                                   4007904565      32.928962
#                                                   4050545721      29.157486
#                                                   4256600727       0.410790
# {'name': 'comp_large', 'type': 'function'}        69778151         0.034054
#                                                   399177385        1.739800
#                                                   523387201        0.038526
#                                                   938112548        0.151510
#                                                   1066994924       7.304669
#                                                   1071674850      40.764125
#                                                   1091449174      29.887258
#                                                   1091677715       1.675153
#                                                   1193204644     121.243968
#                                                   1216137125       1.672031
#                                                   1364689108       0.426908
#                                                   1453497524     118.582725
#                                                   1459960355     178.411775
#                                                   1472059284       7.429985
#                                                   1567983953       0.122243
#                                                   1690623772       0.378747
#                                                   2006852609       1.732840
#                                                   2034263549       0.033026
#                                                   2117806238     135.432421
#                                                   2331711899       0.150488
#                                                   2407546354     119.758761
#                                                   2522125044       0.366735
#                                                   2598285721       0.426914
#                                                   2646206980       0.027841
#                                                   2759465296       0.033133
#                                                   2992502833      29.289081
#                                                   3185965169       0.147481
#                                                   3357991400       0.136166
#                                                   3425464094       8.134013
#                                                   3548853050       7.563438
#                                                   3606745995       1.766011
#                                                   3807311974       7.373329
#                                                   4007904565      32.928921
#                                                   4050545721      29.157445
#                                                   4256600727       0.410767
# {'name': 'correctness_check', 'type': 'function'} 69778151         0.000235
#                                                   399177385        0.012170
#                                                   523387201        0.000209
#                                                   938112548        0.000775
#                                                   1066994924       0.048417
#                                                   1071674850       0.193946
#                                                   1091449174       0.194378
#                                                   1091677715       0.012160
#                                                   1193204644       0.774039
#                                                   1216137125       0.012122
#                                                   1364689108       0.003051
#                                                   1453497524       0.776120
#                                                   1459960355       0.776382
#                                                   1472059284       0.048581
#                                                   1567983953       0.000771
#                                                   1690623772       0.003063
#                                                   2006852609       0.012138
#                                                   2034263549       0.000219
#                                                   2117806238       0.779535
#                                                   2331711899       0.000771
#                                                   2407546354       0.782500
#                                                   2522125044       0.003068
#                                                   2598285721       0.003053
#                                                   2646206980       0.000214
#                                                   2759465296       0.000209
#                                                   2992502833       0.194182
#                                                   3185965169       0.000783
#                                                   3357991400       0.000789
#                                                   3425464094       0.048549
#                                                   3548853050       0.048581
#                                                   3606745995       0.012172
#                                                   3807311974       0.048579
#                                                   4007904565       0.193765
#                                                   4050545721       0.193940
#                                                   4256600727       0.003045
# {'name': 'data_init', 'type': 'function'}         69778151         0.001437
#                                                   399177385        0.087305
#                                                   523387201        0.001403
#                                                   938112548        0.005541
#                                                   1066994924       0.348672
#                                                   1071674850       1.397609
#                                                   1091449174       1.393553
#                                                   1091677715       0.087170
#                                                   1193204644       5.573571
#                                                   1216137125       0.087270
#                                                   1364689108       0.022703
#                                                   1453497524       5.572289
#                                                   1459960355       5.572866
#                                                   1472059284       0.351818
#                                                   1567983953       0.005660
#                                                   1690623772       0.022599
#                                                   2006852609       0.087497
#                                                   2034263549       0.001438
#                                                   2117806238       5.570243
#                                                   2331711899       0.006730
#                                                   2407546354       5.572730
#                                                   2522125044       0.022494
#                                                   2598285721       0.021914
#                                                   2646206980       0.001400
#                                                   2759465296       0.001398
#                                                   2992502833       1.392990
#                                                   3185965169       0.005926
#                                                   3357991400       0.005577
#                                                   3425464094       0.348004
#                                                   3548853050       0.348702
#                                                   3606745995       0.087476
#                                                   3807311974       0.348555
#                                                   4007904565       1.393361
#                                                   4050545721       1.397217
#                                                   4256600727       0.021844
#
#                                                                            name
# node                                              profile
# {'name': 'main_function', 'type': 'function'}     69778151        main_function
#                                                   399177385       main_function
#                                                   523387201       main_function
#                                                   938112548       main_function
#                                                   1066994924      main_function
#                                                   1071674850      main_function
#                                                   1091449174      main_function
#                                                   1091677715      main_function
#                                                   1193204644      main_function
#                                                   1216137125      main_function
#                                                   1364689108      main_function
#                                                   1453497524      main_function
#                                                   1459960355      main_function
#                                                   1472059284      main_function
#                                                   1567983953      main_function
#                                                   1690623772      main_function
#                                                   2006852609      main_function
#                                                   2034263549      main_function
#                                                   2117806238      main_function
#                                                   2331711899      main_function
#                                                   2407546354      main_function
#                                                   2522125044      main_function
#                                                   2598285721      main_function
#                                                   2646206980      main_function
#                                                   2759465296      main_function
#                                                   2992502833      main_function
#                                                   3185965169      main_function
#                                                   3357991400      main_function
#                                                   3425464094      main_function
#                                                   3548853050      main_function
#                                                   3606745995      main_function
#                                                   3807311974      main_function
#                                                   4007904565      main_function
#                                                   4050545721      main_function
#                                                   4256600727      main_function
# {'name': 'comm', 'type': 'function'}              69778151                 comm
#                                                   399177385                comm
#                                                   523387201                comm
#                                                   938112548                comm
#                                                   1066994924               comm
#                                                   1071674850               comm
#                                                   1091449174               comm
#                                                   1091677715               comm
#                                                   1193204644               comm
#                                                   1216137125               comm
#                                                   1364689108               comm
#                                                   1453497524               comm
#                                                   1459960355               comm
#                                                   1472059284               comm
#                                                   1567983953               comm
#                                                   1690623772               comm
#                                                   2006852609               comm
#                                                   2034263549               comm
#                                                   2117806238               comm
#                                                   2331711899               comm
#                                                   2407546354               comm
#                                                   2522125044               comm
#                                                   2598285721               comm
#                                                   2646206980               comm
#                                                   2759465296               comm
#                                                   2992502833               comm
#                                                   3185965169               comm
#                                                   3357991400               comm
#                                                   3425464094               comm
#                                                   3548853050               comm
#                                                   3606745995               comm
#                                                   3807311974               comm
#                                                   4007904565               comm
#                                                   4050545721               comm
#                                                   4256600727               comm
# {'name': 'comm_large', 'type': 'function'}        69778151           comm_large
#                                                   399177385          comm_large
#                                                   523387201          comm_large
#                                                   938112548          comm_large
#                                                   1066994924         comm_large
#                                                   1071674850         comm_large
#                                                   1091449174         comm_large
#                                                   1091677715         comm_large
#                                                   1193204644         comm_large
#                                                   1216137125         comm_large
#                                                   1364689108         comm_large
#                                                   1453497524         comm_large
#                                                   1459960355         comm_large
#                                                   1472059284         comm_large
#                                                   1567983953         comm_large
#                                                   1690623772         comm_large
#                                                   2006852609         comm_large
#                                                   2034263549         comm_large
#                                                   2117806238         comm_large
#                                                   2331711899         comm_large
#                                                   2407546354         comm_large
#                                                   2522125044         comm_large
#                                                   2598285721         comm_large
#                                                   2646206980         comm_large
#                                                   2759465296         comm_large
#                                                   2992502833         comm_large
#                                                   3185965169         comm_large
#                                                   3357991400         comm_large
#                                                   3425464094         comm_large
#                                                   3548853050         comm_large
#                                                   3606745995         comm_large
#                                                   3807311974         comm_large
#                                                   4007904565         comm_large
#                                                   4050545721         comm_large
#                                                   4256600727         comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}        69778151           cudaMemcpy
#                                                   399177385          cudaMemcpy
#                                                   523387201          cudaMemcpy
#                                                   938112548          cudaMemcpy
#                                                   1066994924         cudaMemcpy
#                                                   1071674850         cudaMemcpy
#                                                   1091449174         cudaMemcpy
#                                                   1091677715         cudaMemcpy
#                                                   1193204644         cudaMemcpy
#                                                   1216137125         cudaMemcpy
#                                                   1364689108         cudaMemcpy
#                                                   1453497524         cudaMemcpy
#                                                   1459960355         cudaMemcpy
#                                                   1472059284         cudaMemcpy
#                                                   1567983953         cudaMemcpy
#                                                   1690623772         cudaMemcpy
#                                                   2006852609         cudaMemcpy
#                                                   2034263549         cudaMemcpy
#                                                   2117806238         cudaMemcpy
#                                                   2331711899         cudaMemcpy
#                                                   2407546354         cudaMemcpy
#                                                   2522125044         cudaMemcpy
#                                                   2598285721         cudaMemcpy
#                                                   2646206980         cudaMemcpy
#                                                   2759465296         cudaMemcpy
#                                                   2992502833         cudaMemcpy
#                                                   3185965169         cudaMemcpy
#                                                   3357991400         cudaMemcpy
#                                                   3425464094         cudaMemcpy
#                                                   3548853050         cudaMemcpy
#                                                   3606745995         cudaMemcpy
#                                                   3807311974         cudaMemcpy
#                                                   4007904565         cudaMemcpy
#                                                   4050545721         cudaMemcpy
#                                                   4256600727         cudaMemcpy
# {'name': 'comp', 'type': 'function'}              69778151                 comp
#                                                   399177385                comp
#                                                   523387201                comp
#                                                   938112548                comp
#                                                   1066994924               comp
#                                                   1071674850               comp
#                                                   1091449174               comp
#                                                   1091677715               comp
#                                                   1193204644               comp
#                                                   1216137125               comp
#                                                   1364689108               comp
#                                                   1453497524               comp
#                                                   1459960355               comp
#                                                   1472059284               comp
#                                                   1567983953               comp
#                                                   1690623772               comp
#                                                   2006852609               comp
#                                                   2034263549               comp
#                                                   2117806238               comp
#                                                   2331711899               comp
#                                                   2407546354               comp
#                                                   2522125044               comp
#                                                   2598285721               comp
#                                                   2646206980               comp
#                                                   2759465296               comp
#                                                   2992502833               comp
#                                                   3185965169               comp
#                                                   3357991400               comp
#                                                   3425464094               comp
#                                                   3548853050               comp
#                                                   3606745995               comp
#                                                   3807311974               comp
#                                                   4007904565               comp
#                                                   4050545721               comp
#                                                   4256600727               comp
# {'name': 'comp_large', 'type': 'function'}        69778151           comp_large
#                                                   399177385          comp_large
#                                                   523387201          comp_large
#                                                   938112548          comp_large
#                                                   1066994924         comp_large
#                                                   1071674850         comp_large
#                                                   1091449174         comp_large
#                                                   1091677715         comp_large
#                                                   1193204644         comp_large
#                                                   1216137125         comp_large
#                                                   1364689108         comp_large
#                                                   1453497524         comp_large
#                                                   1459960355         comp_large
#                                                   1472059284         comp_large
#                                                   1567983953         comp_large
#                                                   1690623772         comp_large
#                                                   2006852609         comp_large
#                                                   2034263549         comp_large
#                                                   2117806238         comp_large
#                                                   2331711899         comp_large
#                                                   2407546354         comp_large
#                                                   2522125044         comp_large
#                                                   2598285721         comp_large
#                                                   2646206980         comp_large
#                                                   2759465296         comp_large
#                                                   2992502833         comp_large
#                                                   3185965169         comp_large
#                                                   3357991400         comp_large
#                                                   3425464094         comp_large
#                                                   3548853050         comp_large
#                                                   3606745995         comp_large
#                                                   3807311974         comp_large
#                                                   4007904565         comp_large
#                                                   4050545721         comp_large
#                                                   4256600727         comp_large
# {'name': 'correctness_check', 'type': 'function'} 69778151    correctness_check
#                                                   399177385   correctness_check
#                                                   523387201   correctness_check
#                                                   938112548   correctness_check
#                                                   1066994924  correctness_check
#                                                   1071674850  correctness_check
#                                                   1091449174  correctness_check
#                                                   1091677715  correctness_check
#                                                   1193204644  correctness_check
#                                                   1216137125  correctness_check
#                                                   1364689108  correctness_check
#                                                   1453497524  correctness_check
#                                                   1459960355  correctness_check
#                                                   1472059284  correctness_check
#                                                   1567983953  correctness_check
#                                                   1690623772  correctness_check
#                                                   2006852609  correctness_check
#                                                   2034263549  correctness_check
#                                                   2117806238  correctness_check
#                                                   2331711899  correctness_check
#                                                   2407546354  correctness_check
#                                                   2522125044  correctness_check
#                                                   2598285721  correctness_check
#                                                   2646206980  correctness_check
#                                                   2759465296  correctness_check
#                                                   2992502833  correctness_check
#                                                   3185965169  correctness_check
#                                                   3357991400  correctness_check
#                                                   3425464094  correctness_check
#                                                   3548853050  correctness_check
#                                                   3606745995  correctness_check
#                                                   3807311974  correctness_check
#                                                   4007904565  correctness_check
#                                                   4050545721  correctness_check
#                                                   4256600727  correctness_check
# {'name': 'data_init', 'type': 'function'}         69778151            data_init
#                                                   399177385           data_init
#                                                   523387201           data_init
#                                                   938112548           data_init
#                                                   1066994924          data_init
#                                                   1071674850          data_init
#                                                   1091449174          data_init
#                                                   1091677715          data_init
#                                                   1193204644          data_init
#                                                   1216137125          data_init
#                                                   1364689108          data_init
#                                                   1453497524          data_init
#                                                   1459960355          data_init
#                                                   1472059284          data_init
#                                                   1567983953          data_init
#                                                   1690623772          data_init
#                                                   2006852609          data_init
#                                                   2034263549          data_init
#                                                   2117806238          data_init
#                                                   2331711899          data_init
#                                                   2407546354          data_init
#                                                   2522125044          data_init
#                                                   2598285721          data_init
#                                                   2646206980          data_init
#                                                   2759465296          data_init
#                                                   2992502833          data_init
#                                                   3185965169          data_init
#                                                   3357991400          data_init
#                                                   3425464094          data_init
#                                                   3548853050          data_init
#                                                   3606745995          data_init
#                                                   3807311974          data_init
#                                                   4007904565          data_init
#                                                   4050545721          data_init
#                                                   4256600727          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 69778151             2.11.0-dev
# 399177385            2.11.0-dev
# 523387201            2.11.0-dev
# 938112548            2.11.0-dev
# 1066994924           2.11.0-dev
# 1071674850           2.11.0-dev
# 1091449174           2.11.0-dev
# 1091677715           2.11.0-dev
# 1193204644           2.11.0-dev
# 1216137125           2.11.0-dev
# 1364689108           2.11.0-dev
# 1453497524           2.11.0-dev
# 1459960355           2.11.0-dev
# 1472059284           2.11.0-dev
# 1567983953           2.11.0-dev
# 1690623772           2.11.0-dev
# 2006852609           2.11.0-dev
# 2034263549           2.11.0-dev
# 2117806238           2.11.0-dev
# 2331711899           2.11.0-dev
# 2407546354           2.11.0-dev
# 2522125044           2.11.0-dev
# 2598285721           2.11.0-dev
# 2646206980           2.11.0-dev
# 2759465296           2.11.0-dev
# 2992502833           2.11.0-dev
# 3185965169           2.11.0-dev
# 3357991400           2.11.0-dev
# 3425464094           2.11.0-dev
# 3548853050           2.11.0-dev
# 3606745995           2.11.0-dev
# 3807311974           2.11.0-dev
# 4007904565           2.11.0-dev
# 4050545721           2.11.0-dev
# 4256600727           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 69778151    min#inclusive#sum#time.duration,max#inclusive#...
# 399177385   min#inclusive#sum#time.duration,max#inclusive#...
# 523387201   min#inclusive#sum#time.duration,max#inclusive#...
# 938112548   min#inclusive#sum#time.duration,max#inclusive#...
# 1066994924  min#inclusive#sum#time.duration,max#inclusive#...
# 1071674850  min#inclusive#sum#time.duration,max#inclusive#...
# 1091449174  min#inclusive#sum#time.duration,max#inclusive#...
# 1091677715  min#inclusive#sum#time.duration,max#inclusive#...
# 1193204644  min#inclusive#sum#time.duration,max#inclusive#...
# 1216137125  min#inclusive#sum#time.duration,max#inclusive#...
# 1364689108  min#inclusive#sum#time.duration,max#inclusive#...
# 1453497524  min#inclusive#sum#time.duration,max#inclusive#...
# 1459960355  min#inclusive#sum#time.duration,max#inclusive#...
# 1472059284  min#inclusive#sum#time.duration,max#inclusive#...
# 1567983953  min#inclusive#sum#time.duration,max#inclusive#...
# 1690623772  min#inclusive#sum#time.duration,max#inclusive#...
# 2006852609  min#inclusive#sum#time.duration,max#inclusive#...
# 2034263549  min#inclusive#sum#time.duration,max#inclusive#...
# 2117806238  min#inclusive#sum#time.duration,max#inclusive#...
# 2331711899  min#inclusive#sum#time.duration,max#inclusive#...
# 2407546354  min#inclusive#sum#time.duration,max#inclusive#...
# 2522125044  min#inclusive#sum#time.duration,max#inclusive#...
# 2598285721  min#inclusive#sum#time.duration,max#inclusive#...
# 2646206980  min#inclusive#sum#time.duration,max#inclusive#...
# 2759465296  min#inclusive#sum#time.duration,max#inclusive#...
# 2992502833  min#inclusive#sum#time.duration,max#inclusive#...
# 3185965169  min#inclusive#sum#time.duration,max#inclusive#...
# 3357991400  min#inclusive#sum#time.duration,max#inclusive#...
# 3425464094  min#inclusive#sum#time.duration,max#inclusive#...
# 3548853050  min#inclusive#sum#time.duration,max#inclusive#...
# 3606745995  min#inclusive#sum#time.duration,max#inclusive#...
# 3807311974  min#inclusive#sum#time.duration,max#inclusive#...
# 4007904565  min#inclusive#sum#time.duration,max#inclusive#...
# 4050545721  min#inclusive#sum#time.duration,max#inclusive#...
# 4256600727  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 69778151                                              2
# 399177385                                             2
# 523387201                                             2
# 938112548                                             2
# 1066994924                                            2
# 1071674850                                            2
# 1091449174                                            2
# 1091677715                                            2
# 1193204644                                            2
# 1216137125                                            2
# 1364689108                                            2
# 1453497524                                            2
# 1459960355                                            2
# 1472059284                                            2
# 1567983953                                            2
# 1690623772                                            2
# 2006852609                                            2
# 2034263549                                            2
# 2117806238                                            2
# 2331711899                                            2
# 2407546354                                            2
# 2522125044                                            2
# 2598285721                                            2
# 2646206980                                            2
# 2759465296                                            2
# 2992502833                                            2
# 3185965169                                            2
# 3357991400                                            2
# 3425464094                                            2
# 3548853050                                            2
# 3606745995                                            2
# 3807311974                                            2
# 4007904565                                            2
# 4050545721                                            2
# 4256600727                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 69778151    cuda.gputime,node.order  regionprofile         spot
# 399177385   cuda.gputime,node.order  regionprofile         spot
# 523387201   cuda.gputime,node.order  regionprofile         spot
# 938112548   cuda.gputime,node.order  regionprofile         spot
# 1066994924  cuda.gputime,node.order  regionprofile         spot
# 1071674850  cuda.gputime,node.order  regionprofile         spot
# 1091449174  cuda.gputime,node.order  regionprofile         spot
# 1091677715  cuda.gputime,node.order  regionprofile         spot
# 1193204644  cuda.gputime,node.order  regionprofile         spot
# 1216137125  cuda.gputime,node.order  regionprofile         spot
# 1364689108  cuda.gputime,node.order  regionprofile         spot
# 1453497524  cuda.gputime,node.order  regionprofile         spot
# 1459960355  cuda.gputime,node.order  regionprofile         spot
# 1472059284  cuda.gputime,node.order  regionprofile         spot
# 1567983953  cuda.gputime,node.order  regionprofile         spot
# 1690623772  cuda.gputime,node.order  regionprofile         spot
# 2006852609  cuda.gputime,node.order  regionprofile         spot
# 2034263549  cuda.gputime,node.order  regionprofile         spot
# 2117806238  cuda.gputime,node.order  regionprofile         spot
# 2331711899  cuda.gputime,node.order  regionprofile         spot
# 2407546354  cuda.gputime,node.order  regionprofile         spot
# 2522125044  cuda.gputime,node.order  regionprofile         spot
# 2598285721  cuda.gputime,node.order  regionprofile         spot
# 2646206980  cuda.gputime,node.order  regionprofile         spot
# 2759465296  cuda.gputime,node.order  regionprofile         spot
# 2992502833  cuda.gputime,node.order  regionprofile         spot
# 3185965169  cuda.gputime,node.order  regionprofile         spot
# 3357991400  cuda.gputime,node.order  regionprofile         spot
# 3425464094  cuda.gputime,node.order  regionprofile         spot
# 3548853050  cuda.gputime,node.order  regionprofile         spot
# 3606745995  cuda.gputime,node.order  regionprofile         spot
# 3807311974  cuda.gputime,node.order  regionprofile         spot
# 4007904565  cuda.gputime,node.order  regionprofile         spot
# 4050545721  cuda.gputime,node.order  regionprofile         spot
# 4256600727  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order               spot:output  \
# profile
# 69778151                true            true       t512-n65536-i0.cali
# 399177385               true            true    t1024-n4194304-i0.cali
# 523387201               true            true       t256-n65536-i0.cali
# 938112548               true            true      t128-n262144-i0.cali
# 1066994924              true            true     t64-n16777216-i0.cali
# 1071674850              true            true   t1024-n67108864-i0.cali
# 1091449174              true            true    t256-n67108864-i0.cali
# 1091677715              true            true     t128-n4194304-i0.cali
# 1193204644              true            true   t256-n268435456-i0.cali
# 1216137125              true            true      t64-n4194304-i0.cali
# 1364689108              true            true    t1024-n1048576-i0.cali
# 1453497524              true            true   t128-n268435456-i0.cali
# 1459960355              true            true  t1024-n268435456-i0.cali
# 1472059284              true            true    t256-n16777216-i0.cali
# 1567983953              true            true      t512-n262144-i0.cali
# 1690623772              true            true     t256-n1048576-i0.cali
# 2006852609              true            true     t256-n4194304-i0.cali
# 2034263549              true            true        t64-n65536-i0.cali
# 2117806238              true            true   t512-n268435456-i0.cali
# 2331711899              true            true       t64-n262144-i0.cali
# 2407546354              true            true    t64-n268435456-i0.cali
# 2522125044              true            true      t64-n1048576-i0.cali
# 2598285721              true            true     t512-n1048576-i0.cali
# 2646206980              true            true       t128-n65536-i0.cali
# 2759465296              true            true      t1024-n65536-i0.cali
# 2992502833              true            true    t128-n67108864-i0.cali
# 3185965169              true            true      t256-n262144-i0.cali
# 3357991400              true            true     t1024-n262144-i0.cali
# 3425464094              true            true   t1024-n16777216-i0.cali
# 3548853050              true            true    t512-n16777216-i0.cali
# 3606745995              true            true     t512-n4194304-i0.cali
# 3807311974              true            true    t128-n16777216-i0.cali
# 4007904565              true            true    t512-n67108864-i0.cali
# 4050545721              true            true     t64-n67108864-i0.cali
# 4256600727              true            true     t128-n1048576-i0.cali
#
#                user  launchdate  \
# profile
# 69778151    smathen  1700075991
# 399177385   smathen  1700076393
# 523387201   smathen  1700075971
# 938112548   smathen  1700076011
# 1066994924  smathen  1700076414
# 1071674850  smathen  1700076572
# 1091449174  smathen  1700076532
# 1091677715  smathen  1700076332
# 1193204644  smathen  1700076632
# 1216137125  smathen  1700076312
# 1364689108  smathen  1700076312
# 1453497524  smathen  1700076612
# 1459960355  smathen  1700076772
# 1472059284  smathen  1700076464
# 1567983953  smathen  1700076011
# 1690623772  smathen  1700076269
# 2006852609  smathen  1700076374
# 2034263549  smathen  1700075951
# 2117806238  smathen  1700076712
# 2331711899  smathen  1700075993
# 2407546354  smathen  1700076587
# 2522125044  smathen  1700076230
# 2598285721  smathen  1700076292
# 2646206980  smathen  1700075963
# 2759465296  smathen  1700075991
# 2992502833  smathen  1700076513
# 3185965169  smathen  1700076012
# 3357991400  smathen  1700076023
# 3425464094  smathen  1700076493
# 3548853050  smathen  1700076464
# 3606745995  smathen  1700076374
# 3807311974  smathen  1700076432
# 4007904565  smathen  1700076552
# 4050545721  smathen  1700076513
# 4256600727  smathen  1700076250
#
#                                                     libraries  \
# profile
# 69778151    [/scratch/group/csce435-f23/Caliper/caliper/li...
# 399177385   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 523387201   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 938112548   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1066994924  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1071674850  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1091449174  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1091677715  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1193204644  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1216137125  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1364689108  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1453497524  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1459960355  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1472059284  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1567983953  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1690623772  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2006852609  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2034263549  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2117806238  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2331711899  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2407546354  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2522125044  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2598285721  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2646206980  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2759465296  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2992502833  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3185965169  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3357991400  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3425464094  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3548853050  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3606745995  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3807311974  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4007904565  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4050545721  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4256600727  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                       cmdline cluster  Algorithm  \
# profile
# 69778151         [./mergesort, 512, 65536, 0]       g  MergeSort
# 399177385     [./mergesort, 1024, 4194304, 0]       g  MergeSort
# 523387201        [./mergesort, 256, 65536, 0]       g  MergeSort
# 938112548       [./mergesort, 128, 262144, 0]       g  MergeSort
# 1066994924     [./mergesort, 64, 16777216, 0]       g  MergeSort
# 1071674850   [./mergesort, 1024, 67108864, 0]       g  MergeSort
# 1091449174    [./mergesort, 256, 67108864, 0]       g  MergeSort
# 1091677715     [./mergesort, 128, 4194304, 0]       g  MergeSort
# 1193204644   [./mergesort, 256, 268435456, 0]       g  MergeSort
# 1216137125      [./mergesort, 64, 4194304, 0]       g  MergeSort
# 1364689108    [./mergesort, 1024, 1048576, 0]       g  MergeSort
# 1453497524   [./mergesort, 128, 268435456, 0]       g  MergeSort
# 1459960355  [./mergesort, 1024, 268435456, 0]       g  MergeSort
# 1472059284    [./mergesort, 256, 16777216, 0]       g  MergeSort
# 1567983953      [./mergesort, 512, 262144, 0]       g  MergeSort
# 1690623772     [./mergesort, 256, 1048576, 0]       g  MergeSort
# 2006852609     [./mergesort, 256, 4194304, 0]       g  MergeSort
# 2034263549        [./mergesort, 64, 65536, 0]       g  MergeSort
# 2117806238   [./mergesort, 512, 268435456, 0]       g  MergeSort
# 2331711899       [./mergesort, 64, 262144, 0]       g  MergeSort
# 2407546354    [./mergesort, 64, 268435456, 0]       g  MergeSort
# 2522125044      [./mergesort, 64, 1048576, 0]       g  MergeSort
# 2598285721     [./mergesort, 512, 1048576, 0]       g  MergeSort
# 2646206980       [./mergesort, 128, 65536, 0]       g  MergeSort
# 2759465296      [./mergesort, 1024, 65536, 0]       g  MergeSort
# 2992502833    [./mergesort, 128, 67108864, 0]       g  MergeSort
# 3185965169      [./mergesort, 256, 262144, 0]       g  MergeSort
# 3357991400     [./mergesort, 1024, 262144, 0]       g  MergeSort
# 3425464094   [./mergesort, 1024, 16777216, 0]       g  MergeSort
# 3548853050    [./mergesort, 512, 16777216, 0]       g  MergeSort
# 3606745995     [./mergesort, 512, 4194304, 0]       g  MergeSort
# 3807311974    [./mergesort, 128, 16777216, 0]       g  MergeSort
# 4007904565    [./mergesort, 512, 67108864, 0]       g  MergeSort
# 4050545721     [./mergesort, 64, 67108864, 0]       g  MergeSort
# 4256600727     [./mergesort, 128, 1048576, 0]       g  MergeSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize     InputType  \
# profile
# 69778151               CUDA      int               4      65536  random_array
# 399177385              CUDA      int               4    4194304  random_array
# 523387201              CUDA      int               4      65536  random_array
# 938112548              CUDA      int               4     262144  random_array
# 1066994924             CUDA      int               4   16777216  random_array
# 1071674850             CUDA      int               4   67108864  random_array
# 1091449174             CUDA      int               4   67108864  random_array
# 1091677715             CUDA      int               4    4194304  random_array
# 1193204644             CUDA      int               4  268435456  random_array
# 1216137125             CUDA      int               4    4194304  random_array
# 1364689108             CUDA      int               4    1048576  random_array
# 1453497524             CUDA      int               4  268435456  random_array
# 1459960355             CUDA      int               4  268435456  random_array
# 1472059284             CUDA      int               4   16777216  random_array
# 1567983953             CUDA      int               4     262144  random_array
# 1690623772             CUDA      int               4    1048576  random_array
# 2006852609             CUDA      int               4    4194304  random_array
# 2034263549             CUDA      int               4      65536  random_array
# 2117806238             CUDA      int               4  268435456  random_array
# 2331711899             CUDA      int               4     262144  random_array
# 2407546354             CUDA      int               4  268435456  random_array
# 2522125044             CUDA      int               4    1048576  random_array
# 2598285721             CUDA      int               4    1048576  random_array
# 2646206980             CUDA      int               4      65536  random_array
# 2759465296             CUDA      int               4      65536  random_array
# 2992502833             CUDA      int               4   67108864  random_array
# 3185965169             CUDA      int               4     262144  random_array
# 3357991400             CUDA      int               4     262144  random_array
# 3425464094             CUDA      int               4   16777216  random_array
# 3548853050             CUDA      int               4   16777216  random_array
# 3606745995             CUDA      int               4    4194304  random_array
# 3807311974             CUDA      int               4   16777216  random_array
# 4007904565             CUDA      int               4   67108864  random_array
# 4050545721             CUDA      int               4   67108864  random_array
# 4256600727             CUDA      int               4    1048576  random_array
#
#             num_threads  num_blocks  group_num implementation_source
# profile
# 69778151            512         128         16           Online & AI
# 399177385          1024        4096         16           Online & AI
# 523387201           256         256         16           Online & AI
# 938112548           128        2048         16           Online & AI
# 1066994924           64      262144         16           Online & AI
# 1071674850         1024       65536         16           Online & AI
# 1091449174          256      262144         16           Online & AI
# 1091677715          128       32768         16           Online & AI
# 1193204644          256     1048576         16           Online & AI
# 1216137125           64       65536         16           Online & AI
# 1364689108         1024        1024         16           Online & AI
# 1453497524          128     2097152         16           Online & AI
# 1459960355         1024      262144         16           Online & AI
# 1472059284          256       65536         16           Online & AI
# 1567983953          512         512         16           Online & AI
# 1690623772          256        4096         16           Online & AI
# 2006852609          256       16384         16           Online & AI
# 2034263549           64        1024         16           Online & AI
# 2117806238          512      524288         16           Online & AI
# 2331711899           64        4096         16           Online & AI
# 2407546354           64     4194304         16           Online & AI
# 2522125044           64       16384         16           Online & AI
# 2598285721          512        2048         16           Online & AI
# 2646206980          128         512         16           Online & AI
# 2759465296         1024          64         16           Online & AI
# 2992502833          128      524288         16           Online & AI
# 3185965169          256        1024         16           Online & AI
# 3357991400         1024         256         16           Online & AI
# 3425464094         1024       16384         16           Online & AI
# 3548853050          512       32768         16           Online & AI
# 3606745995          512        8192         16           Online & AI
# 3807311974          128      131072         16           Online & AI
# 4007904565          512      131072         16           Online & AI
# 4050545721           64     1048576         16           Online & AI
# 4256600727          128        8192         16           Online & AI

# %%
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main_function
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# │     └─ 1.000 cudaMemcpy
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
gb = tk.groupby("InputSize")
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b4efabdfe20>, 262144: <thicket.thicket.Thicket object at 0x2b4efab955e0>, 1048576: <thicket.thicket.Thicket object at 0x2b4efac4c100>, 4194304: <thicket.thicket.Thicket object at 0x2b4efac4f8e0>, 16777216: <thicket.thicket.Thicket object at 0x2b4efaa7e6a0>, 67108864: <thicket.thicket.Thicket object at 0x2b4efaa8b7f0>, 268435456: <thicket.thicket.Thicket object at 0x2b4efaa8bd30>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                                       65536  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main_function', 'type': 'function'}     64               0.496085
#                                                   128              0.365640
#                                                   256              0.386522
#                                                   512              0.381760
#                                                   1024             0.383424
# {'name': 'comm', 'type': 'function'}              64               0.000304
#                                                   128              0.000304
#                                                   256              0.000308
#                                                   512              0.000310
#                                                   1024             0.000319
# {'name': 'comm_large', 'type': 'function'}        64               0.000244
#                                                   128              0.000244
#                                                   256              0.000248
#                                                   512              0.000252
#                                                   1024             0.000258
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000211
#                                                   128              0.000210
#                                                   256              0.000214
#                                                   512              0.000221
#                                                   1024             0.000224
# {'name': 'comp', 'type': 'function'}              64               0.033042
#                                                   128              0.027857
#                                                   256              0.038543
#                                                   512              0.034069
#                                                   1024             0.033149
# {'name': 'comp_large', 'type': 'function'}        64               0.033026
#                                                   128              0.027841
#                                                   256              0.038526
#                                                   512              0.034054
#                                                   1024             0.033133
# {'name': 'correctness_check', 'type': 'function'} 64               0.000219
#                                                   128              0.000214
#                                                   256              0.000209
#                                                   512              0.000235
#                                                   1024             0.000209
# {'name': 'data_init', 'type': 'function'}         64               0.001438
#                                                   128              0.001400
#                                                   256              0.001403
#                                                   512              0.001437
#                                                   1024             0.001398
#
#                                                                      262144  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main_function', 'type': 'function'}     64               0.794167
#                                                   128              0.761398
#                                                   256              0.769003
#                                                   512              0.467005
#                                                   1024             0.478986
# {'name': 'comm', 'type': 'function'}              64               0.000755
#                                                   128              0.000730
#                                                   256              0.000687
#                                                   512              0.000685
#                                                   1024             0.000687
# {'name': 'comm_large', 'type': 'function'}        64               0.000695
#                                                   128              0.000675
#                                                   256              0.000636
#                                                   512              0.000626
#                                                   1024             0.000628
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000649
#                                                   128              0.000631
#                                                   256              0.000599
#                                                   512              0.000589
#                                                   1024             0.000591
# {'name': 'comp', 'type': 'function'}              64               0.150510
#                                                   128              0.151529
#                                                   256              0.147498
#                                                   512              0.122260
#                                                   1024             0.136183
# {'name': 'comp_large', 'type': 'function'}        64               0.150488
#                                                   128              0.151510
#                                                   256              0.147481
#                                                   512              0.122243
#                                                   1024             0.136166
# {'name': 'correctness_check', 'type': 'function'} 64               0.000771
#                                                   128              0.000775
#                                                   256              0.000783
#                                                   512              0.000771
#                                                   1024             0.000789
# {'name': 'data_init', 'type': 'function'}         64               0.006730
#                                                   128              0.005541
#                                                   256              0.005926
#                                                   512              0.005660
#                                                   1024             0.005577
#
#                                                                     1048576  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main_function', 'type': 'function'}     64               0.728784
#                                                   128              0.762219
#                                                   256              0.746155
#                                                   512              1.054431
#                                                   1024             1.038207
# {'name': 'comm', 'type': 'function'}              64               0.002008
#                                                   128              0.002040
#                                                   256              0.002032
#                                                   512              0.002040
#                                                   1024             0.002104
# {'name': 'comm_large', 'type': 'function'}        64               0.001948
#                                                   128              0.001979
#                                                   256              0.001971
#                                                   512              0.001979
#                                                   1024             0.002049
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.001899
#                                                   128              0.001932
#                                                   256              0.001926
#                                                   512              0.001935
#                                                   1024             0.002001
# {'name': 'comp', 'type': 'function'}              64               0.366756
#                                                   128              0.410790
#                                                   256              0.378768
#                                                   512              0.426933
#                                                   1024             0.426931
# {'name': 'comp_large', 'type': 'function'}        64               0.366735
#                                                   128              0.410767
#                                                   256              0.378747
#                                                   512              0.426914
#                                                   1024             0.426908
# {'name': 'correctness_check', 'type': 'function'} 64               0.003068
#                                                   128              0.003045
#                                                   256              0.003063
#                                                   512              0.003053
#                                                   1024             0.003051
# {'name': 'data_init', 'type': 'function'}         64               0.022494
#                                                   128              0.021844
#                                                   256              0.022599
#                                                   512              0.021914
#                                                   1024             0.022703
#
#                                                                     4194304  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main_function', 'type': 'function'}     64               2.114890
#                                                   128              2.116284
#                                                   256              2.421228
#                                                   512              2.477061
#                                                   1024             2.174373
# {'name': 'comm', 'type': 'function'}              64               0.007917
#                                                   128              0.007953
#                                                   256              0.008080
#                                                   512              0.007827
#                                                   1024             0.007964
# {'name': 'comm_large', 'type': 'function'}        64               0.007856
#                                                   128              0.007890
#                                                   256              0.008024
#                                                   512              0.007766
#                                                   1024             0.007901
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.007810
#                                                   128              0.007839
#                                                   256              0.007978
#                                                   512              0.007721
#                                                   1024             0.007854
# {'name': 'comp', 'type': 'function'}              64               1.672067
#                                                   128              1.675189
#                                                   256              1.732875
#                                                   512              1.766048
#                                                   1024             1.739836
# {'name': 'comp_large', 'type': 'function'}        64               1.672031
#                                                   128              1.675153
#                                                   256              1.732840
#                                                   512              1.766011
#                                                   1024             1.739800
# {'name': 'correctness_check', 'type': 'function'} 64               0.012122
#                                                   128              0.012160
#                                                   256              0.012138
#                                                   512              0.012172
#                                                   1024             0.012170
# {'name': 'data_init', 'type': 'function'}         64               0.087270
#                                                   128              0.087170
#                                                   256              0.087497
#                                                   512              0.087476
#                                                   1024             0.087305
#
#                                                                    16777216  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main_function', 'type': 'function'}     64               8.057966
#                                                   128              8.137852
#                                                   256              8.196782
#                                                   512              8.313851
#                                                   1024             8.894542
# {'name': 'comm', 'type': 'function'}              64               0.029537
#                                                   128              0.029784
#                                                   256              0.030135
#                                                   512              0.029124
#                                                   1024             0.029306
# {'name': 'comm_large', 'type': 'function'}        64               0.029476
#                                                   128              0.029723
#                                                   256              0.030072
#                                                   512              0.029066
#                                                   1024             0.029243
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.029424
#                                                   128              0.029672
#                                                   256              0.030013
#                                                   512              0.029021
#                                                   1024             0.029192
# {'name': 'comp', 'type': 'function'}              64               7.304709
#                                                   128              7.373369
#                                                   256              7.430029
#                                                   512              7.563479
#                                                   1024             8.134053
# {'name': 'comp_large', 'type': 'function'}        64               7.304669
#                                                   128              7.373329
#                                                   256              7.429985
#                                                   512              7.563438
#                                                   1024             8.134013
# {'name': 'correctness_check', 'type': 'function'} 64               0.048417
#                                                   128              0.048579
#                                                   256              0.048581
#                                                   512              0.048581
#                                                   1024             0.048549
# {'name': 'data_init', 'type': 'function'}         64               0.348672
#                                                   128              0.348555
#                                                   256              0.351818
#                                                   512              0.348702
#                                                   1024             0.348004
#
#                                                                    67108864  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main_function', 'type': 'function'}     64              31.193742
#                                                   128             31.319518
#                                                   256             31.972805
#                                                   512             34.959160
#                                                   1024            42.811338
# {'name': 'comm', 'type': 'function'}              64               0.117513
#                                                   128              0.114071
#                                                   256              0.117640
#                                                   512              0.116573
#                                                   1024             0.117640
# {'name': 'comm_large', 'type': 'function'}        64               0.117449
#                                                   128              0.114011
#                                                   256              0.117579
#                                                   512              0.116508
#                                                   1024             0.117576
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.117396
#                                                   128              0.113961
#                                                   256              0.117518
#                                                   512              0.116456
#                                                   1024             0.117525
# {'name': 'comp', 'type': 'function'}              64              29.157486
#                                                   128             29.289125
#                                                   256             29.887301
#                                                   512             32.928962
#                                                   1024            40.764169
# {'name': 'comp_large', 'type': 'function'}        64              29.157445
#                                                   128             29.289081
#                                                   256             29.887258
#                                                   512             32.928921
#                                                   1024            40.764125
# {'name': 'correctness_check', 'type': 'function'} 64               0.193940
#                                                   128              0.194182
#                                                   256              0.194378
#                                                   512              0.193765
#                                                   1024             0.193946
# {'name': 'data_init', 'type': 'function'}         64               1.397217
#                                                   128              1.392990
#                                                   256              1.393553
#                                                   512              1.393361
#                                                   1024             1.397609
#
#                                                                   268435456  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main_function', 'type': 'function'}     64             126.923596
#                                                   128            125.730707
#                                                   256            128.390969
#                                                   512            142.570528
#                                                   1024           185.574192
# {'name': 'comm', 'type': 'function'}              64               0.471789
#                                                   128              0.468051
#                                                   256              0.468648
#                                                   512              0.456290
#                                                   1024             0.470181
# {'name': 'comm_large', 'type': 'function'}        64               0.471721
#                                                   128              0.467984
#                                                   256              0.468578
#                                                   512              0.456226
#                                                   1024             0.470114
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.471665
#                                                   128              0.467931
#                                                   256              0.468520
#                                                   512              0.456177
#                                                   1024             0.470062
# {'name': 'comp', 'type': 'function'}              64             119.761913
#                                                   128            118.582767
#                                                   256            121.244023
#                                                   512            135.432461
#                                                   1024           178.411817
# {'name': 'comp_large', 'type': 'function'}        64             119.758761
#                                                   128            118.582725
#                                                   256            121.243968
#                                                   512            135.432421
#                                                   1024           178.411775
# {'name': 'correctness_check', 'type': 'function'} 64               0.782500
#                                                   128              0.776120
#                                                   256              0.774039
#                                                   512              0.779535
#                                                   1024             0.776382
# {'name': 'data_init', 'type': 'function'}         64               5.572730
#                                                   128              5.572289
#                                                   256              5.573571
#                                                   512              5.570243
#                                                   1024             5.572866
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main_function', 'type': 'function'}     64               main_function
#                                                   128              main_function
#                                                   256              main_function
#                                                   512              main_function
#                                                   1024             main_function
# {'name': 'comm', 'type': 'function'}              64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
# {'name': 'comm_large', 'type': 'function'}        64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}        64                  cudaMemcpy
#                                                   128                 cudaMemcpy
#                                                   256                 cudaMemcpy
#                                                   512                 cudaMemcpy
#                                                   1024                cudaMemcpy
# {'name': 'comp', 'type': 'function'}              64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
# {'name': 'comp_large', 'type': 'function'}        64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
# {'name': 'correctness_check', 'type': 'function'} 64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %%
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
# Out:
# <ipython-input-9-9853eafaa581>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)

# %%
function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

# %%
for name in function_names:
     #for size in input_sizes:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"CUDA Weak Scaling - Merge Sort, {name}, Random Array", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main_function",64]/ctk.dataframe.loc["main_function"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, main_function, Random Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comp_large, Random Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comm, Random Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, comm, Random Array'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %% [markdown]
# # Weak Scaling for Sorted

# %%
tk = th.Thicket.from_caliperreader(glob("*-i1*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
gb = tk.groupby("InputSize")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

for name in function_names:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"CUDA Weak Scaling - Merge Sort, {name}, Sorted Array", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main_function",64]/ctk.dataframe.loc["main_function"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, main_function, Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comp_large, Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comm, Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b4efb6fa910>, 262144: <thicket.thicket.Thicket object at 0x2b4efb847340>, 1048576: <thicket.thicket.Thicket object at 0x2b4efb768bb0>, 4194304: <thicket.thicket.Thicket object at 0x2b4efb6bd790>, 16777216: <thicket.thicket.Thicket object at 0x2b4efb9f2130>, 67108864: <thicket.thicket.Thicket object at 0x2b4efbdebee0>, 268435456: <thicket.thicket.Thicket object at 0x2b4efbccc460>}
# <ipython-input-22-a81cc21fd739>:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, comm, Sorted Array'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %% [markdown]
# # Weak Scaling for Reverse Sorted

# %%
tk = th.Thicket.from_caliperreader(glob("*-i2*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
gb = tk.groupby("InputSize")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

for name in function_names:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"Cuda Weak Scaling - Merge Sort, {name}, Reverse Sorted", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main_function",64]/ctk.dataframe.loc["main_function"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, main_function, Reverse Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comp_large, Reverse Sorteed Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comm, Reverse Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b4efbdb31f0>, 262144: <thicket.thicket.Thicket object at 0x2b4efab45fd0>, 1048576: <thicket.thicket.Thicket object at 0x2b4efac4f6a0>, 4194304: <thicket.thicket.Thicket object at 0x2b4efb88d7c0>, 16777216: <thicket.thicket.Thicket object at 0x2b4efab8b790>, 67108864: <thicket.thicket.Thicket object at 0x2b4efbd300a0>, 268435456: <thicket.thicket.Thicket object at 0x2b4efabff100>}
# <ipython-input-23-3fd02f08186f>:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, comm, Reverse Sorted Array'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %% [markdown]
# # Weak Scaling for 1% Perturbed

# %%
tk = th.Thicket.from_caliperreader(glob("*-i2*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
gb = tk.groupby("InputSize")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

for name in function_names:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"Cuda Weak Scaling- Merge Sort, {name}, 1% Perturbed", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main_function",64]/ctk.dataframe.loc["main_function"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, Main, 1% Perturbed", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comp_large, 1% Perturbed", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comm, 1% Perturbed", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b4efb85d730>, 262144: <thicket.thicket.Thicket object at 0x2b4efad74460>, 1048576: <thicket.thicket.Thicket object at 0x2b4efba24f10>, 4194304: <thicket.thicket.Thicket object at 0x2b4efbac45e0>, 16777216: <thicket.thicket.Thicket object at 0x2b4efbf62910>, 67108864: <thicket.thicket.Thicket object at 0x2b4efb738be0>, 268435456: <thicket.thicket.Thicket object at 0x2b4efbeac790>}
# <ipython-input-24-1f1c693bd249>:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, comm, 1% Perturbed'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %%
for name in function_names:
    print(ctk.dataframe.loc[name])
# Out:
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.365209      0.435673      0.676326      1.678311
# 128              0.361349      0.444920      0.679299      1.948663
# 256              0.378347      0.446680      0.639909      1.670137
# 512              0.351364      0.444952      0.688070      1.965936
# 1024             0.655468      0.448572      0.668694      1.681413
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               5.952724     22.605947     89.341515
# 128              5.930179     22.579987     90.716756
# 256              5.990372     23.377346     93.814193
# 512              6.167911     25.534015    105.943310
# 1024             6.551929     31.741193    144.466017
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000210      0.000782      0.003078      0.012191
# 128              0.000212      0.000773      0.003067      0.012169
# 256              0.000211      0.000772      0.003054      0.012121
# 512              0.000211      0.000786      0.003041      0.012199
# 1024             0.000211      0.000782      0.003032      0.012207
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.048617      0.194457      0.776276
# 128              0.048664      0.193783      0.775506
# 256              0.048525      0.194792      0.799017
# 512              0.048477      0.190828      0.777941
# 1024             0.048661      0.193517      0.774742
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000236      0.000662      0.001955      0.007313
# 128              0.000233      0.000656      0.001992      0.008022
# 256              0.000239      0.000661      0.001956      0.007296
# 512              0.000223      0.000653      0.001925      0.007814
# 1024             0.000277      0.000663      0.001970      0.007223
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.030142      0.116697      0.465848
# 128              0.028842      0.116420      0.467404
# 256              0.029713      0.114870      0.454369
# 512              0.030125      0.116558      0.468394
# 1024             0.029154      0.117836      0.465374
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000203      0.000616      0.001912      0.007270
# 128              0.000203      0.000612      0.001947      0.007970
# 256              0.000206      0.000617      0.001911      0.007250
# 512              0.000192      0.000608      0.001876      0.007774
# 1024             0.000235      0.000617      0.001924      0.007179
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.030090      0.116646      0.465789
# 128              0.028788      0.116370      0.467340
# 256              0.029667      0.114821      0.454300
# 512              0.030073      0.116505      0.468327
# 1024             0.029100      0.117776      0.465322
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000344      0.001148      0.004223      0.016119
# 128              0.000320      0.001136      0.004438      0.016256
# 256              0.000345      0.001317      0.004379      0.016083
# 512              0.000308      0.001322      0.004244      0.016127
# 1024             0.000317      0.001150      0.004200      0.016016
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.063265      0.251517      1.002875
# 128              0.062881      0.251043      1.005752
# 256              0.063946      0.251132      1.000543
# 512              0.063247      0.251051      1.003041
# 1024             0.062934      0.251895      1.002706
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.023861      0.093142      0.325038      1.317334
# 128              0.025243      0.100137      0.343733      1.311236
# 256              0.025634      0.092592      0.304403      1.305314
# 512              0.026468      0.106915      0.347586      1.329694
# 1024             0.032094      0.099080      0.334200      1.324145
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               5.420650     21.701083     86.769689
# 128              5.451744     21.683510     88.134870
# 256              5.507266     22.281421     91.220693
# 512              5.651794     24.638782    103.261989
# 1024             6.083335     30.855175    141.880634
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000297      0.000723      0.002013      0.007372
# 128              0.000289      0.000717      0.002050      0.008084
# 256              0.000300      0.000728      0.002015      0.007360
# 512              0.000277      0.000716      0.001989      0.007867
# 1024             0.000343      0.000723      0.002032      0.007283
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.030209      0.116761      0.465926
# 128              0.028901      0.116481      0.467481
# 256              0.029775      0.114921      0.454443
# 512              0.030187      0.116622      0.468505
# 1024             0.029212      0.117900      0.465450
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.023845      0.093122      0.325020      1.317311
# 128              0.025228      0.100118      0.343712      1.311196
# 256              0.025619      0.092572      0.304385      1.305291
# 512              0.026454      0.106895      0.347565      1.329658
# 1024             0.032074      0.099059      0.334180      1.324123
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               5.420606     21.701039     86.769646
# 128              5.451702     21.683472     88.134822
# 256              5.507230     22.281384     91.220643
# 512              5.651752     24.638742    103.261936
# 1024             6.083291     30.855130    141.880596

# %%
speedup=ctk.dataframe.loc["main_function",64]/ctk.dataframe.loc["main_function"]
speedup
# Out:
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               1.000000      1.000000      1.000000      1.000000
# 128              1.010682      0.979216      0.995623      0.861263
# 256              0.965275      0.975358      1.056910      1.004894
# 512              1.039404      0.979146      0.982932      0.853696
# 1024             0.557173      0.971244      1.011413      0.998155
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               1.000000      1.000000      1.000000
# 128              1.003802      1.001150      0.984840
# 256              0.993715      0.967002      0.952324
# 512              0.965112      0.885327      0.843295
# 1024             0.908545      0.712196      0.618426

# %%
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, Main", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, Main'}, xlabel='Number of Threads', ylabel='Speed Up'>)
