# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd
import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
tk = th.Thicket.from_caliperreader(glob("*s1024*.cali"))

# %%
tk.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              12920090      1
#                                                   14545233      1
#                                                   273214451     1
#                                                   877689597     1
#                                                   935783004     1
#                                                   967458955     1
#                                                   1085707340    1
#                                                   1543217329    1
#                                                   1762794704    1
#                                                   1791469599    1
#                                                   1935664902    1
#                                                   2303387681    1
#                                                   2366065115    1
#                                                   2483166518    1
#                                                   2735425868    1
#                                                   2951417281    1
#                                                   2992267074    1
#                                                   3092812754    1
#                                                   3213772206    1
#                                                   3714709675    1
# {'name': 'comm', 'type': 'function'}              12920090      6
#                                                   14545233      6
#                                                   273214451     6
#                                                   877689597     6
#                                                   935783004     6
#                                                   967458955     6
#                                                   1085707340    6
#                                                   1543217329    6
#                                                   1762794704    6
#                                                   1791469599    6
#                                                   1935664902    6
#                                                   2303387681    6
#                                                   2366065115    6
#                                                   2483166518    6
#                                                   2735425868    6
#                                                   2951417281    6
#                                                   2992267074    6
#                                                   3092812754    6
#                                                   3213772206    6
#                                                   3714709675    6
# {'name': 'comm_large', 'type': 'function'}        12920090      7
#                                                   14545233      7
#                                                   273214451     7
#                                                   877689597     7
#                                                   935783004     7
#                                                   967458955     7
#                                                   1085707340    7
#                                                   1543217329    7
#                                                   1762794704    7
#                                                   1791469599    7
#                                                   1935664902    7
#                                                   2303387681    7
#                                                   2366065115    7
#                                                   2483166518    7
#                                                   2735425868    7
#                                                   2951417281    7
#                                                   2992267074    7
#                                                   3092812754    7
#                                                   3213772206    7
#                                                   3714709675    7
# {'name': 'comm_small', 'type': 'function'}        12920090      8
#                                                   14545233      8
#                                                   273214451     8
#                                                   877689597     8
#                                                   935783004     8
#                                                   967458955     8
#                                                   1085707340    8
#                                                   1543217329    8
#                                                   1762794704    8
#                                                   1791469599    8
#                                                   1935664902    8
#                                                   2303387681    8
#                                                   2366065115    8
#                                                   2483166518    8
#                                                   2735425868    8
#                                                   2951417281    8
#                                                   2992267074    8
#                                                   3092812754    8
#                                                   3213772206    8
#                                                   3714709675    8
# {'name': 'comp', 'type': 'function'}              12920090      3
#                                                   14545233      3
#                                                   273214451     3
#                                                   877689597     3
#                                                   935783004     3
#                                                   967458955     3
#                                                   1085707340    3
#                                                   1543217329    3
#                                                   1762794704    3
#                                                   1791469599    3
#                                                   1935664902    3
#                                                   2303387681    3
#                                                   2366065115    3
#                                                   2483166518    3
#                                                   2735425868    3
#                                                   2951417281    3
#                                                   2992267074    3
#                                                   3092812754    3
#                                                   3213772206    3
#                                                   3714709675    3
# {'name': 'comp_large', 'type': 'function'}        12920090      4
#                                                   14545233      4
#                                                   273214451     4
#                                                   877689597     4
#                                                   935783004     4
#                                                   967458955     4
#                                                   1085707340    4
#                                                   1543217329    4
#                                                   1762794704    4
#                                                   1791469599    4
#                                                   1935664902    4
#                                                   2303387681    4
#                                                   2366065115    4
#                                                   2483166518    4
#                                                   2735425868    4
#                                                   2951417281    4
#                                                   2992267074    4
#                                                   3092812754    4
#                                                   3213772206    4
#                                                   3714709675    4
# {'name': 'comp_small', 'type': 'function'}        12920090      5
#                                                   14545233      5
#                                                   273214451     5
#                                                   877689597     5
#                                                   935783004     5
#                                                   967458955     5
#                                                   1085707340    5
#                                                   1543217329    5
#                                                   1762794704    5
#                                                   1791469599    5
#                                                   1935664902    5
#                                                   2303387681    5
#                                                   2366065115    5
#                                                   2483166518    5
#                                                   2735425868    5
#                                                   2951417281    5
#                                                   2992267074    5
#                                                   3092812754    5
#                                                   3213772206    5
#                                                   3714709675    5
# {'name': 'correctness_check', 'type': 'function'} 12920090      9
#                                                   14545233      9
#                                                   273214451     9
#                                                   877689597     9
#                                                   935783004     9
#                                                   967458955     9
#                                                   1085707340    9
#                                                   1543217329    9
#                                                   1762794704    9
#                                                   1791469599    9
#                                                   1935664902    9
#                                                   2303387681    9
#                                                   2366065115    9
#                                                   2483166518    9
#                                                   2735425868    9
#                                                   2951417281    9
#                                                   2992267074    9
#                                                   3092812754    9
#                                                   3213772206    9
#                                                   3714709675    9
# {'name': 'data_init', 'type': 'function'}         12920090      2
#                                                   14545233      2
#                                                   273214451     2
#                                                   877689597     2
#                                                   935783004     2
#                                                   967458955     2
#                                                   1085707340    2
#                                                   1543217329    2
#                                                   1762794704    2
#                                                   1791469599    2
#                                                   1935664902    2
#                                                   2303387681    2
#                                                   2366065115    2
#                                                   2483166518    2
#                                                   2735425868    2
#                                                   2951417281    2
#                                                   2992267074    2
#                                                   3092812754    2
#                                                   3213772206    2
#                                                   3714709675    2
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              12920090    regionprofile
#                                                   14545233    regionprofile
#                                                   273214451   regionprofile
#                                                   877689597   regionprofile
#                                                   935783004   regionprofile
#                                                   967458955   regionprofile
#                                                   1085707340  regionprofile
#                                                   1543217329  regionprofile
#                                                   1762794704  regionprofile
#                                                   1791469599  regionprofile
#                                                   1935664902  regionprofile
#                                                   2303387681  regionprofile
#                                                   2366065115  regionprofile
#                                                   2483166518  regionprofile
#                                                   2735425868  regionprofile
#                                                   2951417281  regionprofile
#                                                   2992267074  regionprofile
#                                                   3092812754  regionprofile
#                                                   3213772206  regionprofile
#                                                   3714709675  regionprofile
# {'name': 'comm', 'type': 'function'}              12920090    regionprofile
#                                                   14545233    regionprofile
#                                                   273214451   regionprofile
#                                                   877689597   regionprofile
#                                                   935783004   regionprofile
#                                                   967458955   regionprofile
#                                                   1085707340  regionprofile
#                                                   1543217329  regionprofile
#                                                   1762794704  regionprofile
#                                                   1791469599  regionprofile
#                                                   1935664902  regionprofile
#                                                   2303387681  regionprofile
#                                                   2366065115  regionprofile
#                                                   2483166518  regionprofile
#                                                   2735425868  regionprofile
#                                                   2951417281  regionprofile
#                                                   2992267074  regionprofile
#                                                   3092812754  regionprofile
#                                                   3213772206  regionprofile
#                                                   3714709675  regionprofile
# {'name': 'comm_large', 'type': 'function'}        12920090    regionprofile
#                                                   14545233    regionprofile
#                                                   273214451   regionprofile
#                                                   877689597   regionprofile
#                                                   935783004   regionprofile
#                                                   967458955   regionprofile
#                                                   1085707340  regionprofile
#                                                   1543217329  regionprofile
#                                                   1762794704  regionprofile
#                                                   1791469599  regionprofile
#                                                   1935664902  regionprofile
#                                                   2303387681  regionprofile
#                                                   2366065115  regionprofile
#                                                   2483166518  regionprofile
#                                                   2735425868  regionprofile
#                                                   2951417281  regionprofile
#                                                   2992267074  regionprofile
#                                                   3092812754  regionprofile
#                                                   3213772206  regionprofile
#                                                   3714709675  regionprofile
# {'name': 'comm_small', 'type': 'function'}        12920090    regionprofile
#                                                   14545233    regionprofile
#                                                   273214451   regionprofile
#                                                   877689597   regionprofile
#                                                   935783004   regionprofile
#                                                   967458955   regionprofile
#                                                   1085707340  regionprofile
#                                                   1543217329  regionprofile
#                                                   1762794704  regionprofile
#                                                   1791469599  regionprofile
#                                                   1935664902  regionprofile
#                                                   2303387681  regionprofile
#                                                   2366065115  regionprofile
#                                                   2483166518  regionprofile
#                                                   2735425868  regionprofile
#                                                   2951417281  regionprofile
#                                                   2992267074  regionprofile
#                                                   3092812754  regionprofile
#                                                   3213772206  regionprofile
#                                                   3714709675  regionprofile
# {'name': 'comp', 'type': 'function'}              12920090    regionprofile
#                                                   14545233    regionprofile
#                                                   273214451   regionprofile
#                                                   877689597   regionprofile
#                                                   935783004   regionprofile
#                                                   967458955   regionprofile
#                                                   1085707340  regionprofile
#                                                   1543217329  regionprofile
#                                                   1762794704  regionprofile
#                                                   1791469599  regionprofile
#                                                   1935664902  regionprofile
#                                                   2303387681  regionprofile
#                                                   2366065115  regionprofile
#                                                   2483166518  regionprofile
#                                                   2735425868  regionprofile
#                                                   2951417281  regionprofile
#                                                   2992267074  regionprofile
#                                                   3092812754  regionprofile
#                                                   3213772206  regionprofile
#                                                   3714709675  regionprofile
# {'name': 'comp_large', 'type': 'function'}        12920090    regionprofile
#                                                   14545233    regionprofile
#                                                   273214451   regionprofile
#                                                   877689597   regionprofile
#                                                   935783004   regionprofile
#                                                   967458955   regionprofile
#                                                   1085707340  regionprofile
#                                                   1543217329  regionprofile
#                                                   1762794704  regionprofile
#                                                   1791469599  regionprofile
#                                                   1935664902  regionprofile
#                                                   2303387681  regionprofile
#                                                   2366065115  regionprofile
#                                                   2483166518  regionprofile
#                                                   2735425868  regionprofile
#                                                   2951417281  regionprofile
#                                                   2992267074  regionprofile
#                                                   3092812754  regionprofile
#                                                   3213772206  regionprofile
#                                                   3714709675  regionprofile
# {'name': 'comp_small', 'type': 'function'}        12920090    regionprofile
#                                                   14545233    regionprofile
#                                                   273214451   regionprofile
#                                                   877689597   regionprofile
#                                                   935783004   regionprofile
#                                                   967458955   regionprofile
#                                                   1085707340  regionprofile
#                                                   1543217329  regionprofile
#                                                   1762794704  regionprofile
#                                                   1791469599  regionprofile
#                                                   1935664902  regionprofile
#                                                   2303387681  regionprofile
#                                                   2366065115  regionprofile
#                                                   2483166518  regionprofile
#                                                   2735425868  regionprofile
#                                                   2951417281  regionprofile
#                                                   2992267074  regionprofile
#                                                   3092812754  regionprofile
#                                                   3213772206  regionprofile
#                                                   3714709675  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 12920090    regionprofile
#                                                   14545233    regionprofile
#                                                   273214451   regionprofile
#                                                   877689597   regionprofile
#                                                   935783004   regionprofile
#                                                   967458955   regionprofile
#                                                   1085707340  regionprofile
#                                                   1543217329  regionprofile
#                                                   1762794704  regionprofile
#                                                   1791469599  regionprofile
#                                                   1935664902  regionprofile
#                                                   2303387681  regionprofile
#                                                   2366065115  regionprofile
#                                                   2483166518  regionprofile
#                                                   2735425868  regionprofile
#                                                   2951417281  regionprofile
#                                                   2992267074  regionprofile
#                                                   3092812754  regionprofile
#                                                   3213772206  regionprofile
#                                                   3714709675  regionprofile
# {'name': 'data_init', 'type': 'function'}         12920090    regionprofile
#                                                   14545233    regionprofile
#                                                   273214451   regionprofile
#                                                   877689597   regionprofile
#                                                   935783004   regionprofile
#                                                   967458955   regionprofile
#                                                   1085707340  regionprofile
#                                                   1543217329  regionprofile
#                                                   1762794704  regionprofile
#                                                   1791469599  regionprofile
#                                                   1935664902  regionprofile
#                                                   2303387681  regionprofile
#                                                   2366065115  regionprofile
#                                                   2483166518  regionprofile
#                                                   2735425868  regionprofile
#                                                   2951417281  regionprofile
#                                                   2992267074  regionprofile
#                                                   3092812754  regionprofile
#                                                   3213772206  regionprofile
#                                                   3714709675  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              12920090         0.444636
#                                                   14545233         0.379552
#                                                   273214451        0.382485
#                                                   877689597        0.381697
#                                                   935783004        0.401048
#                                                   967458955        0.373932
#                                                   1085707340       0.379839
#                                                   1543217329       0.361356
#                                                   1762794704       0.381512
#                                                   1791469599       0.383361
#                                                   1935664902       0.377296
#                                                   2303387681       0.370438
#                                                   2366065115       0.523927
#                                                   2483166518       0.609915
#                                                   2735425868       0.472675
#                                                   2951417281       0.372986
#                                                   2992267074       0.384723
#                                                   3092812754       0.408603
#                                                   3213772206       0.428615
#                                                   3714709675       0.377582
# {'name': 'comm', 'type': 'function'}              12920090         0.000099
#                                                   14545233         0.000081
#                                                   273214451        0.000082
#                                                   877689597        0.000082
#                                                   935783004        0.000093
#                                                   967458955        0.000085
#                                                   1085707340       0.000074
#                                                   1543217329       0.000081
#                                                   1762794704       0.000081
#                                                   1791469599       0.000087
#                                                   1935664902       0.000081
#                                                   2303387681       0.000085
#                                                   2366065115       0.000108
#                                                   2483166518       0.000148
#                                                   2735425868       0.000100
#                                                   2951417281       0.000083
#                                                   2992267074       0.000075
#                                                   3092812754       0.000097
#                                                   3213772206       0.000112
#                                                   3714709675       0.000089
# {'name': 'comm_large', 'type': 'function'}        12920090         0.000086
#                                                   14545233         0.000069
#                                                   273214451        0.000070
#                                                   877689597        0.000070
#                                                   935783004        0.000082
#                                                   967458955        0.000072
#                                                   1085707340       0.000062
#                                                   1543217329       0.000068
#                                                   1762794704       0.000069
#                                                   1791469599       0.000075
#                                                   1935664902       0.000069
#                                                   2303387681       0.000072
#                                                   2366065115       0.000095
#                                                   2483166518       0.000136
#                                                   2735425868       0.000088
#                                                   2951417281       0.000071
#                                                   2992267074       0.000064
#                                                   3092812754       0.000085
#                                                   3213772206       0.000100
#                                                   3714709675       0.000077
# {'name': 'comm_small', 'type': 'function'}        12920090         0.000070
#                                                   14545233         0.000055
#                                                   273214451        0.000055
#                                                   877689597        0.000056
#                                                   935783004        0.000068
#                                                   967458955        0.000058
#                                                   1085707340       0.000050
#                                                   1543217329       0.000054
#                                                   1762794704       0.000055
#                                                   1791469599       0.000061
#                                                   1935664902       0.000055
#                                                   2303387681       0.000057
#                                                   2366065115       0.000082
#                                                   2483166518       0.000121
#                                                   2735425868       0.000072
#                                                   2951417281       0.000057
#                                                   2992267074       0.000051
#                                                   3092812754       0.000070
#                                                   3213772206       0.000085
#                                                   3714709675       0.000063
# {'name': 'comp', 'type': 'function'}              12920090         0.032461
#                                                   14545233         0.036949
#                                                   273214451        0.037176
#                                                   877689597        0.036844
#                                                   935783004        0.047493
#                                                   967458955        0.038821
#                                                   1085707340       0.045917
#                                                   1543217329       0.030043
#                                                   1762794704       0.039146
#                                                   1791469599       0.037223
#                                                   1935664902       0.037564
#                                                   2303387681       0.031436
#                                                   2366065115       0.151303
#                                                   2483166518       0.202878
#                                                   2735425868       0.033475
#                                                   2951417281       0.033731
#                                                   2992267074       0.052038
#                                                   3092812754       0.033960
#                                                   3213772206       0.041965
#                                                   3714709675       0.035509
# {'name': 'comp_large', 'type': 'function'}        12920090         0.032422
#                                                   14545233         0.036925
#                                                   273214451        0.037153
#                                                   877689597        0.036819
#                                                   935783004        0.047470
#                                                   967458955        0.038796
#                                                   1085707340       0.045895
#                                                   1543217329       0.030019
#                                                   1762794704       0.039120
#                                                   1791469599       0.037198
#                                                   1935664902       0.037540
#                                                   2303387681       0.031412
#                                                   2366065115       0.151278
#                                                   2483166518       0.202853
#                                                   2735425868       0.033450
#                                                   2951417281       0.033706
#                                                   2992267074       0.052016
#                                                   3092812754       0.033921
#                                                   3213772206       0.041939
#                                                   3714709675       0.035485
# {'name': 'comp_small', 'type': 'function'}        12920090         0.032396
#                                                   14545233         0.036908
#                                                   273214451        0.037137
#                                                   877689597        0.036803
#                                                   935783004        0.047456
#                                                   967458955        0.038778
#                                                   1085707340       0.045880
#                                                   1543217329       0.030003
#                                                   1762794704       0.039104
#                                                   1791469599       0.037182
#                                                   1935664902       0.037524
#                                                   2303387681       0.031394
#                                                   2366065115       0.151260
#                                                   2483166518       0.202837
#                                                   2735425868       0.033434
#                                                   2951417281       0.033689
#                                                   2992267074       0.052001
#                                                   3092812754       0.033896
#                                                   3213772206       0.041923
#                                                   3714709675       0.035466
# {'name': 'correctness_check', 'type': 'function'} 12920090         0.000061
#                                                   14545233         0.000063
#                                                   273214451        0.000063
#                                                   877689597        0.000062
#                                                   935783004        0.000055
#                                                   967458955        0.000063
#                                                   1085707340       0.000051
#                                                   1543217329       0.000058
#                                                   1762794704       0.000062
#                                                   1791469599       0.000058
#                                                   1935664902       0.000060
#                                                   2303387681       0.000061
#                                                   2366065115       0.000082
#                                                   2483166518       0.000081
#                                                   2735425868       0.000062
#                                                   2951417281       0.000060
#                                                   2992267074       0.000055
#                                                   3092812754       0.000059
#                                                   3213772206       0.000065
#                                                   3714709675       0.000065
# {'name': 'data_init', 'type': 'function'}         12920090         0.406226
#                                                   14545233         0.336986
#                                                   273214451        0.339691
#                                                   877689597        0.339254
#                                                   935783004        0.348085
#                                                   967458955        0.329478
#                                                   1085707340       0.328221
#                                                   1543217329       0.325712
#                                                   1762794704       0.336747
#                                                   1791469599       0.340491
#                                                   1935664902       0.334094
#                                                   2303387681       0.333391
#                                                   2366065115       0.366881
#                                                   2483166518       0.400847
#                                                   2735425868       0.433334
#                                                   2951417281       0.333660
#                                                   2992267074       0.327019
#                                                   3092812754       0.368960
#                                                   3213772206       0.380579
#                                                   3714709675       0.336411
#
#                                                               Max time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              12920090         0.444636
#                                                   14545233         0.379552
#                                                   273214451        0.382485
#                                                   877689597        0.381697
#                                                   935783004        0.401048
#                                                   967458955        0.373932
#                                                   1085707340       0.379839
#                                                   1543217329       0.361356
#                                                   1762794704       0.381512
#                                                   1791469599       0.383361
#                                                   1935664902       0.377296
#                                                   2303387681       0.370438
#                                                   2366065115       0.523927
#                                                   2483166518       0.609915
#                                                   2735425868       0.472675
#                                                   2951417281       0.372986
#                                                   2992267074       0.384723
#                                                   3092812754       0.408603
#                                                   3213772206       0.428615
#                                                   3714709675       0.377582
# {'name': 'comm', 'type': 'function'}              12920090         0.000099
#                                                   14545233         0.000081
#                                                   273214451        0.000082
#                                                   877689597        0.000082
#                                                   935783004        0.000093
#                                                   967458955        0.000085
#                                                   1085707340       0.000074
#                                                   1543217329       0.000081
#                                                   1762794704       0.000081
#                                                   1791469599       0.000087
#                                                   1935664902       0.000081
#                                                   2303387681       0.000085
#                                                   2366065115       0.000108
#                                                   2483166518       0.000148
#                                                   2735425868       0.000100
#                                                   2951417281       0.000083
#                                                   2992267074       0.000075
#                                                   3092812754       0.000097
#                                                   3213772206       0.000112
#                                                   3714709675       0.000089
# {'name': 'comm_large', 'type': 'function'}        12920090         0.000086
#                                                   14545233         0.000069
#                                                   273214451        0.000070
#                                                   877689597        0.000070
#                                                   935783004        0.000082
#                                                   967458955        0.000072
#                                                   1085707340       0.000062
#                                                   1543217329       0.000068
#                                                   1762794704       0.000069
#                                                   1791469599       0.000075
#                                                   1935664902       0.000069
#                                                   2303387681       0.000072
#                                                   2366065115       0.000095
#                                                   2483166518       0.000136
#                                                   2735425868       0.000088
#                                                   2951417281       0.000071
#                                                   2992267074       0.000064
#                                                   3092812754       0.000085
#                                                   3213772206       0.000100
#                                                   3714709675       0.000077
# {'name': 'comm_small', 'type': 'function'}        12920090         0.000070
#                                                   14545233         0.000055
#                                                   273214451        0.000055
#                                                   877689597        0.000056
#                                                   935783004        0.000068
#                                                   967458955        0.000058
#                                                   1085707340       0.000050
#                                                   1543217329       0.000054
#                                                   1762794704       0.000055
#                                                   1791469599       0.000061
#                                                   1935664902       0.000055
#                                                   2303387681       0.000057
#                                                   2366065115       0.000082
#                                                   2483166518       0.000121
#                                                   2735425868       0.000072
#                                                   2951417281       0.000057
#                                                   2992267074       0.000051
#                                                   3092812754       0.000070
#                                                   3213772206       0.000085
#                                                   3714709675       0.000063
# {'name': 'comp', 'type': 'function'}              12920090         0.032461
#                                                   14545233         0.036949
# ...
#                                                   1543217329        0.000004
#                                                   1762794704        0.000006
#                                                   1791469599        0.000006
#                                                   1935664902        0.000006
#                                                   2303387681        0.000005
#                                                   2366065115        0.000011
#                                                   2483166518        0.000013
#                                                   2735425868        0.000006
#                                                   2951417281        0.000005
#                                                   2992267074        0.000006
#                                                   3092812754        0.000005
#                                                   3213772206        0.000006
#                                                   3714709675        0.000005
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              12920090                 main
#                                                   14545233                 main
#                                                   273214451                main
#                                                   877689597                main
#                                                   935783004                main
#                                                   967458955                main
#                                                   1085707340               main
#                                                   1543217329               main
#                                                   1762794704               main
#                                                   1791469599               main
#                                                   1935664902               main
#                                                   2303387681               main
#                                                   2366065115               main
#                                                   2483166518               main
#                                                   2735425868               main
#                                                   2951417281               main
#                                                   2992267074               main
#                                                   3092812754               main
#                                                   3213772206               main
#                                                   3714709675               main
# {'name': 'comm', 'type': 'function'}              12920090                 comm
#                                                   14545233                 comm
#                                                   273214451                comm
#                                                   877689597                comm
#                                                   935783004                comm
#                                                   967458955                comm
#                                                   1085707340               comm
#                                                   1543217329               comm
#                                                   1762794704               comm
#                                                   1791469599               comm
#                                                   1935664902               comm
#                                                   2303387681               comm
#                                                   2366065115               comm
#                                                   2483166518               comm
#                                                   2735425868               comm
#                                                   2951417281               comm
#                                                   2992267074               comm
#                                                   3092812754               comm
#                                                   3213772206               comm
#                                                   3714709675               comm
# {'name': 'comm_large', 'type': 'function'}        12920090           comm_large
#                                                   14545233           comm_large
#                                                   273214451          comm_large
#                                                   877689597          comm_large
#                                                   935783004          comm_large
#                                                   967458955          comm_large
#                                                   1085707340         comm_large
#                                                   1543217329         comm_large
#                                                   1762794704         comm_large
#                                                   1791469599         comm_large
#                                                   1935664902         comm_large
#                                                   2303387681         comm_large
#                                                   2366065115         comm_large
#                                                   2483166518         comm_large
#                                                   2735425868         comm_large
#                                                   2951417281         comm_large
#                                                   2992267074         comm_large
#                                                   3092812754         comm_large
#                                                   3213772206         comm_large
#                                                   3714709675         comm_large
# {'name': 'comm_small', 'type': 'function'}        12920090           comm_small
#                                                   14545233           comm_small
#                                                   273214451          comm_small
#                                                   877689597          comm_small
#                                                   935783004          comm_small
#                                                   967458955          comm_small
#                                                   1085707340         comm_small
#                                                   1543217329         comm_small
#                                                   1762794704         comm_small
#                                                   1791469599         comm_small
#                                                   1935664902         comm_small
#                                                   2303387681         comm_small
#                                                   2366065115         comm_small
#                                                   2483166518         comm_small
#                                                   2735425868         comm_small
#                                                   2951417281         comm_small
#                                                   2992267074         comm_small
#                                                   3092812754         comm_small
#                                                   3213772206         comm_small
#                                                   3714709675         comm_small
# {'name': 'comp', 'type': 'function'}              12920090                 comp
#                                                   14545233                 comp
#                                                   273214451                comp
#                                                   877689597                comp
#                                                   935783004                comp
#                                                   967458955                comp
#                                                   1085707340               comp
#                                                   1543217329               comp
#                                                   1762794704               comp
#                                                   1791469599               comp
#                                                   1935664902               comp
#                                                   2303387681               comp
#                                                   2366065115               comp
#                                                   2483166518               comp
#                                                   2735425868               comp
#                                                   2951417281               comp
#                                                   2992267074               comp
#                                                   3092812754               comp
#                                                   3213772206               comp
#                                                   3714709675               comp
# {'name': 'comp_large', 'type': 'function'}        12920090           comp_large
#                                                   14545233           comp_large
#                                                   273214451          comp_large
#                                                   877689597          comp_large
#                                                   935783004          comp_large
#                                                   967458955          comp_large
#                                                   1085707340         comp_large
#                                                   1543217329         comp_large
#                                                   1762794704         comp_large
#                                                   1791469599         comp_large
#                                                   1935664902         comp_large
#                                                   2303387681         comp_large
#                                                   2366065115         comp_large
#                                                   2483166518         comp_large
#                                                   2735425868         comp_large
#                                                   2951417281         comp_large
#                                                   2992267074         comp_large
#                                                   3092812754         comp_large
#                                                   3213772206         comp_large
#                                                   3714709675         comp_large
# {'name': 'comp_small', 'type': 'function'}        12920090           comp_small
#                                                   14545233           comp_small
#                                                   273214451          comp_small
#                                                   877689597          comp_small
#                                                   935783004          comp_small
#                                                   967458955          comp_small
#                                                   1085707340         comp_small
#                                                   1543217329         comp_small
#                                                   1762794704         comp_small
#                                                   1791469599         comp_small
#                                                   1935664902         comp_small
#                                                   2303387681         comp_small
#                                                   2366065115         comp_small
#                                                   2483166518         comp_small
#                                                   2735425868         comp_small
#                                                   2951417281         comp_small
#                                                   2992267074         comp_small
#                                                   3092812754         comp_small
#                                                   3213772206         comp_small
#                                                   3714709675         comp_small
# {'name': 'correctness_check', 'type': 'function'} 12920090    correctness_check
#                                                   14545233    correctness_check
#                                                   273214451   correctness_check
#                                                   877689597   correctness_check
#                                                   935783004   correctness_check
#                                                   967458955   correctness_check
#                                                   1085707340  correctness_check
#                                                   1543217329  correctness_check
#                                                   1762794704  correctness_check
#                                                   1791469599  correctness_check
#                                                   1935664902  correctness_check
#                                                   2303387681  correctness_check
#                                                   2366065115  correctness_check
#                                                   2483166518  correctness_check
#                                                   2735425868  correctness_check
#                                                   2951417281  correctness_check
#                                                   2992267074  correctness_check
#                                                   3092812754  correctness_check
#                                                   3213772206  correctness_check
#                                                   3714709675  correctness_check
# {'name': 'data_init', 'type': 'function'}         12920090            data_init
#                                                   14545233            data_init
#                                                   273214451           data_init
#                                                   877689597           data_init
#                                                   935783004           data_init
#                                                   967458955           data_init
#                                                   1085707340          data_init
#                                                   1543217329          data_init
#                                                   1762794704          data_init
#                                                   1791469599          data_init
#                                                   1935664902          data_init
#                                                   2303387681          data_init
#                                                   2366065115          data_init
#                                                   2483166518          data_init
#                                                   2735425868          data_init
#                                                   2951417281          data_init
#                                                   2992267074          data_init
#                                                   3092812754          data_init
#                                                   3213772206          data_init
#                                                   3714709675          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 12920090             2.11.0-dev
# 14545233             2.11.0-dev
# 273214451            2.11.0-dev
# 877689597            2.11.0-dev
# 935783004            2.11.0-dev
# 967458955            2.11.0-dev
# 1085707340           2.11.0-dev
# 1543217329           2.11.0-dev
# 1762794704           2.11.0-dev
# 1791469599           2.11.0-dev
# 1935664902           2.11.0-dev
# 2303387681           2.11.0-dev
# 2366065115           2.11.0-dev
# 2483166518           2.11.0-dev
# 2735425868           2.11.0-dev
# 2951417281           2.11.0-dev
# 2992267074           2.11.0-dev
# 3092812754           2.11.0-dev
# 3213772206           2.11.0-dev
# 3714709675           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 12920090    min#inclusive#sum#time.duration,max#inclusive#...
# 14545233    min#inclusive#sum#time.duration,max#inclusive#...
# 273214451   min#inclusive#sum#time.duration,max#inclusive#...
# 877689597   min#inclusive#sum#time.duration,max#inclusive#...
# 935783004   min#inclusive#sum#time.duration,max#inclusive#...
# 967458955   min#inclusive#sum#time.duration,max#inclusive#...
# 1085707340  min#inclusive#sum#time.duration,max#inclusive#...
# 1543217329  min#inclusive#sum#time.duration,max#inclusive#...
# 1762794704  min#inclusive#sum#time.duration,max#inclusive#...
# 1791469599  min#inclusive#sum#time.duration,max#inclusive#...
# 1935664902  min#inclusive#sum#time.duration,max#inclusive#...
# 2303387681  min#inclusive#sum#time.duration,max#inclusive#...
# 2366065115  min#inclusive#sum#time.duration,max#inclusive#...
# 2483166518  min#inclusive#sum#time.duration,max#inclusive#...
# 2735425868  min#inclusive#sum#time.duration,max#inclusive#...
# 2951417281  min#inclusive#sum#time.duration,max#inclusive#...
# 2992267074  min#inclusive#sum#time.duration,max#inclusive#...
# 3092812754  min#inclusive#sum#time.duration,max#inclusive#...
# 3213772206  min#inclusive#sum#time.duration,max#inclusive#...
# 3714709675  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 12920090                                              2
# 14545233                                              2
# 273214451                                             2
# 877689597                                             2
# 935783004                                             2
# 967458955                                             2
# 1085707340                                            2
# 1543217329                                            2
# 1762794704                                            2
# 1791469599                                            2
# 1935664902                                            2
# 2303387681                                            2
# 2366065115                                            2
# 2483166518                                            2
# 2735425868                                            2
# 2951417281                                            2
# 2992267074                                            2
# 3092812754                                            2
# 3213772206                                            2
# 3714709675                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 12920090    cuda.gputime,node.order  regionprofile         spot
# 14545233    cuda.gputime,node.order  regionprofile         spot
# 273214451   cuda.gputime,node.order  regionprofile         spot
# 877689597   cuda.gputime,node.order  regionprofile         spot
# 935783004   cuda.gputime,node.order  regionprofile         spot
# 967458955   cuda.gputime,node.order  regionprofile         spot
# 1085707340  cuda.gputime,node.order  regionprofile         spot
# 1543217329  cuda.gputime,node.order  regionprofile         spot
# 1762794704  cuda.gputime,node.order  regionprofile         spot
# 1791469599  cuda.gputime,node.order  regionprofile         spot
# 1935664902  cuda.gputime,node.order  regionprofile         spot
# 2303387681  cuda.gputime,node.order  regionprofile         spot
# 2366065115  cuda.gputime,node.order  regionprofile         spot
# 2483166518  cuda.gputime,node.order  regionprofile         spot
# 2735425868  cuda.gputime,node.order  regionprofile         spot
# 2951417281  cuda.gputime,node.order  regionprofile         spot
# 2992267074  cuda.gputime,node.order  regionprofile         spot
# 3092812754  cuda.gputime,node.order  regionprofile         spot
# 3213772206  cuda.gputime,node.order  regionprofile         spot
# 3714709675  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order          spot:output  launchdate  \
# profile
# 12920090                true            true    t64-s1024-i0.cali  1702056326
# 14545233                true            true    t64-s1024-i2.cali  1702064608
# 273214451               true            true   t512-s1024-i3.cali  1702083543
# 877689597               true            true   t512-s1024-i1.cali  1702083523
# 935783004               true            true  t1024-s1024-i1.cali  1702092268
# 967458955               true            true   t512-s1024-i2.cali  1702083536
# 1085707340              true            true  t1024-s1024-i2.cali  1702092287
# 1543217329              true            true    t64-s1024-i3.cali  1702064622
# 1762794704              true            true   t128-s1024-i0.cali  1702066830
# 1791469599              true            true   t256-s1024-i2.cali  1702068152
# 1935664902              true            true   t128-s1024-i1.cali  1702066850
# 2303387681              true            true   t128-s1024-i3.cali  1702066881
# 2366065115              true            true   t256-s1024-i3.cali  1702068166
# 2483166518              true            true  t1024-s1024-i0.cali  1702091985
# 2735425868              true            true    t64-s1024-i1.cali  1702064593
# 2951417281              true            true   t128-s1024-i2.cali  1702066871
# 2992267074              true            true  t1024-s1024-i3.cali  1702092303
# 3092812754              true            true   t512-s1024-i0.cali  1702083504
# 3213772206              true            true   t256-s1024-i0.cali  1702068109
# 3714709675              true            true   t256-s1024-i1.cali  1702068132
#
#                                                     libraries  \
# profile
# 12920090    [/scratch/group/csce435-f23/Caliper/caliper/li...
# 14545233    [/scratch/group/csce435-f23/Caliper/caliper/li...
# 273214451   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 877689597   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 935783004   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 967458955   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1085707340  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1543217329  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1762794704  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1791469599  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1935664902  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2303387681  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2366065115  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2483166518  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2735425868  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2951417281  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2992267074  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3092812754  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3213772206  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3714709675  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                       cmdline cluster       Algorithm  \
# profile
# 12920090      [./Selection_Sort, 0, 64, 1024]       g  Selection Sort
# 14545233      [./Selection_Sort, 2, 64, 1024]       g  Selection Sort
# 273214451    [./Selection_Sort, 3, 512, 1024]       g  Selection Sort
# 877689597    [./Selection_Sort, 1, 512, 1024]       g  Selection Sort
# 935783004   [./Selection_Sort, 1, 1024, 1024]       g  Selection Sort
# 967458955    [./Selection_Sort, 2, 512, 1024]       g  Selection Sort
# 1085707340  [./Selection_Sort, 2, 1024, 1024]       g  Selection Sort
# 1543217329    [./Selection_Sort, 3, 64, 1024]       g  Selection Sort
# 1762794704   [./Selection_Sort, 0, 128, 1024]       g  Selection Sort
# 1791469599   [./Selection_Sort, 2, 256, 1024]       g  Selection Sort
# 1935664902   [./Selection_Sort, 1, 128, 1024]       g  Selection Sort
# 2303387681   [./Selection_Sort, 3, 128, 1024]       g  Selection Sort
# 2366065115   [./Selection_Sort, 3, 256, 1024]       g  Selection Sort
# 2483166518  [./Selection_Sort, 0, 1024, 1024]       g  Selection Sort
# 2735425868    [./Selection_Sort, 1, 64, 1024]       g  Selection Sort
# 2951417281   [./Selection_Sort, 2, 128, 1024]       g  Selection Sort
# 2992267074  [./Selection_Sort, 3, 1024, 1024]       g  Selection Sort
# 3092812754   [./Selection_Sort, 0, 512, 1024]       g  Selection Sort
# 3213772206   [./Selection_Sort, 0, 256, 1024]       g  Selection Sort
# 3714709675   [./Selection_Sort, 1, 256, 1024]       g  Selection Sort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize  \
# profile
# 12920090               CUDA      int               4       1024
# 14545233               CUDA      int               4       1024
# 273214451              CUDA      int               4       1024
# 877689597              CUDA      int               4       1024
# 935783004              CUDA      int               4       1024
# 967458955              CUDA      int               4       1024
# 1085707340             CUDA      int               4       1024
# 1543217329             CUDA      int               4       1024
# 1762794704             CUDA      int               4       1024
# 1791469599             CUDA      int               4       1024
# 1935664902             CUDA      int               4       1024
# 2303387681             CUDA      int               4       1024
# 2366065115             CUDA      int               4       1024
# 2483166518             CUDA      int               4       1024
# 2735425868             CUDA      int               4       1024
# 2951417281             CUDA      int               4       1024
# 2992267074             CUDA      int               4       1024
# 3092812754             CUDA      int               4       1024
# 3213772206             CUDA      int               4       1024
# 3714709675             CUDA      int               4       1024
#
#                  InputType  num_threads  num_blocks  group_num  \
# profile
# 12920090        Randomized           64          16         16
# 14545233    Reverse Sorted           64          16         16
# 273214451     1% Perturbed          512           2         16
# 877689597           Sorted          512           2         16
# 935783004           Sorted         1024           1         16
# 967458955   Reverse Sorted          512           2         16
# 1085707340  Reverse Sorted         1024           1         16
# 1543217329    1% Perturbed           64          16         16
# 1762794704      Randomized          128           8         16
# 1791469599  Reverse Sorted          256           4         16
# 1935664902          Sorted          128           8         16
# 2303387681    1% Perturbed          128           8         16
# 2366065115    1% Perturbed          256           4         16
# 2483166518      Randomized         1024           1         16
# 2735425868          Sorted           64          16         16
# 2951417281  Reverse Sorted          128           8         16
# 2992267074    1% Perturbed         1024           1         16
# 3092812754      Randomized          512           2         16
# 3213772206      Randomized          256           4         16
# 3714709675          Sorted          256           4         16
#
#                 implementation_source
# profile
# 12920090    Handwritten, AI, & Online
# 14545233    Handwritten, AI, & Online
# 273214451   Handwritten, AI, & Online
# 877689597   Handwritten, AI, & Online
# 935783004   Handwritten, AI, & Online
# 967458955   Handwritten, AI, & Online
# 1085707340  Handwritten, AI, & Online
# 1543217329  Handwritten, AI, & Online
# 1762794704  Handwritten, AI, & Online
# 1791469599  Handwritten, AI, & Online
# 1935664902  Handwritten, AI, & Online
# 2303387681  Handwritten, AI, & Online
# 2366065115  Handwritten, AI, & Online
# 2483166518  Handwritten, AI, & Online
# 2735425868  Handwritten, AI, & Online
# 2951417281  Handwritten, AI, & Online
# 2992267074  Handwritten, AI, & Online
# 3092812754  Handwritten, AI, & Online
# 3213772206  Handwritten, AI, & Online
# 3714709675  Handwritten, AI, & Online

# %%
tk.statsframe.dataframe["time"] = 1

# %%
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# │     └─ 1.000 comm_small
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# │     └─ 1.000 comp_small
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
gb = tk.groupby("InputType")
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b0ac68034f0>, 'Randomized': <thicket.thicket.Thicket object at 0x2b0ac5189310>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b0ac5dba220>, 'Sorted': <thicket.thicket.Thicket object at 0x2b0ac64e5d00>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_threads'
)

# %%
ctk.dataframe
# Out:
#                                                               1% Perturbed  \
#                                                                        nid
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                     1
#                                                   128                    1
#                                                   256                    1
#                                                   512                    1
#                                                   1024                   1
# {'name': 'comm', 'type': 'function'}              64                     6
#                                                   128                    6
#                                                   256                    6
#                                                   512                    6
#                                                   1024                   6
# {'name': 'comm_large', 'type': 'function'}        64                     7
#                                                   128                    7
#                                                   256                    7
#                                                   512                    7
#                                                   1024                   7
# {'name': 'comm_small', 'type': 'function'}        64                     8
#                                                   128                    8
#                                                   256                    8
#                                                   512                    8
#                                                   1024                   8
# {'name': 'comp', 'type': 'function'}              64                     3
#                                                   128                    3
#                                                   256                    3
#                                                   512                    3
#                                                   1024                   3
# {'name': 'comp_large', 'type': 'function'}        64                     4
#                                                   128                    4
#                                                   256                    4
#                                                   512                    4
#                                                   1024                   4
# {'name': 'comp_small', 'type': 'function'}        64                     5
#                                                   128                    5
#                                                   256                    5
#                                                   512                    5
#                                                   1024                   5
# {'name': 'correctness_check', 'type': 'function'} 64                     9
#                                                   128                    9
#                                                   256                    9
#                                                   512                    9
#                                                   1024                   9
# {'name': 'data_init', 'type': 'function'}         64                     2
#                                                   128                    2
#                                                   256                    2
#                                                   512                    2
#                                                   1024                   2
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_small', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_small', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'data_init', 'type': 'function'}         64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.361356
#                                                   128              0.370438
#                                                   256              0.523927
#                                                   512              0.382485
#                                                   1024             0.384723
# {'name': 'comm', 'type': 'function'}              64               0.000081
#                                                   128              0.000085
#                                                   256              0.000108
#                                                   512              0.000082
#                                                   1024             0.000075
# {'name': 'comm_large', 'type': 'function'}        64               0.000068
#                                                   128              0.000072
#                                                   256              0.000095
#                                                   512              0.000070
#                                                   1024             0.000064
# {'name': 'comm_small', 'type': 'function'}        64               0.000054
#                                                   128              0.000057
#                                                   256              0.000082
#                                                   512              0.000055
#                                                   1024             0.000051
# {'name': 'comp', 'type': 'function'}              64               0.030043
#                                                   128              0.031436
#                                                   256              0.151303
#                                                   512              0.037176
#                                                   1024             0.052038
# {'name': 'comp_large', 'type': 'function'}        64               0.030019
#                                                   128              0.031412
#                                                   256              0.151278
#                                                   512              0.037153
#                                                   1024             0.052016
# {'name': 'comp_small', 'type': 'function'}        64               0.030003
#                                                   128              0.031394
#                                                   256              0.151260
#                                                   512              0.037137
#                                                   1024             0.052001
# {'name': 'correctness_check', 'type': 'function'} 64               0.000058
#                                                   128              0.000061
#                                                   256              0.000082
#                                                   512              0.000063
#                                                   1024             0.000055
# {'name': 'data_init', 'type': 'function'}         64               0.325712
#                                                   128              0.333391
#                                                   256              0.366881
#                                                   512              0.339691
#                                                   1024             0.327019
#
#                                                                              \
#                                                               Max time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.361356
#                                                   128              0.370438
#                                                   256              0.523927
#                                                   512              0.382485
#                                                   1024             0.384723
# {'name': 'comm', 'type': 'function'}              64               0.000081
#                                                   128              0.000085
#                                                   256              0.000108
#                                                   512              0.000082
#                                                   1024             0.000075
# {'name': 'comm_large', 'type': 'function'}        64               0.000068
#                                                   128              0.000072
#                                                   256              0.000095
#                                                   512              0.000070
#                                                   1024             0.000064
# {'name': 'comm_small', 'type': 'function'}        64               0.000054
#                                                   128              0.000057
#                                                   256              0.000082
#                                                   512              0.000055
#                                                   1024             0.000051
# {'name': 'comp', 'type': 'function'}              64               0.030043
#                                                   128              0.031436
#                                                   256              0.151303
#                                                   512              0.037176
#                                                   1024             0.052038
# {'name': 'comp_large', 'type': 'function'}        64               0.030019
#                                                   128              0.031412
#                                                   256              0.151278
#                                                   512              0.037153
#                                                   1024             0.052016
# {'name': 'comp_small', 'type': 'function'}        64               0.030003
#                                                   128              0.031394
#                                                   256              0.151260
#                                                   512              0.037137
#                                                   1024             0.052001
# {'name': 'correctness_check', 'type': 'function'} 64               0.000058
#                                                   128              0.000061
#                                                   256              0.000082
#                                                   512              0.000063
#                                                   1024             0.000055
# {'name': 'data_init', 'type': 'function'}         64               0.325712
#                                                   128              0.333391
#                                                   256              0.366881
#                                                   512              0.339691
#                                                   1024             0.327019
#
#                                                                              \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.361356
#                                                   128              0.370438
#                                                   256              0.523927
#                                                   512              0.382485
#                                                   1024             0.384723
# {'name': 'comm', 'type': 'function'}              64               0.000081
#                                                   128              0.000085
#                                                   256              0.000108
#                                                   512              0.000082
#                                                   1024             0.000075
# {'name': 'comm_large', 'type': 'function'}        64               0.000068
#                                                   128              0.000072
#                                                   256              0.000095
#                                                   512              0.000070
#                                                   1024             0.000064
# {'name': 'comm_small', 'type': 'function'}        64               0.000054
#                                                   128              0.000057
#                                                   256              0.000082
#                                                   512              0.000055
#                                                   1024             0.000051
# {'name': 'comp', 'type': 'function'}              64               0.030043
#                                                   128              0.031436
#                                                   256              0.151303
#                                                   512              0.037176
#                                                   1024             0.052038
# {'name': 'comp_large', 'type': 'function'}        64               0.030019
#                                                   128              0.031412
#                                                   256              0.151278
#                                                   512              0.037153
#                                                   1024             0.052016
# {'name': 'comp_small', 'type': 'function'}        64               0.030003
#                                                   128              0.031394
#                                                   256              0.151260
#                                                   512              0.037137
#                                                   1024             0.052001
# {'name': 'correctness_check', 'type': 'function'} 64               0.000058
#                                                   128              0.000061
#                                                   256              0.000082
#                                                   512              0.000063
#                                                   1024             0.000055
# {'name': 'data_init', 'type': 'function'}         64               0.325712
#                                                   128              0.333391
#                                                   256              0.366881
#                                                   512              0.339691
#                                                   1024             0.327019
#
#                                                                           \
#                                                               Total time
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64            0.361356
#                                                   128           0.370438
#                                                   256           0.523927
#                                                   512           0.382485
#                                                   1024          0.384723
# {'name': 'comm', 'type': 'function'}              64            0.000081
#                                                   128           0.000085
#                                                   256           0.000108
#                                                   512           0.000082
#                                                   1024          0.000075
# {'name': 'comm_large', 'type': 'function'}        64            0.000068
#                                                   128           0.000072
#                                                   256           0.000095
#                                                   512           0.000070
#                                                   1024          0.000064
# {'name': 'comm_small', 'type': 'function'}        64            0.000054
#                                                   128           0.000057
#                                                   256           0.000082
#                                                   512           0.000055
#                                                   1024          0.000051
# {'name': 'comp', 'type': 'function'}              64            0.030043
#                                                   128           0.031436
#                                                   256           0.151303
#                                                   512           0.037176
#                                                   1024          0.052038
# {'name': 'comp_large', 'type': 'function'}        64            0.030019
#                                                   128           0.031412
#                                                   256           0.151278
#                                                   512           0.037153
#                                                   1024          0.052016
# {'name': 'comp_small', 'type': 'function'}        64            0.030003
#                                                   128           0.031394
#                                                   256           0.151260
#                                                   512           0.037137
#                                                   1024          0.052001
# {'name': 'correctness_check', 'type': 'function'} 64            0.000058
#                                                   128           0.000061
#                                                   256           0.000082
#                                                   512           0.000063
#                                                   1024          0.000055
# {'name': 'data_init', 'type': 'function'}         64            0.325712
#                                                   128           0.333391
#                                                   256           0.366881
#                                                   512           0.339691
#                                                   1024          0.327019
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.029989
#                                                   128                  0.031376
#                                                   256                  0.151252
#                                                   512                  0.037115
#                                                   1024                 0.051992
# {'name': 'comm', 'type': 'function'}              64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000004
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_large', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000004
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_small', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000004
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comp', 'type': 'function'}              64                   0.029974
#                                                   128                  0.031361
#                                                   256                  0.151222
#                                                   512                  0.037098
#                                                   1024                 0.051975
# {'name': 'comp_large', 'type': 'function'}        64                   0.029974
#                                                   128                  0.031361
#                                                   256                  0.151222
#                                                   512                  0.037098
#                                                   1024                 0.051975
# {'name': 'comp_small', 'type': 'function'}        64                   0.029974
#                                                   128                  0.031361
#                                                   256                  0.151222
#                                                   512                  0.037098
#                                                   1024                 0.051975
# {'name': 'correctness_check', 'type': 'function'} 64                   0.000007
#                                                   128                  0.000007
#                                                   256                  0.000015
#                                                   512                  0.000008
#                                                   1024                 0.000008
# {'name': 'data_init', 'type': 'function'}         64                   0.000004
#                                                   128                  0.000005
#                                                   256                  0.000011
#                                                   512                  0.000006
#                                                   1024                 0.000006
#
#                                                                                  \
#                                                               Min GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.029989
#                                                   128                  0.031376
#                                                   256                  0.151252
#                                                   512                  0.037115
#                                                   1024                 0.051992
# {'name': 'comm', 'type': 'function'}              64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000004
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_large', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000004
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_small', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000004
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comp', 'type': 'function'}              64                   0.029974
#                                                   128                  0.031361
#                                                   256                  0.151222
#                                                   512                  0.037098
#                                                   1024                 0.051975
# {'name': 'comp_large', 'type': 'function'}        64                   0.029974
#                                                   128                  0.031361
#                                                   256                  0.151222
#                                                   512                  0.037098
#                                                   1024                 0.051975
# {'name': 'comp_small', 'type': 'function'}        64                   0.029974
#                                                   128                  0.031361
#                                                   256                  0.151222
#                                                   512                  0.037098
#                                                   1024                 0.051975
# {'name': 'correctness_check', 'type': 'function'} 64                   0.000007
#                                                   128                  0.000007
#                                                   256                  0.000015
#                                                   512                  0.000008
#                                                   1024                 0.000008
# {'name': 'data_init', 'type': 'function'}         64                   0.000004
#                                                   128                  0.000005
#                                                   256                  0.000011
#                                                   512                  0.000006
#                                                   1024                 0.000006
#
#                                                                                  \
#                                                               Max GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.029989
#                                                   128                  0.031376
#                                                   256                  0.151252
#                                                   512                  0.037115
#                                                   1024                 0.051992
# {'name': 'comm', 'type': 'function'}              64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000004
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_large', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000004
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_small', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000004
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comp', 'type': 'function'}              64                   0.029974
#                                                   128                  0.031361
#                                                   256                  0.151222
#                                                   512                  0.037098
#                                                   1024                 0.051975
# {'name': 'comp_large', 'type': 'function'}        64                   0.029974
#                                                   128                  0.031361
#                                                   256                  0.151222
#                                                   512                  0.037098
#                                                   1024                 0.051975
# {'name': 'comp_small', 'type': 'function'}        64                   0.029974
#                                                   128                  0.031361
#                                                   256                  0.151222
#                                                   512                  0.037098
#                                                   1024                 0.051975
# {'name': 'correctness_check', 'type': 'function'} 64                   0.000007
#                                                   128                  0.000007
#                                                   256                  0.000015
#                                                   512                  0.000008
#                                                   1024                 0.000008
# {'name': 'data_init', 'type': 'function'}         64                   0.000004
#                                                   128                  0.000005
#                                                   256                  0.000011
#                                                   512                  0.000006
#                                                   1024                 0.000006
#
#                                                                               \
#                                                               Total GPU time
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                0.029989
#                                                   128               0.031376
#                                                   256               0.151252
#                                                   512               0.037115
#                                                   1024              0.051992
# {'name': 'comm', 'type': 'function'}              64                0.000003
#                                                   128               0.000003
#                                                   256               0.000004
#                                                   512               0.000003
#                                                   1024              0.000003
# {'name': 'comm_large', 'type': 'function'}        64                0.000003
#                                                   128               0.000003
#                                                   256               0.000004
#                                                   512               0.000003
#                                                   1024              0.000003
# {'name': 'comm_small', 'type': 'function'}        64                0.000003
#                                                   128               0.000003
#                                                   256               0.000004
#                                                   512               0.000003
#                                                   1024              0.000003
# {'name': 'comp', 'type': 'function'}              64                0.029974
#                                                   128               0.031361
#                                                   256               0.151222
#                                                   512               0.037098
#                                                   1024              0.051975
# {'name': 'comp_large', 'type': 'function'}        64                0.029974
#                                                   128               0.031361
#                                                   256               0.151222
#                                                   512               0.037098
#                                                   1024              0.051975
# {'name': 'comp_small', 'type': 'function'}        64                0.029974
#                                                   128               0.031361
#                                                   256               0.151222
#                                                   512               0.037098
#                                                   1024              0.051975
# {'name': 'correctness_check', 'type': 'function'} 64                0.000007
#                                                   128               0.000007
#                                                   256               0.000015
#                                                   512               0.000008
#                                                   1024              0.000008
# {'name': 'data_init', 'type': 'function'}         64                0.000004
#                                                   128               0.000005
#                                                   256               0.000011
#                                                   512               0.000006
#                                                   1024              0.000006
#
#                                                               Randomized  \
#                                                                      nid
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   1
#                                                   128                  1
#                                                   256                  1
#                                                   512                  1
#                                                   1024                 1
# {'name': 'comm', 'type': 'function'}              64                   6
#                                                   128                  6
#                                                   256                  6
#                                                   512                  6
#                                                   1024                 6
# {'name': 'comm_large', 'type': 'function'}        64                   7
#                                                   128                  7
#                                                   256                  7
#                                                   512                  7
#                                                   1024                 7
# {'name': 'comm_small', 'type': 'function'}        64                   8
#                                                   128                  8
#                                                   256                  8
#                                                   512                  8
#                                                   1024                 8
# {'name': 'comp', 'type': 'function'}              64                   3
#                                                   128                  3
#                                                   256                  3
#                                                   512                  3
#                                                   1024                 3
# {'name': 'comp_large', 'type': 'function'}        64                   4
#                                                   128                  4
#                                                   256                  4
#                                                   512                  4
#                                                   1024                 4
# {'name': 'comp_small', 'type': 'function'}        64                   5
#                                                   128                  5
#                                                   256                  5
#                                                   512                  5
#                                                   1024                 5
# {'name': 'correctness_check', 'type': 'function'} 64                   9
#                                                   128                  9
#                                                   256                  9
#                                                   512                  9
#                                                   1024                 9
# {'name': 'data_init', 'type': 'function'}         64                   2
#                                                   128                  2
#                                                   256                  2
#                                                   512                  2
#                                                   1024                 2
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_small', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_small', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'data_init', 'type': 'function'}         64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.444636
#                                                   128              0.381512
#                                                   256              0.428615
#                                                   512              0.408603
#                                                   1024             0.609915
# {'name': 'comm', 'type': 'function'}              64               0.000099
#                                                   128              0.000081
#                                                   256              0.000112
#                                                   512              0.000097
#                                                   1024             0.000148
# {'name': 'comm_large', 'type': 'function'}        64               0.000086
#                                                   128              0.000069
#                                                   256              0.000100
#                                                   512              0.000085
#                                                   1024             0.000136
# {'name': 'comm_small', 'type': 'function'}        64               0.000070
#                                                   128              0.000055
#                                                   256              0.000085
#                                                   512              0.000070
#                                                   1024             0.000121
# {'name': 'comp', 'type': 'function'}              64               0.032461
#                                                   128              0.039146
#                                                   256              0.041965
# ...
#                                                   512                  0.000005
#                                                   1024                 0.000006
#
#                                                                                  \
#                                                               Min GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.033422
#                                                   128                  0.037512
#                                                   256                  0.035450
#                                                   512                  0.036788
#                                                   1024                 0.047446
# {'name': 'comm', 'type': 'function'}              64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000003
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_large', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000003
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_small', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000003
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comp', 'type': 'function'}              64                   0.033405
#                                                   128                  0.037495
#                                                   256                  0.035433
#                                                   512                  0.036772
#                                                   1024                 0.047430
# {'name': 'comp_large', 'type': 'function'}        64                   0.033405
#                                                   128                  0.037495
#                                                   256                  0.035433
#                                                   512                  0.036772
#                                                   1024                 0.047430
# {'name': 'comp_small', 'type': 'function'}        64                   0.033405
#                                                   128                  0.037495
#                                                   256                  0.035433
#                                                   512                  0.036772
#                                                   1024                 0.047430
# {'name': 'correctness_check', 'type': 'function'} 64                   0.000008
#                                                   128                  0.000008
#                                                   256                  0.000008
#                                                   512                  0.000008
#                                                   1024                 0.000007
# {'name': 'data_init', 'type': 'function'}         64                   0.000006
#                                                   128                  0.000006
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000006
#
#                                                                                  \
#                                                               Max GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.033422
#                                                   128                  0.037512
#                                                   256                  0.035450
#                                                   512                  0.036788
#                                                   1024                 0.047446
# {'name': 'comm', 'type': 'function'}              64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000003
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_large', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000003
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comm_small', 'type': 'function'}        64                   0.000003
#                                                   128                  0.000003
#                                                   256                  0.000003
#                                                   512                  0.000003
#                                                   1024                 0.000003
# {'name': 'comp', 'type': 'function'}              64                   0.033405
#                                                   128                  0.037495
#                                                   256                  0.035433
#                                                   512                  0.036772
#                                                   1024                 0.047430
# {'name': 'comp_large', 'type': 'function'}        64                   0.033405
#                                                   128                  0.037495
#                                                   256                  0.035433
#                                                   512                  0.036772
#                                                   1024                 0.047430
# {'name': 'comp_small', 'type': 'function'}        64                   0.033405
#                                                   128                  0.037495
#                                                   256                  0.035433
#                                                   512                  0.036772
#                                                   1024                 0.047430
# {'name': 'correctness_check', 'type': 'function'} 64                   0.000008
#                                                   128                  0.000008
#                                                   256                  0.000008
#                                                   512                  0.000008
#                                                   1024                 0.000007
# {'name': 'data_init', 'type': 'function'}         64                   0.000006
#                                                   128                  0.000006
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000006
#
#                                                                               \
#                                                               Total GPU time
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                0.033422
#                                                   128               0.037512
#                                                   256               0.035450
#                                                   512               0.036788
#                                                   1024              0.047446
# {'name': 'comm', 'type': 'function'}              64                0.000003
#                                                   128               0.000003
#                                                   256               0.000003
#                                                   512               0.000003
#                                                   1024              0.000003
# {'name': 'comm_large', 'type': 'function'}        64                0.000003
#                                                   128               0.000003
#                                                   256               0.000003
#                                                   512               0.000003
#                                                   1024              0.000003
# {'name': 'comm_small', 'type': 'function'}        64                0.000003
#                                                   128               0.000003
#                                                   256               0.000003
#                                                   512               0.000003
#                                                   1024              0.000003
# {'name': 'comp', 'type': 'function'}              64                0.033405
#                                                   128               0.037495
#                                                   256               0.035433
#                                                   512               0.036772
#                                                   1024              0.047430
# {'name': 'comp_large', 'type': 'function'}        64                0.033405
#                                                   128               0.037495
#                                                   256               0.035433
#                                                   512               0.036772
#                                                   1024              0.047430
# {'name': 'comp_small', 'type': 'function'}        64                0.033405
#                                                   128               0.037495
#                                                   256               0.035433
#                                                   512               0.036772
#                                                   1024              0.047430
# {'name': 'correctness_check', 'type': 'function'} 64                0.000008
#                                                   128               0.000008
#                                                   256               0.000008
#                                                   512               0.000008
#                                                   1024              0.000007
# {'name': 'data_init', 'type': 'function'}         64                0.000006
#                                                   128               0.000006
#                                                   256               0.000005
#                                                   512               0.000005
#                                                   1024              0.000006
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                        main
#                                                   128                       main
#                                                   256                       main
#                                                   512                       main
#                                                   1024                      main
# {'name': 'comm', 'type': 'function'}              64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
# {'name': 'comm_large', 'type': 'function'}        64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
# {'name': 'comm_small', 'type': 'function'}        64                  comm_small
#                                                   128                 comm_small
#                                                   256                 comm_small
#                                                   512                 comm_small
#                                                   1024                comm_small
# {'name': 'comp', 'type': 'function'}              64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
# {'name': 'comp_large', 'type': 'function'}        64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
# {'name': 'comp_small', 'type': 'function'}        64                  comp_small
#                                                   128                 comp_small
#                                                   256                 comp_small
#                                                   512                 comp_small
#                                                   1024                comp_small
# {'name': 'correctness_check', 'type': 'function'} 64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %%
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Avg GPU time/rank"), ('1% Perturbed', "Min GPU time/rank"),('1% Perturbed', "Total GPU time"), ('1% Perturbed', "Max GPU time/rank"),
                                                  ("node", ""), ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Avg GPU time/rank"), ('Randomized', "Min GPU time/rank"),('Randomized', "Total GPU time"), ('Randomized', "Max GPU time/rank"),
                                                  ("node", ""), ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Avg GPU time/rank"), ('Reverse Sorted', "Min GPU time/rank"),('Reverse Sorted', "Total GPU time"), ('Reverse Sorted', "Max GPU time/rank"),
                                                  ("node", ""), ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Avg GPU time/rank"), ('Sorted', "Min GPU time/rank"),('Sorted', "Total GPU time"), ('Sorted', "Max GPU time/rank")
                                                 ], axis=1)

# %%
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
ctk.dataframe
# Out:
#                                1% Perturbed    Randomized Reverse Sorted  \
#                               Avg time/rank Avg time/rank  Avg time/rank
# name              num_threads
# main              64               0.361356      0.444636       0.379552
#                   128              0.370438      0.381512       0.372986
#                   256              0.523927      0.428615       0.383361
#                   512              0.382485      0.408603       0.373932
#                   1024             0.384723      0.609915       0.379839
# comm              64               0.000081      0.000099       0.000081
#                   128              0.000085      0.000081       0.000083
#                   256              0.000108      0.000112       0.000087
#                   512              0.000082      0.000097       0.000085
#                   1024             0.000075      0.000148       0.000074
# comm_large        64               0.000068      0.000086       0.000069
#                   128              0.000072      0.000069       0.000071
#                   256              0.000095      0.000100       0.000075
#                   512              0.000070      0.000085       0.000072
#                   1024             0.000064      0.000136       0.000062
# comm_small        64               0.000054      0.000070       0.000055
#                   128              0.000057      0.000055       0.000057
#                   256              0.000082      0.000085       0.000061
#                   512              0.000055      0.000070       0.000058
#                   1024             0.000051      0.000121       0.000050
# comp              64               0.030043      0.032461       0.036949
#                   128              0.031436      0.039146       0.033731
#                   256              0.151303      0.041965       0.037223
#                   512              0.037176      0.033960       0.038821
#                   1024             0.052038      0.202878       0.045917
# comp_large        64               0.030019      0.032422       0.036925
#                   128              0.031412      0.039120       0.033706
#                   256              0.151278      0.041939       0.037198
#                   512              0.037153      0.033921       0.038796
#                   1024             0.052016      0.202853       0.045895
# comp_small        64               0.030003      0.032396       0.036908
#                   128              0.031394      0.039104       0.033689
#                   256              0.151260      0.041923       0.037182
#                   512              0.037137      0.033896       0.038778
#                   1024             0.052001      0.202837       0.045880
# correctness_check 64               0.000058      0.000061       0.000063
#                   128              0.000061      0.000062       0.000060
#                   256              0.000082      0.000065       0.000058
#                   512              0.000063      0.000059       0.000063
#                   1024             0.000055      0.000081       0.000051
# data_init         64               0.325712      0.406226       0.336986
#                   128              0.333391      0.336747       0.333660
#                   256              0.366881      0.380579       0.340491
#                   512              0.339691      0.368960       0.329478
#                   1024             0.327019      0.400847       0.328221
#
#                                      Sorted
#                               Avg time/rank
# name              num_threads
# main              64               0.472675
#                   128              0.377296
#                   256              0.377582
#                   512              0.381697
#                   1024             0.401048
# comm              64               0.000100
#                   128              0.000081
#                   256              0.000089
#                   512              0.000082
#                   1024             0.000093
# comm_large        64               0.000088
#                   128              0.000069
#                   256              0.000077
#                   512              0.000070
#                   1024             0.000082
# comm_small        64               0.000072
#                   128              0.000055
#                   256              0.000063
#                   512              0.000056
#                   1024             0.000068
# comp              64               0.033475
#                   128              0.037564
#                   256              0.035509
#                   512              0.036844
#                   1024             0.047493
# comp_large        64               0.033450
#                   128              0.037540
#                   256              0.035485
#                   512              0.036819
#                   1024             0.047470
# comp_small        64               0.033434
#                   128              0.037524
#                   256              0.035466
#                   512              0.036803
#                   1024             0.047456
# correctness_check 64               0.000062
#                   128              0.000060
#                   256              0.000065
#                   512              0.000062
#                   1024             0.000055
# data_init         64               0.433334
#                   128              0.334094
#                   256              0.336411
#                   512              0.339254
#                   1024             0.348085

# %%
main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]

# %%
for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Threads')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'CUDA Merge Sort - Strong Scaling for 2^10 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Strong Scaling for 2^11 Elements

# %%
tk = th.Thicket.from_caliperreader(glob("*s2048*.cali"))
tk.statsframe.dataframe["time"] = 1
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_threads'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Avg GPU time/rank"), ('1% Perturbed', "Min GPU time/rank"),('1% Perturbed', "Total GPU time"), ('1% Perturbed', "Max GPU time/rank"),
                                                  ("node", ""), ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Avg GPU time/rank"), ('Randomized', "Min GPU time/rank"),('Randomized', "Total GPU time"), ('Randomized', "Max GPU time/rank"),
                                                  ("node", ""), ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Avg GPU time/rank"), ('Reverse Sorted', "Min GPU time/rank"),('Reverse Sorted', "Total GPU time"), ('Reverse Sorted', "Max GPU time/rank"),
                                                  ("node", ""), ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Avg GPU time/rank"), ('Sorted', "Min GPU time/rank"),('Sorted', "Total GPU time"), ('Sorted', "Max GPU time/rank")
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]

for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Threads')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'CUDA Merge Sort - Strong Scaling for 2^11 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b0ac61aee80>, 'Randomized': <thicket.thicket.Thicket object at 0x2b0ac6461a00>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b0ac6672940>, 'Sorted': <thicket.thicket.Thicket object at 0x2b0ac6612fa0>}

# %% [markdown]
# # Strong Scaling for 2^12

# %%
tk = th.Thicket.from_caliperreader(glob("*s4096*.cali"))
tk.statsframe.dataframe["time"] = 1
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_threads'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Avg GPU time/rank"), ('1% Perturbed', "Min GPU time/rank"),('1% Perturbed', "Total GPU time"), ('1% Perturbed', "Max GPU time/rank"),
                                                  ("node", ""), ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Avg GPU time/rank"), ('Randomized', "Min GPU time/rank"),('Randomized', "Total GPU time"), ('Randomized', "Max GPU time/rank"),
                                                  ("node", ""), ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Avg GPU time/rank"), ('Reverse Sorted', "Min GPU time/rank"),('Reverse Sorted', "Total GPU time"), ('Reverse Sorted', "Max GPU time/rank"),
                                                  ("node", ""), ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Avg GPU time/rank"), ('Sorted', "Min GPU time/rank"),('Sorted', "Total GPU time"), ('Sorted', "Max GPU time/rank")
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]

for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Threads')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'CUDA Merge Sort - Strong Scaling for 2^12 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b0ac64a1640>, 'Randomized': <thicket.thicket.Thicket object at 0x2b0ac6100280>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b0ac514c190>, 'Sorted': <thicket.thicket.Thicket object at 0x2b0ac649b340>}

# %% [markdown]
# # Strong Scaling for 2^13

# %%
tk = th.Thicket.from_caliperreader(glob("*s8192*.cali"))
tk.statsframe.dataframe["time"] = 1
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_threads'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Avg GPU time/rank"), ('1% Perturbed', "Min GPU time/rank"),('1% Perturbed', "Total GPU time"), ('1% Perturbed', "Max GPU time/rank"),
                                                  ("node", ""), ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Avg GPU time/rank"), ('Randomized', "Min GPU time/rank"),('Randomized', "Total GPU time"), ('Randomized', "Max GPU time/rank"),
                                                  ("node", ""), ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Avg GPU time/rank"), ('Reverse Sorted', "Min GPU time/rank"),('Reverse Sorted', "Total GPU time"), ('Reverse Sorted', "Max GPU time/rank"),
                                                  ("node", ""), ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Avg GPU time/rank"), ('Sorted', "Min GPU time/rank"),('Sorted', "Total GPU time"), ('Sorted', "Max GPU time/rank")
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large",  "comp", "comp_large", "correctness_check", "data_init"]

for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Threads')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'CUDA Merge Sort - Strong Scaling for 2^13 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b0ac6290d90>, 'Randomized': <thicket.thicket.Thicket object at 0x2b0ac50d6970>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b0ac64f78b0>, 'Sorted': <thicket.thicket.Thicket object at 0x2b0ac612f4f0>}

# %% [markdown]
# # Strong Scaling for 2^14

# %%
tk = th.Thicket.from_caliperreader(glob("*s16384*.cali"))
tk.statsframe.dataframe["time"] = 1
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_threads'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Avg GPU time/rank"), ('1% Perturbed', "Min GPU time/rank"),('1% Perturbed', "Total GPU time"), ('1% Perturbed', "Max GPU time/rank"),
                                                  ("node", ""), ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Avg GPU time/rank"), ('Randomized', "Min GPU time/rank"),('Randomized', "Total GPU time"), ('Randomized', "Max GPU time/rank"),
                                                  ("node", ""), ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Avg GPU time/rank"), ('Reverse Sorted', "Min GPU time/rank"),('Reverse Sorted', "Total GPU time"), ('Reverse Sorted', "Max GPU time/rank"),
                                                  ("node", ""), ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Avg GPU time/rank"), ('Sorted', "Min GPU time/rank"),('Sorted', "Total GPU time"), ('Sorted', "Max GPU time/rank")
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]

for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Threads')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'CUDA Merge Sort - Strong Scaling for 2^14 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b0ac6733370>, 'Randomized': <thicket.thicket.Thicket object at 0x2b0ac64dd9d0>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b0ac67b34c0>, 'Sorted': <thicket.thicket.Thicket object at 0x2b0ac67263a0>}

# %% [markdown]
# # Strong Scaling for 2^15

# %%
tk = th.Thicket.from_caliperreader(glob("*s32768*.cali"))
tk.statsframe.dataframe["time"] = 1
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_threads'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Avg GPU time/rank"), ('1% Perturbed', "Min GPU time/rank"),('1% Perturbed', "Total GPU time"), ('1% Perturbed', "Max GPU time/rank"),
                                                  ("node", ""), ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Avg GPU time/rank"), ('Randomized', "Min GPU time/rank"),('Randomized', "Total GPU time"), ('Randomized', "Max GPU time/rank"),
                                                  ("node", ""), ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Avg GPU time/rank"), ('Reverse Sorted', "Min GPU time/rank"),('Reverse Sorted', "Total GPU time"), ('Reverse Sorted', "Max GPU time/rank"),
                                                  ("node", ""), ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Avg GPU time/rank"), ('Sorted', "Min GPU time/rank"),('Sorted', "Total GPU time"), ('Sorted', "Max GPU time/rank")
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]

for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Threads')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'CUDA Merge Sort - Strong Scaling for 2^15 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b0ac613fdc0>, 'Randomized': <thicket.thicket.Thicket object at 0x2b0ac622dc70>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b0ac661ddf0>, 'Sorted': <thicket.thicket.Thicket object at 0x2b0ac50ce0d0>}

# %% [markdown]
# # Strong Scaling for 2^16

# %%
tk = th.Thicket.from_caliperreader(glob("*s65536*.cali"))
tk.statsframe.dataframe["time"] = 1
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_threads'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Avg GPU time/rank"), ('1% Perturbed', "Min GPU time/rank"),('1% Perturbed', "Total GPU time"), ('1% Perturbed', "Max GPU time/rank"),
                                                  ("node", ""), ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Avg GPU time/rank"), ('Randomized', "Min GPU time/rank"),('Randomized', "Total GPU time"), ('Randomized', "Max GPU time/rank"),
                                                  ("node", ""), ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Avg GPU time/rank"), ('Reverse Sorted', "Min GPU time/rank"),('Reverse Sorted', "Total GPU time"), ('Reverse Sorted', "Max GPU time/rank"),
                                                  ("node", ""), ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Avg GPU time/rank"), ('Sorted', "Min GPU time/rank"),('Sorted', "Total GPU time"), ('Sorted', "Max GPU time/rank")
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]

for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Threads')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'CUDA Merge Sort - Strong Scaling for 2^16 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b0ac6187b20>, 'Randomized': <thicket.thicket.Thicket object at 0x2b0ac66699a0>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b0ac66befd0>, 'Sorted': <thicket.thicket.Thicket object at 0x2b0ac6416340>}
