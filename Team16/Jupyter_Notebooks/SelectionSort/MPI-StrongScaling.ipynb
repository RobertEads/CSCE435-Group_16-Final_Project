\
# node                                              profile
# {'name': 'main', 'type': 'function'}              159906272   regionprofile
#                                                   953174584   regionprofile
#                                                   1071778005  regionprofile
#                                                   1087836440  regionprofile
#                                                   1327331677  regionprofile
#                                                   1424922791  regionprofile
#                                                   1438853916  regionprofile
#                                                   1543041692  regionprofile
#                                                   1623898012  regionprofile
#                                                   1827980037  regionprofile
#                                                   1894185536  regionprofile
#                                                   1924649228  regionprofile
#                                                   1957635544  regionprofile
#                                                   2058892351  regionprofile
#                                                   2070791099  regionprofile
#                                                   2107736924  regionprofile
#                                                   2136595877  regionprofile
#                                                   2156774464  regionprofile
#                                                   2199133481  regionprofile
#                                                   2241141572  regionprofile
#                                                   2322971876  regionprofile
#                                                   2372782952  regionprofile
#                                                   2619958893  regionprofile
#                                                   2824179464  regionprofile
#                                                   2829002560  regionprofile
#                                                   2859419785  regionprofile
#                                                   3093073098  regionprofile
#                                                   3111480413  regionprofile
#                                                   3550702409  regionprofile
#                                                   3565458465  regionprofile
#                                                   3603672664  regionprofile
#                                                   3775748758  regionprofile
#                                                   3924219113  regionprofile
#                                                   3929308676  regionprofile
#                                                   3991634214  regionprofile
#                                                   4241647462  regionprofile
# {'name': 'comm', 'type': 'function'}              159906272   regionprofile
#                                                   953174584   regionprofile
#                                                   1071778005  regionprofile
#                                                   1087836440  regionprofile
#                                                   1327331677  regionprofile
#                                                   1424922791  regionprofile
#                                                   1438853916  regionprofile
#                                                   1543041692  regionprofile
#                                                   1623898012  regionprofile
#                                                   1827980037  regionprofile
#                                                   1894185536  regionprofile
#                                                   1924649228  regionprofile
#                                                   1957635544  regionprofile
#                                                   2058892351  regionprofile
#                                                   2070791099  regionprofile
#                                                   2107736924  regionprofile
#                                                   2136595877  regionprofile
#                                                   2156774464  regionprofile
#                                                   2199133481  regionprofile
#                                                   2241141572  regionprofile
#                                                   2322971876  regionprofile
#                                                   2372782952  regionprofile
#                                                   2619958893  regionprofile
#                                                   2824179464  regionprofile
#                                                   2829002560  regionprofile
#                                                   2859419785  regionprofile
#                                                   3093073098  regionprofile
#                                                   3111480413  regionprofile
#                                                   3550702409  regionprofile
#                                                   3565458465  regionprofile
#                                                   3603672664  regionprofile
#                                                   3775748758  regionprofile
#                                                   3924219113  regionprofile
#                                                   3929308676  regionprofile
#                                                   3991634214  regionprofile
#                                                   4241647462  regionprofile
# {'name': 'comm_large', 'type': 'function'}        159906272   regionprofile
#                                                   953174584   regionprofile
#                                                   1071778005  regionprofile
#                                                   1087836440  regionprofile
#                                                   1327331677  regionprofile
#                                                   1424922791  regionprofile
#                                                   1438853916  regionprofile
#                                                   1543041692  regionprofile
#                                                   1623898012  regionprofile
#                                                   1827980037  regionprofile
#                                                   1894185536  regionprofile
#                                                   1924649228  regionprofile
#                                                   1957635544  regionprofile
#                                                   2058892351  regionprofile
#                                                   2070791099  regionprofile
#                                                   2107736924  regionprofile
#                                                   2136595877  regionprofile
#                                                   2156774464  regionprofile
#                                                   2199133481  regionprofile
#                                                   2241141572  regionprofile
#                                                   2322971876  regionprofile
#                                                   2372782952  regionprofile
#                                                   2619958893  regionprofile
#                                                   2824179464  regionprofile
#                                                   2829002560  regionprofile
#                                                   2859419785  regionprofile
#                                                   3093073098  regionprofile
#                                                   3111480413  regionprofile
#                                                   3550702409  regionprofile
#                                                   3565458465  regionprofile
#                                                   3603672664  regionprofile
#                                                   3775748758  regionprofile
#                                                   3924219113  regionprofile
#                                                   3929308676  regionprofile
#                                                   3991634214  regionprofile
#                                                   4241647462  regionprofile
# {'name': 'comp', 'type': 'function'}              159906272   regionprofile
#                                                   953174584   regionprofile
#                                                   1071778005  regionprofile
#                                                   1087836440  regionprofile
#                                                   1327331677  regionprofile
#                                                   1424922791  regionprofile
#                                                   1438853916  regionprofile
#                                                   1543041692  regionprofile
#                                                   1623898012  regionprofile
#                                                   1827980037  regionprofile
#                                                   1894185536  regionprofile
#                                                   1924649228  regionprofile
#                                                   1957635544  regionprofile
#                                                   2058892351  regionprofile
#                                                   2070791099  regionprofile
#                                                   2107736924  regionprofile
#                                                   2136595877  regionprofile
#                                                   2156774464  regionprofile
#                                                   2199133481  regionprofile
#                                                   2241141572  regionprofile
#                                                   2322971876  regionprofile
#                                                   2372782952  regionprofile
#                                                   2619958893  regionprofile
#                                                   2824179464  regionprofile
#                                                   2829002560  regionprofile
#                                                   2859419785  regionprofile
#                                                   3093073098  regionprofile
#                                                   3111480413  regionprofile
#                                                   3550702409  regionprofile
#                                                   3565458465  regionprofile
#                                                   3603672664  regionprofile
#                                                   3775748758  regionprofile
#                                                   3924219113  regionprofile
#                                                   3929308676  regionprofile
#                                                   3991634214  regionprofile
#                                                   4241647462  regionprofile
# {'name': 'comp_large', 'type': 'function'}        159906272   regionprofile
#                                                   953174584   regionprofile
#                                                   1071778005  regionprofile
#                                                   1087836440  regionprofile
#                                                   1327331677  regionprofile
#                                                   1424922791  regionprofile
#                                                   1438853916  regionprofile
#                                                   1543041692  regionprofile
#                                                   1623898012  regionprofile
#                                                   1827980037  regionprofile
#                                                   1894185536  regionprofile
#                                                   1924649228  regionprofile
#                                                   1957635544  regionprofile
#                                                   2058892351  regionprofile
#                                                   2070791099  regionprofile
#                                                   2107736924  regionprofile
#                                                   2136595877  regionprofile
#                                                   2156774464  regionprofile
#                                                   2199133481  regionprofile
#                                                   2241141572  regionprofile
#                                                   2322971876  regionprofile
#                                                   2372782952  regionprofile
#                                                   2619958893  regionprofile
#                                                   2824179464  regionprofile
#                                                   2829002560  regionprofile
#                                                   2859419785  regionprofile
#                                                   3093073098  regionprofile
#                                                   3111480413  regionprofile
#                                                   3550702409  regionprofile
#                                                   3565458465  regionprofile
#                                                   3603672664  regionprofile
#                                                   3775748758  regionprofile
#                                                   3924219113  regionprofile
#                                                   3929308676  regionprofile
#                                                   3991634214  regionprofile
#                                                   4241647462  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 159906272   regionprofile
#                                                   953174584   regionprofile
#                                                   1071778005  regionprofile
#                                                   1087836440  regionprofile
#                                                   1327331677  regionprofile
#                                                   1424922791  regionprofile
#                                                   1438853916  regionprofile
#                                                   1543041692  regionprofile
#                                                   1623898012  regionprofile
#                                                   1827980037  regionprofile
#                                                   1894185536  regionprofile
#                                                   1924649228  regionprofile
#                                                   1957635544  regionprofile
#                                                   2058892351  regionprofile
#                                                   2070791099  regionprofile
#                                                   2107736924  regionprofile
#                                                   2136595877  regionprofile
#                                                   2156774464  regionprofile
#                                                   2199133481  regionprofile
#                                                   2241141572  regionprofile
#                                                   2322971876  regionprofile
#                                                   2372782952  regionprofile
#                                                   2619958893  regionprofile
#                                                   2824179464  regionprofile
#                                                   2829002560  regionprofile
#                                                   2859419785  regionprofile
#                                                   3093073098  regionprofile
#                                                   3111480413  regionprofile
#                                                   3550702409  regionprofile
#                                                   3565458465  regionprofile
#                                                   3603672664  regionprofile
#                                                   3775748758  regionprofile
#                                                   3924219113  regionprofile
#                                                   3929308676  regionprofile
#                                                   3991634214  regionprofile
#                                                   4241647462  regionprofile
# {'name': 'data_init', 'type': 'function'}         159906272   regionprofile
#                                                   953174584   regionprofile
#                                                   1071778005  regionprofile
#                                                   1087836440  regionprofile
#                                                   1327331677  regionprofile
#                                                   1424922791  regionprofile
#                                                   1438853916  regionprofile
#                                                   1543041692  regionprofile
#                                                   1623898012  regionprofile
#                                                   1827980037  regionprofile
#                                                   1894185536  regionprofile
#                                                   1924649228  regionprofile
#                                                   1957635544  regionprofile
#                                                   2058892351  regionprofile
#                                                   2070791099  regionprofile
#                                                   2107736924  regionprofile
#                                                   2136595877  regionprofile
#                                                   2156774464  regionprofile
#                                                   2199133481  regionprofile
#                                                   2241141572  regionprofile
#                                                   2322971876  regionprofile
#                                                   2372782952  regionprofile
#                                                   2619958893  regionprofile
#                                                   2824179464  regionprofile
#                                                   2829002560  regionprofile
#                                                   2859419785  regionprofile
#                                                   3093073098  regionprofile
#                                                   3111480413  regionprofile
#                                                   3550702409  regionprofile
#                                                   3565458465  regionprofile
#                                                   3603672664  regionprofile
#                                                   3775748758  regionprofile
#                                                   3924219113  regionprofile
#                                                   3929308676  regionprofile
#                                                   3991634214  regionprofile
#                                                   4241647462  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              159906272        0.005364
#                                                   953174584        0.005373
#                                                   1071778005       0.005357
#                                                   1087836440       0.005361
#                                                   1327331677       0.005571
#                                                   1424922791       0.005350
#                                                   1438853916       0.005346
#                                                   1543041692       0.005367
#                                                   1623898012       0.005341
#                                                   1827980037       0.005696
#                                                   1894185536       0.005885
#                                                   1924649228       0.005345
#                                                   1957635544       0.005398
#                                                   2058892351       0.005397
#                                                   2070791099       0.008731
#                                                   2107736924       0.005358
#                                                   2136595877       0.005380
#                                                   2156774464       0.008606
#                                                   2199133481       0.005353
#                                                   2241141572       0.005365
#                                                   2322971876       0.005328
#                                                   2372782952       0.005363
#                                                   2619958893       0.005345
#                                                   2824179464       0.005357
#                                                   2829002560       0.011260
#                                                   2859419785       0.005442
#                                                   3093073098       0.005400
#                                                   3111480413       0.005374
#                                                   2372782952         comp_large
#                                                   2619958893         comp_large
#                                                   2824179464         comp_large
#                                                   2829002560         comp_large
#                                                   2859419785         comp_large
#                                                   3093073098         comp_large
#                                                   3111480413         comp_large
#                                                   3550702409         comp_large
#                                                   3565458465         comp_large
#                                                   3603672664         comp_large
#                                                   3775748758         comp_large
#                                                   3924219113         comp_large
#                                                   3929308676         comp_large
#                                                   3991634214         comp_large
#                                                   4241647462         comp_large
# {'name': 'correctness_check', 'type': 'function'} 159906272   correctness_check
#                                                   953174584   correctness_check
#                                                   1071778005  correctness_check
#                                                   1087836440  correctness_check
#                                                   1327331677  correctness_check
#                                                   1424922791  correctness_check
#                                                   1438853916  correctness_check
#                                                   1543041692  correctness_check
#                                                   1623898012  correctness_check
#                                                   1827980037  correctness_check
#                                                   1894185536  correctness_check
#                                                   1924649228  correctness_check
#                                                   1957635544  correctness_check
#                                                   2058892351  correctness_check
#                                                   2070791099  correctness_check
#                                                   2107736924  correctness_check
#                                                   2136595877  correctness_check
#                                                   2156774464  correctness_check
#                                                   2199133481  correctness_check
#                                                   2241141572  correctness_check
#                                                   2322971876  correctness_check
#                                                   2372782952  correctness_check
#                                                   2619958893  correctness_check
#                                                   2824179464  correctness_check
#                                                   2829002560  correctness_check
#                                                   2859419785  correctness_check
#                                                   3093073098  correctness_check
#                                                   3111480413  correctness_check
#                                                   3550702409  correctness_check
#                                                   3565458465  correctness_check
#                                                   3603672664  correctness_check
#                                                   3775748758  correctness_check
#                                                   3924219113  correctness_check
#                                                   3929308676  correctness_check
#                                                   3991634214  correctness_check
#                                                   4241647462  correctness_check
# {'name': 'data_init', 'type': 'function'}         159906272           data_init
#                                                   953174584           data_init
#                                                   1071778005          data_init
#                                                   1087836440          data_init
#                                                   1327331677          data_init
#                                                   1424922791          data_init
#                                                   1438853916          data_init
#                                                   1543041692          data_init
#                                                   1623898012          data_init
#                                                   1827980037          data_init
#                                                   1894185536          data_init
#                                                   1924649228          data_init
#                                                   1957635544          data_init
#                                                   2058892351          data_init
#                                                   2070791099          data_init
#                                                   2107736924          data_init
#                                                   2136595877          data_init
#                                                   2156774464          data_init
#                                                   2199133481          data_init
#                                                   2241141572          data_init
#                                                   2322971876          data_init
#                                                   2372782952          data_init
#                                                   2619958893          data_init
#                                                   2824179464          data_init
#                                                   2829002560          data_init
#                                                   2859419785          data_init
#                                                   3093073098          data_init
#                                                   3111480413          data_init
#                                                   3550702409          data_init
#                                                   3565458465          data_init
#                                                   3603672664          data_init
#                                                   3775748758          data_init
#                                                   3924219113          data_init
#                                                   3929308676          data_init
#                                                   3991634214          data_init
#                                                   4241647462          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 159906272            2.11.0-dev              64
# 953174584            2.11.0-dev              32
# 1071778005           2.11.0-dev              64
# 1087836440           2.11.0-dev             512
# 1327331677           2.11.0-dev               2
# 1424922791           2.11.0-dev              32
# 1438853916           2.11.0-dev              16
# 1543041692           2.11.0-dev               8
# 1623898012           2.11.0-dev             512
# 1827980037           2.11.0-dev               4
# 1894185536           2.11.0-dev               2
# 1924649228           2.11.0-dev             512
# 1957635544           2.11.0-dev               8
# 2058892351           2.11.0-dev               2
# 2070791099           2.11.0-dev              16
# 2107736924           2.11.0-dev              64
# 2136595877           2.11.0-dev             128
# 2156774464           2.11.0-dev              32
# 2199133481           2.11.0-dev             128
# 2241141572           2.11.0-dev             128
# 2322971876           2.11.0-dev              32
# 2372782952           2.11.0-dev             128
# 2619958893           2.11.0-dev             256
# 2824179464           2.11.0-dev              64
# 2829002560           2.11.0-dev               8
# 2859419785           2.11.0-dev               4
# 3093073098           2.11.0-dev               4
# 3111480413           2.11.0-dev              16
# 3550702409           2.11.0-dev               4
# 3565458465           2.11.0-dev             256
# 3603672664           2.11.0-dev             256
# 3775748758           2.11.0-dev              16
# 3924219113           2.11.0-dev             256
# 3929308676           2.11.0-dev               2
# 3991634214           2.11.0-dev               8
# 4241647462           2.11.0-dev             512
#
#                                                  spot.metrics  \
# profile
# 159906272   min#inclusive#sum#time.duration,max#inclusive#...
# 953174584   min#inclusive#sum#time.duration,max#inclusive#...
# 1071778005  min#inclusive#sum#time.duration,max#inclusive#...
# 1087836440  min#inclusive#sum#time.duration,max#inclusive#...
# 1327331677  min#inclusive#sum#time.duration,max#inclusive#...
# 1424922791  min#inclusive#sum#time.duration,max#inclusive#...
# 1438853916  min#inclusive#sum#time.duration,max#inclusive#...
# 1543041692  min#inclusive#sum#time.duration,max#inclusive#...
# 1623898012  min#inclusive#sum#time.duration,max#inclusive#...
# 1827980037  min#inclusive#sum#time.duration,max#inclusive#...
# 1894185536  min#inclusive#sum#time.duration,max#inclusive#...
# 1924649228  min#inclusive#sum#time.duration,max#inclusive#...
# 1957635544  min#inclusive#sum#time.duration,max#inclusive#...
# 2058892351  min#inclusive#sum#time.duration,max#inclusive#...
# 2070791099  min#inclusive#sum#time.duration,max#inclusive#...
# 2107736924  min#inclusive#sum#time.duration,max#inclusive#...
# 2136595877  min#inclusive#sum#time.duration,max#inclusive#...
# 2156774464  min#inclusive#sum#time.duration,max#inclusive#...
# 2199133481  min#inclusive#sum#time.duration,max#inclusive#...
# 2241141572  min#inclusive#sum#time.duration,max#inclusive#...
# 2322971876  min#inclusive#sum#time.duration,max#inclusive#...
# 2372782952  min#inclusive#sum#time.duration,max#inclusive#...
# 2619958893  min#inclusive#sum#time.duration,max#inclusive#...
# 2824179464  min#inclusive#sum#time.duration,max#inclusive#...
# 2829002560  min#inclusive#sum#time.duration,max#inclusive#...
# 2859419785  min#inclusive#sum#time.duration,max#inclusive#...
# 3093073098  min#inclusive#sum#time.duration,max#inclusive#...
# 3111480413  min#inclusive#sum#time.duration,max#inclusive#...
# 3550702409  min#inclusive#sum#time.duration,max#inclusive#...
# 3565458465  min#inclusive#sum#time.duration,max#inclusive#...
# 3603672664  min#inclusive#sum#time.duration,max#inclusive#...
# 3775748758  min#inclusive#sum#time.duration,max#inclusive#...
# 3924219113  min#inclusive#sum#time.duration,max#inclusive#...
# 3929308676  min#inclusive#sum#time.duration,max#inclusive#...
# 3991634214  min#inclusive#sum#time.duration,max#inclusive#...
# 4241647462  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 159906272                                             2
# 953174584                                             2
# 1071778005                                            2
# 1087836440                                            2
# 1327331677                                            2
# 1424922791                                            2
# 1438853916                                            2
# 1543041692                                            2
# 1623898012                                            2
# 1827980037                                            2
# 1894185536                                            2
# 1924649228                                            2
# 1957635544                                            2
# 2058892351                                            2
# 2070791099                                            2
# 2107736924                                            2
# 2136595877                                            2
# 2156774464                                            2
# 2199133481                                            2
# 2241141572                                            2
# 2322971876                                            2
# 2372782952                                            2
# 2619958893                                            2
# 2824179464                                            2
# 2829002560                                            2
# 2859419785                                            2
# 3093073098                                            2
# 3111480413                                            2
# 3550702409                                            2
# 3565458465                                            2
# 3603672664                                            2
# 3775748758                                            2
# 3924219113                                            2
# 3929308676                                            2
# 3991634214                                            2
# 4241647462                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 159906272   time.variance,node.order  regionprofile         spot
# 953174584   time.variance,node.order  regionprofile         spot
# 1071778005  time.variance,node.order  regionprofile         spot
# 1087836440  time.variance,node.order  regionprofile         spot
# 1327331677  time.variance,node.order  regionprofile         spot
# 1424922791  time.variance,node.order  regionprofile         spot
# 1438853916  time.variance,node.order  regionprofile         spot
# 1543041692  time.variance,node.order  regionprofile         spot
# 1623898012  time.variance,node.order  regionprofile         spot
# 1827980037  time.variance,node.order  regionprofile         spot
# 1894185536  time.variance,node.order  regionprofile         spot
# 1924649228  time.variance,node.order  regionprofile         spot
# 1957635544  time.variance,node.order  regionprofile         spot
# 2058892351  time.variance,node.order  regionprofile         spot
# 2070791099  time.variance,node.order  regionprofile         spot
# 2107736924  time.variance,node.order  regionprofile         spot
# 2136595877  time.variance,node.order  regionprofile         spot
# 2156774464  time.variance,node.order  regionprofile         spot
# 2199133481  time.variance,node.order  regionprofile         spot
# 2241141572  time.variance,node.order  regionprofile         spot
# 2322971876  time.variance,node.order  regionprofile         spot
# 2372782952  time.variance,node.order  regionprofile         spot
# 2619958893  time.variance,node.order  regionprofile         spot
# 2824179464  time.variance,node.order  regionprofile         spot
# 2829002560  time.variance,node.order  regionprofile         spot
# 2859419785  time.variance,node.order  regionprofile         spot
# 3093073098  time.variance,node.order  regionprofile         spot
# 3111480413  time.variance,node.order  regionprofile         spot
# 3550702409  time.variance,node.order  regionprofile         spot
# 3565458465  time.variance,node.order  regionprofile         spot
# 3603672664  time.variance,node.order  regionprofile         spot
# 3775748758  time.variance,node.order  regionprofile         spot
# 3924219113  time.variance,node.order  regionprofile         spot
# 3929308676  time.variance,node.order  regionprofile         spot
# 3991634214  time.variance,node.order  regionprofile         spot
# 4241647462  time.variance,node.order  regionprofile         spot
#
#            spot:node.order         spot:output spot:time.variance  launchdate  \
# profile
# 159906272             true   p64-s1024-t2.cali               true  1702001580
# 953174584             true   p32-s1024-t0.cali               true  1702014127
# 1071778005            true   p64-s1024-t0.cali               true  1702014127
# 1087836440            true  p512-s1024-t2.cali               true  1702004363
# 1327331677            true    p2-s1024-t3.cali               true  1702001577
# 1424922791            true   p32-s1024-t3.cali               true  1702001620
# 1438853916            true   p16-s1024-t1.cali               true  1702001401
# 1543041692            true    p8-s1024-t3.cali               true  1702001600
# 1623898012            true  p512-s1024-t1.cali               true  1702004363
# 1827980037            true    p4-s1024-t0.cali               true  1702013944
# 1894185536            true    p2-s1024-t1.cali               true  1702001360
# 1924649228            true  p512-s1024-t3.cali               true  1702004363
# 1957635544            true    p8-s1024-t1.cali               true  1702001380
# 2058892351            true    p2-s1024-t2.cali               true  1702001560
# 2070791099            true   p16-s1024-t3.cali               true  1702001600
# 2107736924            true   p64-s1024-t1.cali               true  1702001401
# 2136595877            true  p128-s1024-t3.cali               true  1702003242
# 2156774464            true   p32-s1024-t2.cali               true  1702001561
# 2199133481            true  p128-s1024-t2.cali               true  1702003226
# 2241141572            true  p128-s1024-t0.cali               true  1702015789
# 2322971876            true   p32-s1024-t1.cali               true  1702001401
# 2372782952            true  p128-s1024-t1.cali               true  1702003217
# 2619958893            true  p256-s1024-t2.cali               true  1702003845
# 2824179464            true   p64-s1024-t3.cali               true  1702001620
# 2829002560            true    p8-s1024-t2.cali               true  1702001561
# 2859419785            true    p4-s1024-t1.cali               true  1702001380
# 3093073098            true    p4-s1024-t3.cali               true  1702001600
# 3111480413            true   p16-s1024-t0.cali               true  1702013944
# 3550702409            true    p4-s1024-t2.cali               true  1702001548
# 3565458465            true  p256-s1024-t3.cali               true  1702003845
# 3603672664            true  p256-s1024-t0.cali               true  1702017189
# 3775748758            true   p16-s1024-t2.cali               true  1702001561
# 3924219113            true  p256-s1024-t1.cali               true  1702003783
# 3929308676            true    p2-s1024-t0.cali               true  1702013887
# 3991634214            true    p8-s1024-t0.cali               true  1702013944
# 4241647462            true  p512-s1024-t0.cali               true  1702017670
#
#                                                     libraries  \
# profile
# 159906272   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 953174584   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1071778005  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1087836440  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1327331677  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1424922791  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1438853916  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1543041692  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1623898012  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1827980037  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1894185536  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1924649228  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1957635544  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2058892351  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2070791099  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2107736924  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2136595877  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2156774464  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2199133481  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2241141572  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2322971876  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2372782952  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2619958893  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2824179464  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2829002560  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2859419785  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3093073098  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3111480413  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3550702409  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3565458465  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3603672664  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3775748758  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3924219113  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3929308676  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3991634214  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4241647462  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                      cmdline cluster       Algorithm  \
# profile
# 159906272    [./Selection_Sort, 2, 64, 1024]       c  Selection Sort
# 953174584    [./Selection_Sort, 0, 32, 1024]       c  Selection Sort
# 1071778005   [./Selection_Sort, 0, 64, 1024]       c  Selection Sort
# 1087836440  [./Selection_Sort, 2, 512, 1024]       c  Selection Sort
# 1327331677    [./Selection_Sort, 3, 2, 1024]       c  Selection Sort
# 1424922791   [./Selection_Sort, 3, 32, 1024]       c  Selection Sort
# 1438853916   [./Selection_Sort, 1, 16, 1024]       c  Selection Sort
# 1543041692    [./Selection_Sort, 3, 8, 1024]       c  Selection Sort
# 1623898012  [./Selection_Sort, 1, 512, 1024]       c  Selection Sort
# 1827980037    [./Selection_Sort, 0, 4, 1024]       c  Selection Sort
# 1894185536    [./Selection_Sort, 1, 2, 1024]       c  Selection Sort
# 1924649228  [./Selection_Sort, 3, 512, 1024]       c  Selection Sort
# 1957635544    [./Selection_Sort, 1, 8, 1024]       c  Selection Sort
# 2058892351    [./Selection_Sort, 2, 2, 1024]       c  Selection Sort
# 2070791099   [./Selection_Sort, 3, 16, 1024]       c  Selection Sort
# 2107736924   [./Selection_Sort, 1, 64, 1024]       c  Selection Sort
# 2136595877  [./Selection_Sort, 3, 128, 1024]       c  Selection Sort
# 2156774464   [./Selection_Sort, 2, 32, 1024]       c  Selection Sort
# 2199133481  [./Selection_Sort, 2, 128, 1024]       c  Selection Sort
# 2241141572  [./Selection_Sort, 0, 128, 1024]       c  Selection Sort
# 2322971876   [./Selection_Sort, 1, 32, 1024]       c  Selection Sort
# 2372782952  [./Selection_Sort, 1, 128, 1024]       c  Selection Sort
# 2619958893  [./Selection_Sort, 2, 256, 1024]       c  Selection Sort
# 2824179464   [./Selection_Sort, 3, 64, 1024]       c  Selection Sort
# 2829002560    [./Selection_Sort, 2, 8, 1024]       c  Selection Sort
# 2859419785    [./Selection_Sort, 1, 4, 1024]       c  Selection Sort
# 3093073098    [./Selection_Sort, 3, 4, 1024]       c  Selection Sort
# 3111480413   [./Selection_Sort, 0, 16, 1024]       c  Selection Sort
# 3550702409    [./Selection_Sort, 2, 4, 1024]       c  Selection Sort
# 3565458465  [./Selection_Sort, 3, 256, 1024]       c  Selection Sort
# 3603672664  [./Selection_Sort, 0, 256, 1024]       c  Selection Sort
# 3775748758   [./Selection_Sort, 2, 16, 1024]       c  Selection Sort
# 3924219113  [./Selection_Sort, 1, 256, 1024]       c  Selection Sort
# 3929308676    [./Selection_Sort, 0, 2, 1024]       c  Selection Sort
# 3991634214    [./Selection_Sort, 0, 8, 1024]       c  Selection Sort
# 4241647462  [./Selection_Sort, 0, 512, 1024]       c  Selection Sort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize  \
# profile
# 159906272               MPI      int               4       1024
# 953174584               MPI      int               4       1024
# 1071778005              MPI      int               4       1024
# 1087836440              MPI      int               4       1024
# 1327331677              MPI      int               4       1024
# 1424922791              MPI      int               4       1024
# 1438853916              MPI      int               4       1024
# 1543041692              MPI      int               4       1024
# 1623898012              MPI      int               4       1024
# 1827980037              MPI      int               4       1024
# 1894185536              MPI      int               4       1024
# 1924649228              MPI      int               4       1024
# 1957635544              MPI      int               4       1024
# 2058892351              MPI      int               4       1024
# 2070791099              MPI      int               4       1024
# 2107736924              MPI      int               4       1024
# 2136595877              MPI      int               4       1024
# 2156774464              MPI      int               4       1024
# 2199133481              MPI      int               4       1024
# 2241141572              MPI      int               4       1024
# 2322971876              MPI      int               4       1024
# 2372782952              MPI      int               4       1024
# 2619958893              MPI      int               4       1024
# 2824179464              MPI      int               4       1024
# 2829002560              MPI      int               4       1024
# 2859419785              MPI      int               4       1024
# 3093073098              MPI      int               4       1024
# 3111480413              MPI      int               4       1024
# 3550702409              MPI      int               4       1024
# 3565458465              MPI      int               4       1024
# 3603672664              MPI      int               4       1024
# 3775748758              MPI      int               4       1024
# 3924219113              MPI      int               4       1024
# 3929308676              MPI      int               4       1024
# 3991634214              MPI      int               4       1024
# 4241647462              MPI      int               4       1024
#
#                  InputType  num_procs  group_num      implementation_source
# profile
# 159906272   Reverse Sorted         64         16  Handwritten, AI, & Online
# 953174584       Randomized         32         16  Handwritten, AI, & Online
# 1071778005      Randomized         64         16  Handwritten, AI, & Online
# 1087836440  Reverse Sorted        512         16  Handwritten, AI, & Online
# 1327331677    1% Perturbed          2         16  Handwritten, AI, & Online
# 1424922791    1% Perturbed         32         16  Handwritten, AI, & Online
# 1438853916          Sorted         16         16  Handwritten, AI, & Online
# 1543041692    1% Perturbed          8         16  Handwritten, AI, & Online
# 1623898012          Sorted        512         16  Handwritten, AI, & Online
# 1827980037      Randomized          4         16  Handwritten, AI, & Online
# 1894185536          Sorted          2         16  Handwritten, AI, & Online
# 1924649228    1% Perturbed        512         16  Handwritten, AI, & Online
# 1957635544          Sorted          8         16  Handwritten, AI, & Online
# 2058892351  Reverse Sorted          2         16  Handwritten, AI, & Online
# 2070791099    1% Perturbed         16         16  Handwritten, AI, & Online
# 2107736924          Sorted         64         16  Handwritten, AI, & Online
# 2136595877    1% Perturbed        128         16  Handwritten, AI, & Online
# 2156774464  Reverse Sorted         32         16  Handwritten, AI, & Online
# 2199133481  Reverse Sorted        128         16  Handwritten, AI, & Online
# 2241141572      Randomized        128         16  Handwritten, AI, & Online
# 2322971876          Sorted         32         16  Handwritten, AI, & Online
# 2372782952          Sorted        128         16  Handwritten, AI, & Online
# 2619958893  Reverse Sorted        256         16  Handwritten, AI, & Online
# 2824179464    1% Perturbed         64         16  Handwritten, AI, & Online
# 2829002560  Reverse Sorted          8         16  Handwritten, AI, & Online
# 2859419785          Sorted          4         16  Handwritten, AI, & Online
# 3093073098    1% Perturbed          4         16  Handwritten, AI, & Online
# 3111480413      Randomized         16         16  Handwritten, AI, & Online
# 3550702409  Reverse Sorted          4         16  Handwritten, AI, & Online
# 3565458465    1% Perturbed        256         16  Handwritten, AI, & Online
# 3603672664      Randomized        256         16  Handwritten, AI, & Online
# 3775748758  Reverse Sorted         16         16  Handwritten, AI, & Online
# 3924219113          Sorted        256         16  Handwritten, AI, & Online
# 3929308676      Randomized          2         16  Handwritten, AI, & Online
# 3991634214      Randomized          8         16  Handwritten, AI, & Online
# 4241647462      Randomized        512         16  Handwritten, AI, & Online

# %%
tk.statsframe.dataframe["time"] = 1

# %%
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
gb = tk.groupby("InputType")
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b611ab64e80>, 'Randomized': <thicket.thicket.Thicket object at 0x2b611ad25a00>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b611ac57670>, 'Sorted': <thicket.thicket.Thicket object at 0x2b6119fa8eb0>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_procs'
)

# %%
ctk.dataframe
# Out:
#                                                             1% Perturbed  \
#                                                                      nid
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                    1
#                                                   4                    1
#                                                   8                    1
#                                                   16                   1
#                                                   32                   1
#                                                   64                   1
#                                                   128                  1
#                                                   256                  1
#                                                   512                  1
# {'name': 'comm', 'type': 'function'}              2                    3
#                                                   4                    3
#                                                   8                    3
#                                                   16                   3
#                                                   32                   3
#                                                   64                   3
#                                                   128                  3
#                                                   256                  3
#                                                   512                  3
# {'name': 'comm_large', 'type': 'function'}        2                    4
#                                                   4                    4
#                                                   8                    4
#                                                   16                   4
#                                                   32                   4
#                                                   64                   4
#                                                   128                  4
#                                                   256                  4
#                                                   512                  4
# {'name': 'comp', 'type': 'function'}              2                    5
#                                                   4                    5
#                                                   8                    5
#                                                   16                   5
#                                                   32                   5
#                                                   64                   5
#                                                   128                  5
#                                                   256                  5
#                                                   512                  5
# {'name': 'comp_large', 'type': 'function'}        2                    6
#                                                   4                    6
#                                                   8                    6
#                                                   16                   6
#                                                   32                   6
#                                                   64                   6
#                                                   128                  6
#                                                   256                  6
#                                                   512                  6
# {'name': 'correctness_check', 'type': 'function'} 2                    7
#                                                   4                    7
#                                                   8                    7
#                                                   16                   7
#                                                   32                   7
#                                                   64                   7
#                                                   128                  7
#                                                   256                  7
#                                                   512                  7
# {'name': 'data_init', 'type': 'function'}         2                    2
#                                                   4                    2
#                                                   8                    2
#                                                   16                   2
#                                                   32                   2
#                                                   64                   2
#                                                   128                  2
#                                                   256                  2
#                                                   512                  2
#
#                                                                             \
#                                                               spot.channel
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'comm', 'type': 'function'}              2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'comm_large', 'type': 'function'}        2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'comp', 'type': 'function'}              2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'comp_large', 'type': 'function'}        2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'correctness_check', 'type': 'function'} 2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'data_init', 'type': 'function'}         2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#
#                                                                            \
#                                                             Min time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              0.005571
#                                                   4              0.005400
#                                                   8              0.005367
#                                                   16             0.008731
#                                                   32             0.005350
#                                                   64             0.005357
#                                                   128            0.005380
#                                                   256            0.005369
#                                                   512            0.005345
# {'name': 'comm', 'type': 'function'}              2              0.000121
#                                                   4              0.000099
#                                                   8              0.000092
#                                                   16             0.003314
#                                                   32             0.000086
#                                                   64             0.000083
#                                                   128            0.000081
#                                                   256            0.000082
#                                                   512            0.000084
# {'name': 'comm_large', 'type': 'function'}        2              0.000108
#                                                   4              0.000087
#                                                   8              0.000080
#                                                   16             0.003300
#                                                   32             0.000074
#                                                   64             0.000071
#                                                   128            0.000069
#                                                   256            0.000071
#                                                   512            0.000072
# {'name': 'comp', 'type': 'function'}              2              0.000017
#                                                   4              0.000015
#                                                   8              0.000015
#                                                   16             0.000016
#                                                   32             0.000015
#                                                   64             0.000015
#                                                   128            0.000015
#                                                   256            0.000015
#                                                   512            0.000015
# {'name': 'comp_large', 'type': 'function'}        2              0.000007
#                                                   4              0.000006
#                                                   8              0.000006
#                                                   16             0.000006
#                                                   32             0.000006
#                                                   64             0.000006
#                                                   128            0.000006
#                                                   256            0.000006
#                                                   512            0.000006
# {'name': 'correctness_check', 'type': 'function'} 2              0.000005
#                                                   4              0.000005
#                                                   8              0.000005
#                                                   16             0.000005
#                                                   32             0.000005
#                                                   64             0.000005
#                                                   128            0.000005
#                                                   256            0.000005
#                                                   512            0.000005
# {'name': 'data_init', 'type': 'function'}         2              0.000046
#                                                   4              0.000034
#                                                   8              0.000028
#                                                   16             0.000023
#                                                   32             0.000022
#                                                   64             0.000021
#                                                   128            0.000021
#                                                   256            0.000020
#                                                   512            0.000019
#
#                                                                            \
#                                                             Max time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              0.007009
#                                                   4              0.007070
#                                                   8              0.008458
#                                                   16             0.012191
#                                                   32             0.020574
#                                                   64             0.089989
#                                                   128            0.094696
#                                                   256            0.335867
#                                                   512            1.769399
# {'name': 'comm', 'type': 'function'}              2              0.000154
#                                                   4              0.001315
#                                                   8              0.001616
#                                                   16             0.004586
#                                                   32             0.015243
#                                                   64             0.073962
#                                                   128            0.089415
#                                                   256            0.330548
#                                                   512            1.764097
# {'name': 'comm_large', 'type': 'function'}        2              0.000141
#                                                   4              0.001298
#                                                   8              0.001599
#                                                   16             0.004567
#                                                   32             0.015224
#                                                   64             0.073941
#                                                   128            0.089390
#                                                   256            0.330521
#                                                   512            1.764071
# {'name': 'comp', 'type': 'function'}              2              0.001554
#                                                   4              0.001555
#                                                   8              0.001555
#                                                   16             0.002333
#                                                   32             0.001546
#                                                   64             0.001557
#                                                   128            0.001571
#                                                   256            0.026069
#                                                   512            0.016942
# {'name': 'comp_large', 'type': 'function'}        2              0.001544
#                                                   4              0.001544
#                                                   8              0.001543
#                                                   16             0.002317
#                                                   32             0.001534
#                                                   64             0.001544
#                                                   128            0.001554
#                                                   256            0.026048
#                                                   512            0.001545
# {'name': 'correctness_check', 'type': 'function'} 2              0.000018
#                                                   4              0.000012
#                                                   8              0.000008
#                                                   16             0.000007
#                                                   32             0.000006
#                                                   64             0.000012
#                                                   128            0.004340
#                                                   256            0.026485
#                                                   512            0.000012
# {'name': 'data_init', 'type': 'function'}         2              0.000049
#                                                   4              0.000035
#                                                   8              0.000030
#                                                   16             0.000032
#                                                   32             0.000028
#                                                   64             0.000030
#                                                   128            0.000060
#                                                   256            0.000047
#                                                   512            0.000034
#
#                                                                            \
#                                                             Avg time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              0.006290
#                                                   4              0.006156
#                                                   8              0.005998
#                                                   16             0.009461
#                                                   32             0.011297
#                                                   64             0.017713
#                                                   128            0.022814
#                                                   256            0.081045
#                                                   512            0.171259
# {'name': 'comm', 'type': 'function'}              2              0.000138
#                                                   4              0.000437
#                                                   8              0.000494
#                                                   16             0.003909
#                                                   32             0.005912
#                                                   64             0.011307
#                                                   128            0.013094
#                                                   256            0.040397
#                                                   512            0.160382
# {'name': 'comm_large', 'type': 'function'}        2              0.000125
#                                                   4              0.000423
#                                                   8              0.000480
#                                                   16             0.003892
#                                                   32             0.005896
#                                                   64             0.011293
#                                                   128            0.013078
#                                                   256            0.040379
#                                                   512            0.160331
# {'name': 'comp', 'type': 'function'}              2              0.000786
#                                                   4              0.000401
#                                                   8              0.000209
#                                                   16             0.000163
#                                                   32             0.000065
#                                                   64             0.000043
#                                                   128            0.000030
#                                                   256            0.000214
#                                                   512            0.000054
# {'name': 'comp_large', 'type': 'function'}        2              0.000775
#                                                   4              0.000391
#                                                   8              0.000199
#                                                   16             0.000152
#                                                   32             0.000055
#                                                   64             0.000031
#                                                   128            0.000019
#                                                   256            0.000203
#                                                   512            0.000010
# {'name': 'correctness_check', 'type': 'function'} 2              0.000012
#                                                   4              0.000007
#                                                   8              0.000005
#                                                   16             0.000005
#                                                   32             0.000005
#                                                   64             0.000005
#                                                   128            0.000039
#                                                   256            0.000108
#                                                   512            0.000005
# {'name': 'data_init', 'type': 'function'}         2              0.000048
#                                                   4              0.000034
#                                                   8              0.000028
#                                                   16             0.000025
#                                                   32             0.000023
#                                                   64             0.000023
#                                                   128            0.000026
#                                                   256            0.000027
#                                                   512            0.000023
#
#                                                                         \
#                                                             Total time
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2           0.012581
#                                                   4           0.024624
#                                                   8           0.047985
#                                                   16          0.151378
#                                                   32          0.361518
#                                                   64          1.133652
#                                                   128         2.920239
#                                                   256        20.747438
#                                                   512        87.684752
# {'name': 'comm', 'type': 'function'}              2           0.000275
#                                                   4           0.001748
#                                                   8           0.003950
#                                                   16          0.062547
#                                                   32          0.189176
#                                                   64          0.723624
#                                                   128         1.676074
#                                                   256        10.341583
#                                                   512        82.115792
# {'name': 'comm_large', 'type': 'function'}        2           0.000249
#                                                   4           0.001690
#                                                   8           0.003840
#                                                   16          0.062279
#                                                   32          0.188681
#                                                   64          0.722729
#                                                   128         1.673998
#                                                   256        10.336905
#                                                   512        82.089725
# {'name': 'comp', 'type': 'function'}              2           0.001571
#                                                   4           0.001604
#                                                   8           0.001671
#                                                   16          0.002608
#                                                   32          0.002095
#                                                   64          0.002751
#                                                   128         0.003834
#                                                   256         0.054847
#                                                   512         0.027754
# {'name': 'comp_large', 'type': 'function'}        2           0.001551
#                                                   4           0.001563
#                                                   8           0.001589
#                                                   16          0.002430
#                                                   32          0.001751
#                                                   64          0.001960
#                                                   128         0.002475
#                                                   256         0.052061
#                                                   512         0.005253
# {'name': 'correctness_check', 'type': 'function'} 2           0.000023
#                                                   4           0.000027
#                                                   8           0.000043
#                                                   16          0.000082
#                                                   32          0.000159
#                                                   64          0.000328
#                                                   128         0.004963
#                                                   256         0.027734
#                                                   512         0.002563
# {'name': 'data_init', 'type': 'function'}         2           0.000095
#                                                   4           0.000138
#                                                   8           0.000227
#                                                   16          0.000407
#                                                   32          0.000747
#                                                   64          0.001442
#                                                   128         0.003332
#                                                   256         0.006972
#                                                   512         0.011683
#
#                                                                                 \
#                                                             Variance time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                   0.000001
#                                                   4                   0.000001
#                                                   8                   0.000001
#                                                   16                  0.000001
#                                                   32                  0.000040
#                                                   64                  0.000465
#                                                   128                 0.000605
#                                                   256                 0.004767
#                                                   512                 0.101318
# {'name': 'comm', 'type': 'function'}              2                   0.000000
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000039
#                                                   64                  0.000437
#                                                   128                 0.000566
#                                                   256                 0.004781
#                                                   512                 0.101121
# {'name': 'comm_large', 'type': 'function'}        2                   0.000000
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000039
#                                                   64                  0.000437
#                                                   128                 0.000566
#                                                   256                 0.004780
#                                                   512                 0.101092
# {'name': 'comp', 'type': 'function'}              2                   0.000001
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000000
#                                                   64                  0.000000
#                                                   128                 0.000000
#                                                   256                 0.000005
#                                                   512                 0.000001
# {'name': 'comp_large', 'type': 'function'}        2                   0.000001
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000000
#                                                   64                  0.000000
#                                                   128                 0.000000
#                                                   256                 0.000005
#                                                   512                 0.000000
# {'name': 'correctness_check', 'type': 'function'} 2                   0.000000
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000000
#                                                   64                  0.000000
#                                                   128                 0.000000
#                                                   256                 0.000003
#                                                   512                 0.000000
# {'name': 'data_init', 'type': 'function'}         2                   0.000000
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000000
#                                                   64                  0.000000
#                                                   128                 0.000000
#                                                   256                 0.000000
#                                                   512                 0.000000
#
#                                                             Randomized  \
#                                                                    nid
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                  1
#                                                   4                  1
#                                                   8                  1
#                                                   16                 1
#                                                   32                 1
#                                                   64                 1
#                                                   128                1
#                                                   256                1
#                                                   512                1
# {'name': 'comm', 'type': 'function'}              2                  3
#                                                   4                  3
#                                                   8                  3
#                                                   16                 3
#                                                   32                 3
#                                                   64                 3
#                                                   128                3
#                                                   256                3
#                                                   512                3
# {'name': 'comm_large', 'type': 'function'}        2                  4
#                                                   4                  4
#                                                   8                  4
#                                                   16                 4
#                                                   32                 4
#                                                   64                 4
#                                                   128                4
#                                                   256                4
#                                                   512                4
# {'name': 'comp', 'type': 'function'}              2                  5
#                                                   4                  5
#                                                   8                  5
#                                                   16                 5
#                                                   32                 5
#                                                   64                 5
#                                                   128                5
#                                                   256                5
#                                                   512                5
# {'name': 'comp_large', 'type': 'function'}        2                  6
#                                                   4                  6
#                                                   8                  6
#                                                   16                 6
#                                                   32                 6
#                                                   64                 6
#                                                   128                6
#                                                   256                6
#                                                   512                6
# {'name': 'correctness_check', 'type': 'function'} 2                  7
#                                                   4                  7
#                                                   8                  7
#                                                   16                 7
#                                                   32                 7
#                                                   64                 7
#                                                   128                7
#                                                   256                7
#                                                   512                7
# {'name': 'data_init', 'type': 'function'}         2                  2
#                                                   4                  2
#                                                   8                  2
#                                                   16                 2
#                                                   32                 2
#                                                   64                 2
#                                                   128                2
#                                                   256                2
#                                                   512                2
#
#                                                                             \
#                                                               spot.channel
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'comm', 'type': 'function'}              2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'comm_large', 'type': 'function'}        2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'comp', 'type': 'function'}              2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'comp_large', 'type': 'function'}        2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'correctness_check', 'type': 'function'} 2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
# {'name': 'data_init', 'type': 'function'}         2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#                                                   16         regionprofile
#                                                   32         regionprofile
#                                                   64         regionprofile
#                                                   128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#
#                                                                            \
#                                                             Min time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              0.005416
#                                                   4              0.005696
#                                                   8              0.005390
#                                                   16             0.005374
#                                                   32             0.005373
#                                                   64             0.005357
#                                                   128            0.005365
#                                                   256            0.005378
#                                                   512            0.005341
# {'name': 'comm', 'type': 'function'}              2              0.000103
#                                                   4              0.000365
#                                                   8              0.000092
#                                                   16             0.000087
#                                                   32             0.000086
#                                                   64             0.000084
#                                                   128            0.000080
#                                                   256            0.000083
#                                                   512            0.000083
# {'name': 'comm_large', 'type': 'function'}        2              0.000091
#                                                   4              0.000351
#                                                   8              0.000080
#                                                   16             0.000075
#                                                   32             0.000074
#                                                   64             0.000072
#                                                   128            0.000069
#                                                   256            0.000070
# ...
#                                                   64             0.000019
#                                                   128            0.000020
#                                                   256            0.000214
#                                                   512            0.000020
#
#                                                                         \
#                                                             Total time
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2           0.013967
#                                                   4           0.032107
#                                                   8           0.051683
#                                                   16          0.106743
#                                                   32          0.365863
#                                                   64          1.215298
#                                                   128         5.040149
#                                                   256        17.075830
#                                                   512        88.750799
# {'name': 'comm', 'type': 'function'}              2           0.001453
#                                                   4           0.009241
#                                                   8           0.007216
#                                                   16          0.020495
#                                                   32          0.188132
#                                                   64          0.785548
#                                                   128         4.181129
#                                                   256         5.686814
#                                                   512        82.144908
# {'name': 'comm_large', 'type': 'function'}        2           0.001419
#                                                   4           0.009181
#                                                   8           0.007094
#                                                   16          0.020256
#                                                   32          0.187635
#                                                   64          0.784609
#                                                   128         4.171979
#                                                   256         5.682669
#                                                   512        82.131735
# {'name': 'comp', 'type': 'function'}              2           0.001947
#                                                   4           0.001582
#                                                   8           0.002066
#                                                   16          0.001806
#                                                   32          0.002070
#                                                   64          0.004073
#                                                   128         0.008332
#                                                   256         0.037064
#                                                   512         0.010876
# {'name': 'comp_large', 'type': 'function'}        2           0.001926
#                                                   4           0.001537
#                                                   8           0.001980
#                                                   16          0.001636
#                                                   32          0.001733
#                                                   64          0.003282
#                                                   128         0.006953
#                                                   256         0.034340
#                                                   512         0.005305
# {'name': 'correctness_check', 'type': 'function'} 2           0.000023
#                                                   4           0.000027
#                                                   8           0.000044
#                                                   16          0.000082
#                                                   32          0.000164
#                                                   64          0.000318
#                                                   128         0.000645
#                                                   256         0.001295
#                                                   512         0.002553
# {'name': 'data_init', 'type': 'function'}         2           0.000058
#                                                   4           0.000099
#                                                   8           0.000173
#                                                   16          0.000320
#                                                   32          0.000642
#                                                   64          0.001194
#                                                   128         0.002599
#                                                   256         0.054774
#                                                   512         0.010029
#
#                                                                                 \
#                                                             Variance time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                   0.000001
#                                                   4                   0.000007
#                                                   8                   0.000002
#                                                   16                  0.000003
#                                                   32                  0.000044
#                                                   64                  0.000479
#                                                   128                 0.004161
#                                                   256                 0.003473
#                                                   512                 0.103046
# {'name': 'comm', 'type': 'function'}              2                   0.000000
#                                                   4                   0.000005
#                                                   8                   0.000001
#                                                   16                  0.000002
#                                                   32                  0.000043
#                                                   64                  0.000473
#                                                   128                 0.004174
#                                                   256                 0.002541
#                                                   512                 0.103410
# {'name': 'comm_large', 'type': 'function'}        2                   0.000000
#                                                   4                   0.000005
#                                                   8                   0.000001
#                                                   16                  0.000002
#                                                   32                  0.000043
#                                                   64                  0.000473
#                                                   128                 0.004177
#                                                   256                 0.002541
#                                                   512                 0.103409
# {'name': 'comp', 'type': 'function'}              2                   0.000001
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000000
#                                                   64                  0.000000
#                                                   128                 0.000000
#                                                   256                 0.000002
#                                                   512                 0.000000
# {'name': 'comp_large', 'type': 'function'}        2                   0.000001
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000000
#                                                   64                  0.000000
#                                                   128                 0.000000
#                                                   256                 0.000002
#                                                   512                 0.000000
# {'name': 'correctness_check', 'type': 'function'} 2                   0.000000
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000000
#                                                   64                  0.000000
#                                                   128                 0.000000
#                                                   256                 0.000000
#                                                   512                 0.000000
# {'name': 'data_init', 'type': 'function'}         2                   0.000000
#                                                   4                   0.000000
#                                                   8                   0.000000
#                                                   16                  0.000000
#                                                   32                  0.000000
#                                                   64                  0.000000
#                                                   128                 0.000000
#                                                   256                 0.000003
#                                                   512                 0.000000
#
#                                                                           name
#
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                       main
#                                                   4                       main
#                                                   8                       main
#                                                   16                      main
#                                                   32                      main
#                                                   64                      main
#                                                   128                     main
#                                                   256                     main
#                                                   512                     main
# {'name': 'comm', 'type': 'function'}              2                       comm
#                                                   4                       comm
#                                                   8                       comm
#                                                   16                      comm
#                                                   32                      comm
#                                                   64                      comm
#                                                   128                     comm
#                                                   256                     comm
#                                                   512                     comm
# {'name': 'comm_large', 'type': 'function'}        2                 comm_large
#                                                   4                 comm_large
#                                                   8                 comm_large
#                                                   16                comm_large
#                                                   32                comm_large
#                                                   64                comm_large
#                                                   128               comm_large
#                                                   256               comm_large
#                                                   512               comm_large
# {'name': 'comp', 'type': 'function'}              2                       comp
#                                                   4                       comp
#                                                   8                       comp
#                                                   16                      comp
#                                                   32                      comp
#                                                   64                      comp
#                                                   128                     comp
#                                                   256                     comp
#                                                   512                     comp
# {'name': 'comp_large', 'type': 'function'}        2                 comp_large
#                                                   4                 comp_large
#                                                   8                 comp_large
#                                                   16                comp_large
#                                                   32                comp_large
#                                                   64                comp_large
#                                                   128               comp_large
#                                                   256               comp_large
#                                                   512               comp_large
# {'name': 'correctness_check', 'type': 'function'} 2          correctness_check
#                                                   4          correctness_check
#                                                   8          correctness_check
#                                                   16         correctness_check
#                                                   32         correctness_check
#                                                   64         correctness_check
#                                                   128        correctness_check
#                                                   256        correctness_check
#                                                   512        correctness_check
# {'name': 'data_init', 'type': 'function'}         2                  data_init
#                                                   4                  data_init
#                                                   8                  data_init
#                                                   16                 data_init
#                                                   32                 data_init
#                                                   64                 data_init
#                                                   128                data_init
#                                                   256                data_init
#                                                   512                data_init

# %%
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Variance time/rank"),
                                                 ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Variance time/rank"),
                                                 ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Variance time/rank"),
                                                 ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Variance time/rank"),
                                                 
                                                 ], axis=1)

# %%
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"
#                   4              0.000395
#                   8              0.000258
#                   16             0.000113
#                   32             0.000065
#                   64             0.000064
#                   128            0.000065
#                   256            0.000145
#                   512            0.000021
# comp_large        2              0.000963
#                   4              0.000384
#                   8              0.000248
#                   16             0.000102
#                   32             0.000054
#                   64             0.000051
#                   128            0.000054
#                   256            0.000134
#                   512            0.000010
# correctness_check 2              0.000011
#                   4              0.000007
#                   8              0.000005
#                   16             0.000005
#                   32             0.000005
#                   64             0.000005
#                   128            0.000005
#                   256            0.000005
#                   512            0.000005
# data_init         2              0.000029
#                   4              0.000025
#                   8              0.000022
#                   16             0.000020
#                   32             0.000020
#                   64             0.000019
#                   128            0.000020
#                   256            0.000214
#                   512            0.000020

# %%
main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]

comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

# %%
regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]

# %%
for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Processors')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'MPI - Strong Scaling for 2^10 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()

# %% [markdown]
# # STRONG SCALING 2^11

# %%
tk = th.Thicket.from_caliperreader(glob("*s2048*.cali"))
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_procs'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Variance time/rank"),
                                                 ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Variance time/rank"),
                                                 ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Variance time/rank"),
                                                 ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Variance time/rank"),
                                                 
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]


for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Processors')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'MPI - Strong Scaling for 2^11 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b6119fc49d0>, 'Randomized': <thicket.thicket.Thicket object at 0x2b611abe5730>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b611ad4c370>, 'Sorted': <thicket.thicket.Thicket object at 0x2b611ad3e9d0>}

# %% [markdown]
# # STRONG SCALING 2^12

# %%
tk = th.Thicket.from_caliperreader(glob("*s4096*.cali"))
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_procs'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Variance time/rank"),
                                                 ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Variance time/rank"),
                                                 ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Variance time/rank"),
                                                 ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Variance time/rank"),
                                                 
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large,comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]


for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Processors')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'MPI - Strong Scaling for 2^12 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b6119f12b20>, 'Randomized': <thicket.thicket.Thicket object at 0x2b611ac28b80>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b6119d82d60>, 'Sorted': <thicket.thicket.Thicket object at 0x2b611ad3ceb0>}

# %% [markdown]
# # STRONG SCALING 2^13

# %%
tk = th.Thicket.from_caliperreader(glob("*s8192*.cali"))
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_procs'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Variance time/rank"),
                                                 ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Variance time/rank"),
                                                 ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Variance time/rank"),
                                                 ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Variance time/rank"),
                                                 
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large,comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large","comp", "comp_large", "correctness_check", "data_init"]


for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Processors')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'MPI - Strong Scaling for 2^13 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b611b0ccb20>, 'Randomized': <thicket.thicket.Thicket object at 0x2b611abaa7c0>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b611ab71d00>, 'Sorted': <thicket.thicket.Thicket object at 0x2b6119f4feb0>}

# %% [markdown]
# # Strong Scaling 2^14

# %%
tk = th.Thicket.from_caliperreader(glob("*s16384*.cali"))
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_procs'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Variance time/rank"),
                                                 ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Variance time/rank"),
                                                 ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Variance time/rank"),
                                                 ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Variance time/rank"),
                                                 
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]


for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Processors')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'MPI - Strong Scaling for 2^14 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b611a022c70>, 'Randomized': <thicket.thicket.Thicket object at 0x2b611ac87e80>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b611ad74b20>, 'Sorted': <thicket.thicket.Thicket object at 0x2b60f57b6940>}

# %% [markdown]
# # Strong Scaling 2^15

# %%
tk = th.Thicket.from_caliperreader(glob("*s32768*.cali"))
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_procs'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Variance time/rank"),
                                                 ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Variance time/rank"),
                                                 ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Variance time/rank"),
                                                 ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Variance time/rank"),
                                                 
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]


for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Processors')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'MPI - Strong Scaling for 2^15 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b611a0d8a60>, 'Randomized': <thicket.thicket.Thicket object at 0x2b611a1249d0>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b611af0d400>, 'Sorted': <thicket.thicket.Thicket object at 0x2b611a13d730>}

# %% [markdown]
# # Strong Scaling 2^16

# %%
tk = th.Thicket.from_caliperreader(glob("*s65536*.cali"))
gb = tk.groupby("InputType")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_procs'
)
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), ('1% Perturbed', "nid"), ('1% Perturbed', "spot.channel"),('1% Perturbed', "Min time/rank"), ('1% Perturbed', "Max time/rank"),('1% Perturbed', "Total time"), ('1% Perturbed', "Variance time/rank"),
                                                 ('Randomized', "nid"), ('Randomized', "spot.channel"),('Randomized', "Min time/rank"), ('Randomized', "Max time/rank"),('Randomized', "Total time"), ('Randomized', "Variance time/rank"),
                                                 ('Reverse Sorted', "nid"), ('Reverse Sorted', "spot.channel"),('Reverse Sorted', "Min time/rank"), ('Reverse Sorted', "Max time/rank"),('Reverse Sorted', "Total time"), ('Reverse Sorted', "Variance time/rank"),
                                                 ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Variance time/rank"),
                                                 
                                                 ], axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

main_function = ctk.dataframe.loc["main"]
comm = ctk.dataframe.loc["comm"]
comm_large = ctk.dataframe.loc["comm_large"]
comp = ctk.dataframe.loc["comp"]
comp_large = ctk.dataframe.loc["comp_large"]
correctness_check = ctk.dataframe.loc["correctness_check"]
data_init = ctk.dataframe.loc["data_init"]

regions = [main_function, comm, comm_large, comp, comp_large, correctness_check, data_init]
names = ["main", "comm", "comm_large", "comp", "comp_large", "correctness_check", "data_init"]


for region, name in zip(regions, names):
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    legend_labels = []
    for column in region.columns:
        first_index = column[0]  # Extract the first index
        legend_labels.append(first_index)
        plt.plot(region.index, region.xs(column, axis=1), marker='o', label=column)

    plt.xlabel('Number of Processors')
    plt.ylabel('Avg time per rank (s)')
    plt.title(f'MPI - Strong Scaling for 2^16 Elements: Selection Sort {name}')
    plt.legend(legend_labels)
    plt.grid(True)
    plt.show()
# Out:
# 4  thickets created...
# {'1% Perturbed': <thicket.thicket.Thicket object at 0x2b611af63730>, 'Randomized': <thicket.thicket.Thicket object at 0x2b611ac7e3d0>, 'Reverse Sorted': <thicket.thicket.Thicket object at 0x2b6119e820a0>, 'Sorted': <thicket.thicket.Thicket object at 0x2b611acda2e0>}
