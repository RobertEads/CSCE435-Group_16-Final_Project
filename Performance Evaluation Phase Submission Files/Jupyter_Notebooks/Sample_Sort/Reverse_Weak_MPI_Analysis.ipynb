# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
file1 = glob("SS-MPI-i2-p16-s65536.cali")
file2 = glob("SS-MPI-i2-p64-s262144.cali")
file3 = glob("SS-MPI-i2-p256-s1048576.cali")
all_files = [file1[0], file2[0], file3[0]]
print(all_files)
tk = th.Thicket.from_caliperreader(all_files)
# Out:
# ['SS-MPI-i2-p16-s65536.cali', 'SS-MPI-i2-p64-s262144.cali', 'SS-MPI-i2-p256-s1048576.cali']

# %%
tk.profile_mapping
# Out:
# OrderedDict([(1609882629, 'SS-MPI-i2-p16-s65536.cali'),
#              (2508994716, 'SS-MPI-i2-p64-s262144.cali'),
#              (2606695566, 'SS-MPI-i2-p256-s1048576.cali')])

# %%
tk.dataframe
# Out:
#                                                                nid  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               1609882629    1
#                                                    2508994716    1
#                                                    2606695566    1
# {'name': 'comm', 'type': 'function'}               1609882629    5
#                                                    2508994716    5
#                                                    2606695566    5
# {'name': 'comm_large', 'type': 'function'}         1609882629   10
#                                                    2508994716   10
#                                                    2606695566   10
# {'name': 'MPI_Gatherv', 'type': 'function'}        1609882629   11
#                                                    2508994716   11
#                                                    2606695566   11
# {'name': 'comm_small', 'type': 'function'}         1609882629    6
#                                                    2508994716    6
#                                                    2606695566    6
# {'name': 'MPI_Allgather', 'type': 'function'}      1609882629    7
#                                                    2508994716    7
#                                                    2606695566    7
# {'name': 'MPI_Gather', 'type': 'function'}         1609882629    9
#                                                    2508994716    9
#                                                    2606695566    9
# {'name': 'comp', 'type': 'function'}               1609882629    3
#                                                    2508994716    3
#                                                    2606695566    3
# {'name': 'comp_large', 'type': 'function'}         1609882629    8
#                                                    2508994716    8
#                                                    2606695566    8
# {'name': 'comp_small', 'type': 'function'}         1609882629    4
#                                                    2508994716    4
#                                                    2606695566    4
# {'name': 'correctness_check ', 'type': 'function'} 1609882629   12
#                                                    2508994716   12
#                                                    2606695566   12
# {'name': 'data_init', 'type': 'function'}          1609882629    2
#                                                    2508994716    2
#                                                    2606695566    2
#
#                                                                 spot.channel  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'comm', 'type': 'function'}               1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'comm_large', 'type': 'function'}         1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'MPI_Gatherv', 'type': 'function'}        1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'comm_small', 'type': 'function'}         1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'MPI_Allgather', 'type': 'function'}      1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'MPI_Gather', 'type': 'function'}         1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'comp', 'type': 'function'}               1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'comp_large', 'type': 'function'}         1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'comp_small', 'type': 'function'}         1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'correctness_check ', 'type': 'function'} 1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
# {'name': 'data_init', 'type': 'function'}          1609882629  regionprofile
#                                                    2508994716  regionprofile
#                                                    2606695566  regionprofile
#
#                                                                Min time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               1609882629       3.133215
#                                                    2508994716       2.488703
#                                                    2606695566       5.382337
# {'name': 'comm', 'type': 'function'}               1609882629       2.413088
#                                                    2508994716       0.521065
#                                                    2606695566       2.274230
# {'name': 'comm_large', 'type': 'function'}         1609882629       0.448004
#                                                    2508994716       0.025533
#                                                    2606695566       0.759196
# {'name': 'MPI_Gatherv', 'type': 'function'}        1609882629       0.447968
#                                                    2508994716       0.025496
#                                                    2606695566       0.759168
# {'name': 'comm_small', 'type': 'function'}         1609882629       1.613082
#                                                    2508994716       0.461253
#                                                    2606695566       1.356241
# {'name': 'MPI_Allgather', 'type': 'function'}      1609882629       0.073434
#                                                    2508994716       0.079187
#                                                    2606695566       0.166120
# {'name': 'MPI_Gather', 'type': 'function'}         1609882629       1.504186
#                                                    2508994716       0.082356
#                                                    2606695566       0.997357
# {'name': 'comp', 'type': 'function'}               1609882629       0.258810
#                                                    2508994716       0.863962
#                                                    2606695566       1.094244
# {'name': 'comp_large', 'type': 'function'}         1609882629       0.258717
#                                                    2508994716       0.863789
#                                                    2606695566       1.092823
# {'name': 'comp_small', 'type': 'function'}         1609882629       0.000028
#                                                    2508994716       0.000113
#                                                    2606695566       0.001345
# {'name': 'correctness_check ', 'type': 'function'} 1609882629       0.064041
#                                                    2508994716       0.000164
#                                                    2606695566       0.000170
# {'name': 'data_init', 'type': 'function'}          1609882629       0.000102
#                                                    2508994716       0.000096
#                                                    2606695566       0.000097
#
#                                                                Max time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               1609882629       3.307900
#                                                    2508994716       2.856956
#                                                    2606695566       6.293576
# {'name': 'comm', 'type': 'function'}               1609882629       2.750589
#                                                    2508994716       1.341015
#                                                    2606695566       4.911293
# {'name': 'comm_large', 'type': 'function'}         1609882629       0.895954
#                                                    2508994716       0.462265
#                                                    2606695566       1.330764
# {'name': 'MPI_Gatherv', 'type': 'function'}        1609882629       0.895924
#                                                    2508994716       0.462223
#                                                    2606695566       1.330729
# {'name': 'comm_small', 'type': 'function'}         1609882629       1.995772
#                                                    2508994716       1.106994
#                                                    2606695566       3.865474
# {'name': 'MPI_Allgather', 'type': 'function'}      1609882629       0.306381
#                                                    2508994716       0.882961
#                                                    2606695566       1.137286
# {'name': 'MPI_Gather', 'type': 'function'}         1609882629       1.789433
#                                                    2508994716       0.789041
#                                                    2606695566       2.826097
# {'name': 'comp', 'type': 'function'}               1609882629       0.325697
#                                                    2508994716       1.779445
#                                                    2606695566       2.947602
# {'name': 'comp_large', 'type': 'function'}         1609882629       0.325608
#                                                    2508994716       1.779238
#                                                    2606695566       2.946169
# {'name': 'comp_small', 'type': 'function'}         1609882629       0.000036
#                                                    2508994716       0.020942
#                                                    2606695566       0.209371
# {'name': 'correctness_check ', 'type': 'function'} 1609882629       0.373511
#                                                    2508994716       0.263846
#                                                    2606695566       0.372587
# {'name': 'data_init', 'type': 'function'}          1609882629       0.000133
#                                                    2508994716       0.000116
#                                                    2606695566       0.406251
#
#                                                                Avg time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               1609882629       3.199082
#                                                    2508994716       2.655296
#                                                    2606695566       5.888904
# {'name': 'comm', 'type': 'function'}               1609882629       2.596431
#                                                    2508994716       0.966190
#                                                    2606695566       3.571167
# {'name': 'comm_large', 'type': 'function'}         1609882629       0.749971
#                                                    2508994716       0.138688
#                                                    2606695566       1.004748
# {'name': 'MPI_Gatherv', 'type': 'function'}        1609882629       0.749940
#                                                    2508994716       0.138662
#                                                    2606695566       1.004720
# {'name': 'comm_small', 'type': 'function'}         1609882629       1.846433
#                                                    2508994716       0.827475
#                                                    2606695566       2.566294
# {'name': 'MPI_Allgather', 'type': 'function'}      1609882629       0.164866
#                                                    2508994716       0.342012
#                                                    2606695566       0.685898
# {'name': 'MPI_Gather', 'type': 'function'}         1609882629       1.681518
#                                                    2508994716       0.485418
#                                                    2606695566       1.879650
# {'name': 'comp', 'type': 'function'}               1609882629       0.313324
#                                                    2508994716       1.304399
#                                                    2606695566       1.980644
# {'name': 'comp_large', 'type': 'function'}         1609882629       0.313231
#                                                    2508994716       1.303890
#                                                    2606695566       1.971386
# {'name': 'comp_small', 'type': 'function'}         1609882629       0.000031
#                                                    2508994716       0.000440
#                                                    2606695566       0.004325
# {'name': 'correctness_check ', 'type': 'function'} 1609882629       0.191902
#                                                    2508994716       0.159884
#                                                    2606695566       0.154323
# {'name': 'data_init', 'type': 'function'}          1609882629       0.000115
#                                                    2508994716       0.000109
#                                                    2606695566       0.011744
#
#                                                                 Total time  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               1609882629    51.185304
#                                                    2508994716   169.938959
#                                                    2606695566  1507.559498
# {'name': 'comm', 'type': 'function'}               1609882629    41.542899
#                                                    2508994716    61.836182
#                                                    2606695566   914.218868
# {'name': 'comm_large', 'type': 'function'}         1609882629    11.999536
#                                                    2508994716     8.876014
#                                                    2606695566   257.215458
# {'name': 'MPI_Gatherv', 'type': 'function'}        1609882629    11.999035
#                                                    2508994716     8.874345
#                                                    2606695566   257.208289
# {'name': 'comm_small', 'type': 'function'}         1609882629    29.542923
#                                                    2508994716    52.958393
#                                                    2606695566   656.971324
# {'name': 'MPI_Allgather', 'type': 'function'}      1609882629     2.637856
#                                                    2508994716    21.888741
#                                                    2606695566   175.589762
# {'name': 'MPI_Gather', 'type': 'function'}         1609882629    26.904283
#                                                    2508994716    31.066736
#                                                    2606695566   481.190512
# {'name': 'comp', 'type': 'function'}               1609882629     5.013186
#                                                    2508994716    83.481526
#                                                    2606695566   507.044894
# {'name': 'comp_large', 'type': 'function'}         1609882629     5.011697
#                                                    2508994716    83.448940
#                                                    2606695566   504.674719
# {'name': 'comp_small', 'type': 'function'}         1609882629     0.000491
#                                                    2508994716     0.028179
#                                                    2606695566     1.107312
# {'name': 'correctness_check ', 'type': 'function'} 1609882629     3.070429
#                                                    2508994716    10.232592
#                                                    2606695566    39.506588
# {'name': 'data_init', 'type': 'function'}          1609882629     0.001836
#                                                    2508994716     0.006956
#                                                    2606695566     3.006566
#
#                                                                Variance time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               1609882629            0.002052
#                                                    2508994716            0.008512
#                                                    2606695566            0.049291
# {'name': 'comm', 'type': 'function'}               1609882629            0.007358
#                                                    2508994716            0.036116
#                                                    2606695566            0.296400
# {'name': 'comm_large', 'type': 'function'}         1609882629            0.011001
#                                                    2508994716            0.005248
#                                                    2606695566            0.006928
# {'name': 'MPI_Gatherv', 'type': 'function'}        1609882629            0.011002
#                                                    2508994716            0.005248
#                                                    2606695566            0.006928
# {'name': 'comm_small', 'type': 'function'}         1609882629            0.011908
#                                                    2508994716            0.020174
#                                                    2606695566            0.279910
# {'name': 'MPI_Allgather', 'type': 'function'}      1609882629            0.004592
#                                                    2508994716            0.035084
#                                                    2606695566            0.050068
# {'name': 'MPI_Gather', 'type': 'function'}         1609882629            0.007553
#                                                    2508994716            0.040721
#                                                    2606695566            0.222823
# {'name': 'comp', 'type': 'function'}               1609882629            0.000320
#                                                    2508994716            0.032623
#                                                    2606695566            0.219644
# {'name': 'comp_large', 'type': 'function'}         1609882629            0.000320
#                                                    2508994716            0.032686
#                                                    2606695566            0.221863
# {'name': 'comp_small', 'type': 'function'}         1609882629            0.000000
#                                                    2508994716            0.000007
#                                                    2606695566            0.000496
# {'name': 'correctness_check ', 'type': 'function'} 1609882629            0.006350
#                                                    2508994716            0.002302
#                                                    2606695566            0.002452
# {'name': 'data_init', 'type': 'function'}          1609882629            0.000000
#                                                    2508994716            0.000000
#                                                    2606695566            0.002990
#
#                                                                              name
# node                                               profile
# {'name': 'main', 'type': 'function'}               1609882629                main
#                                                    2508994716                main
#                                                    2606695566                main
# {'name': 'comm', 'type': 'function'}               1609882629                comm
#                                                    2508994716                comm
#                                                    2606695566                comm
# {'name': 'comm_large', 'type': 'function'}         1609882629          comm_large
#                                                    2508994716          comm_large
#                                                    2606695566          comm_large
# {'name': 'MPI_Gatherv', 'type': 'function'}        1609882629         MPI_Gatherv
#                                                    2508994716         MPI_Gatherv
#                                                    2606695566         MPI_Gatherv
# {'name': 'comm_small', 'type': 'function'}         1609882629          comm_small
#                                                    2508994716          comm_small
#                                                    2606695566          comm_small
# {'name': 'MPI_Allgather', 'type': 'function'}      1609882629       MPI_Allgather
#                                                    2508994716       MPI_Allgather
#                                                    2606695566       MPI_Allgather
# {'name': 'MPI_Gather', 'type': 'function'}         1609882629          MPI_Gather
#                                                    2508994716          MPI_Gather
#                                                    2606695566          MPI_Gather
# {'name': 'comp', 'type': 'function'}               1609882629                comp
#                                                    2508994716                comp
#                                                    2606695566                comp
# {'name': 'comp_large', 'type': 'function'}         1609882629          comp_large
#                                                    2508994716          comp_large
#                                                    2606695566          comp_large
# {'name': 'comp_small', 'type': 'function'}         1609882629          comp_small
#                                                    2508994716          comp_small
#                                                    2606695566          comp_small
# {'name': 'correctness_check ', 'type': 'function'} 1609882629  correctness_check
#                                                    2508994716  correctness_check
#                                                    2606695566  correctness_check
# {'name': 'data_init', 'type': 'function'}          1609882629           data_init
#                                                    2508994716           data_init
#                                                    2606695566           data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 1609882629           2.11.0-dev              16
# 2508994716           2.11.0-dev              64
# 2606695566           2.11.0-dev             256
#
#                                                  spot.metrics  \
# profile
# 1609882629  min#inclusive#sum#time.duration,max#inclusive#...
# 2508994716  min#inclusive#sum#time.duration,max#inclusive#...
# 2606695566  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 1609882629                                            2
# 2508994716                                            2
# 2606695566                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 1609882629  time.variance,node.order  regionprofile         spot
# 2508994716  time.variance,node.order  regionprofile         spot
# 2606695566  time.variance,node.order  regionprofile         spot
#
#            spot:node.order                   spot:output spot:time.variance  \
# profile
# 1609882629            true     SS-MPI-i2-p16-s65536.cali               true
# 2508994716            true    SS-MPI-i2-p64-s262144.cali               true
# 2606695566            true  SS-MPI-i2-p256-s1048576.cali               true
#
#             launchdate                                          libraries  \
# profile
# 1609882629  1700026724  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2508994716  1700033884  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2606695566  1700027635  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                             cmdline cluster   Algorithm  \
# profile
# 1609882629     [../../../Sample_Sort, 2, 16, 65536]       c  SampleSort
# 2508994716    [../../../Sample_Sort, 2, 64, 262144]       c  SampleSort
# 2606695566  [../../../Sample_Sort, 2, 256, 1048576]       c  SampleSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize  \
# profile
# 1609882629              MPI      int               4      65536
# 2508994716              MPI      int               4     262144
# 2606695566              MPI      int               4    1048576
#
#                  InputType  num_procs  group_num implementation_source
# profile
# 1609882629  Reverse Sorted         16         16                Online
# 2508994716  Reverse Sorted         64         16                Online
# 2606695566  Reverse Sorted        256         16                Online

# %%
#tk.statsframe.dataframe["time"] = 1

# %%
#print(tk.tree())

# %%
gb = tk.groupby("InputSize")
# Out:
# 3  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ab359886d30>, 262144: <thicket.thicket.Thicket object at 0x2ab3598b76d0>, 1048576: <thicket.thicket.Thicket object at 0x2ab3598f2f40>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_procs"
)

# %%
ctk.dataframe
# Out:
#                                                              65536  \
#                                                                nid
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16            1
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comm', 'type': 'function'}               16            5
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comm_large', 'type': 'function'}         16           10
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'MPI_Gatherv', 'type': 'function'}        16           11
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comm_small', 'type': 'function'}         16            6
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'MPI_Allgather', 'type': 'function'}      16            7
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'MPI_Gather', 'type': 'function'}         16            9
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comp', 'type': 'function'}               16            3
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comp_large', 'type': 'function'}         16            8
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comp_small', 'type': 'function'}         16            4
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'correctness_check ', 'type': 'function'} 16           12
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'data_init', 'type': 'function'}          16            2
#                                                    64         <NA>
#                                                    256        <NA>
#
#                                                                              \
#                                                                spot.channel
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comm', 'type': 'function'}               16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comm_large', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comm_small', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comp', 'type': 'function'}               16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comp_large', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comp_small', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'data_init', 'type': 'function'}          16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
#
#                                                                             \
#                                                              Min time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16             3.133215
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16             2.413088
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16             0.448004
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16             0.447968
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16             1.613082
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16             0.073434
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16             1.504186
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16             0.258810
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16             0.258717
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16             0.000028
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16             0.064041
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16             0.000102
#                                                    64                  NaN
#                                                    256                 NaN
#
#                                                                             \
#                                                              Max time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16             3.307900
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16             2.750589
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16             0.895954
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16             0.895924
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16             1.995772
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16             0.306381
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16             1.789433
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16             0.325697
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16             0.325608
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16             0.000036
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16             0.373511
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16             0.000133
#                                                    64                  NaN
#                                                    256                 NaN
#
#                                                                             \
#                                                              Avg time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16             3.199082
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16             2.596431
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16             0.749971
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16             0.749940
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16             1.846433
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16             0.164866
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16             1.681518
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16             0.313324
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16             0.313231
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16             0.000031
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16             0.191902
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16             0.000115
#                                                    64                  NaN
#                                                    256                 NaN
#
#                                                                          \
#                                                              Total time
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16         51.185304
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comm', 'type': 'function'}               16         41.542899
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comm_large', 'type': 'function'}         16         11.999536
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16         11.999035
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comm_small', 'type': 'function'}         16         29.542923
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16          2.637856
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16         26.904283
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comp', 'type': 'function'}               16          5.013186
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comp_large', 'type': 'function'}         16          5.011697
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comp_small', 'type': 'function'}         16          0.000491
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'correctness_check ', 'type': 'function'} 16          3.070429
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'data_init', 'type': 'function'}          16          0.001836
#                                                    64               NaN
#                                                    256              NaN
#
#                                                                                  \
#                                                              Variance time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  0.002052
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comm', 'type': 'function'}               16                  0.007358
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comm_large', 'type': 'function'}         16                  0.011001
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  0.011002
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comm_small', 'type': 'function'}         16                  0.011908
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  0.004592
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                  0.007553
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comp', 'type': 'function'}               16                  0.000320
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comp_large', 'type': 'function'}         16                  0.000320
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comp_small', 'type': 'function'}         16                  0.000000
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                  0.006350
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'data_init', 'type': 'function'}          16                  0.000000
#                                                    64                       NaN
#                                                    256                      NaN
#
#                                                              262144  \
#                                                                 nid
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16          <NA>
#                                                    64             1
#                                                    256         <NA>
# {'name': 'comm', 'type': 'function'}               16          <NA>
#                                                    64             5
#                                                    256         <NA>
# {'name': 'comm_large', 'type': 'function'}         16          <NA>
#                                                    64            10
#                                                    256         <NA>
# {'name': 'MPI_Gatherv', 'type': 'function'}        16          <NA>
#                                                    64            11
#                                                    256         <NA>
# {'name': 'comm_small', 'type': 'function'}         16          <NA>
#                                                    64             6
#                                                    256         <NA>
# {'name': 'MPI_Allgather', 'type': 'function'}      16          <NA>
#                                                    64             7
#                                                    256         <NA>
# {'name': 'MPI_Gather', 'type': 'function'}         16          <NA>
#                                                    64             9
#                                                    256         <NA>
# {'name': 'comp', 'type': 'function'}               16          <NA>
#                                                    64             3
#                                                    256         <NA>
# {'name': 'comp_large', 'type': 'function'}         16          <NA>
#                                                    64             8
#                                                    256         <NA>
# {'name': 'comp_small', 'type': 'function'}         16          <NA>
#                                                    64             4
#                                                    256         <NA>
# {'name': 'correctness_check ', 'type': 'function'} 16          <NA>
#                                                    64            12
#                                                    256         <NA>
# {'name': 'data_init', 'type': 'function'}          16          <NA>
#                                                    64             2
#                                                    256         <NA>
#
#                                                                              \
#                                                                spot.channel
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comm', 'type': 'function'}               16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comm_large', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comm_small', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comp', 'type': 'function'}               16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comp_large', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comp_small', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'data_init', 'type': 'function'}          16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
#
#                                                                             \
#                                                              Min time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64             2.488703
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64             0.521065
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64             0.025533
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64             0.025496
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64             0.461253
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64             0.079187
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64             0.082356
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64             0.863962
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64             0.863789
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64             0.000113
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64             0.000164
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64             0.000096
#                                                    256                 NaN
#
#                                                                             \
#                                                              Max time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64             2.856956
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64             1.341015
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64             0.462265
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64             0.462223
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64             1.106994
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64             0.882961
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64             0.789041
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64             1.779445
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64             1.779238
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64             0.020942
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64             0.263846
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64             0.000116
#                                                    256                 NaN
#
#                                                                             \
#                                                              Avg time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64             2.655296
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64             0.966190
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64             0.138688
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64             0.138662
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64             0.827475
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64             0.342012
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64             0.485418
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64             1.304399
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64             1.303890
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64             0.000440
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64             0.159884
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64             0.000109
#                                                    256                 NaN
#
#                                                                           \
#                                                               Total time
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                NaN
#                                                    64         169.938959
#                                                    256               NaN
# {'name': 'comm', 'type': 'function'}               16                NaN
#                                                    64          61.836182
#                                                    256               NaN
# {'name': 'comm_large', 'type': 'function'}         16                NaN
#                                                    64           8.876014
#                                                    256               NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                NaN
#                                                    64           8.874345
#                                                    256               NaN
# {'name': 'comm_small', 'type': 'function'}         16                NaN
#                                                    64          52.958393
#                                                    256               NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                NaN
#                                                    64          21.888741
#                                                    256               NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                NaN
#                                                    64          31.066736
#                                                    256               NaN
# {'name': 'comp', 'type': 'function'}               16                NaN
#                                                    64          83.481526
#                                                    256               NaN
# {'name': 'comp_large', 'type': 'function'}         16                NaN
#                                                    64          83.448940
#                                                    256               NaN
# {'name': 'comp_small', 'type': 'function'}         16                NaN
#                                                    64           0.028179
#                                                    256               NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                NaN
#                                                    64          10.232592
#                                                    256               NaN
# {'name': 'data_init', 'type': 'function'}          16                NaN
#                                                    64           0.006956
#                                                    256               NaN
#
#                                                                                  \
#                                                              Variance time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                       NaN
#                                                    64                  0.008512
#                                                    256                      NaN
# {'name': 'comm', 'type': 'function'}               16                       NaN
#                                                    64                  0.036116
#                                                    256                      NaN
# {'name': 'comm_large', 'type': 'function'}         16                       NaN
#                                                    64                  0.005248
#                                                    256                      NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                       NaN
#                                                    64                  0.005248
#                                                    256                      NaN
# {'name': 'comm_small', 'type': 'function'}         16                       NaN
#                                                    64                  0.020174
#                                                    256                      NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                       NaN
#                                                    64                  0.035084
#                                                    256                      NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                       NaN
#                                                    64                  0.040721
#                                                    256                      NaN
# {'name': 'comp', 'type': 'function'}               16                       NaN
#                                                    64                  0.032623
#                                                    256                      NaN
# {'name': 'comp_large', 'type': 'function'}         16                       NaN
#                                                    64                  0.032686
#                                                    256                      NaN
# {'name': 'comp_small', 'type': 'function'}         16                       NaN
#                                                    64                  0.000007
#                                                    256                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                       NaN
#                                                    64                  0.002302
#                                                    256                      NaN
# {'name': 'data_init', 'type': 'function'}          16                       NaN
#                                                    64                  0.000000
#                                                    256                      NaN
#
#                                                              1048576  \
#                                                                  nid
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16           <NA>
#                                                    64           <NA>
#                                                    256             1
# {'name': 'comm', 'type': 'function'}               16           <NA>
#                                                    64           <NA>
#                                                    256             5
# {'name': 'comm_large', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256            10
# {'name': 'MPI_Gatherv', 'type': 'function'}        16           <NA>
#                                                    64           <NA>
#                                                    256            11
# {'name': 'comm_small', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256             6
# {'name': 'MPI_Allgather', 'type': 'function'}      16           <NA>
#                                                    64           <NA>
#                                                    256             7
# {'name': 'MPI_Gather', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256             9
# {'name': 'comp', 'type': 'function'}               16           <NA>
#                                                    64           <NA>
#                                                    256             3
# {'name': 'comp_large', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256             8
# {'name': 'comp_small', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256             4
# {'name': 'correctness_check ', 'type': 'function'} 16           <NA>
#                                                    64           <NA>
#                                                    256            12
# {'name': 'data_init', 'type': 'function'}          16           <NA>
#                                                    64           <NA>
#                                                    256             2
#
#                                                                              \
#                                                                spot.channel
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comm', 'type': 'function'}               16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comm_large', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comm_small', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'MPI_Allgather', 'type': 'function'}      16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'MPI_Gather', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comp', 'type': 'function'}               16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comp_large', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comp_small', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'correctness_check ', 'type': 'function'} 16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# ...
#                                                    64                  NaN
#                                                    256            0.000170
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64                  NaN
#                                                    256            0.000097
#
#                                                                             \
#                                                              Max time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256            6.293576
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256            4.911293
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            1.330764
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64                  NaN
#                                                    256            1.330729
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            3.865474
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64                  NaN
#                                                    256            1.137286
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            2.826097
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256            2.947602
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            2.946169
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            0.209371
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64                  NaN
#                                                    256            0.372587
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64                  NaN
#                                                    256            0.406251
#
#                                                                             \
#                                                              Avg time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256            5.888904
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256            3.571167
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            1.004748
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64                  NaN
#                                                    256            1.004720
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            2.566294
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64                  NaN
#                                                    256            0.685898
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            1.879650
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256            1.980644
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            1.971386
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            0.004325
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64                  NaN
#                                                    256            0.154323
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64                  NaN
#                                                    256            0.011744
#
#                                                                            \
#                                                                Total time
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                 NaN
#                                                    64                 NaN
#                                                    256        1507.559498
# {'name': 'comm', 'type': 'function'}               16                 NaN
#                                                    64                 NaN
#                                                    256         914.218868
# {'name': 'comm_large', 'type': 'function'}         16                 NaN
#                                                    64                 NaN
#                                                    256         257.215458
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                 NaN
#                                                    64                 NaN
#                                                    256         257.208289
# {'name': 'comm_small', 'type': 'function'}         16                 NaN
#                                                    64                 NaN
#                                                    256         656.971324
# {'name': 'MPI_Allgather', 'type': 'function'}      16                 NaN
#                                                    64                 NaN
#                                                    256         175.589762
# {'name': 'MPI_Gather', 'type': 'function'}         16                 NaN
#                                                    64                 NaN
#                                                    256         481.190512
# {'name': 'comp', 'type': 'function'}               16                 NaN
#                                                    64                 NaN
#                                                    256         507.044894
# {'name': 'comp_large', 'type': 'function'}         16                 NaN
#                                                    64                 NaN
#                                                    256         504.674719
# {'name': 'comp_small', 'type': 'function'}         16                 NaN
#                                                    64                 NaN
#                                                    256           1.107312
# {'name': 'correctness_check ', 'type': 'function'} 16                 NaN
#                                                    64                 NaN
#                                                    256          39.506588
# {'name': 'data_init', 'type': 'function'}          16                 NaN
#                                                    64                 NaN
#                                                    256           3.006566
#
#                                                                                  \
#                                                              Variance time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                       NaN
#                                                    64                       NaN
#                                                    256                 0.049291
# {'name': 'comm', 'type': 'function'}               16                       NaN
#                                                    64                       NaN
#                                                    256                 0.296400
# {'name': 'comm_large', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.006928
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                       NaN
#                                                    64                       NaN
#                                                    256                 0.006928
# {'name': 'comm_small', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.279910
# {'name': 'MPI_Allgather', 'type': 'function'}      16                       NaN
#                                                    64                       NaN
#                                                    256                 0.050068
# {'name': 'MPI_Gather', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.222823
# {'name': 'comp', 'type': 'function'}               16                       NaN
#                                                    64                       NaN
#                                                    256                 0.219644
# {'name': 'comp_large', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.221863
# {'name': 'comp_small', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.000496
# {'name': 'correctness_check ', 'type': 'function'} 16                       NaN
#                                                    64                       NaN
#                                                    256                 0.002452
# {'name': 'data_init', 'type': 'function'}          16                       NaN
#                                                    64                       NaN
#                                                    256                 0.002990
#
#                                                                             name
#
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                       main
#                                                    64                       main
#                                                    256                      main
# {'name': 'comm', 'type': 'function'}               16                       comm
#                                                    64                       comm
#                                                    256                      comm
# {'name': 'comm_large', 'type': 'function'}         16                 comm_large
#                                                    64                 comm_large
#                                                    256                comm_large
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                MPI_Gatherv
#                                                    64                MPI_Gatherv
#                                                    256               MPI_Gatherv
# {'name': 'comm_small', 'type': 'function'}         16                 comm_small
#                                                    64                 comm_small
#                                                    256                comm_small
# {'name': 'MPI_Allgather', 'type': 'function'}      16              MPI_Allgather
#                                                    64              MPI_Allgather
#                                                    256             MPI_Allgather
# {'name': 'MPI_Gather', 'type': 'function'}         16                 MPI_Gather
#                                                    64                 MPI_Gather
#                                                    256                MPI_Gather
# {'name': 'comp', 'type': 'function'}               16                       comp
#                                                    64                       comp
#                                                    256                      comp
# {'name': 'comp_large', 'type': 'function'}         16                 comp_large
#                                                    64                 comp_large
#                                                    256                comp_large
# {'name': 'comp_small', 'type': 'function'}         16                 comp_small
#                                                    64                 comp_small
#                                                    256                comp_small
# {'name': 'correctness_check ', 'type': 'function'} 16         correctness_check
#                                                    64         correctness_check
#                                                    256        correctness_check
# {'name': 'data_init', 'type': 'function'}          16                  data_init
#                                                    64                  data_init
#                                                    256                 data_init

# %%
ctk.metadata
# Out:
#                        65536                   \
#           cali.caliper.version mpi.world.size
# num_procs
# 16                  2.11.0-dev           16.0
# 64                         NaN            NaN
# 256                        NaN            NaN
#
#                                                               \
#                                                 spot.metrics
# num_procs
# 16         min#inclusive#sum#time.duration,max#inclusive#...
# 64                                                       NaN
# 256                                                      NaN
#
#                                                        \
#           spot.timeseries.metrics spot.format.version
# num_procs
# 16                                                2.0
# 64                            NaN                 NaN
# 256                           NaN                 NaN
#
#                                                                  \
#                        spot.options  spot.channels cali.channel
# num_procs
# 16         time.variance,node.order  regionprofile         spot
# 64                              NaN            NaN          NaN
# 256                             NaN            NaN          NaN
#
#                                                                          \
#           spot:node.order                spot:output spot:time.variance
# num_procs
# 16                   true  SS-MPI-i2-p16-s65536.cali               true
# 64                    NaN                        NaN                NaN
# 256                   NaN                        NaN                NaN
#
#                                                                             \
#              launchdate                                          libraries
# num_procs
# 16         1.700027e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 64                  NaN                                                NaN
# 256                 NaN                                                NaN
#
#                                                                      \
#                                         cmdline cluster   Algorithm
# num_procs
# 16         [../../../Sample_Sort, 2, 16, 65536]       c  SampleSort
# 64                                          NaN     NaN         NaN
# 256                                         NaN     NaN         NaN
#
#                                                                               \
#           ProgrammingModel Datatype SizeOfDatatype InputSize       InputType
# num_procs
# 16                     MPI      int            4.0   65536.0  Reverse Sorted
# 64                     NaN      NaN            NaN       NaN             NaN
# 256                    NaN      NaN            NaN       NaN             NaN
#
#                                                        262144                  \
#           group_num implementation_source cali.caliper.version mpi.world.size
# num_procs
# 16             16.0                Online                  NaN            NaN
# 64              NaN                   NaN           2.11.0-dev           64.0
# 256             NaN                   NaN                  NaN            NaN
#
#                                                               \
#                                                 spot.metrics
# num_procs
# 16                                                       NaN
# 64         min#inclusive#sum#time.duration,max#inclusive#...
# 256                                                      NaN
#
#                                                        \
#           spot.timeseries.metrics spot.format.version
# num_procs
# 16                            NaN                 NaN
# 64                                                2.0
# 256                           NaN                 NaN
#
#                                                                  \
#                        spot.options  spot.channels cali.channel
# num_procs
# 16                              NaN            NaN          NaN
# 64         time.variance,node.order  regionprofile         spot
# 256                             NaN            NaN          NaN
#
#                                                                           \
#           spot:node.order                 spot:output spot:time.variance
# num_procs
# 16                    NaN                         NaN                NaN
# 64                   true  SS-MPI-i2-p64-s262144.cali               true
# 256                   NaN                         NaN                NaN
#
#                                                                             \
#              launchdate                                          libraries
# num_procs
# 16                  NaN                                                NaN
# 64         1.700034e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 256                 NaN                                                NaN
#
#                                                                       \
#                                          cmdline cluster   Algorithm
# num_procs
# 16                                           NaN     NaN         NaN
# 64         [../../../Sample_Sort, 2, 64, 262144]       c  SampleSort
# 256                                          NaN     NaN         NaN
#
#                                                                               \
#           ProgrammingModel Datatype SizeOfDatatype InputSize       InputType
# num_procs
# 16                     NaN      NaN            NaN       NaN             NaN
# 64                     MPI      int            4.0  262144.0  Reverse Sorted
# 256                    NaN      NaN            NaN       NaN             NaN
#
#                                                        1048576                 \
#           group_num implementation_source cali.caliper.version mpi.world.size
# num_procs
# 16              NaN                   NaN                  NaN            NaN
# 64             16.0                Online                  NaN            NaN
# 256             NaN                   NaN           2.11.0-dev          256.0
#
#                                                               \
#                                                 spot.metrics
# num_procs
# 16                                                       NaN
# 64                                                       NaN
# 256        min#inclusive#sum#time.duration,max#inclusive#...
#
#                                                        \
#           spot.timeseries.metrics spot.format.version
# num_procs
# 16                            NaN                 NaN
# 64                            NaN                 NaN
# 256                                               2.0
#
#                                                                  \
#                        spot.options  spot.channels cali.channel
# num_procs
# 16                              NaN            NaN          NaN
# 64                              NaN            NaN          NaN
# 256        time.variance,node.order  regionprofile         spot
#
#                                                                             \
#           spot:node.order                   spot:output spot:time.variance
# num_procs
# 16                    NaN                           NaN                NaN
# 64                    NaN                           NaN                NaN
# 256                  true  SS-MPI-i2-p256-s1048576.cali               true
#
#                                                                             \
#              launchdate                                          libraries
# num_procs
# 16                  NaN                                                NaN
# 64                  NaN                                                NaN
# 256        1.700028e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                                                         \
#                                            cmdline cluster   Algorithm
# num_procs
# 16                                             NaN     NaN         NaN
# 64                                             NaN     NaN         NaN
# 256        [../../../Sample_Sort, 2, 256, 1048576]       c  SampleSort
#
#                                                                                \
#           ProgrammingModel Datatype SizeOfDatatype  InputSize       InputType
# num_procs
# 16                     NaN      NaN            NaN        NaN             NaN
# 64                     NaN      NaN            NaN        NaN             NaN
# 256                    MPI      int            4.0  1048576.0  Reverse Sorted
#
#
#           group_num implementation_source
# num_procs
# 16              NaN                   NaN
# 64              NaN                   NaN
# 256            16.0                Online

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (65536, "nid"), (1048576, "nid"), (262144, "nid"),(65536, "spot.channel"), (1048576, "spot.channel"), (262144, "spot.channel")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([(65536, "Min time/rank"), (1048576, "Min time/rank"), (262144, "Min time/rank"),(65536, "Max time/rank"), (1048576, "Max time/rank"), (262144, "Max time/rank"),(65536, "Variance time/rank"), (1048576, "Variance time/rank"), (262144, "Variance time/rank"), (65536, "Avg time/rank"), (1048576, "Avg time/rank"), (262144, "Avg time/rank")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

# %%
ctk.dataframe
# Out:
#                              index      65536      262144      1048576
#                                    Total time  Total time   Total time
# name               num_procs
# main               16            0  51.185304         NaN          NaN
#                    64            1        NaN  169.938959          NaN
#                    256           2        NaN         NaN  1507.559498
# comm               16            3  41.542899         NaN          NaN
#                    64            4        NaN   61.836182          NaN
#                    256           5        NaN         NaN   914.218868
# comm_large         16            6  11.999536         NaN          NaN
#                    64            7        NaN    8.876014          NaN
#                    256           8        NaN         NaN   257.215458
# MPI_Gatherv        16            9  11.999035         NaN          NaN
#                    64           10        NaN    8.874345          NaN
#                    256          11        NaN         NaN   257.208289
# comm_small         16           12  29.542923         NaN          NaN
#                    64           13        NaN   52.958393          NaN
#                    256          14        NaN         NaN   656.971324
# MPI_Allgather      16           15   2.637856         NaN          NaN
#                    64           16        NaN   21.888741          NaN
#                    256          17        NaN         NaN   175.589762
# MPI_Gather         16           18  26.904283         NaN          NaN
#                    64           19        NaN   31.066736          NaN
#                    256          20        NaN         NaN   481.190512
# comp               16           21   5.013186         NaN          NaN
#                    64           22        NaN   83.481526          NaN
#                    256          23        NaN         NaN   507.044894
# comp_large         16           24   5.011697         NaN          NaN
#                    64           25        NaN   83.448940          NaN
#                    256          26        NaN         NaN   504.674719
# comp_small         16           27   0.000491         NaN          NaN
#                    64           28        NaN    0.028179          NaN
#                    256          29        NaN         NaN     1.107312
# correctness_check  16           30   3.070429         NaN          NaN
#                    64           31        NaN   10.232592          NaN
#                    256          32        NaN         NaN    39.506588
# data_init          16           33   0.001836         NaN          NaN
#                    64           34        NaN    0.006956          NaN
#                    256          35        NaN         NaN     3.006566

# %%
# Define common variables
numProcs = [16,64,256]
dataType = "Reverse"
functions = ["main", "comm", "comp"]

# %%
def plot_mpl(df, title, xlabel, ylabel, columns):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(columns)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(numProcs)
    plt.show()
    return fig, ax

# %%
for func in functions:
    tempData = [ctk.dataframe.loc[func][65536].at[16, "Total time"], ctk.dataframe.loc[func][262144].at[64, "Total time"], ctk.dataframe.loc[func][1048576].at[256, "Total time"]]
    dfTemp = pd.DataFrame(tempData, columns=["Total time"], index=numProcs) 
    plot_mpl(
                df=dfTemp,
                title= func + "-" + dataType + "-Weak_Scaling",
                xlabel="Number of Processes",
                ylabel="Time (seconds)",
                columns=["Total time"]
            )
