# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
file1 = glob("SS-CUDA-i2-t64-s65536.cali")
file2 = glob("SS-CUDA-i2-t256-s262144.cali")
file3 = glob("SS-CUDA-i2-t1024-s1048576.cali")
all_files = [file1[0], file2[0], file3[0]]
print(all_files)
tk = th.Thicket.from_caliperreader(all_files)
# Out:
# ['SS-CUDA-i2-t64-s65536.cali', 'SS-CUDA-i2-t256-s262144.cali', 'SS-CUDA-i2-t1024-s1048576.cali']

# %%
tk.profile_mapping
# Out:
# OrderedDict([(753777932, 'SS-CUDA-i2-t1024-s1048576.cali'),
#              (1881612570, 'SS-CUDA-i2-t64-s65536.cali'),
#              (4161307711, 'SS-CUDA-i2-t256-s262144.cali')])

# %%
tk.dataframe
# Out:
#                                                                nid  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932     1
#                                                    1881612570    1
#                                                    4161307711    1
# {'name': 'comm', 'type': 'function'}               753777932     6
#                                                    1881612570    6
#                                                    4161307711    6
# {'name': 'comm_large', 'type': 'function'}         753777932     7
#                                                    1881612570    7
#                                                    4161307711    7
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932     8
#                                                    1881612570    8
#                                                    4161307711    8
# {'name': 'comp', 'type': 'function'}               753777932     3
#                                                    1881612570    3
#                                                    4161307711    3
# {'name': 'comp_large', 'type': 'function'}         753777932     5
#                                                    1881612570    5
#                                                    4161307711    5
# {'name': 'comp_small', 'type': 'function'}         753777932     4
#                                                    1881612570    4
#                                                    4161307711    4
# {'name': 'correctness_check ', 'type': 'function'} 753777932     9
#                                                    1881612570    9
#                                                    4161307711    9
# {'name': 'data_init', 'type': 'function'}          753777932     2
#                                                    1881612570    2
#                                                    4161307711    2
#
#                                                                 spot.channel  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932   regionprofile
#                                                    1881612570  regionprofile
#                                                    4161307711  regionprofile
# {'name': 'comm', 'type': 'function'}               753777932   regionprofile
#                                                    1881612570  regionprofile
#                                                    4161307711  regionprofile
# {'name': 'comm_large', 'type': 'function'}         753777932   regionprofile
#                                                    1881612570  regionprofile
#                                                    4161307711  regionprofile
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932   regionprofile
#                                                    1881612570  regionprofile
#                                                    4161307711  regionprofile
# {'name': 'comp', 'type': 'function'}               753777932   regionprofile
#                                                    1881612570  regionprofile
#                                                    4161307711  regionprofile
# {'name': 'comp_large', 'type': 'function'}         753777932   regionprofile
#                                                    1881612570  regionprofile
#                                                    4161307711  regionprofile
# {'name': 'comp_small', 'type': 'function'}         753777932   regionprofile
#                                                    1881612570  regionprofile
#                                                    4161307711  regionprofile
# {'name': 'correctness_check ', 'type': 'function'} 753777932   regionprofile
#                                                    1881612570  regionprofile
#                                                    4161307711  regionprofile
# {'name': 'data_init', 'type': 'function'}          753777932   regionprofile
#                                                    1881612570  regionprofile
#                                                    4161307711  regionprofile
#
#                                                                Min time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932        1.731449
#                                                    1881612570       0.475595
#                                                    4161307711       0.703748
# {'name': 'comm', 'type': 'function'}               753777932        0.003548
#                                                    1881612570       0.000296
#                                                    4161307711       0.001079
# {'name': 'comm_large', 'type': 'function'}         753777932        0.003528
#                                                    1881612570       0.000279
#                                                    4161307711       0.001059
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932        0.003499
#                                                    1881612570       0.000264
#                                                    4161307711       0.001035
# {'name': 'comp', 'type': 'function'}               753777932        1.372661
#                                                    1881612570       0.134144
#                                                    4161307711       0.364064
# {'name': 'comp_large', 'type': 'function'}         753777932        1.372555
#                                                    1881612570       0.134068
#                                                    4161307711       0.363940
# {'name': 'comp_small', 'type': 'function'}         753777932        0.000039
#                                                    1881612570       0.000040
#                                                    4161307711       0.000058
# {'name': 'correctness_check ', 'type': 'function'} 753777932        0.003941
#                                                    1881612570       0.000299
#                                                    4161307711       0.001058
# {'name': 'data_init', 'type': 'function'}          753777932        0.345400
#                                                    1881612570       0.335306
#                                                    4161307711       0.331834
#
#                                                                Max time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932        1.731449
#                                                    1881612570       0.475595
#                                                    4161307711       0.703748
# {'name': 'comm', 'type': 'function'}               753777932        0.003548
#                                                    1881612570       0.000296
#                                                    4161307711       0.001079
# {'name': 'comm_large', 'type': 'function'}         753777932        0.003528
#                                                    1881612570       0.000279
#                                                    4161307711       0.001059
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932        0.003499
#                                                    1881612570       0.000264
#                                                    4161307711       0.001035
# {'name': 'comp', 'type': 'function'}               753777932        1.372661
#                                                    1881612570       0.134144
#                                                    4161307711       0.364064
# {'name': 'comp_large', 'type': 'function'}         753777932        1.372555
#                                                    1881612570       0.134068
#                                                    4161307711       0.363940
# {'name': 'comp_small', 'type': 'function'}         753777932        0.000039
#                                                    1881612570       0.000040
#                                                    4161307711       0.000058
# {'name': 'correctness_check ', 'type': 'function'} 753777932        0.003941
#                                                    1881612570       0.000299
#                                                    4161307711       0.001058
# {'name': 'data_init', 'type': 'function'}          753777932        0.345400
#                                                    1881612570       0.335306
#                                                    4161307711       0.331834
#
#                                                                Avg time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932        1.731449
#                                                    1881612570       0.475595
#                                                    4161307711       0.703748
# {'name': 'comm', 'type': 'function'}               753777932        0.003548
#                                                    1881612570       0.000296
#                                                    4161307711       0.001079
# {'name': 'comm_large', 'type': 'function'}         753777932        0.003528
#                                                    1881612570       0.000279
#                                                    4161307711       0.001059
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932        0.003499
#                                                    1881612570       0.000264
#                                                    4161307711       0.001035
# {'name': 'comp', 'type': 'function'}               753777932        1.372661
#                                                    1881612570       0.134144
#                                                    4161307711       0.364064
# {'name': 'comp_large', 'type': 'function'}         753777932        1.372555
#                                                    1881612570       0.134068
#                                                    4161307711       0.363940
# {'name': 'comp_small', 'type': 'function'}         753777932        0.000039
#                                                    1881612570       0.000040
#                                                    4161307711       0.000058
# {'name': 'correctness_check ', 'type': 'function'} 753777932        0.003941
#                                                    1881612570       0.000299
#                                                    4161307711       0.001058
# {'name': 'data_init', 'type': 'function'}          753777932        0.345400
#                                                    1881612570       0.335306
#                                                    4161307711       0.331834
#
#                                                                Total time  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932     1.731449
#                                                    1881612570    0.475595
#                                                    4161307711    0.703748
# {'name': 'comm', 'type': 'function'}               753777932     0.003548
#                                                    1881612570    0.000296
#                                                    4161307711    0.001079
# {'name': 'comm_large', 'type': 'function'}         753777932     0.003528
#                                                    1881612570    0.000279
#                                                    4161307711    0.001059
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932     0.003499
#                                                    1881612570    0.000264
#                                                    4161307711    0.001035
# {'name': 'comp', 'type': 'function'}               753777932     1.372661
#                                                    1881612570    0.134144
#                                                    4161307711    0.364064
# {'name': 'comp_large', 'type': 'function'}         753777932     1.372555
#                                                    1881612570    0.134068
#                                                    4161307711    0.363940
# {'name': 'comp_small', 'type': 'function'}         753777932     0.000039
#                                                    1881612570    0.000040
#                                                    4161307711    0.000058
# {'name': 'correctness_check ', 'type': 'function'} 753777932     0.003941
#                                                    1881612570    0.000299
#                                                    4161307711    0.001058
# {'name': 'data_init', 'type': 'function'}          753777932     0.345400
#                                                    1881612570    0.335306
#                                                    4161307711    0.331834
#
#                                                                Avg GPU time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932            1.374444
#                                                    1881612570           0.134114
#                                                    4161307711           0.364035
# {'name': 'comm', 'type': 'function'}               753777932            0.001835
#                                                    1881612570           0.000022
#                                                    4161307711           0.000083
# {'name': 'comm_large', 'type': 'function'}         753777932            0.001835
#                                                    1881612570           0.000022
#                                                    4161307711           0.000083
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932            0.001835
#                                                    1881612570           0.000022
#                                                    4161307711           0.000083
# {'name': 'comp', 'type': 'function'}               753777932            1.372514
#                                                    1881612570           0.134073
#                                                    4161307711           0.363918
# {'name': 'comp_large', 'type': 'function'}         753777932            1.200175
#                                                    1881612570           0.126741
#                                                    4161307711           0.331443
# {'name': 'comp_small', 'type': 'function'}         753777932            0.172338
#                                                    1881612570           0.007332
#                                                    4161307711           0.032475
# {'name': 'correctness_check ', 'type': 'function'} 753777932            0.000088
#                                                    1881612570           0.000012
#                                                    4161307711           0.000027
# {'name': 'data_init', 'type': 'function'}          753777932            0.000008
#                                                    1881612570           0.000006
#                                                    4161307711           0.000007
#
#                                                                Min GPU time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932            1.374444
#                                                    1881612570           0.134114
#                                                    4161307711           0.364035
# {'name': 'comm', 'type': 'function'}               753777932            0.001835
#                                                    1881612570           0.000022
#                                                    4161307711           0.000083
# {'name': 'comm_large', 'type': 'function'}         753777932            0.001835
#                                                    1881612570           0.000022
#                                                    4161307711           0.000083
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932            0.001835
#                                                    1881612570           0.000022
#                                                    4161307711           0.000083
# {'name': 'comp', 'type': 'function'}               753777932            1.372514
#                                                    1881612570           0.134073
#                                                    4161307711           0.363918
# {'name': 'comp_large', 'type': 'function'}         753777932            1.200175
#                                                    1881612570           0.126741
#                                                    4161307711           0.331443
# {'name': 'comp_small', 'type': 'function'}         753777932            0.172338
#                                                    1881612570           0.007332
#                                                    4161307711           0.032475
# {'name': 'correctness_check ', 'type': 'function'} 753777932            0.000088
#                                                    1881612570           0.000012
#                                                    4161307711           0.000027
# {'name': 'data_init', 'type': 'function'}          753777932            0.000008
#                                                    1881612570           0.000006
#                                                    4161307711           0.000007
#
#                                                                Max GPU time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932            1.374444
#                                                    1881612570           0.134114
#                                                    4161307711           0.364035
# {'name': 'comm', 'type': 'function'}               753777932            0.001835
#                                                    1881612570           0.000022
#                                                    4161307711           0.000083
# {'name': 'comm_large', 'type': 'function'}         753777932            0.001835
#                                                    1881612570           0.000022
#                                                    4161307711           0.000083
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932            0.001835
#                                                    1881612570           0.000022
#                                                    4161307711           0.000083
# {'name': 'comp', 'type': 'function'}               753777932            1.372514
#                                                    1881612570           0.134073
#                                                    4161307711           0.363918
# {'name': 'comp_large', 'type': 'function'}         753777932            1.200175
#                                                    1881612570           0.126741
#                                                    4161307711           0.331443
# {'name': 'comp_small', 'type': 'function'}         753777932            0.172338
#                                                    1881612570           0.007332
#                                                    4161307711           0.032475
# {'name': 'correctness_check ', 'type': 'function'} 753777932            0.000088
#                                                    1881612570           0.000012
#                                                    4161307711           0.000027
# {'name': 'data_init', 'type': 'function'}          753777932            0.000008
#                                                    1881612570           0.000006
#                                                    4161307711           0.000007
#
#                                                                Total GPU time  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932         1.374444
#                                                    1881612570        0.134114
#                                                    4161307711        0.364035
# {'name': 'comm', 'type': 'function'}               753777932         0.001835
#                                                    1881612570        0.000022
#                                                    4161307711        0.000083
# {'name': 'comm_large', 'type': 'function'}         753777932         0.001835
#                                                    1881612570        0.000022
#                                                    4161307711        0.000083
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932         0.001835
#                                                    1881612570        0.000022
#                                                    4161307711        0.000083
# {'name': 'comp', 'type': 'function'}               753777932         1.372514
#                                                    1881612570        0.134073
#                                                    4161307711        0.363918
# {'name': 'comp_large', 'type': 'function'}         753777932         1.200175
#                                                    1881612570        0.126741
#                                                    4161307711        0.331443
# {'name': 'comp_small', 'type': 'function'}         753777932         0.172338
#                                                    1881612570        0.007332
#                                                    4161307711        0.032475
# {'name': 'correctness_check ', 'type': 'function'} 753777932         0.000088
#                                                    1881612570        0.000012
#                                                    4161307711        0.000027
# {'name': 'data_init', 'type': 'function'}          753777932         0.000008
#                                                    1881612570        0.000006
#                                                    4161307711        0.000007
#
#                                                                              name
# node                                               profile
# {'name': 'main', 'type': 'function'}               753777932                 main
#                                                    1881612570                main
#                                                    4161307711                main
# {'name': 'comm', 'type': 'function'}               753777932                 comm
#                                                    1881612570                comm
#                                                    4161307711                comm
# {'name': 'comm_large', 'type': 'function'}         753777932           comm_large
#                                                    1881612570          comm_large
#                                                    4161307711          comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}         753777932           cudaMemcpy
#                                                    1881612570          cudaMemcpy
#                                                    4161307711          cudaMemcpy
# {'name': 'comp', 'type': 'function'}               753777932                 comp
#                                                    1881612570                comp
#                                                    4161307711                comp
# {'name': 'comp_large', 'type': 'function'}         753777932           comp_large
#                                                    1881612570          comp_large
#                                                    4161307711          comp_large
# {'name': 'comp_small', 'type': 'function'}         753777932           comp_small
#                                                    1881612570          comp_small
#                                                    4161307711          comp_small
# {'name': 'correctness_check ', 'type': 'function'} 753777932   correctness_check
#                                                    1881612570  correctness_check
#                                                    4161307711  correctness_check
# {'name': 'data_init', 'type': 'function'}          753777932            data_init
#                                                    1881612570           data_init
#                                                    4161307711           data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 753777932            2.11.0-dev
# 1881612570           2.11.0-dev
# 4161307711           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 753777932   min#inclusive#sum#time.duration,max#inclusive#...
# 1881612570  min#inclusive#sum#time.duration,max#inclusive#...
# 4161307711  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 753777932                                             2
# 1881612570                                            2
# 4161307711                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 753777932   cuda.gputime,node.order  regionprofile         spot
# 1881612570  cuda.gputime,node.order  regionprofile         spot
# 4161307711  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order                     spot:output  \
# profile
# 753777932               true            true  SS-CUDA-i2-t1024-s1048576.cali
# 1881612570              true            true      SS-CUDA-i2-t64-s65536.cali
# 4161307711              true            true    SS-CUDA-i2-t256-s262144.cali
#
#             launchdate                                          libraries  \
# profile
# 753777932   1700034350  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1881612570  1700034284  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4161307711  1700034316  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                              cmdline cluster   Algorithm  \
# profile
# 753777932   [../../../Sample_Sort, 2, 1024, 1048576]       g  SampleSort
# 1881612570      [../../../Sample_Sort, 2, 64, 65536]       g  SampleSort
# 4161307711    [../../../Sample_Sort, 2, 256, 262144]       g  SampleSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize  \
# profile
# 753777932              CUDA      int               4    1048576
# 1881612570             CUDA      int               4      65536
# 4161307711             CUDA      int               4     262144
#
#                  InputType  num_threads  num_blocks  group_num  \
# profile
# 753777932   Reverse Sorted         1024        1024         16
# 1881612570  Reverse Sorted           64        1024         16
# 4161307711  Reverse Sorted          256        1024         16
#
#            implementation_source
# profile
# 753777932                     AI
# 1881612570                    AI
# 4161307711                    AI

# %%
#tk.statsframe.dataframe["time"] = 1

# %%
#print(tk.tree())

# %%
gb = tk.groupby("InputSize")
# Out:
# 3  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ad7bd58d3a0>, 262144: <thicket.thicket.Thicket object at 0x2ad7bd5898b0>, 1048576: <thicket.thicket.Thicket object at 0x2ad7bd5d73d0>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                                65536  \
#                                                                  nid
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64              1
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comm', 'type': 'function'}               64              6
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comm_large', 'type': 'function'}         64              7
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'cudaMemcpy', 'type': 'function'}         64              8
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comp', 'type': 'function'}               64              3
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comp_large', 'type': 'function'}         64              5
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comp_small', 'type': 'function'}         64              4
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'correctness_check ', 'type': 'function'} 64              9
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'data_init', 'type': 'function'}          64              2
#                                                    256          <NA>
#                                                    1024         <NA>
#
#                                                                                \
#                                                                  spot.channel
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comm', 'type': 'function'}               64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comm_large', 'type': 'function'}         64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp', 'type': 'function'}               64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp_large', 'type': 'function'}         64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp_small', 'type': 'function'}         64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'correctness_check ', 'type': 'function'} 64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'data_init', 'type': 'function'}          64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
#
#                                                                               \
#                                                                Min time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64               0.475595
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64               0.000296
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64               0.000279
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64               0.000264
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64               0.134144
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64               0.134068
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64               0.000040
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64               0.000299
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64               0.335306
#                                                    256                   NaN
#                                                    1024                  NaN
#
#                                                                               \
#                                                                Max time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64               0.475595
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64               0.000296
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64               0.000279
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64               0.000264
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64               0.134144
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64               0.134068
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64               0.000040
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64               0.000299
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64               0.335306
#                                                    256                   NaN
#                                                    1024                  NaN
#
#                                                                               \
#                                                                Avg time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64               0.475595
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64               0.000296
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64               0.000279
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64               0.000264
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64               0.134144
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64               0.134068
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64               0.000040
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64               0.000299
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64               0.335306
#                                                    256                   NaN
#                                                    1024                  NaN
#
#                                                                            \
#                                                                Total time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64            0.475595
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comm', 'type': 'function'}               64            0.000296
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comm_large', 'type': 'function'}         64            0.000279
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64            0.000264
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comp', 'type': 'function'}               64            0.134144
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comp_large', 'type': 'function'}         64            0.134068
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comp_small', 'type': 'function'}         64            0.000040
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'correctness_check ', 'type': 'function'} 64            0.000299
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'data_init', 'type': 'function'}          64            0.335306
#                                                    256                NaN
#                                                    1024               NaN
#
#                                                                                   \
#                                                                Avg GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                   0.134114
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                   0.000022
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                   0.000022
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                   0.000022
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                   0.134073
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                   0.126741
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                   0.007332
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                   0.000012
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                   0.000006
#                                                    256                       NaN
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Min GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                   0.134114
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                   0.000022
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                   0.000022
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                   0.000022
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                   0.134073
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                   0.126741
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                   0.007332
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                   0.000012
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                   0.000006
#                                                    256                       NaN
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Max GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                   0.134114
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                   0.000022
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                   0.000022
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                   0.000022
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                   0.134073
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                   0.126741
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                   0.007332
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                   0.000012
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                   0.000006
#                                                    256                       NaN
#                                                    1024                      NaN
#
#                                                                                \
#                                                                Total GPU time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                0.134114
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comm', 'type': 'function'}               64                0.000022
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comm_large', 'type': 'function'}         64                0.000022
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                0.000022
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp', 'type': 'function'}               64                0.134073
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp_large', 'type': 'function'}         64                0.126741
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp_small', 'type': 'function'}         64                0.007332
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                0.000012
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'data_init', 'type': 'function'}          64                0.000006
#                                                    256                    NaN
#                                                    1024                   NaN
#
#                                                                262144  \
#                                                                   nid
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64            <NA>
#                                                    256              1
#                                                    1024          <NA>
# {'name': 'comm', 'type': 'function'}               64            <NA>
#                                                    256              6
#                                                    1024          <NA>
# {'name': 'comm_large', 'type': 'function'}         64            <NA>
#                                                    256              7
#                                                    1024          <NA>
# {'name': 'cudaMemcpy', 'type': 'function'}         64            <NA>
#                                                    256              8
#                                                    1024          <NA>
# {'name': 'comp', 'type': 'function'}               64            <NA>
#                                                    256              3
#                                                    1024          <NA>
# {'name': 'comp_large', 'type': 'function'}         64            <NA>
#                                                    256              5
#                                                    1024          <NA>
# {'name': 'comp_small', 'type': 'function'}         64            <NA>
#                                                    256              4
#                                                    1024          <NA>
# {'name': 'correctness_check ', 'type': 'function'} 64            <NA>
#                                                    256              9
#                                                    1024          <NA>
# {'name': 'data_init', 'type': 'function'}          64            <NA>
#                                                    256              2
#                                                    1024          <NA>
#
#                                                                                \
#                                                                  spot.channel
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comm', 'type': 'function'}               64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comm_large', 'type': 'function'}         64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comp', 'type': 'function'}               64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comp_large', 'type': 'function'}         64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comp_small', 'type': 'function'}         64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'data_init', 'type': 'function'}          64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
#
#                                                                               \
#                                                                Min time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                    NaN
#                                                    256              0.703748
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64                    NaN
#                                                    256              0.001079
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64                    NaN
#                                                    256              0.001059
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                    NaN
#                                                    256              0.001035
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64                    NaN
#                                                    256              0.364064
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64                    NaN
#                                                    256              0.363940
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64                    NaN
#                                                    256              0.000058
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                    NaN
#                                                    256              0.001058
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64                    NaN
#                                                    256              0.331834
#                                                    1024                  NaN
#
#                                                                               \
#                                                                Max time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                    NaN
#                                                    256              0.703748
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64                    NaN
#                                                    256              0.001079
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64                    NaN
#                                                    256              0.001059
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                    NaN
#                                                    256              0.001035
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64                    NaN
#                                                    256              0.364064
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64                    NaN
#                                                    256              0.363940
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64                    NaN
#                                                    256              0.000058
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                    NaN
#                                                    256              0.001058
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64                    NaN
#                                                    256              0.331834
#                                                    1024                  NaN
#
#                                                                               \
#                                                                Avg time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                    NaN
#                                                    256              0.703748
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64                    NaN
#                                                    256              0.001079
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64                    NaN
#                                                    256              0.001059
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                    NaN
#                                                    256              0.001035
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64                    NaN
#                                                    256              0.364064
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64                    NaN
#                                                    256              0.363940
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64                    NaN
#                                                    256              0.000058
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                    NaN
#                                                    256              0.001058
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64                    NaN
#                                                    256              0.331834
#                                                    1024                  NaN
#
#                                                                            \
#                                                                Total time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                 NaN
#                                                    256           0.703748
#                                                    1024               NaN
# {'name': 'comm', 'type': 'function'}               64                 NaN
#                                                    256           0.001079
#                                                    1024               NaN
# {'name': 'comm_large', 'type': 'function'}         64                 NaN
#                                                    256           0.001059
#                                                    1024               NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                 NaN
#                                                    256           0.001035
#                                                    1024               NaN
# {'name': 'comp', 'type': 'function'}               64                 NaN
#                                                    256           0.364064
#                                                    1024               NaN
# {'name': 'comp_large', 'type': 'function'}         64                 NaN
#                                                    256           0.363940
#                                                    1024               NaN
# {'name': 'comp_small', 'type': 'function'}         64                 NaN
#                                                    256           0.000058
#                                                    1024               NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                 NaN
#                                                    256           0.001058
#                                                    1024               NaN
# {'name': 'data_init', 'type': 'function'}          64                 NaN
#                                                    256           0.331834
#                                                    1024               NaN
#
#                                                                                   \
#                                                                Avg GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                  0.364035
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                  0.000083
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.000083
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                  0.000083
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                  0.363918
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.331443
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                  0.032475
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                  0.000027
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                  0.000007
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Min GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                  0.364035
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                  0.000083
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.000083
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                  0.000083
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                  0.363918
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.331443
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                  0.032475
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                  0.000027
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                  0.000007
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Max GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                  0.364035
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                  0.000083
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.000083
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                  0.000083
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                  0.363918
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.331443
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                  0.032475
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                  0.000027
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                  0.000007
#                                                    1024                      NaN
#
#                                                                                \
#                                                                Total GPU time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                     NaN
#                                                    256               0.364035
#                                                    1024                   NaN
# {'name': 'comm', 'type': 'function'}               64                     NaN
#                                                    256               0.000083
#                                                    1024                   NaN
# {'name': 'comm_large', 'type': 'function'}         64                     NaN
#                                                    256               0.000083
#                                                    1024                   NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                     NaN
#                                                    256               0.000083
#                                                    1024                   NaN
# {'name': 'comp', 'type': 'function'}               64                     NaN
#                                                    256               0.363918
#                                                    1024                   NaN
# {'name': 'comp_large', 'type': 'function'}         64                     NaN
#                                                    256               0.331443
#                                                    1024                   NaN
# {'name': 'comp_small', 'type': 'function'}         64                     NaN
#                                                    256               0.032475
#                                                    1024                   NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                     NaN
#                                                    256               0.000027
#                                                    1024                   NaN
# ...
#                                                    256                   NaN
#                                                    1024             1.372661
# {'name': 'comp_large', 'type': 'function'}         64                    NaN
#                                                    256                   NaN
#                                                    1024             1.372555
# {'name': 'comp_small', 'type': 'function'}         64                    NaN
#                                                    256                   NaN
#                                                    1024             0.000039
# {'name': 'correctness_check ', 'type': 'function'} 64                    NaN
#                                                    256                   NaN
#                                                    1024             0.003941
# {'name': 'data_init', 'type': 'function'}          64                    NaN
#                                                    256                   NaN
#                                                    1024             0.345400
#
#                                                                            \
#                                                                Total time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                 NaN
#                                                    256                NaN
#                                                    1024          1.731449
# {'name': 'comm', 'type': 'function'}               64                 NaN
#                                                    256                NaN
#                                                    1024          0.003548
# {'name': 'comm_large', 'type': 'function'}         64                 NaN
#                                                    256                NaN
#                                                    1024          0.003528
# {'name': 'cudaMemcpy', 'type': 'function'}         64                 NaN
#                                                    256                NaN
#                                                    1024          0.003499
# {'name': 'comp', 'type': 'function'}               64                 NaN
#                                                    256                NaN
#                                                    1024          1.372661
# {'name': 'comp_large', 'type': 'function'}         64                 NaN
#                                                    256                NaN
#                                                    1024          1.372555
# {'name': 'comp_small', 'type': 'function'}         64                 NaN
#                                                    256                NaN
#                                                    1024          0.000039
# {'name': 'correctness_check ', 'type': 'function'} 64                 NaN
#                                                    256                NaN
#                                                    1024          0.003941
# {'name': 'data_init', 'type': 'function'}          64                 NaN
#                                                    256                NaN
#                                                    1024          0.345400
#
#                                                                                   \
#                                                                Avg GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 1.374444
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001835
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001835
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001835
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 1.372514
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 1.200175
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.172338
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000088
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000008
#
#                                                                                   \
#                                                                Min GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 1.374444
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001835
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001835
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001835
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 1.372514
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 1.200175
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.172338
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000088
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000008
#
#                                                                                   \
#                                                                Max GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 1.374444
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001835
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001835
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001835
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 1.372514
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 1.200175
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.172338
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000088
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000008
#
#                                                                                \
#                                                                Total GPU time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                     NaN
#                                                    256                    NaN
#                                                    1024              1.374444
# {'name': 'comm', 'type': 'function'}               64                     NaN
#                                                    256                    NaN
#                                                    1024              0.001835
# {'name': 'comm_large', 'type': 'function'}         64                     NaN
#                                                    256                    NaN
#                                                    1024              0.001835
# {'name': 'cudaMemcpy', 'type': 'function'}         64                     NaN
#                                                    256                    NaN
#                                                    1024              0.001835
# {'name': 'comp', 'type': 'function'}               64                     NaN
#                                                    256                    NaN
#                                                    1024              1.372514
# {'name': 'comp_large', 'type': 'function'}         64                     NaN
#                                                    256                    NaN
#                                                    1024              1.200175
# {'name': 'comp_small', 'type': 'function'}         64                     NaN
#                                                    256                    NaN
#                                                    1024              0.172338
# {'name': 'correctness_check ', 'type': 'function'} 64                     NaN
#                                                    256                    NaN
#                                                    1024              0.000088
# {'name': 'data_init', 'type': 'function'}          64                     NaN
#                                                    256                    NaN
#                                                    1024              0.000008
#
#                                                                               name
#
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                         main
#                                                    256                        main
#                                                    1024                       main
# {'name': 'comm', 'type': 'function'}               64                         comm
#                                                    256                        comm
#                                                    1024                       comm
# {'name': 'comm_large', 'type': 'function'}         64                   comm_large
#                                                    256                  comm_large
#                                                    1024                 comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}         64                   cudaMemcpy
#                                                    256                  cudaMemcpy
#                                                    1024                 cudaMemcpy
# {'name': 'comp', 'type': 'function'}               64                         comp
#                                                    256                        comp
#                                                    1024                       comp
# {'name': 'comp_large', 'type': 'function'}         64                   comp_large
#                                                    256                  comp_large
#                                                    1024                 comp_large
# {'name': 'comp_small', 'type': 'function'}         64                   comp_small
#                                                    256                  comp_small
#                                                    1024                 comp_small
# {'name': 'correctness_check ', 'type': 'function'} 64           correctness_check
#                                                    256          correctness_check
#                                                    1024         correctness_check
# {'name': 'data_init', 'type': 'function'}          64                    data_init
#                                                    256                   data_init
#                                                    1024                  data_init

# %%
ctk.metadata
# Out:
#                          65536    \
#             cali.caliper.version
# num_threads
# 64                    2.11.0-dev
# 256                          NaN
# 1024                         NaN
#
#                                                                 \
#                                                   spot.metrics
# num_threads
# 64           min#inclusive#sum#time.duration,max#inclusive#...
# 256                                                        NaN
# 1024                                                       NaN
#
#                                                          \
#             spot.timeseries.metrics spot.format.version
# num_threads
# 64                                                  2.0
# 256                             NaN                 NaN
# 1024                            NaN                 NaN
#
#                                                                   \
#                         spot.options  spot.channels cali.channel
# num_threads
# 64           cuda.gputime,node.order  regionprofile         spot
# 256                              NaN            NaN          NaN
# 1024                             NaN            NaN          NaN
#
#                                                                            \
#             spot:cuda.gputime spot:node.order                 spot:output
# num_threads
# 64                       true            true  SS-CUDA-i2-t64-s65536.cali
# 256                       NaN             NaN                         NaN
# 1024                      NaN             NaN                         NaN
#
#                                                                               \
#                launchdate                                          libraries
# num_threads
# 64           1.700034e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 256                   NaN                                                NaN
# 1024                  NaN                                                NaN
#
#                                                                        \
#                                           cmdline cluster   Algorithm
# num_threads
# 64           [../../../Sample_Sort, 2, 64, 65536]       g  SampleSort
# 256                                           NaN     NaN         NaN
# 1024                                          NaN     NaN         NaN
#
#                                                                 \
#             ProgrammingModel Datatype SizeOfDatatype InputSize
# num_threads
# 64                      CUDA      int            4.0   65536.0
# 256                      NaN      NaN            NaN       NaN
# 1024                     NaN      NaN            NaN       NaN
#
#                                                                         \
#                   InputType num_blocks group_num implementation_source
# num_threads
# 64           Reverse Sorted     1024.0      16.0                    AI
# 256                     NaN        NaN       NaN                   NaN
# 1024                    NaN        NaN       NaN                   NaN
#
#                          262144   \
#             cali.caliper.version
# num_threads
# 64                           NaN
# 256                   2.11.0-dev
# 1024                         NaN
#
#                                                                 \
#                                                   spot.metrics
# num_threads
# 64                                                         NaN
# 256          min#inclusive#sum#time.duration,max#inclusive#...
# 1024                                                       NaN
#
#                                                          \
#             spot.timeseries.metrics spot.format.version
# num_threads
# 64                              NaN                 NaN
# 256                                                 2.0
# 1024                            NaN                 NaN
#
#                                                                   \
#                         spot.options  spot.channels cali.channel
# num_threads
# 64                               NaN            NaN          NaN
# 256          cuda.gputime,node.order  regionprofile         spot
# 1024                             NaN            NaN          NaN
#
#                                                                              \
#             spot:cuda.gputime spot:node.order                   spot:output
# num_threads
# 64                        NaN             NaN                           NaN
# 256                      true            true  SS-CUDA-i2-t256-s262144.cali
# 1024                      NaN             NaN                           NaN
#
#                                                                               \
#                launchdate                                          libraries
# num_threads
# 64                    NaN                                                NaN
# 256          1.700034e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1024                  NaN                                                NaN
#
#                                                                          \
#                                             cmdline cluster   Algorithm
# num_threads
# 64                                              NaN     NaN         NaN
# 256          [../../../Sample_Sort, 2, 256, 262144]       g  SampleSort
# 1024                                            NaN     NaN         NaN
#
#                                                                 \
#             ProgrammingModel Datatype SizeOfDatatype InputSize
# num_threads
# 64                       NaN      NaN            NaN       NaN
# 256                     CUDA      int            4.0  262144.0
# 1024                     NaN      NaN            NaN       NaN
#
#                                                                         \
#                   InputType num_blocks group_num implementation_source
# num_threads
# 64                      NaN        NaN       NaN                   NaN
# 256          Reverse Sorted     1024.0      16.0                    AI
# 1024                    NaN        NaN       NaN                   NaN
#
#                          1048576  \
#             cali.caliper.version
# num_threads
# 64                           NaN
# 256                          NaN
# 1024                  2.11.0-dev
#
#                                                                 \
#                                                   spot.metrics
# num_threads
# 64                                                         NaN
# 256                                                        NaN
# 1024         min#inclusive#sum#time.duration,max#inclusive#...
#
#                                                          \
#             spot.timeseries.metrics spot.format.version
# num_threads
# 64                              NaN                 NaN
# 256                             NaN                 NaN
# 1024                                                2.0
#
#                                                                   \
#                         spot.options  spot.channels cali.channel
# num_threads
# 64                               NaN            NaN          NaN
# 256                              NaN            NaN          NaN
# 1024         cuda.gputime,node.order  regionprofile         spot
#
#                                                                                \
#             spot:cuda.gputime spot:node.order                     spot:output
# num_threads
# 64                        NaN             NaN                             NaN
# 256                       NaN             NaN                             NaN
# 1024                     true            true  SS-CUDA-i2-t1024-s1048576.cali
#
#                                                                               \
#                launchdate                                          libraries
# num_threads
# 64                    NaN                                                NaN
# 256                   NaN                                                NaN
# 1024         1.700034e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                                                            \
#                                               cmdline cluster   Algorithm
# num_threads
# 64                                                NaN     NaN         NaN
# 256                                               NaN     NaN         NaN
# 1024         [../../../Sample_Sort, 2, 1024, 1048576]       g  SampleSort
#
#                                                                  \
#             ProgrammingModel Datatype SizeOfDatatype  InputSize
# num_threads
# 64                       NaN      NaN            NaN        NaN
# 256                      NaN      NaN            NaN        NaN
# 1024                    CUDA      int            4.0  1048576.0
#
#
#                   InputType num_blocks group_num implementation_source
# num_threads
# 64                      NaN        NaN       NaN                   NaN
# 256                     NaN        NaN       NaN                   NaN
# 1024         Reverse Sorted     1024.0      16.0                    AI

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (65536, "nid"), (1048576, "nid"), (262144, "nid"),(65536, "spot.channel"), (1048576, "spot.channel"), (262144, "spot.channel")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([(65536, "Min time/rank"), (1048576, "Min time/rank"), (262144, "Min time/rank"),(65536, "Max time/rank"), (1048576, "Max time/rank"), (262144, "Max time/rank"), (65536, "Avg time/rank"), (1048576, "Avg time/rank"), (262144, "Avg time/rank")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([(65536, "Min GPU time/rank"), (1048576, "Min GPU time/rank"), (262144, "Min GPU time/rank"),(65536, "Max GPU time/rank"), (1048576, "Max GPU time/rank"), (262144, "Max GPU time/rank"), (65536, "Avg GPU time/rank"), (1048576, "Avg GPU time/rank"), (262144, "Avg GPU time/rank"), (65536, "Total GPU time"), (1048576, "Total GPU time"), (262144, "Total GPU time")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

# %%
ctk.dataframe
# Out:
#                                level_0 index      65536     262144    1048576
#                                              Total time Total time Total time
# name               num_threads
# main               64                0     0   0.475595        NaN        NaN
#                    256               1     1        NaN   0.703748        NaN
#                    1024              2     2        NaN        NaN   1.731449
# comm               64                3     3   0.000296        NaN        NaN
#                    256               4     4        NaN   0.001079        NaN
#                    1024              5     5        NaN        NaN   0.003548
# comm_large         64                6     6   0.000279        NaN        NaN
#                    256               7     7        NaN   0.001059        NaN
#                    1024              8     8        NaN        NaN   0.003528
# cudaMemcpy         64                9     9   0.000264        NaN        NaN
#                    256              10    10        NaN   0.001035        NaN
#                    1024             11    11        NaN        NaN   0.003499
# comp               64               12    12   0.134144        NaN        NaN
#                    256              13    13        NaN   0.364064        NaN
#                    1024             14    14        NaN        NaN   1.372661
# comp_large         64               15    15   0.134068        NaN        NaN
#                    256              16    16        NaN   0.363940        NaN
#                    1024             17    17        NaN        NaN   1.372555
# comp_small         64               18    18   0.000040        NaN        NaN
#                    256              19    19        NaN   0.000058        NaN
#                    1024             20    20        NaN        NaN   0.000039
# correctness_check  64               21    21   0.000299        NaN        NaN
#                    256              22    22        NaN   0.001058        NaN
#                    1024             23    23        NaN        NaN   0.003941
# data_init          64               24    24   0.335306        NaN        NaN
#                    256              25    25        NaN   0.331834        NaN
#                    1024             26    26        NaN        NaN   0.345400

# %%
# Define common variables
numThreads = [64,256, 1024]
dataType = "Reverse"
functions = ["main", "comm", "comp"]

# %%
def plot_mpl(df, title, xlabel, ylabel, columns):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(columns)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(numThreads)
    plt.show()
    return fig, ax

# %%
for func in functions:
    tempData = [ctk.dataframe.loc[func][65536].at[64, "Total time"], ctk.dataframe.loc[func][262144].at[256, "Total time"], ctk.dataframe.loc[func][1048576].at[1024, "Total time"]]
    dfTemp = pd.DataFrame(tempData, columns=["Total time"], index=numThreads) 
    plot_mpl(
                df=dfTemp,
                title= func + "-" + dataType + "-Weak_Scaling",
                xlabel="Number of Threads",
                ylabel="Time (seconds)",
                columns=["Total time"]
            )
