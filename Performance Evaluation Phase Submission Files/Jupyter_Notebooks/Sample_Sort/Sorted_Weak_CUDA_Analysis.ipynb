# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
file1 = glob("SS-CUDA-i1-t64-s65536.cali")
file2 = glob("SS-CUDA-i1-t256-s262144.cali")
file3 = glob("SS-CUDA-i1-t1024-s1048576.cali")
all_files = [file1[0], file2[0], file3[0]]
print(all_files)
tk = th.Thicket.from_caliperreader(all_files)
# Out:
# ['SS-CUDA-i1-t64-s65536.cali', 'SS-CUDA-i1-t256-s262144.cali', 'SS-CUDA-i1-t1024-s1048576.cali']

# %%
tk.profile_mapping
# Out:
# OrderedDict([(3276735306, 'SS-CUDA-i1-t64-s65536.cali'),
#              (3317981574, 'SS-CUDA-i1-t1024-s1048576.cali'),
#              (3760525145, 'SS-CUDA-i1-t256-s262144.cali')])

# %%
tk.dataframe
# Out:
#                                                                nid  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306    1
#                                                    3317981574    1
#                                                    3760525145    1
# {'name': 'comm', 'type': 'function'}               3276735306    6
#                                                    3317981574    6
#                                                    3760525145    6
# {'name': 'comm_large', 'type': 'function'}         3276735306    7
#                                                    3317981574    7
#                                                    3760525145    7
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306    8
#                                                    3317981574    8
#                                                    3760525145    8
# {'name': 'comp', 'type': 'function'}               3276735306    3
#                                                    3317981574    3
#                                                    3760525145    3
# {'name': 'comp_large', 'type': 'function'}         3276735306    5
#                                                    3317981574    5
#                                                    3760525145    5
# {'name': 'comp_small', 'type': 'function'}         3276735306    4
#                                                    3317981574    4
#                                                    3760525145    4
# {'name': 'correctness_check ', 'type': 'function'} 3276735306    9
#                                                    3317981574    9
#                                                    3760525145    9
# {'name': 'data_init', 'type': 'function'}          3276735306    2
#                                                    3317981574    2
#                                                    3760525145    2
#
#                                                                 spot.channel  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306  regionprofile
#                                                    3317981574  regionprofile
#                                                    3760525145  regionprofile
# {'name': 'comm', 'type': 'function'}               3276735306  regionprofile
#                                                    3317981574  regionprofile
#                                                    3760525145  regionprofile
# {'name': 'comm_large', 'type': 'function'}         3276735306  regionprofile
#                                                    3317981574  regionprofile
#                                                    3760525145  regionprofile
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306  regionprofile
#                                                    3317981574  regionprofile
#                                                    3760525145  regionprofile
# {'name': 'comp', 'type': 'function'}               3276735306  regionprofile
#                                                    3317981574  regionprofile
#                                                    3760525145  regionprofile
# {'name': 'comp_large', 'type': 'function'}         3276735306  regionprofile
#                                                    3317981574  regionprofile
#                                                    3760525145  regionprofile
# {'name': 'comp_small', 'type': 'function'}         3276735306  regionprofile
#                                                    3317981574  regionprofile
#                                                    3760525145  regionprofile
# {'name': 'correctness_check ', 'type': 'function'} 3276735306  regionprofile
#                                                    3317981574  regionprofile
#                                                    3760525145  regionprofile
# {'name': 'data_init', 'type': 'function'}          3276735306  regionprofile
#                                                    3317981574  regionprofile
#                                                    3760525145  regionprofile
#
#                                                                Min time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306       0.360051
#                                                    3317981574       0.699833
#                                                    3760525145       0.412749
# {'name': 'comm', 'type': 'function'}               3276735306       0.000294
#                                                    3317981574       0.002505
#                                                    3760525145       0.001018
# {'name': 'comm_large', 'type': 'function'}         3276735306       0.000280
#                                                    3317981574       0.002492
#                                                    3760525145       0.001003
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306       0.000265
#                                                    3317981574       0.002471
#                                                    3760525145       0.000977
# {'name': 'comp', 'type': 'function'}               3276735306       0.016741
#                                                    3317981574       0.342677
#                                                    3760525145       0.073821
# {'name': 'comp_large', 'type': 'function'}         3276735306       0.016664
#                                                    3317981574       0.342598
#                                                    3760525145       0.073725
# {'name': 'comp_small', 'type': 'function'}         3276735306       0.000040
#                                                    3317981574       0.000038
#                                                    3760525145       0.000048
# {'name': 'correctness_check ', 'type': 'function'} 3276735306       0.000301
#                                                    3317981574       0.003845
#                                                    3760525145       0.001040
# {'name': 'data_init', 'type': 'function'}          3276735306       0.337184
#                                                    3317981574       0.345184
#                                                    3760525145       0.331173
#
#                                                                Max time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306       0.360051
#                                                    3317981574       0.699833
#                                                    3760525145       0.412749
# {'name': 'comm', 'type': 'function'}               3276735306       0.000294
#                                                    3317981574       0.002505
#                                                    3760525145       0.001018
# {'name': 'comm_large', 'type': 'function'}         3276735306       0.000280
#                                                    3317981574       0.002492
#                                                    3760525145       0.001003
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306       0.000265
#                                                    3317981574       0.002471
#                                                    3760525145       0.000977
# {'name': 'comp', 'type': 'function'}               3276735306       0.016741
#                                                    3317981574       0.342677
#                                                    3760525145       0.073821
# {'name': 'comp_large', 'type': 'function'}         3276735306       0.016664
#                                                    3317981574       0.342598
#                                                    3760525145       0.073725
# {'name': 'comp_small', 'type': 'function'}         3276735306       0.000040
#                                                    3317981574       0.000038
#                                                    3760525145       0.000048
# {'name': 'correctness_check ', 'type': 'function'} 3276735306       0.000301
#                                                    3317981574       0.003845
#                                                    3760525145       0.001040
# {'name': 'data_init', 'type': 'function'}          3276735306       0.337184
#                                                    3317981574       0.345184
#                                                    3760525145       0.331173
#
#                                                                Avg time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306       0.360051
#                                                    3317981574       0.699833
#                                                    3760525145       0.412749
# {'name': 'comm', 'type': 'function'}               3276735306       0.000294
#                                                    3317981574       0.002505
#                                                    3760525145       0.001018
# {'name': 'comm_large', 'type': 'function'}         3276735306       0.000280
#                                                    3317981574       0.002492
#                                                    3760525145       0.001003
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306       0.000265
#                                                    3317981574       0.002471
#                                                    3760525145       0.000977
# {'name': 'comp', 'type': 'function'}               3276735306       0.016741
#                                                    3317981574       0.342677
#                                                    3760525145       0.073821
# {'name': 'comp_large', 'type': 'function'}         3276735306       0.016664
#                                                    3317981574       0.342598
#                                                    3760525145       0.073725
# {'name': 'comp_small', 'type': 'function'}         3276735306       0.000040
#                                                    3317981574       0.000038
#                                                    3760525145       0.000048
# {'name': 'correctness_check ', 'type': 'function'} 3276735306       0.000301
#                                                    3317981574       0.003845
#                                                    3760525145       0.001040
# {'name': 'data_init', 'type': 'function'}          3276735306       0.337184
#                                                    3317981574       0.345184
#                                                    3760525145       0.331173
#
#                                                                Total time  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306    0.360051
#                                                    3317981574    0.699833
#                                                    3760525145    0.412749
# {'name': 'comm', 'type': 'function'}               3276735306    0.000294
#                                                    3317981574    0.002505
#                                                    3760525145    0.001018
# {'name': 'comm_large', 'type': 'function'}         3276735306    0.000280
#                                                    3317981574    0.002492
#                                                    3760525145    0.001003
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306    0.000265
#                                                    3317981574    0.002471
#                                                    3760525145    0.000977
# {'name': 'comp', 'type': 'function'}               3276735306    0.016741
#                                                    3317981574    0.342677
#                                                    3760525145    0.073821
# {'name': 'comp_large', 'type': 'function'}         3276735306    0.016664
#                                                    3317981574    0.342598
#                                                    3760525145    0.073725
# {'name': 'comp_small', 'type': 'function'}         3276735306    0.000040
#                                                    3317981574    0.000038
#                                                    3760525145    0.000048
# {'name': 'correctness_check ', 'type': 'function'} 3276735306    0.000301
#                                                    3317981574    0.003845
#                                                    3760525145    0.001040
# {'name': 'data_init', 'type': 'function'}          3276735306    0.337184
#                                                    3317981574    0.345184
#                                                    3760525145    0.331173
#
#                                                                Avg GPU time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306           0.016714
#                                                    3317981574           0.344600
#                                                    3760525145           0.073842
# {'name': 'comm', 'type': 'function'}               3276735306           0.000024
#                                                    3317981574           0.001904
#                                                    3760525145           0.000088
# {'name': 'comm_large', 'type': 'function'}         3276735306           0.000024
#                                                    3317981574           0.001904
#                                                    3760525145           0.000088
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306           0.000024
#                                                    3317981574           0.001904
#                                                    3760525145           0.000088
# {'name': 'comp', 'type': 'function'}               3276735306           0.016670
#                                                    3317981574           0.342598
#                                                    3760525145           0.073717
# {'name': 'comp_large', 'type': 'function'}         3276735306           0.009699
#                                                    3317981574           0.172503
#                                                    3760525145           0.041517
# {'name': 'comp_small', 'type': 'function'}         3276735306           0.006971
#                                                    3317981574           0.170095
#                                                    3760525145           0.032200
# {'name': 'correctness_check ', 'type': 'function'} 3276735306           0.000014
#                                                    3317981574           0.000088
#                                                    3760525145           0.000031
# {'name': 'data_init', 'type': 'function'}          3276735306           0.000006
#                                                    3317981574           0.000010
#                                                    3760525145           0.000007
#
#                                                                Min GPU time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306           0.016714
#                                                    3317981574           0.344600
#                                                    3760525145           0.073842
# {'name': 'comm', 'type': 'function'}               3276735306           0.000024
#                                                    3317981574           0.001904
#                                                    3760525145           0.000088
# {'name': 'comm_large', 'type': 'function'}         3276735306           0.000024
#                                                    3317981574           0.001904
#                                                    3760525145           0.000088
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306           0.000024
#                                                    3317981574           0.001904
#                                                    3760525145           0.000088
# {'name': 'comp', 'type': 'function'}               3276735306           0.016670
#                                                    3317981574           0.342598
#                                                    3760525145           0.073717
# {'name': 'comp_large', 'type': 'function'}         3276735306           0.009699
#                                                    3317981574           0.172503
#                                                    3760525145           0.041517
# {'name': 'comp_small', 'type': 'function'}         3276735306           0.006971
#                                                    3317981574           0.170095
#                                                    3760525145           0.032200
# {'name': 'correctness_check ', 'type': 'function'} 3276735306           0.000014
#                                                    3317981574           0.000088
#                                                    3760525145           0.000031
# {'name': 'data_init', 'type': 'function'}          3276735306           0.000006
#                                                    3317981574           0.000010
#                                                    3760525145           0.000007
#
#                                                                Max GPU time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306           0.016714
#                                                    3317981574           0.344600
#                                                    3760525145           0.073842
# {'name': 'comm', 'type': 'function'}               3276735306           0.000024
#                                                    3317981574           0.001904
#                                                    3760525145           0.000088
# {'name': 'comm_large', 'type': 'function'}         3276735306           0.000024
#                                                    3317981574           0.001904
#                                                    3760525145           0.000088
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306           0.000024
#                                                    3317981574           0.001904
#                                                    3760525145           0.000088
# {'name': 'comp', 'type': 'function'}               3276735306           0.016670
#                                                    3317981574           0.342598
#                                                    3760525145           0.073717
# {'name': 'comp_large', 'type': 'function'}         3276735306           0.009699
#                                                    3317981574           0.172503
#                                                    3760525145           0.041517
# {'name': 'comp_small', 'type': 'function'}         3276735306           0.006971
#                                                    3317981574           0.170095
#                                                    3760525145           0.032200
# {'name': 'correctness_check ', 'type': 'function'} 3276735306           0.000014
#                                                    3317981574           0.000088
#                                                    3760525145           0.000031
# {'name': 'data_init', 'type': 'function'}          3276735306           0.000006
#                                                    3317981574           0.000010
#                                                    3760525145           0.000007
#
#                                                                Total GPU time  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306        0.016714
#                                                    3317981574        0.344600
#                                                    3760525145        0.073842
# {'name': 'comm', 'type': 'function'}               3276735306        0.000024
#                                                    3317981574        0.001904
#                                                    3760525145        0.000088
# {'name': 'comm_large', 'type': 'function'}         3276735306        0.000024
#                                                    3317981574        0.001904
#                                                    3760525145        0.000088
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306        0.000024
#                                                    3317981574        0.001904
#                                                    3760525145        0.000088
# {'name': 'comp', 'type': 'function'}               3276735306        0.016670
#                                                    3317981574        0.342598
#                                                    3760525145        0.073717
# {'name': 'comp_large', 'type': 'function'}         3276735306        0.009699
#                                                    3317981574        0.172503
#                                                    3760525145        0.041517
# {'name': 'comp_small', 'type': 'function'}         3276735306        0.006971
#                                                    3317981574        0.170095
#                                                    3760525145        0.032200
# {'name': 'correctness_check ', 'type': 'function'} 3276735306        0.000014
#                                                    3317981574        0.000088
#                                                    3760525145        0.000031
# {'name': 'data_init', 'type': 'function'}          3276735306        0.000006
#                                                    3317981574        0.000010
#                                                    3760525145        0.000007
#
#                                                                              name
# node                                               profile
# {'name': 'main', 'type': 'function'}               3276735306                main
#                                                    3317981574                main
#                                                    3760525145                main
# {'name': 'comm', 'type': 'function'}               3276735306                comm
#                                                    3317981574                comm
#                                                    3760525145                comm
# {'name': 'comm_large', 'type': 'function'}         3276735306          comm_large
#                                                    3317981574          comm_large
#                                                    3760525145          comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}         3276735306          cudaMemcpy
#                                                    3317981574          cudaMemcpy
#                                                    3760525145          cudaMemcpy
# {'name': 'comp', 'type': 'function'}               3276735306                comp
#                                                    3317981574                comp
#                                                    3760525145                comp
# {'name': 'comp_large', 'type': 'function'}         3276735306          comp_large
#                                                    3317981574          comp_large
#                                                    3760525145          comp_large
# {'name': 'comp_small', 'type': 'function'}         3276735306          comp_small
#                                                    3317981574          comp_small
#                                                    3760525145          comp_small
# {'name': 'correctness_check ', 'type': 'function'} 3276735306  correctness_check
#                                                    3317981574  correctness_check
#                                                    3760525145  correctness_check
# {'name': 'data_init', 'type': 'function'}          3276735306           data_init
#                                                    3317981574           data_init
#                                                    3760525145           data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 3276735306           2.11.0-dev
# 3317981574           2.11.0-dev
# 3760525145           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 3276735306  min#inclusive#sum#time.duration,max#inclusive#...
# 3317981574  min#inclusive#sum#time.duration,max#inclusive#...
# 3760525145  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 3276735306                                            2
# 3317981574                                            2
# 3760525145                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 3276735306  cuda.gputime,node.order  regionprofile         spot
# 3317981574  cuda.gputime,node.order  regionprofile         spot
# 3760525145  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order                     spot:output  \
# profile
# 3276735306              true            true      SS-CUDA-i1-t64-s65536.cali
# 3317981574              true            true  SS-CUDA-i1-t1024-s1048576.cali
# 3760525145              true            true    SS-CUDA-i1-t256-s262144.cali
#
#             launchdate                                          libraries  \
# profile
# 3276735306  1700034110  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3317981574  1700034185  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3760525145  1700034128  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                              cmdline cluster   Algorithm  \
# profile
# 3276735306      [../../../Sample_Sort, 1, 64, 65536]       g  SampleSort
# 3317981574  [../../../Sample_Sort, 1, 1024, 1048576]       g  SampleSort
# 3760525145    [../../../Sample_Sort, 1, 256, 262144]       g  SampleSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 3276735306             CUDA      int               4      65536    Sorted
# 3317981574             CUDA      int               4    1048576    Sorted
# 3760525145             CUDA      int               4     262144    Sorted
#
#             num_threads  num_blocks  group_num implementation_source
# profile
# 3276735306           64        1024         16                    AI
# 3317981574         1024        1024         16                    AI
# 3760525145          256        1024         16                    AI

# %%
#tk.statsframe.dataframe["time"] = 1

# %%
#print(tk.tree())

# %%
gb = tk.groupby("InputSize")
# Out:
# 3  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ad69e7cf280>, 262144: <thicket.thicket.Thicket object at 0x2ad69e7368b0>, 1048576: <thicket.thicket.Thicket object at 0x2ad69e8321c0>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                                65536  \
#                                                                  nid
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64              1
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comm', 'type': 'function'}               64              6
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comm_large', 'type': 'function'}         64              7
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'cudaMemcpy', 'type': 'function'}         64              8
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comp', 'type': 'function'}               64              3
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comp_large', 'type': 'function'}         64              5
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'comp_small', 'type': 'function'}         64              4
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'correctness_check ', 'type': 'function'} 64              9
#                                                    256          <NA>
#                                                    1024         <NA>
# {'name': 'data_init', 'type': 'function'}          64              2
#                                                    256          <NA>
#                                                    1024         <NA>
#
#                                                                                \
#                                                                  spot.channel
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comm', 'type': 'function'}               64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comm_large', 'type': 'function'}         64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp', 'type': 'function'}               64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp_large', 'type': 'function'}         64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp_small', 'type': 'function'}         64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'correctness_check ', 'type': 'function'} 64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'data_init', 'type': 'function'}          64           regionprofile
#                                                    256                    NaN
#                                                    1024                   NaN
#
#                                                                               \
#                                                                Min time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64               0.360051
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64               0.000294
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64               0.000280
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64               0.000265
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64               0.016741
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64               0.016664
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64               0.000040
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64               0.000301
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64               0.337184
#                                                    256                   NaN
#                                                    1024                  NaN
#
#                                                                               \
#                                                                Max time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64               0.360051
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64               0.000294
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64               0.000280
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64               0.000265
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64               0.016741
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64               0.016664
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64               0.000040
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64               0.000301
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64               0.337184
#                                                    256                   NaN
#                                                    1024                  NaN
#
#                                                                               \
#                                                                Avg time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64               0.360051
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64               0.000294
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64               0.000280
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64               0.000265
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64               0.016741
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64               0.016664
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64               0.000040
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64               0.000301
#                                                    256                   NaN
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64               0.337184
#                                                    256                   NaN
#                                                    1024                  NaN
#
#                                                                            \
#                                                                Total time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64            0.360051
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comm', 'type': 'function'}               64            0.000294
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comm_large', 'type': 'function'}         64            0.000280
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64            0.000265
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comp', 'type': 'function'}               64            0.016741
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comp_large', 'type': 'function'}         64            0.016664
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'comp_small', 'type': 'function'}         64            0.000040
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'correctness_check ', 'type': 'function'} 64            0.000301
#                                                    256                NaN
#                                                    1024               NaN
# {'name': 'data_init', 'type': 'function'}          64            0.337184
#                                                    256                NaN
#                                                    1024               NaN
#
#                                                                                   \
#                                                                Avg GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                   0.016714
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                   0.000024
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                   0.000024
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                   0.000024
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                   0.016670
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                   0.009699
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                   0.006971
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                   0.000014
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                   0.000006
#                                                    256                       NaN
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Min GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                   0.016714
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                   0.000024
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                   0.000024
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                   0.000024
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                   0.016670
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                   0.009699
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                   0.006971
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                   0.000014
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                   0.000006
#                                                    256                       NaN
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Max GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                   0.016714
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                   0.000024
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                   0.000024
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                   0.000024
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                   0.016670
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                   0.009699
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                   0.006971
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                   0.000014
#                                                    256                       NaN
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                   0.000006
#                                                    256                       NaN
#                                                    1024                      NaN
#
#                                                                                \
#                                                                Total GPU time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                0.016714
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comm', 'type': 'function'}               64                0.000024
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comm_large', 'type': 'function'}         64                0.000024
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                0.000024
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp', 'type': 'function'}               64                0.016670
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp_large', 'type': 'function'}         64                0.009699
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'comp_small', 'type': 'function'}         64                0.006971
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                0.000014
#                                                    256                    NaN
#                                                    1024                   NaN
# {'name': 'data_init', 'type': 'function'}          64                0.000006
#                                                    256                    NaN
#                                                    1024                   NaN
#
#                                                                262144  \
#                                                                   nid
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64            <NA>
#                                                    256              1
#                                                    1024          <NA>
# {'name': 'comm', 'type': 'function'}               64            <NA>
#                                                    256              6
#                                                    1024          <NA>
# {'name': 'comm_large', 'type': 'function'}         64            <NA>
#                                                    256              7
#                                                    1024          <NA>
# {'name': 'cudaMemcpy', 'type': 'function'}         64            <NA>
#                                                    256              8
#                                                    1024          <NA>
# {'name': 'comp', 'type': 'function'}               64            <NA>
#                                                    256              3
#                                                    1024          <NA>
# {'name': 'comp_large', 'type': 'function'}         64            <NA>
#                                                    256              5
#                                                    1024          <NA>
# {'name': 'comp_small', 'type': 'function'}         64            <NA>
#                                                    256              4
#                                                    1024          <NA>
# {'name': 'correctness_check ', 'type': 'function'} 64            <NA>
#                                                    256              9
#                                                    1024          <NA>
# {'name': 'data_init', 'type': 'function'}          64            <NA>
#                                                    256              2
#                                                    1024          <NA>
#
#                                                                                \
#                                                                  spot.channel
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comm', 'type': 'function'}               64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comm_large', 'type': 'function'}         64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comp', 'type': 'function'}               64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comp_large', 'type': 'function'}         64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'comp_small', 'type': 'function'}         64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
# {'name': 'data_init', 'type': 'function'}          64                     NaN
#                                                    256          regionprofile
#                                                    1024                   NaN
#
#                                                                               \
#                                                                Min time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                    NaN
#                                                    256              0.412749
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64                    NaN
#                                                    256              0.001018
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64                    NaN
#                                                    256              0.001003
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                    NaN
#                                                    256              0.000977
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64                    NaN
#                                                    256              0.073821
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64                    NaN
#                                                    256              0.073725
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64                    NaN
#                                                    256              0.000048
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                    NaN
#                                                    256              0.001040
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64                    NaN
#                                                    256              0.331173
#                                                    1024                  NaN
#
#                                                                               \
#                                                                Max time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                    NaN
#                                                    256              0.412749
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64                    NaN
#                                                    256              0.001018
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64                    NaN
#                                                    256              0.001003
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                    NaN
#                                                    256              0.000977
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64                    NaN
#                                                    256              0.073821
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64                    NaN
#                                                    256              0.073725
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64                    NaN
#                                                    256              0.000048
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                    NaN
#                                                    256              0.001040
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64                    NaN
#                                                    256              0.331173
#                                                    1024                  NaN
#
#                                                                               \
#                                                                Avg time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                    NaN
#                                                    256              0.412749
#                                                    1024                  NaN
# {'name': 'comm', 'type': 'function'}               64                    NaN
#                                                    256              0.001018
#                                                    1024                  NaN
# {'name': 'comm_large', 'type': 'function'}         64                    NaN
#                                                    256              0.001003
#                                                    1024                  NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                    NaN
#                                                    256              0.000977
#                                                    1024                  NaN
# {'name': 'comp', 'type': 'function'}               64                    NaN
#                                                    256              0.073821
#                                                    1024                  NaN
# {'name': 'comp_large', 'type': 'function'}         64                    NaN
#                                                    256              0.073725
#                                                    1024                  NaN
# {'name': 'comp_small', 'type': 'function'}         64                    NaN
#                                                    256              0.000048
#                                                    1024                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                    NaN
#                                                    256              0.001040
#                                                    1024                  NaN
# {'name': 'data_init', 'type': 'function'}          64                    NaN
#                                                    256              0.331173
#                                                    1024                  NaN
#
#                                                                            \
#                                                                Total time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                 NaN
#                                                    256           0.412749
#                                                    1024               NaN
# {'name': 'comm', 'type': 'function'}               64                 NaN
#                                                    256           0.001018
#                                                    1024               NaN
# {'name': 'comm_large', 'type': 'function'}         64                 NaN
#                                                    256           0.001003
#                                                    1024               NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                 NaN
#                                                    256           0.000977
#                                                    1024               NaN
# {'name': 'comp', 'type': 'function'}               64                 NaN
#                                                    256           0.073821
#                                                    1024               NaN
# {'name': 'comp_large', 'type': 'function'}         64                 NaN
#                                                    256           0.073725
#                                                    1024               NaN
# {'name': 'comp_small', 'type': 'function'}         64                 NaN
#                                                    256           0.000048
#                                                    1024               NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                 NaN
#                                                    256           0.001040
#                                                    1024               NaN
# {'name': 'data_init', 'type': 'function'}          64                 NaN
#                                                    256           0.331173
#                                                    1024               NaN
#
#                                                                                   \
#                                                                Avg GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                  0.073842
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                  0.000088
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.000088
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                  0.000088
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                  0.073717
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.041517
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                  0.032200
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                  0.000031
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                  0.000007
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Min GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                  0.073842
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                  0.000088
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.000088
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                  0.000088
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                  0.073717
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.041517
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                  0.032200
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                  0.000031
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                  0.000007
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Max GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                  0.073842
#                                                    1024                      NaN
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                  0.000088
#                                                    1024                      NaN
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.000088
#                                                    1024                      NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                  0.000088
#                                                    1024                      NaN
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                  0.073717
#                                                    1024                      NaN
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                  0.041517
#                                                    1024                      NaN
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                  0.032200
#                                                    1024                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                  0.000031
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                  0.000007
#                                                    1024                      NaN
#
#                                                                                \
#                                                                Total GPU time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                     NaN
#                                                    256               0.073842
#                                                    1024                   NaN
# {'name': 'comm', 'type': 'function'}               64                     NaN
#                                                    256               0.000088
#                                                    1024                   NaN
# {'name': 'comm_large', 'type': 'function'}         64                     NaN
#                                                    256               0.000088
#                                                    1024                   NaN
# {'name': 'cudaMemcpy', 'type': 'function'}         64                     NaN
#                                                    256               0.000088
#                                                    1024                   NaN
# {'name': 'comp', 'type': 'function'}               64                     NaN
#                                                    256               0.073717
#                                                    1024                   NaN
# {'name': 'comp_large', 'type': 'function'}         64                     NaN
#                                                    256               0.041517
#                                                    1024                   NaN
# {'name': 'comp_small', 'type': 'function'}         64                     NaN
#                                                    256               0.032200
#                                                    1024                   NaN
# {'name': 'correctness_check ', 'type': 'function'} 64                     NaN
#                                                    256               0.000031
#                                                    1024                   NaN
# ...
#                                                    256                   NaN
#                                                    1024             0.342677
# {'name': 'comp_large', 'type': 'function'}         64                    NaN
#                                                    256                   NaN
#                                                    1024             0.342598
# {'name': 'comp_small', 'type': 'function'}         64                    NaN
#                                                    256                   NaN
#                                                    1024             0.000038
# {'name': 'correctness_check ', 'type': 'function'} 64                    NaN
#                                                    256                   NaN
#                                                    1024             0.003845
# {'name': 'data_init', 'type': 'function'}          64                    NaN
#                                                    256                   NaN
#                                                    1024             0.345184
#
#                                                                            \
#                                                                Total time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                 NaN
#                                                    256                NaN
#                                                    1024          0.699833
# {'name': 'comm', 'type': 'function'}               64                 NaN
#                                                    256                NaN
#                                                    1024          0.002505
# {'name': 'comm_large', 'type': 'function'}         64                 NaN
#                                                    256                NaN
#                                                    1024          0.002492
# {'name': 'cudaMemcpy', 'type': 'function'}         64                 NaN
#                                                    256                NaN
#                                                    1024          0.002471
# {'name': 'comp', 'type': 'function'}               64                 NaN
#                                                    256                NaN
#                                                    1024          0.342677
# {'name': 'comp_large', 'type': 'function'}         64                 NaN
#                                                    256                NaN
#                                                    1024          0.342598
# {'name': 'comp_small', 'type': 'function'}         64                 NaN
#                                                    256                NaN
#                                                    1024          0.000038
# {'name': 'correctness_check ', 'type': 'function'} 64                 NaN
#                                                    256                NaN
#                                                    1024          0.003845
# {'name': 'data_init', 'type': 'function'}          64                 NaN
#                                                    256                NaN
#                                                    1024          0.345184
#
#                                                                                   \
#                                                                Avg GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.344600
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001904
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001904
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001904
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.342598
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.172503
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.170095
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000088
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000010
#
#                                                                                   \
#                                                                Min GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.344600
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001904
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001904
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001904
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.342598
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.172503
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.170095
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000088
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000010
#
#                                                                                   \
#                                                                Max GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.344600
# {'name': 'comm', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001904
# {'name': 'comm_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001904
# {'name': 'cudaMemcpy', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.001904
# {'name': 'comp', 'type': 'function'}               64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.342598
# {'name': 'comp_large', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.172503
# {'name': 'comp_small', 'type': 'function'}         64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.170095
# {'name': 'correctness_check ', 'type': 'function'} 64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000088
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    256                       NaN
#                                                    1024                 0.000010
#
#                                                                                \
#                                                                Total GPU time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                     NaN
#                                                    256                    NaN
#                                                    1024              0.344600
# {'name': 'comm', 'type': 'function'}               64                     NaN
#                                                    256                    NaN
#                                                    1024              0.001904
# {'name': 'comm_large', 'type': 'function'}         64                     NaN
#                                                    256                    NaN
#                                                    1024              0.001904
# {'name': 'cudaMemcpy', 'type': 'function'}         64                     NaN
#                                                    256                    NaN
#                                                    1024              0.001904
# {'name': 'comp', 'type': 'function'}               64                     NaN
#                                                    256                    NaN
#                                                    1024              0.342598
# {'name': 'comp_large', 'type': 'function'}         64                     NaN
#                                                    256                    NaN
#                                                    1024              0.172503
# {'name': 'comp_small', 'type': 'function'}         64                     NaN
#                                                    256                    NaN
#                                                    1024              0.170095
# {'name': 'correctness_check ', 'type': 'function'} 64                     NaN
#                                                    256                    NaN
#                                                    1024              0.000088
# {'name': 'data_init', 'type': 'function'}          64                     NaN
#                                                    256                    NaN
#                                                    1024              0.000010
#
#                                                                               name
#
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                         main
#                                                    256                        main
#                                                    1024                       main
# {'name': 'comm', 'type': 'function'}               64                         comm
#                                                    256                        comm
#                                                    1024                       comm
# {'name': 'comm_large', 'type': 'function'}         64                   comm_large
#                                                    256                  comm_large
#                                                    1024                 comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}         64                   cudaMemcpy
#                                                    256                  cudaMemcpy
#                                                    1024                 cudaMemcpy
# {'name': 'comp', 'type': 'function'}               64                         comp
#                                                    256                        comp
#                                                    1024                       comp
# {'name': 'comp_large', 'type': 'function'}         64                   comp_large
#                                                    256                  comp_large
#                                                    1024                 comp_large
# {'name': 'comp_small', 'type': 'function'}         64                   comp_small
#                                                    256                  comp_small
#                                                    1024                 comp_small
# {'name': 'correctness_check ', 'type': 'function'} 64           correctness_check
#                                                    256          correctness_check
#                                                    1024         correctness_check
# {'name': 'data_init', 'type': 'function'}          64                    data_init
#                                                    256                   data_init
#                                                    1024                  data_init

# %%
ctk.metadata
# Out:
#                          65536    \
#             cali.caliper.version
# num_threads
# 64                    2.11.0-dev
# 256                          NaN
# 1024                         NaN
#
#                                                                 \
#                                                   spot.metrics
# num_threads
# 64           min#inclusive#sum#time.duration,max#inclusive#...
# 256                                                        NaN
# 1024                                                       NaN
#
#                                                          \
#             spot.timeseries.metrics spot.format.version
# num_threads
# 64                                                  2.0
# 256                             NaN                 NaN
# 1024                            NaN                 NaN
#
#                                                                   \
#                         spot.options  spot.channels cali.channel
# num_threads
# 64           cuda.gputime,node.order  regionprofile         spot
# 256                              NaN            NaN          NaN
# 1024                             NaN            NaN          NaN
#
#                                                                            \
#             spot:cuda.gputime spot:node.order                 spot:output
# num_threads
# 64                       true            true  SS-CUDA-i1-t64-s65536.cali
# 256                       NaN             NaN                         NaN
# 1024                      NaN             NaN                         NaN
#
#                                                                               \
#                launchdate                                          libraries
# num_threads
# 64           1.700034e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 256                   NaN                                                NaN
# 1024                  NaN                                                NaN
#
#                                                                        \
#                                           cmdline cluster   Algorithm
# num_threads
# 64           [../../../Sample_Sort, 1, 64, 65536]       g  SampleSort
# 256                                           NaN     NaN         NaN
# 1024                                          NaN     NaN         NaN
#
#                                                                           \
#             ProgrammingModel Datatype SizeOfDatatype InputSize InputType
# num_threads
# 64                      CUDA      int            4.0   65536.0    Sorted
# 256                      NaN      NaN            NaN       NaN       NaN
# 1024                     NaN      NaN            NaN       NaN       NaN
#
#                                                                     262144   \
#             num_blocks group_num implementation_source cali.caliper.version
# num_threads
# 64              1024.0      16.0                    AI                  NaN
# 256                NaN       NaN                   NaN           2.11.0-dev
# 1024               NaN       NaN                   NaN                  NaN
#
#                                                                 \
#                                                   spot.metrics
# num_threads
# 64                                                         NaN
# 256          min#inclusive#sum#time.duration,max#inclusive#...
# 1024                                                       NaN
#
#                                                          \
#             spot.timeseries.metrics spot.format.version
# num_threads
# 64                              NaN                 NaN
# 256                                                 2.0
# 1024                            NaN                 NaN
#
#                                                                   \
#                         spot.options  spot.channels cali.channel
# num_threads
# 64                               NaN            NaN          NaN
# 256          cuda.gputime,node.order  regionprofile         spot
# 1024                             NaN            NaN          NaN
#
#                                                                              \
#             spot:cuda.gputime spot:node.order                   spot:output
# num_threads
# 64                        NaN             NaN                           NaN
# 256                      true            true  SS-CUDA-i1-t256-s262144.cali
# 1024                      NaN             NaN                           NaN
#
#                                                                               \
#                launchdate                                          libraries
# num_threads
# 64                    NaN                                                NaN
# 256          1.700034e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1024                  NaN                                                NaN
#
#                                                                          \
#                                             cmdline cluster   Algorithm
# num_threads
# 64                                              NaN     NaN         NaN
# 256          [../../../Sample_Sort, 1, 256, 262144]       g  SampleSort
# 1024                                            NaN     NaN         NaN
#
#                                                                           \
#             ProgrammingModel Datatype SizeOfDatatype InputSize InputType
# num_threads
# 64                       NaN      NaN            NaN       NaN       NaN
# 256                     CUDA      int            4.0  262144.0    Sorted
# 1024                     NaN      NaN            NaN       NaN       NaN
#
#                                                                     1048576  \
#             num_blocks group_num implementation_source cali.caliper.version
# num_threads
# 64                 NaN       NaN                   NaN                  NaN
# 256             1024.0      16.0                    AI                  NaN
# 1024               NaN       NaN                   NaN           2.11.0-dev
#
#                                                                 \
#                                                   spot.metrics
# num_threads
# 64                                                         NaN
# 256                                                        NaN
# 1024         min#inclusive#sum#time.duration,max#inclusive#...
#
#                                                          \
#             spot.timeseries.metrics spot.format.version
# num_threads
# 64                              NaN                 NaN
# 256                             NaN                 NaN
# 1024                                                2.0
#
#                                                                   \
#                         spot.options  spot.channels cali.channel
# num_threads
# 64                               NaN            NaN          NaN
# 256                              NaN            NaN          NaN
# 1024         cuda.gputime,node.order  regionprofile         spot
#
#                                                                                \
#             spot:cuda.gputime spot:node.order                     spot:output
# num_threads
# 64                        NaN             NaN                             NaN
# 256                       NaN             NaN                             NaN
# 1024                     true            true  SS-CUDA-i1-t1024-s1048576.cali
#
#                                                                               \
#                launchdate                                          libraries
# num_threads
# 64                    NaN                                                NaN
# 256                   NaN                                                NaN
# 1024         1.700034e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                                                            \
#                                               cmdline cluster   Algorithm
# num_threads
# 64                                                NaN     NaN         NaN
# 256                                               NaN     NaN         NaN
# 1024         [../../../Sample_Sort, 1, 1024, 1048576]       g  SampleSort
#
#                                                                            \
#             ProgrammingModel Datatype SizeOfDatatype  InputSize InputType
# num_threads
# 64                       NaN      NaN            NaN        NaN       NaN
# 256                      NaN      NaN            NaN        NaN       NaN
# 1024                    CUDA      int            4.0  1048576.0    Sorted
#
#
#             num_blocks group_num implementation_source
# num_threads
# 64                 NaN       NaN                   NaN
# 256                NaN       NaN                   NaN
# 1024            1024.0      16.0                    AI

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (65536, "nid"), (1048576, "nid"), (262144, "nid"),(65536, "spot.channel"), (1048576, "spot.channel"), (262144, "spot.channel")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([(65536, "Min time/rank"), (1048576, "Min time/rank"), (262144, "Min time/rank"),(65536, "Max time/rank"), (1048576, "Max time/rank"), (262144, "Max time/rank"), (65536, "Avg time/rank"), (1048576, "Avg time/rank"), (262144, "Avg time/rank")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([(65536, "Min GPU time/rank"), (1048576, "Min GPU time/rank"), (262144, "Min GPU time/rank"),(65536, "Max GPU time/rank"), (1048576, "Max GPU time/rank"), (262144, "Max GPU time/rank"), (65536, "Avg GPU time/rank"), (1048576, "Avg GPU time/rank"), (262144, "Avg GPU time/rank"), (65536, "Total GPU time"), (1048576, "Total GPU time"), (262144, "Total GPU time")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

# %%
ctk.dataframe
# Out:
#                                level_0 index      65536     262144    1048576
#                                              Total time Total time Total time
# name               num_threads
# main               64                0     0   0.360051        NaN        NaN
#                    256               1     1        NaN   0.412749        NaN
#                    1024              2     2        NaN        NaN   0.699833
# comm               64                3     3   0.000294        NaN        NaN
#                    256               4     4        NaN   0.001018        NaN
#                    1024              5     5        NaN        NaN   0.002505
# comm_large         64                6     6   0.000280        NaN        NaN
#                    256               7     7        NaN   0.001003        NaN
#                    1024              8     8        NaN        NaN   0.002492
# cudaMemcpy         64                9     9   0.000265        NaN        NaN
#                    256              10    10        NaN   0.000977        NaN
#                    1024             11    11        NaN        NaN   0.002471
# comp               64               12    12   0.016741        NaN        NaN
#                    256              13    13        NaN   0.073821        NaN
#                    1024             14    14        NaN        NaN   0.342677
# comp_large         64               15    15   0.016664        NaN        NaN
#                    256              16    16        NaN   0.073725        NaN
#                    1024             17    17        NaN        NaN   0.342598
# comp_small         64               18    18   0.000040        NaN        NaN
#                    256              19    19        NaN   0.000048        NaN
#                    1024             20    20        NaN        NaN   0.000038
# correctness_check  64               21    21   0.000301        NaN        NaN
#                    256              22    22        NaN   0.001040        NaN
#                    1024             23    23        NaN        NaN   0.003845
# data_init          64               24    24   0.337184        NaN        NaN
#                    256              25    25        NaN   0.331173        NaN
#                    1024             26    26        NaN        NaN   0.345184

# %%
# Define common variables
numThreads = [64,256, 1024]
dataType = "Sorted"
functions = ["main", "comm", "comp"]

# %%
def plot_mpl(df, title, xlabel, ylabel, columns):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(columns)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(numThreads)
    plt.show()
    return fig, ax

# %%
for func in functions:
    tempData = [ctk.dataframe.loc[func][65536].at[64, "Total time"], ctk.dataframe.loc[func][262144].at[256, "Total time"], ctk.dataframe.loc[func][1048576].at[1024, "Total time"]]
    dfTemp = pd.DataFrame(tempData, columns=["Total time"], index=numThreads) 
    plot_mpl(
                df=dfTemp,
                title= func + "-" + dataType + "-Weak_Scaling",
                xlabel="Number of Threads",
                ylabel="Time (seconds)",
                columns=["Total time"]
            )
