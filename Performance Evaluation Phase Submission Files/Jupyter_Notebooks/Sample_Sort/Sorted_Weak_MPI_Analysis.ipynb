# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
file1 = glob("SS-MPI-i1-p16-s65536.cali")
file2 = glob("SS-MPI-i1-p64-s262144.cali")
file3 = glob("SS-MPI-i1-p256-s1048576.cali")
all_files = [file1[0], file2[0], file3[0]]
print(all_files)
tk = th.Thicket.from_caliperreader(all_files)
# Out:
# ['SS-MPI-i1-p16-s65536.cali', 'SS-MPI-i1-p64-s262144.cali', 'SS-MPI-i1-p256-s1048576.cali']

# %%
tk.profile_mapping
# Out:
# OrderedDict([(860414156, 'SS-MPI-i1-p256-s1048576.cali'),
#              (1301531220, 'SS-MPI-i1-p16-s65536.cali'),
#              (1705570607, 'SS-MPI-i1-p64-s262144.cali')])

# %%
tk.dataframe
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
#                                                                nid  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               860414156     1
#                                                    1301531220    1
#                                                    1705570607    1
# {'name': 'comm', 'type': 'function'}               860414156     5
#                                                    1301531220    5
#                                                    1705570607    5
# {'name': 'comm_large', 'type': 'function'}         860414156    10
#                                                    1301531220   10
#                                                    1705570607   10
# {'name': 'MPI_Gatherv', 'type': 'function'}        860414156    11
#                                                    1301531220   11
#                                                    1705570607   11
# {'name': 'comm_small', 'type': 'function'}         860414156     6
#                                                    1301531220    6
#                                                    1705570607    6
# {'name': 'MPI_Allgather', 'type': 'function'}      860414156     7
#                                                    1301531220    7
#                                                    1705570607    7
# {'name': 'MPI_Gather', 'type': 'function'}         860414156     9
#                                                    1301531220    9
#                                                    1705570607    9
# {'name': 'comp', 'type': 'function'}               860414156     3
#                                                    1301531220    3
#                                                    1705570607    3
# {'name': 'comp_large', 'type': 'function'}         860414156     8
#                                                    1301531220    8
#                                                    1705570607    8
# {'name': 'comp_small', 'type': 'function'}         860414156     4
#                                                    1301531220    4
#                                                    1705570607    4
# {'name': 'correctness_check ', 'type': 'function'} 860414156    12
#                                                    1301531220   12
#                                                    1705570607   12
# {'name': 'data_init', 'type': 'function'}          860414156     2
#                                                    1301531220    2
#                                                    1705570607    2
#
#                                                                 spot.channel  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'comm', 'type': 'function'}               860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'comm_large', 'type': 'function'}         860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'MPI_Gatherv', 'type': 'function'}        860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'comm_small', 'type': 'function'}         860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'MPI_Allgather', 'type': 'function'}      860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'MPI_Gather', 'type': 'function'}         860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'comp', 'type': 'function'}               860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'comp_large', 'type': 'function'}         860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'comp_small', 'type': 'function'}         860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'correctness_check ', 'type': 'function'} 860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
# {'name': 'data_init', 'type': 'function'}          860414156   regionprofile
#                                                    1301531220  regionprofile
#                                                    1705570607  regionprofile
#
#                                                                Min time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               860414156       44.870045
#                                                    1301531220       3.996261
#                                                    1705570607       2.691647
# {'name': 'comm', 'type': 'function'}               860414156       41.629970
#                                                    1301531220       3.383729
#                                                    1705570607       0.495104
# {'name': 'comm_large', 'type': 'function'}         860414156       39.794690
#                                                    1301531220       1.279996
#                                                    1705570607       0.102959
# {'name': 'MPI_Gatherv', 'type': 'function'}        860414156       39.794654
#                                                    1301531220       1.279963
#                                                    1705570607       0.102919
# {'name': 'comm_small', 'type': 'function'}         860414156        1.560540
#                                                    1301531220       1.831531
#                                                    1705570607       0.360856
# {'name': 'MPI_Allgather', 'type': 'function'}      860414156        0.147340
#                                                    1301531220       0.068316
#                                                    1705570607       0.092709
# {'name': 'MPI_Gather', 'type': 'function'}         860414156        1.173368
#                                                    1301531220       1.699241
#                                                    1705570607       0.154158
# {'name': 'comp', 'type': 'function'}               860414156        1.301105
#                                                    1301531220       0.322996
#                                                    1705570607       1.247539
# {'name': 'comp_large', 'type': 'function'}         860414156        1.299511
#                                                    1301531220       0.322902
#                                                    1705570607       1.247337
# {'name': 'comp_small', 'type': 'function'}         860414156        0.001528
#                                                    1301531220       0.000029
#                                                    1705570607       0.000124
# {'name': 'correctness_check ', 'type': 'function'} 860414156        0.000185
#                                                    1301531220       0.061310
#                                                    1705570607       0.000159
# {'name': 'data_init', 'type': 'function'}          860414156        0.000101
#                                                    1301531220       0.000105
#                                                    1705570607       0.000107
#
#                                                                Max time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               860414156       45.521664
#                                                    1301531220       4.138033
#                                                    1705570607       3.171724
# {'name': 'comm', 'type': 'function'}               860414156       43.424184
#                                                    1301531220       3.584931
#                                                    1705570607       1.144504
# {'name': 'comm_large', 'type': 'function'}         860414156       40.395358
#                                                    1301531220       1.645948
#                                                    1705570607       0.545361
# {'name': 'MPI_Gatherv', 'type': 'function'}        860414156       40.395319
#                                                    1301531220       1.645922
#                                                    1705570607       0.545320
# {'name': 'comm_small', 'type': 'function'}         860414156        3.551388
#                                                    1301531220       2.103706
#                                                    1705570607       0.866828
# {'name': 'MPI_Allgather', 'type': 'function'}      860414156        0.840339
#                                                    1301531220       0.268343
#                                                    1705570607       0.506471
# {'name': 'MPI_Gather', 'type': 'function'}         860414156        2.876489
#                                                    1301531220       1.964173
#                                                    1705570607       0.538299
# {'name': 'comp', 'type': 'function'}               860414156        3.009342
#                                                    1301531220       0.398838
#                                                    1705570607       1.746178
# {'name': 'comp_large', 'type': 'function'}         860414156        3.007727
#                                                    1301531220       0.398750
#                                                    1705570607       1.745980
# {'name': 'comp_small', 'type': 'function'}         860414156        0.001546
#                                                    1301531220       0.000032
#                                                    1705570607       0.110922
# {'name': 'correctness_check ', 'type': 'function'} 860414156        0.516539
#                                                    1301531220       0.284780
#                                                    1705570607       0.519937
# {'name': 'data_init', 'type': 'function'}          860414156        0.282821
#                                                    1301531220       0.000120
#                                                    1705570607       0.142442
#
#                                                                Avg time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               860414156       45.224109
#                                                    1301531220       4.080310
#                                                    1705570607       2.901321
# {'name': 'comm', 'type': 'function'}               860414156       42.525708
#                                                    1301531220       3.460866
#                                                    1705570607       0.817244
# {'name': 'comm_large', 'type': 'function'}         860414156       40.022018
#                                                    1301531220       1.518370
#                                                    1705570607       0.216681
# {'name': 'MPI_Gatherv', 'type': 'function'}        860414156       40.021982
#                                                    1301531220       1.518343
#                                                    1705570607       0.216655
# {'name': 'comm_small', 'type': 'function'}         860414156        2.502561
#                                                    1301531220       1.942468
#                                                    1705570607       0.600536
# {'name': 'MPI_Allgather', 'type': 'function'}      860414156        0.502897
#                                                    1301531220       0.145274
#                                                    1705570607       0.256003
# {'name': 'MPI_Gather', 'type': 'function'}         860414156        1.998717
#                                                    1301531220       1.793209
#                                                    1705570607       0.344487
# {'name': 'comp', 'type': 'function'}               860414156        2.161057
#                                                    1301531220       0.344588
#                                                    1705570607       1.482981
# {'name': 'comp_large', 'type': 'function'}         860414156        2.157646
#                                                    1301531220       0.344498
#                                                    1705570607       1.479323
# {'name': 'comp_small', 'type': 'function'}         860414156        0.001533
#                                                    1301531220       0.000031
#                                                    1705570607       0.001857
# {'name': 'correctness_check ', 'type': 'function'} 860414156        0.232638
#                                                    1301531220       0.175400
#                                                    1705570607       0.244544
# {'name': 'data_init', 'type': 'function'}          860414156        0.008296
#                                                    1301531220       0.000110
#                                                    1705570607       0.002335
#
#                                                                  Total time  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               860414156   11577.371920
#                                                    1301531220     65.284958
#                                                    1705570607    185.684546
# {'name': 'comm', 'type': 'function'}               860414156   10886.581163
#                                                    1301531220     55.373850
#                                                    1705570607     52.303632
# {'name': 'comm_large', 'type': 'function'}         860414156   10245.636624
#                                                    1301531220     24.293922
#                                                    1705570607     13.867581
# {'name': 'MPI_Gatherv', 'type': 'function'}        860414156   10245.627409
#                                                    1301531220     24.293493
#                                                    1705570607     13.865909
# {'name': 'comm_small', 'type': 'function'}         860414156     640.655607
#                                                    1301531220     31.079493
#                                                    1705570607     38.434291
# {'name': 'MPI_Allgather', 'type': 'function'}      860414156     128.741631
#                                                    1301531220      2.324376
#                                                    1705570607     16.384189
# {'name': 'MPI_Gather', 'type': 'function'}         860414156     511.671465
#                                                    1301531220     28.691349
#                                                    1705570607     22.047179
# {'name': 'comp', 'type': 'function'}               860414156     553.230607
#                                                    1301531220      5.513415
#                                                    1705570607     94.910783
# {'name': 'comp_large', 'type': 'function'}         860414156     552.357311
#                                                    1301531220      5.511963
#                                                    1705570607     94.676687
# {'name': 'comp_small', 'type': 'function'}         860414156       0.392517
#                                                    1301531220      0.000491
#                                                    1705570607      0.118862
# {'name': 'correctness_check ', 'type': 'function'} 860414156      59.555290
#                                                    1301531220      2.806400
#                                                    1705570607     15.650818
# {'name': 'data_init', 'type': 'function'}          860414156       2.123667
#                                                    1301531220      0.001761
#                                                    1705570607      0.149446
#
#                                                                Variance time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               860414156             0.018021
#                                                    1301531220            0.001861
#                                                    1705570607            0.012633
# {'name': 'comm', 'type': 'function'}               860414156             0.195876
#                                                    1301531220            0.002396
#                                                    1705570607            0.021441
# {'name': 'comm_large', 'type': 'function'}         860414156             0.007920
#                                                    1301531220            0.008344
#                                                    1705570607            0.005374
# {'name': 'MPI_Gatherv', 'type': 'function'}        860414156             0.007920
#                                                    1301531220            0.008344
#                                                    1705570607            0.005374
# {'name': 'comm_small', 'type': 'function'}         860414156             0.248269
#                                                    1301531220            0.005505
#                                                    1705570607            0.018164
# {'name': 'MPI_Allgather', 'type': 'function'}      860414156             0.020055
#                                                    1301531220            0.002776
#                                                    1705570607            0.006470
# {'name': 'MPI_Gather', 'type': 'function'}         860414156             0.208829
#                                                    1301531220            0.006230
#                                                    1705570607            0.009680
# {'name': 'comp', 'type': 'function'}               860414156             0.182326
#                                                    1301531220            0.000363
#                                                    1705570607            0.015091
# {'name': 'comp_large', 'type': 'function'}         860414156             0.182224
#                                                    1301531220            0.000363
#                                                    1705570607            0.014838
# {'name': 'comp_small', 'type': 'function'}         860414156             0.000000
#                                                    1301531220            0.000000
#                                                    1705570607            0.000189
# {'name': 'correctness_check ', 'type': 'function'} 860414156             0.002846
#                                                    1301531220            0.004668
#                                                    1705570607            0.004479
# {'name': 'data_init', 'type': 'function'}          860414156             0.001733
#                                                    1301531220            0.000000
#                                                    1705570607            0.000312
#
#                                                                              name
# node                                               profile
# {'name': 'main', 'type': 'function'}               860414156                 main
#                                                    1301531220                main
#                                                    1705570607                main
# {'name': 'comm', 'type': 'function'}               860414156                 comm
#                                                    1301531220                comm
#                                                    1705570607                comm
# {'name': 'comm_large', 'type': 'function'}         860414156           comm_large
#                                                    1301531220          comm_large
#                                                    1705570607          comm_large
# {'name': 'MPI_Gatherv', 'type': 'function'}        860414156          MPI_Gatherv
#                                                    1301531220         MPI_Gatherv
#                                                    1705570607         MPI_Gatherv
# {'name': 'comm_small', 'type': 'function'}         860414156           comm_small
#                                                    1301531220          comm_small
#                                                    1705570607          comm_small
# {'name': 'MPI_Allgather', 'type': 'function'}      860414156        MPI_Allgather
#                                                    1301531220       MPI_Allgather
#                                                    1705570607       MPI_Allgather
# {'name': 'MPI_Gather', 'type': 'function'}         860414156           MPI_Gather
#                                                    1301531220          MPI_Gather
#                                                    1705570607          MPI_Gather
# {'name': 'comp', 'type': 'function'}               860414156                 comp
#                                                    1301531220                comp
#                                                    1705570607                comp
# {'name': 'comp_large', 'type': 'function'}         860414156           comp_large
#                                                    1301531220          comp_large
#                                                    1705570607          comp_large
# {'name': 'comp_small', 'type': 'function'}         860414156           comp_small
#                                                    1301531220          comp_small
#                                                    1705570607          comp_small
# {'name': 'correctness_check ', 'type': 'function'} 860414156   correctness_check
#                                                    1301531220  correctness_check
#                                                    1705570607  correctness_check
# {'name': 'data_init', 'type': 'function'}          860414156            data_init
#                                                    1301531220           data_init
#                                                    1705570607           data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 860414156            2.11.0-dev             256
# 1301531220           2.11.0-dev              16
# 1705570607           2.11.0-dev              64
#
#                                                  spot.metrics  \
# profile
# 860414156   min#inclusive#sum#time.duration,max#inclusive#...
# 1301531220  min#inclusive#sum#time.duration,max#inclusive#...
# 1705570607  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 860414156                                             2
# 1301531220                                            2
# 1705570607                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 860414156   time.variance,node.order  regionprofile         spot
# 1301531220  time.variance,node.order  regionprofile         spot
# 1705570607  time.variance,node.order  regionprofile         spot
#
#            spot:node.order                   spot:output spot:time.variance  \
# profile
# 860414156             true  SS-MPI-i1-p256-s1048576.cali               true
# 1301531220            true     SS-MPI-i1-p16-s65536.cali               true
# 1705570607            true    SS-MPI-i1-p64-s262144.cali               true
#
#             launchdate                                          libraries  \
# profile
# 860414156   1700023373  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1301531220  1700022870  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1705570607  1700033650  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                             cmdline cluster   Algorithm  \
# profile
# 860414156   [../../../Sample_Sort, 1, 256, 1048576]       c  SampleSort
# 1301531220     [../../../Sample_Sort, 1, 16, 65536]       c  SampleSort
# 1705570607    [../../../Sample_Sort, 1, 64, 262144]       c  SampleSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 860414156               MPI      int               4    1048576    Sorted
# 1301531220              MPI      int               4      65536    Sorted
# 1705570607              MPI      int               4     262144    Sorted
#
#             num_procs  group_num implementation_source
# profile
# 860414156         256         16                Online
# 1301531220         16         16                Online
# 1705570607         64         16                Online

# %%
#tk.statsframe.dataframe["time"] = 1

# %%
#print(tk.tree())

# %%
gb = tk.groupby("InputSize")
# Out:
# 3  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ad5a37d2220>, 262144: <thicket.thicket.Thicket object at 0x2ad5a3956940>, 1048576: <thicket.thicket.Thicket object at 0x2ad5a3952ac0>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_procs"
)

# %%
ctk.dataframe
# Out:
#                                                              65536  \
#                                                                nid
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16            1
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comm', 'type': 'function'}               16            5
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comm_large', 'type': 'function'}         16           10
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'MPI_Gatherv', 'type': 'function'}        16           11
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comm_small', 'type': 'function'}         16            6
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'MPI_Allgather', 'type': 'function'}      16            7
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'MPI_Gather', 'type': 'function'}         16            9
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comp', 'type': 'function'}               16            3
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comp_large', 'type': 'function'}         16            8
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'comp_small', 'type': 'function'}         16            4
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'correctness_check ', 'type': 'function'} 16           12
#                                                    64         <NA>
#                                                    256        <NA>
# {'name': 'data_init', 'type': 'function'}          16            2
#                                                    64         <NA>
#                                                    256        <NA>
#
#                                                                              \
#                                                                spot.channel
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comm', 'type': 'function'}               16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comm_large', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comm_small', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comp', 'type': 'function'}               16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comp_large', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'comp_small', 'type': 'function'}         16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
# {'name': 'data_init', 'type': 'function'}          16         regionprofile
#                                                    64                   NaN
#                                                    256                  NaN
#
#                                                                             \
#                                                              Min time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16             3.996261
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16             3.383729
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16             1.279996
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16             1.279963
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16             1.831531
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16             0.068316
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16             1.699241
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16             0.322996
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16             0.322902
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16             0.000029
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16             0.061310
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16             0.000105
#                                                    64                  NaN
#                                                    256                 NaN
#
#                                                                             \
#                                                              Max time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16             4.138033
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16             3.584931
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16             1.645948
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16             1.645922
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16             2.103706
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16             0.268343
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16             1.964173
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16             0.398838
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16             0.398750
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16             0.000032
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16             0.284780
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16             0.000120
#                                                    64                  NaN
#                                                    256                 NaN
#
#                                                                             \
#                                                              Avg time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16             4.080310
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16             3.460866
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16             1.518370
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16             1.518343
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16             1.942468
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16             0.145274
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16             1.793209
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16             0.344588
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16             0.344498
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16             0.000031
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16             0.175400
#                                                    64                  NaN
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16             0.000110
#                                                    64                  NaN
#                                                    256                 NaN
#
#                                                                          \
#                                                              Total time
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16         65.284958
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comm', 'type': 'function'}               16         55.373850
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comm_large', 'type': 'function'}         16         24.293922
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16         24.293493
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comm_small', 'type': 'function'}         16         31.079493
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16          2.324376
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16         28.691349
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comp', 'type': 'function'}               16          5.513415
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comp_large', 'type': 'function'}         16          5.511963
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'comp_small', 'type': 'function'}         16          0.000491
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'correctness_check ', 'type': 'function'} 16          2.806400
#                                                    64               NaN
#                                                    256              NaN
# {'name': 'data_init', 'type': 'function'}          16          0.001761
#                                                    64               NaN
#                                                    256              NaN
#
#                                                                                  \
#                                                              Variance time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  0.001861
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comm', 'type': 'function'}               16                  0.002396
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comm_large', 'type': 'function'}         16                  0.008344
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  0.008344
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comm_small', 'type': 'function'}         16                  0.005505
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  0.002776
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                  0.006230
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comp', 'type': 'function'}               16                  0.000363
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comp_large', 'type': 'function'}         16                  0.000363
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'comp_small', 'type': 'function'}         16                  0.000000
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                  0.004668
#                                                    64                       NaN
#                                                    256                      NaN
# {'name': 'data_init', 'type': 'function'}          16                  0.000000
#                                                    64                       NaN
#                                                    256                      NaN
#
#                                                              262144  \
#                                                                 nid
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16          <NA>
#                                                    64             1
#                                                    256         <NA>
# {'name': 'comm', 'type': 'function'}               16          <NA>
#                                                    64             5
#                                                    256         <NA>
# {'name': 'comm_large', 'type': 'function'}         16          <NA>
#                                                    64            10
#                                                    256         <NA>
# {'name': 'MPI_Gatherv', 'type': 'function'}        16          <NA>
#                                                    64            11
#                                                    256         <NA>
# {'name': 'comm_small', 'type': 'function'}         16          <NA>
#                                                    64             6
#                                                    256         <NA>
# {'name': 'MPI_Allgather', 'type': 'function'}      16          <NA>
#                                                    64             7
#                                                    256         <NA>
# {'name': 'MPI_Gather', 'type': 'function'}         16          <NA>
#                                                    64             9
#                                                    256         <NA>
# {'name': 'comp', 'type': 'function'}               16          <NA>
#                                                    64             3
#                                                    256         <NA>
# {'name': 'comp_large', 'type': 'function'}         16          <NA>
#                                                    64             8
#                                                    256         <NA>
# {'name': 'comp_small', 'type': 'function'}         16          <NA>
#                                                    64             4
#                                                    256         <NA>
# {'name': 'correctness_check ', 'type': 'function'} 16          <NA>
#                                                    64            12
#                                                    256         <NA>
# {'name': 'data_init', 'type': 'function'}          16          <NA>
#                                                    64             2
#                                                    256         <NA>
#
#                                                                              \
#                                                                spot.channel
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comm', 'type': 'function'}               16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comm_large', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comm_small', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comp', 'type': 'function'}               16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comp_large', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'comp_small', 'type': 'function'}         16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
# {'name': 'data_init', 'type': 'function'}          16                   NaN
#                                                    64         regionprofile
#                                                    256                  NaN
#
#                                                                             \
#                                                              Min time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64             2.691647
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64             0.495104
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64             0.102959
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64             0.102919
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64             0.360856
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64             0.092709
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64             0.154158
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64             1.247539
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64             1.247337
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64             0.000124
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64             0.000159
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64             0.000107
#                                                    256                 NaN
#
#                                                                             \
#                                                              Max time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64             3.171724
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64             1.144504
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64             0.545361
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64             0.545320
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64             0.866828
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64             0.506471
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64             0.538299
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64             1.746178
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64             1.745980
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64             0.110922
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64             0.519937
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64             0.142442
#                                                    256                 NaN
#
#                                                                             \
#                                                              Avg time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64             2.901321
#                                                    256                 NaN
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64             0.817244
#                                                    256                 NaN
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64             0.216681
#                                                    256                 NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64             0.216655
#                                                    256                 NaN
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64             0.600536
#                                                    256                 NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64             0.256003
#                                                    256                 NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64             0.344487
#                                                    256                 NaN
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64             1.482981
#                                                    256                 NaN
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64             1.479323
#                                                    256                 NaN
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64             0.001857
#                                                    256                 NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64             0.244544
#                                                    256                 NaN
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64             0.002335
#                                                    256                 NaN
#
#                                                                           \
#                                                               Total time
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                NaN
#                                                    64         185.684546
#                                                    256               NaN
# {'name': 'comm', 'type': 'function'}               16                NaN
#                                                    64          52.303632
#                                                    256               NaN
# {'name': 'comm_large', 'type': 'function'}         16                NaN
#                                                    64          13.867581
#                                                    256               NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                NaN
#                                                    64          13.865909
#                                                    256               NaN
# {'name': 'comm_small', 'type': 'function'}         16                NaN
#                                                    64          38.434291
#                                                    256               NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                NaN
#                                                    64          16.384189
#                                                    256               NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                NaN
#                                                    64          22.047179
#                                                    256               NaN
# {'name': 'comp', 'type': 'function'}               16                NaN
#                                                    64          94.910783
#                                                    256               NaN
# {'name': 'comp_large', 'type': 'function'}         16                NaN
#                                                    64          94.676687
#                                                    256               NaN
# {'name': 'comp_small', 'type': 'function'}         16                NaN
#                                                    64           0.118862
#                                                    256               NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                NaN
#                                                    64          15.650818
#                                                    256               NaN
# {'name': 'data_init', 'type': 'function'}          16                NaN
#                                                    64           0.149446
#                                                    256               NaN
#
#                                                                                  \
#                                                              Variance time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                       NaN
#                                                    64                  0.012633
#                                                    256                      NaN
# {'name': 'comm', 'type': 'function'}               16                       NaN
#                                                    64                  0.021441
#                                                    256                      NaN
# {'name': 'comm_large', 'type': 'function'}         16                       NaN
#                                                    64                  0.005374
#                                                    256                      NaN
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                       NaN
#                                                    64                  0.005374
#                                                    256                      NaN
# {'name': 'comm_small', 'type': 'function'}         16                       NaN
#                                                    64                  0.018164
#                                                    256                      NaN
# {'name': 'MPI_Allgather', 'type': 'function'}      16                       NaN
#                                                    64                  0.006470
#                                                    256                      NaN
# {'name': 'MPI_Gather', 'type': 'function'}         16                       NaN
#                                                    64                  0.009680
#                                                    256                      NaN
# {'name': 'comp', 'type': 'function'}               16                       NaN
#                                                    64                  0.015091
#                                                    256                      NaN
# {'name': 'comp_large', 'type': 'function'}         16                       NaN
#                                                    64                  0.014838
#                                                    256                      NaN
# {'name': 'comp_small', 'type': 'function'}         16                       NaN
#                                                    64                  0.000189
#                                                    256                      NaN
# {'name': 'correctness_check ', 'type': 'function'} 16                       NaN
#                                                    64                  0.004479
#                                                    256                      NaN
# {'name': 'data_init', 'type': 'function'}          16                       NaN
#                                                    64                  0.000312
#                                                    256                      NaN
#
#                                                              1048576  \
#                                                                  nid
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16           <NA>
#                                                    64           <NA>
#                                                    256             1
# {'name': 'comm', 'type': 'function'}               16           <NA>
#                                                    64           <NA>
#                                                    256             5
# {'name': 'comm_large', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256            10
# {'name': 'MPI_Gatherv', 'type': 'function'}        16           <NA>
#                                                    64           <NA>
#                                                    256            11
# {'name': 'comm_small', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256             6
# {'name': 'MPI_Allgather', 'type': 'function'}      16           <NA>
#                                                    64           <NA>
#                                                    256             7
# {'name': 'MPI_Gather', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256             9
# {'name': 'comp', 'type': 'function'}               16           <NA>
#                                                    64           <NA>
#                                                    256             3
# {'name': 'comp_large', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256             8
# {'name': 'comp_small', 'type': 'function'}         16           <NA>
#                                                    64           <NA>
#                                                    256             4
# {'name': 'correctness_check ', 'type': 'function'} 16           <NA>
#                                                    64           <NA>
#                                                    256            12
# {'name': 'data_init', 'type': 'function'}          16           <NA>
#                                                    64           <NA>
#                                                    256             2
#
#                                                                              \
#                                                                spot.channel
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comm', 'type': 'function'}               16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comm_large', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comm_small', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'MPI_Allgather', 'type': 'function'}      16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'MPI_Gather', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comp', 'type': 'function'}               16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comp_large', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'comp_small', 'type': 'function'}         16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# {'name': 'correctness_check ', 'type': 'function'} 16                   NaN
#                                                    64                   NaN
#                                                    256        regionprofile
# ...
#                                                    64                  NaN
#                                                    256            0.000185
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64                  NaN
#                                                    256            0.000101
#
#                                                                             \
#                                                              Max time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256           45.521664
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256           43.424184
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256           40.395358
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64                  NaN
#                                                    256           40.395319
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            3.551388
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64                  NaN
#                                                    256            0.840339
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            2.876489
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256            3.009342
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            3.007727
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            0.001546
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64                  NaN
#                                                    256            0.516539
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64                  NaN
#                                                    256            0.282821
#
#                                                                             \
#                                                              Avg time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256           45.224109
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256           42.525708
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256           40.022018
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64                  NaN
#                                                    256           40.021982
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            2.502561
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64                  NaN
#                                                    256            0.502897
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            1.998717
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256            2.161057
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            2.157646
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            0.001533
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64                  NaN
#                                                    256            0.232638
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64                  NaN
#                                                    256            0.008296
#
#                                                                             \
#                                                                 Total time
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256        11577.371920
# {'name': 'comm', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256        10886.581163
# {'name': 'comm_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256        10245.636624
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                  NaN
#                                                    64                  NaN
#                                                    256        10245.627409
# {'name': 'comm_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256          640.655607
# {'name': 'MPI_Allgather', 'type': 'function'}      16                  NaN
#                                                    64                  NaN
#                                                    256          128.741631
# {'name': 'MPI_Gather', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256          511.671465
# {'name': 'comp', 'type': 'function'}               16                  NaN
#                                                    64                  NaN
#                                                    256          553.230607
# {'name': 'comp_large', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256          552.357311
# {'name': 'comp_small', 'type': 'function'}         16                  NaN
#                                                    64                  NaN
#                                                    256            0.392517
# {'name': 'correctness_check ', 'type': 'function'} 16                  NaN
#                                                    64                  NaN
#                                                    256           59.555290
# {'name': 'data_init', 'type': 'function'}          16                  NaN
#                                                    64                  NaN
#                                                    256            2.123667
#
#                                                                                  \
#                                                              Variance time/rank
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                       NaN
#                                                    64                       NaN
#                                                    256                 0.018021
# {'name': 'comm', 'type': 'function'}               16                       NaN
#                                                    64                       NaN
#                                                    256                 0.195876
# {'name': 'comm_large', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.007920
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                       NaN
#                                                    64                       NaN
#                                                    256                 0.007920
# {'name': 'comm_small', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.248269
# {'name': 'MPI_Allgather', 'type': 'function'}      16                       NaN
#                                                    64                       NaN
#                                                    256                 0.020055
# {'name': 'MPI_Gather', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.208829
# {'name': 'comp', 'type': 'function'}               16                       NaN
#                                                    64                       NaN
#                                                    256                 0.182326
# {'name': 'comp_large', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.182224
# {'name': 'comp_small', 'type': 'function'}         16                       NaN
#                                                    64                       NaN
#                                                    256                 0.000000
# {'name': 'correctness_check ', 'type': 'function'} 16                       NaN
#                                                    64                       NaN
#                                                    256                 0.002846
# {'name': 'data_init', 'type': 'function'}          16                       NaN
#                                                    64                       NaN
#                                                    256                 0.001733
#
#                                                                             name
#
# node                                               num_procs
# {'name': 'main', 'type': 'function'}               16                       main
#                                                    64                       main
#                                                    256                      main
# {'name': 'comm', 'type': 'function'}               16                       comm
#                                                    64                       comm
#                                                    256                      comm
# {'name': 'comm_large', 'type': 'function'}         16                 comm_large
#                                                    64                 comm_large
#                                                    256                comm_large
# {'name': 'MPI_Gatherv', 'type': 'function'}        16                MPI_Gatherv
#                                                    64                MPI_Gatherv
#                                                    256               MPI_Gatherv
# {'name': 'comm_small', 'type': 'function'}         16                 comm_small
#                                                    64                 comm_small
#                                                    256                comm_small
# {'name': 'MPI_Allgather', 'type': 'function'}      16              MPI_Allgather
#                                                    64              MPI_Allgather
#                                                    256             MPI_Allgather
# {'name': 'MPI_Gather', 'type': 'function'}         16                 MPI_Gather
#                                                    64                 MPI_Gather
#                                                    256                MPI_Gather
# {'name': 'comp', 'type': 'function'}               16                       comp
#                                                    64                       comp
#                                                    256                      comp
# {'name': 'comp_large', 'type': 'function'}         16                 comp_large
#                                                    64                 comp_large
#                                                    256                comp_large
# {'name': 'comp_small', 'type': 'function'}         16                 comp_small
#                                                    64                 comp_small
#                                                    256                comp_small
# {'name': 'correctness_check ', 'type': 'function'} 16         correctness_check
#                                                    64         correctness_check
#                                                    256        correctness_check
# {'name': 'data_init', 'type': 'function'}          16                  data_init
#                                                    64                  data_init
#                                                    256                 data_init

# %%
ctk.metadata
# Out:
#                        65536                   \
#           cali.caliper.version mpi.world.size
# num_procs
# 16                  2.11.0-dev           16.0
# 64                         NaN            NaN
# 256                        NaN            NaN
#
#                                                               \
#                                                 spot.metrics
# num_procs
# 16         min#inclusive#sum#time.duration,max#inclusive#...
# 64                                                       NaN
# 256                                                      NaN
#
#                                                        \
#           spot.timeseries.metrics spot.format.version
# num_procs
# 16                                                2.0
# 64                            NaN                 NaN
# 256                           NaN                 NaN
#
#                                                                  \
#                        spot.options  spot.channels cali.channel
# num_procs
# 16         time.variance,node.order  regionprofile         spot
# 64                              NaN            NaN          NaN
# 256                             NaN            NaN          NaN
#
#                                                                          \
#           spot:node.order                spot:output spot:time.variance
# num_procs
# 16                   true  SS-MPI-i1-p16-s65536.cali               true
# 64                    NaN                        NaN                NaN
# 256                   NaN                        NaN                NaN
#
#                                                                             \
#              launchdate                                          libraries
# num_procs
# 16         1.700023e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 64                  NaN                                                NaN
# 256                 NaN                                                NaN
#
#                                                                      \
#                                         cmdline cluster   Algorithm
# num_procs
# 16         [../../../Sample_Sort, 1, 16, 65536]       c  SampleSort
# 64                                          NaN     NaN         NaN
# 256                                         NaN     NaN         NaN
#
#                                                                         \
#           ProgrammingModel Datatype SizeOfDatatype InputSize InputType
# num_procs
# 16                     MPI      int            4.0   65536.0    Sorted
# 64                     NaN      NaN            NaN       NaN       NaN
# 256                    NaN      NaN            NaN       NaN       NaN
#
#                                                        262144                  \
#           group_num implementation_source cali.caliper.version mpi.world.size
# num_procs
# 16             16.0                Online                  NaN            NaN
# 64              NaN                   NaN           2.11.0-dev           64.0
# 256             NaN                   NaN                  NaN            NaN
#
#                                                               \
#                                                 spot.metrics
# num_procs
# 16                                                       NaN
# 64         min#inclusive#sum#time.duration,max#inclusive#...
# 256                                                      NaN
#
#                                                        \
#           spot.timeseries.metrics spot.format.version
# num_procs
# 16                            NaN                 NaN
# 64                                                2.0
# 256                           NaN                 NaN
#
#                                                                  \
#                        spot.options  spot.channels cali.channel
# num_procs
# 16                              NaN            NaN          NaN
# 64         time.variance,node.order  regionprofile         spot
# 256                             NaN            NaN          NaN
#
#                                                                           \
#           spot:node.order                 spot:output spot:time.variance
# num_procs
# 16                    NaN                         NaN                NaN
# 64                   true  SS-MPI-i1-p64-s262144.cali               true
# 256                   NaN                         NaN                NaN
#
#                                                                             \
#              launchdate                                          libraries
# num_procs
# 16                  NaN                                                NaN
# 64         1.700034e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 256                 NaN                                                NaN
#
#                                                                       \
#                                          cmdline cluster   Algorithm
# num_procs
# 16                                           NaN     NaN         NaN
# 64         [../../../Sample_Sort, 1, 64, 262144]       c  SampleSort
# 256                                          NaN     NaN         NaN
#
#                                                                         \
#           ProgrammingModel Datatype SizeOfDatatype InputSize InputType
# num_procs
# 16                     NaN      NaN            NaN       NaN       NaN
# 64                     MPI      int            4.0  262144.0    Sorted
# 256                    NaN      NaN            NaN       NaN       NaN
#
#                                                        1048576                 \
#           group_num implementation_source cali.caliper.version mpi.world.size
# num_procs
# 16              NaN                   NaN                  NaN            NaN
# 64             16.0                Online                  NaN            NaN
# 256             NaN                   NaN           2.11.0-dev          256.0
#
#                                                               \
#                                                 spot.metrics
# num_procs
# 16                                                       NaN
# 64                                                       NaN
# 256        min#inclusive#sum#time.duration,max#inclusive#...
#
#                                                        \
#           spot.timeseries.metrics spot.format.version
# num_procs
# 16                            NaN                 NaN
# 64                            NaN                 NaN
# 256                                               2.0
#
#                                                                  \
#                        spot.options  spot.channels cali.channel
# num_procs
# 16                              NaN            NaN          NaN
# 64                              NaN            NaN          NaN
# 256        time.variance,node.order  regionprofile         spot
#
#                                                                             \
#           spot:node.order                   spot:output spot:time.variance
# num_procs
# 16                    NaN                           NaN                NaN
# 64                    NaN                           NaN                NaN
# 256                  true  SS-MPI-i1-p256-s1048576.cali               true
#
#                                                                             \
#              launchdate                                          libraries
# num_procs
# 16                  NaN                                                NaN
# 64                  NaN                                                NaN
# 256        1.700023e+09  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                                                         \
#                                            cmdline cluster   Algorithm
# num_procs
# 16                                             NaN     NaN         NaN
# 64                                             NaN     NaN         NaN
# 256        [../../../Sample_Sort, 1, 256, 1048576]       c  SampleSort
#
#                                                                          \
#           ProgrammingModel Datatype SizeOfDatatype  InputSize InputType
# num_procs
# 16                     NaN      NaN            NaN        NaN       NaN
# 64                     NaN      NaN            NaN        NaN       NaN
# 256                    MPI      int            4.0  1048576.0    Sorted
#
#
#           group_num implementation_source
# num_procs
# 16              NaN                   NaN
# 64              NaN                   NaN
# 256            16.0                Online

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (65536, "nid"), (1048576, "nid"), (262144, "nid"),(65536, "spot.channel"), (1048576, "spot.channel"), (262144, "spot.channel")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([(65536, "Min time/rank"), (1048576, "Min time/rank"), (262144, "Min time/rank"),(65536, "Max time/rank"), (1048576, "Max time/rank"), (262144, "Max time/rank"),(65536, "Variance time/rank"), (1048576, "Variance time/rank"), (262144, "Variance time/rank"), (65536, "Avg time/rank"), (1048576, "Avg time/rank"), (262144, "Avg time/rank")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

# %%
ctk.dataframe
# Out:
#                              index      65536      262144       1048576
#                                    Total time  Total time    Total time
# name               num_procs
# main               16            0  65.284958         NaN           NaN
#                    64            1        NaN  185.684546           NaN
#                    256           2        NaN         NaN  11577.371920
# comm               16            3  55.373850         NaN           NaN
#                    64            4        NaN   52.303632           NaN
#                    256           5        NaN         NaN  10886.581163
# comm_large         16            6  24.293922         NaN           NaN
#                    64            7        NaN   13.867581           NaN
#                    256           8        NaN         NaN  10245.636624
# MPI_Gatherv        16            9  24.293493         NaN           NaN
#                    64           10        NaN   13.865909           NaN
#                    256          11        NaN         NaN  10245.627409
# comm_small         16           12  31.079493         NaN           NaN
#                    64           13        NaN   38.434291           NaN
#                    256          14        NaN         NaN    640.655607
# MPI_Allgather      16           15   2.324376         NaN           NaN
#                    64           16        NaN   16.384189           NaN
#                    256          17        NaN         NaN    128.741631
# MPI_Gather         16           18  28.691349         NaN           NaN
#                    64           19        NaN   22.047179           NaN
#                    256          20        NaN         NaN    511.671465
# comp               16           21   5.513415         NaN           NaN
#                    64           22        NaN   94.910783           NaN
#                    256          23        NaN         NaN    553.230607
# comp_large         16           24   5.511963         NaN           NaN
#                    64           25        NaN   94.676687           NaN
#                    256          26        NaN         NaN    552.357311
# comp_small         16           27   0.000491         NaN           NaN
#                    64           28        NaN    0.118862           NaN
#                    256          29        NaN         NaN      0.392517
# correctness_check  16           30   2.806400         NaN           NaN
#                    64           31        NaN   15.650818           NaN
#                    256          32        NaN         NaN     59.555290
# data_init          16           33   0.001761         NaN           NaN
#                    64           34        NaN    0.149446           NaN
#                    256          35        NaN         NaN      2.123667

# %%
# Define common variables
numProcs = [16,64,256]
dataType = "Sorted"
functions = ["main", "comm", "comp"]

# %%
def plot_mpl(df, title, xlabel, ylabel, columns):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(columns)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(numProcs)
    plt.show()
    return fig, ax

# %%
for func in functions:
    tempData = [ctk.dataframe.loc[func][65536].at[16, "Total time"], ctk.dataframe.loc[func][262144].at[64, "Total time"], ctk.dataframe.loc[func][1048576].at[256, "Total time"]]
    dfTemp = pd.DataFrame(tempData, columns=["Total time"], index=numProcs) 
    plot_mpl(
                df=dfTemp,
                title= func + "-" + dataType + "-Weak_Scaling",
                xlabel="Number of Processes",
                ylabel="Time (seconds)",
                columns=["Total time"]
            )
