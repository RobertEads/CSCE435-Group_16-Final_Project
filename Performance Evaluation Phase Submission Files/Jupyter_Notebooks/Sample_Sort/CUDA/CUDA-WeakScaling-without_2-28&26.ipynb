# {'name': 'comp_small', 'type': 'function'}        25743418           comp_small
#                                                   205232290          comp_small
#                                                   449059957          comp_small
#                                                   496282906          comp_small
#                                                   551498311          comp_small
#                                                   562011953          comp_small
#                                                   920816070          comp_small
#                                                   976138149          comp_small
#                                                   1270882337         comp_small
#                                                   1591275513         comp_small
#                                                   1723062004         comp_small
#                                                   1729559995         comp_small
#                                                   1811973823         comp_small
#                                                   1969631885         comp_small
#                                                   2137444031         comp_small
#                                                   2201299794         comp_small
#                                                   2519053334         comp_small
#                                                   2537162421         comp_small
#                                                   2631832200         comp_small
#                                                   2661124955         comp_small
#                                                   2687656021         comp_small
#                                                   2894281355         comp_small
#                                                   2914686680         comp_small
#                                                   2916068631         comp_small
#                                                   3025443433         comp_small
#                                                   3187664228         comp_small
#                                                   3249251004         comp_small
#                                                   3477988594         comp_small
#                                                   3711185514         comp_small
#                                                   3758979163         comp_small
#                                                   3799277778         comp_small
#                                                   3912700202         comp_small
#                                                   4166642359         comp_small
#                                                   4213769552         comp_small
#                                                   4220056260         comp_small
# {'name': 'correctness_check', 'type': 'function'} 25743418    correctness_check
#                                                   205232290   correctness_check
#                                                   449059957   correctness_check
#                                                   496282906   correctness_check
#                                                   551498311   correctness_check
#                                                   562011953   correctness_check
#                                                   920816070   correctness_check
#                                                   976138149   correctness_check
#                                                   1270882337  correctness_check
#                                                   1591275513  correctness_check
#                                                   1723062004  correctness_check
#                                                   1729559995  correctness_check
#                                                   1811973823  correctness_check
#                                                   1969631885  correctness_check
#                                                   2137444031  correctness_check
#                                                   2201299794  correctness_check
#                                                   2519053334  correctness_check
#                                                   2537162421  correctness_check
#                                                   2631832200  correctness_check
#                                                   2661124955  correctness_check
#                                                   2687656021  correctness_check
#                                                   2894281355  correctness_check
#                                                   2914686680  correctness_check
#                                                   2916068631  correctness_check
#                                                   3025443433  correctness_check
#                                                   3187664228  correctness_check
#                                                   3249251004  correctness_check
#                                                   3477988594  correctness_check
#                                                   3711185514  correctness_check
#                                                   3758979163  correctness_check
#                                                   3799277778  correctness_check
#                                                   3912700202  correctness_check
#                                                   4166642359  correctness_check
#                                                   4213769552  correctness_check
#                                                   4220056260  correctness_check
# {'name': 'data_init', 'type': 'function'}         25743418            data_init
#                                                   205232290           data_init
#                                                   449059957           data_init
#                                                   496282906           data_init
#                                                   551498311           data_init
#                                                   562011953           data_init
#                                                   920816070           data_init
#                                                   976138149           data_init
#                                                   1270882337          data_init
#                                                   1591275513          data_init
#                                                   1723062004          data_init
#                                                   1729559995          data_init
#                                                   1811973823          data_init
#                                                   1969631885          data_init
#                                                   2137444031          data_init
#                                                   2201299794          data_init
#                                                   2519053334          data_init
#                                                   2537162421          data_init
#                                                   2631832200          data_init
#                                                   2661124955          data_init
#                                                   2687656021          data_init
#                                                   2894281355          data_init
#                                                   2914686680          data_init
#                                                   2916068631          data_init
#                                                   3025443433          data_init
#                                                   3187664228          data_init
#                                                   3249251004          data_init
#                                                   3477988594          data_init
#                                                   3711185514          data_init
#                                                   3758979163          data_init
#                                                   3799277778          data_init
#                                                   3912700202          data_init
#                                                   4166642359          data_init
#                                                   4213769552          data_init
#                                                   4220056260          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 25743418             2.11.0-dev
# 205232290            2.11.0-dev
# 449059957            2.11.0-dev
# 496282906            2.11.0-dev
# 551498311            2.11.0-dev
# 562011953            2.11.0-dev
# 920816070            2.11.0-dev
# 976138149            2.11.0-dev
# 1270882337           2.11.0-dev
# 1591275513           2.11.0-dev
# 1723062004           2.11.0-dev
# 1729559995           2.11.0-dev
# 1811973823           2.11.0-dev
# 1969631885           2.11.0-dev
# 2137444031           2.11.0-dev
# 2201299794           2.11.0-dev
# 2519053334           2.11.0-dev
# 2537162421           2.11.0-dev
# 2631832200           2.11.0-dev
# 2661124955           2.11.0-dev
# 2687656021           2.11.0-dev
# 2894281355           2.11.0-dev
# 2914686680           2.11.0-dev
# 2916068631           2.11.0-dev
# 3025443433           2.11.0-dev
# 3187664228           2.11.0-dev
# 3249251004           2.11.0-dev
# 3477988594           2.11.0-dev
# 3711185514           2.11.0-dev
# 3758979163           2.11.0-dev
# 3799277778           2.11.0-dev
# 3912700202           2.11.0-dev
# 4166642359           2.11.0-dev
# 4213769552           2.11.0-dev
# 4220056260           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 25743418    min#inclusive#sum#time.duration,max#inclusive#...
# 205232290   min#inclusive#sum#time.duration,max#inclusive#...
# 449059957   min#inclusive#sum#time.duration,max#inclusive#...
# 496282906   min#inclusive#sum#time.duration,max#inclusive#...
# 551498311   min#inclusive#sum#time.duration,max#inclusive#...
# 562011953   min#inclusive#sum#time.duration,max#inclusive#...
# 920816070   min#inclusive#sum#time.duration,max#inclusive#...
# 976138149   min#inclusive#sum#time.duration,max#inclusive#...
# 1270882337  min#inclusive#sum#time.duration,max#inclusive#...
# 1591275513  min#inclusive#sum#time.duration,max#inclusive#...
# 1723062004  min#inclusive#sum#time.duration,max#inclusive#...
# 1729559995  min#inclusive#sum#time.duration,max#inclusive#...
# 1811973823  min#inclusive#sum#time.duration,max#inclusive#...
# 1969631885  min#inclusive#sum#time.duration,max#inclusive#...
# 2137444031  min#inclusive#sum#time.duration,max#inclusive#...
# 2201299794  min#inclusive#sum#time.duration,max#inclusive#...
# 2519053334  min#inclusive#sum#time.duration,max#inclusive#...
# 2537162421  min#inclusive#sum#time.duration,max#inclusive#...
# 2631832200  min#inclusive#sum#time.duration,max#inclusive#...
# 2661124955  min#inclusive#sum#time.duration,max#inclusive#...
# 2687656021  min#inclusive#sum#time.duration,max#inclusive#...
# 2894281355  min#inclusive#sum#time.duration,max#inclusive#...
# 2914686680  min#inclusive#sum#time.duration,max#inclusive#...
# 2916068631  min#inclusive#sum#time.duration,max#inclusive#...
# 3025443433  min#inclusive#sum#time.duration,max#inclusive#...
# 3187664228  min#inclusive#sum#time.duration,max#inclusive#...
# 3249251004  min#inclusive#sum#time.duration,max#inclusive#...
# 3477988594  min#inclusive#sum#time.duration,max#inclusive#...
# 3711185514  min#inclusive#sum#time.duration,max#inclusive#...
# 3758979163  min#inclusive#sum#time.duration,max#inclusive#...
# 3799277778  min#inclusive#sum#time.duration,max#inclusive#...
# 3912700202  min#inclusive#sum#time.duration,max#inclusive#...
# 4166642359  min#inclusive#sum#time.duration,max#inclusive#...
# 4213769552  min#inclusive#sum#time.duration,max#inclusive#...
# 4220056260  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 25743418                                              2
# 205232290                                             2
# 449059957                                             2
# 496282906                                             2
# 551498311                                             2
# 562011953                                             2
# 920816070                                             2
# 976138149                                             2
# 1270882337                                            2
# 1591275513                                            2
# 1723062004                                            2
# 1729559995                                            2
# 1811973823                                            2
# 1969631885                                            2
# 2137444031                                            2
# 2201299794                                            2
# 2519053334                                            2
# 2537162421                                            2
# 2631832200                                            2
# 2661124955                                            2
# 2687656021                                            2
# 2894281355                                            2
# 2914686680                                            2
# 2916068631                                            2
# 3025443433                                            2
# 3187664228                                            2
# 3249251004                                            2
# 3477988594                                            2
# 3711185514                                            2
# 3758979163                                            2
# 3799277778                                            2
# 3912700202                                            2
# 4166642359                                            2
# 4213769552                                            2
# 4220056260                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 25743418    cuda.gputime,node.order  regionprofile         spot
# 205232290   cuda.gputime,node.order  regionprofile         spot
# 449059957   cuda.gputime,node.order  regionprofile         spot
# 496282906   cuda.gputime,node.order  regionprofile         spot
# 551498311   cuda.gputime,node.order  regionprofile         spot
# 562011953   cuda.gputime,node.order  regionprofile         spot
# 920816070   cuda.gputime,node.order  regionprofile         spot
# 976138149   cuda.gputime,node.order  regionprofile         spot
# 1270882337  cuda.gputime,node.order  regionprofile         spot
# 1591275513  cuda.gputime,node.order  regionprofile         spot
# 1723062004  cuda.gputime,node.order  regionprofile         spot
# 1729559995  cuda.gputime,node.order  regionprofile         spot
# 1811973823  cuda.gputime,node.order  regionprofile         spot
# 1969631885  cuda.gputime,node.order  regionprofile         spot
# 2137444031  cuda.gputime,node.order  regionprofile         spot
# 2201299794  cuda.gputime,node.order  regionprofile         spot
# 2519053334  cuda.gputime,node.order  regionprofile         spot
# 2537162421  cuda.gputime,node.order  regionprofile         spot
# 2631832200  cuda.gputime,node.order  regionprofile         spot
# 2661124955  cuda.gputime,node.order  regionprofile         spot
# 2687656021  cuda.gputime,node.order  regionprofile         spot
# 2894281355  cuda.gputime,node.order  regionprofile         spot
# 2914686680  cuda.gputime,node.order  regionprofile         spot
# 2916068631  cuda.gputime,node.order  regionprofile         spot
# 3025443433  cuda.gputime,node.order  regionprofile         spot
# 3187664228  cuda.gputime,node.order  regionprofile         spot
# 3249251004  cuda.gputime,node.order  regionprofile         spot
# 3477988594  cuda.gputime,node.order  regionprofile         spot
# 3711185514  cuda.gputime,node.order  regionprofile         spot
# 3758979163  cuda.gputime,node.order  regionprofile         spot
# 3799277778  cuda.gputime,node.order  regionprofile         spot
# 3912700202  cuda.gputime,node.order  regionprofile         spot
# 4166642359  cuda.gputime,node.order  regionprofile         spot
# 4213769552  cuda.gputime,node.order  regionprofile         spot
# 4220056260  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order  \
# profile
# 25743418                true            true
# 205232290               true            true
# 449059957               true            true
# 496282906               true            true
# 551498311               true            true
# 562011953               true            true
# 920816070               true            true
# 976138149               true            true
# 1270882337              true            true
# 1591275513              true            true
# 1723062004              true            true
# 1729559995              true            true
# 1811973823              true            true
# 1969631885              true            true
# 2137444031              true            true
# 2201299794              true            true
# 2519053334              true            true
# 2537162421              true            true
# 2631832200              true            true
# 2661124955              true            true
# 2687656021              true            true
# 2894281355              true            true
# 2914686680              true            true
# 2916068631              true            true
# 3025443433              true            true
# 3187664228              true            true
# 3249251004              true            true
# 3477988594              true            true
# 3711185514              true            true
# 3758979163              true            true
# 3799277778              true            true
# 3912700202              true            true
# 4166642359              true            true
# 4213769552              true            true
# 4220056260              true            true
#
#                                  spot:output  launchdate  \
# profile
# 25743418       SS-CUDA-i0-t256-s4194304.cali  1701913745
# 205232290         SS-CUDA-i0-t64-s65536.cali  1701913534
# 449059957    SS-CUDA-i0-t512-s268435456.cali  1701921088
# 496282906     SS-CUDA-i0-t128-s67108864.cali  1701913884
# 551498311      SS-CUDA-i0-t128-s4194304.cali  1701913745
# 562011953      SS-CUDA-i0-t1024-s262144.cali  1701913595
# 920816070        SS-CUDA-i0-t256-s65536.cali  1701913523
# 976138149      SS-CUDA-i0-t128-s1048576.cali  1701913685
# 1270882337       SS-CUDA-i0-t128-s65536.cali  1701913523
# 1591275513    SS-CUDA-i0-t64-s268435456.cali  1701921088
# 1723062004   SS-CUDA-i0-t1024-s16777216.cali  1701912521
# 1729559995       SS-CUDA-i0-t512-s65536.cali  1701913523
# 1811973823    SS-CUDA-i0-t128-s16777216.cali  1701913823
# 1969631885     SS-CUDA-i0-t64-s16777216.cali  1701913823
# 2137444031      SS-CUDA-i0-t64-s1048576.cali  1701913685
# 2201299794      SS-CUDA-i0-t1024-s65536.cali  1701913523
# 2519053334      SS-CUDA-i0-t128-s262144.cali  1701913625
# 2537162421    SS-CUDA-i0-t256-s16777216.cali  1701913824
# 2631832200    SS-CUDA-i0-t256-s67108864.cali  1701913884
# 2661124955   SS-CUDA-i0-t128-s268435456.cali  1701921088
# 2687656021    SS-CUDA-i0-t1024-s1048576.cali  1701913685
# 2894281355  SS-CUDA-i0-t1024-s268435456.cali  1701920847
# 2914686680     SS-CUDA-i0-t256-s1048576.cali  1701913685
# 2916068631      SS-CUDA-i0-t512-s262144.cali  1701913625
# 3025443433     SS-CUDA-i0-t64-s67108864.cali  1701913884
# 3187664228       SS-CUDA-i0-t64-s262144.cali  1701913626
# 3249251004    SS-CUDA-i0-t1024-s4194304.cali  1701913745
# 3477988594      SS-CUDA-i0-t256-s262144.cali  1701913625
# 3711185514   SS-CUDA-i0-t256-s268435456.cali  1701921088
# 3758979163    SS-CUDA-i0-t512-s16777216.cali  1701913824
# 3799277778    SS-CUDA-i0-t512-s67108864.cali  1701913884
# 3912700202   SS-CUDA-i0-t1024-s67108864.cali  1701912582
# 4166642359     SS-CUDA-i0-t512-s4194304.cali  1701913745
# 4213769552      SS-CUDA-i0-t64-s4194304.cali  1701913745
# 4220056260     SS-CUDA-i0-t512-s1048576.cali  1701913685
#
#                                                     libraries  \
# profile
# 25743418    [/scratch/group/csce435-f23/Caliper/caliper/li...
# 205232290   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 449059957   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 496282906   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 551498311   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 562011953   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 920816070   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 976138149   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1270882337  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1591275513  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1723062004  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1729559995  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1811973823  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1969631885  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2137444031  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2201299794  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2519053334  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2537162421  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2631832200  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2661124955  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2687656021  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2894281355  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2914686680  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2916068631  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3025443433  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3187664228  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3249251004  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3477988594  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3711185514  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3758979163  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3799277778  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3912700202  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4166642359  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4213769552  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4220056260  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                                cmdline cluster   Algorithm  \
# profile
# 25743418       [../../../Sample_Sort, 0, 256, 4194304]       g  SampleSort
# 205232290         [../../../Sample_Sort, 0, 64, 65536]       g  SampleSort
# 449059957    [../../../Sample_Sort, 0, 512, 268435456]       g  SampleSort
# 496282906     [../../../Sample_Sort, 0, 128, 67108864]       g  SampleSort
# 551498311      [../../../Sample_Sort, 0, 128, 4194304]       g  SampleSort
# 562011953      [../../../Sample_Sort, 0, 1024, 262144]       g  SampleSort
# 920816070        [../../../Sample_Sort, 0, 256, 65536]       g  SampleSort
# 976138149      [../../../Sample_Sort, 0, 128, 1048576]       g  SampleSort
# 1270882337       [../../../Sample_Sort, 0, 128, 65536]       g  SampleSort
# 1591275513    [../../../Sample_Sort, 0, 64, 268435456]       g  SampleSort
# 1723062004          [./Sample_Sort, 0, 1024, 16777216]       g  SampleSort
# 1729559995       [../../../Sample_Sort, 0, 512, 65536]       g  SampleSort
# 1811973823    [../../../Sample_Sort, 0, 128, 16777216]       g  SampleSort
# 1969631885     [../../../Sample_Sort, 0, 64, 16777216]       g  SampleSort
# 2137444031      [../../../Sample_Sort, 0, 64, 1048576]       g  SampleSort
# 2201299794      [../../../Sample_Sort, 0, 1024, 65536]       g  SampleSort
# 2519053334      [../../../Sample_Sort, 0, 128, 262144]       g  SampleSort
# 2537162421    [../../../Sample_Sort, 0, 256, 16777216]       g  SampleSort
# 2631832200    [../../../Sample_Sort, 0, 256, 67108864]       g  SampleSort
# 2661124955   [../../../Sample_Sort, 0, 128, 268435456]       g  SampleSort
# 2687656021    [../../../Sample_Sort, 0, 1024, 1048576]       g  SampleSort
# 2894281355  [../../../Sample_Sort, 0, 1024, 268435456]       g  SampleSort
# 2914686680     [../../../Sample_Sort, 0, 256, 1048576]       g  SampleSort
# 2916068631      [../../../Sample_Sort, 0, 512, 262144]       g  SampleSort
# 3025443433     [../../../Sample_Sort, 0, 64, 67108864]       g  SampleSort
# 3187664228       [../../../Sample_Sort, 0, 64, 262144]       g  SampleSort
# 3249251004    [../../../Sample_Sort, 0, 1024, 4194304]       g  SampleSort
# 3477988594      [../../../Sample_Sort, 0, 256, 262144]       g  SampleSort
# 3711185514   [../../../Sample_Sort, 0, 256, 268435456]       g  SampleSort
# 3758979163    [../../../Sample_Sort, 0, 512, 16777216]       g  SampleSort
# 3799277778    [../../../Sample_Sort, 0, 512, 67108864]       g  SampleSort
# 3912700202          [./Sample_Sort, 0, 1024, 67108864]       g  SampleSort
# 4166642359     [../../../Sample_Sort, 0, 512, 4194304]       g  SampleSort
# 4213769552      [../../../Sample_Sort, 0, 64, 4194304]       g  SampleSort
# 4220056260     [../../../Sample_Sort, 0, 512, 1048576]       g  SampleSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 25743418               CUDA      int               4    4194304    Random
# 205232290              CUDA      int               4      65536    Random
# 449059957              CUDA      int               4  268435456    Random
# 496282906              CUDA      int               4   67108864    Random
# 551498311              CUDA      int               4    4194304    Random
# 562011953              CUDA      int               4     262144    Random
# 920816070              CUDA      int               4      65536    Random
# 976138149              CUDA      int               4    1048576    Random
# 1270882337             CUDA      int               4      65536    Random
# 1591275513             CUDA      int               4  268435456    Random
# 1723062004             CUDA      int               4   16777216    Random
# 1729559995             CUDA      int               4      65536    Random
# 1811973823             CUDA      int               4   16777216    Random
# 1969631885             CUDA      int               4   16777216    Random
# 2137444031             CUDA      int               4    1048576    Random
# 2201299794             CUDA      int               4      65536    Random
# 2519053334             CUDA      int               4     262144    Random
# 2537162421             CUDA      int               4   16777216    Random
# 2631832200             CUDA      int               4   67108864    Random
# 2661124955             CUDA      int               4  268435456    Random
# 2687656021             CUDA      int               4    1048576    Random
# 2894281355             CUDA      int               4  268435456    Random
# 2914686680             CUDA      int               4    1048576    Random
# 2916068631             CUDA      int               4     262144    Random
# 3025443433             CUDA      int               4   67108864    Random
# 3187664228             CUDA      int               4     262144    Random
# 3249251004             CUDA      int               4    4194304    Random
# 3477988594             CUDA      int               4     262144    Random
# 3711185514             CUDA      int               4  268435456    Random
# 3758979163             CUDA      int               4   16777216    Random
# 3799277778             CUDA      int               4   67108864    Random
# 3912700202             CUDA      int               4   67108864    Random
# 4166642359             CUDA      int               4    4194304    Random
# 4213769552             CUDA      int               4    4194304    Random
# 4220056260             CUDA      int               4    1048576    Random
#
#             num_threads  num_blocks  group_num implementation_source
# profile
# 25743418            256       16384         16                    AI
# 205232290            64        1024         16                    AI
# 449059957           512      524288         16                    AI
# 496282906           128      524288         16                    AI
# 551498311           128       32768         16                    AI
# 562011953          1024         256         16                    AI
# 920816070           256         256         16                    AI
# 976138149           128        8192         16                    AI
# 1270882337          128         512         16                    AI
# 1591275513           64     4194304         16                    AI
# 1723062004         1024       16384         16                    AI
# 1729559995          512         128         16                    AI
# 1811973823          128      131072         16                    AI
# 1969631885           64      262144         16                    AI
# 2137444031           64       16384         16                    AI
# 2201299794         1024          64         16                    AI
# 2519053334          128        2048         16                    AI
# 2537162421          256       65536         16                    AI
# 2631832200          256      262144         16                    AI
# 2661124955          128     2097152         16                    AI
# 2687656021         1024        1024         16                    AI
# 2894281355         1024      262144         16                    AI
# 2914686680          256        4096         16                    AI
# 2916068631          512         512         16                    AI
# 3025443433           64     1048576         16                    AI
# 3187664228           64        4096         16                    AI
# 3249251004         1024        4096         16                    AI
# 3477988594          256        1024         16                    AI
# 3711185514          256     1048576         16                    AI
# 3758979163          512       32768         16                    AI
# 3799277778          512      131072         16                    AI
# 3912700202         1024       65536         16                    AI
# 4166642359          512        8192         16                    AI
# 4213769552           64       65536         16                    AI
# 4220056260          512        2048         16                    AI

# %%
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comp
# │  ├─ 1.000 comp_large
# │  └─ 1.000 comp_small
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
gb = tk.groupby("InputSize")
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ac82ef408e0>, 262144: <thicket.thicket.Thicket object at 0x2ac82ee78e50>, 1048576: <thicket.thicket.Thicket object at 0x2ac82ee2d940>, 4194304: <thicket.thicket.Thicket object at 0x2ac82ee444f0>, 16777216: <thicket.thicket.Thicket object at 0x2ac82ee2d670>, 67108864: <thicket.thicket.Thicket object at 0x2ac82ee0d1f0>, 268435456: <thicket.thicket.Thicket object at 0x2ac82ee06760>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)

# %%
#ctk.dataframe = ctk.dataframe.drop([268435456, 67108864,16777216], axis=1)
ctk.dataframe = ctk.dataframe.drop([268435456,67108864], axis=1)
#ctk.dataframe = ctk.dataframe.drop([268435456], axis=1)
ctk.dataframe
# Out:
#                                                                       65536  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.373597
#                                                   128              0.385603
#                                                   256              0.366894
#                                                   512              0.402455
#                                                   1024             0.402721
# {'name': 'comp', 'type': 'function'}              64               0.025648
#                                                   128              0.025439
#                                                   256              0.022351
#                                                   512              0.024212
#                                                   1024             0.029995
# {'name': 'comp_large', 'type': 'function'}        64               0.013663
#                                                   128              0.013300
#                                                   256              0.011723
#                                                   512              0.012792
#                                                   1024             0.015312
# {'name': 'comp_small', 'type': 'function'}        64               0.011948
#                                                   128              0.012102
#                                                   256              0.010592
#                                                   512              0.011386
#                                                   1024             0.014648
# {'name': 'correctness_check', 'type': 'function'} 64               0.000085
#                                                   128              0.000107
#                                                   256              0.000094
#                                                   512              0.000089
#                                                   1024             0.000096
# {'name': 'data_init', 'type': 'function'}         64               0.342235
#                                                   128              0.354371
#                                                   256              0.338938
#                                                   512              0.372653
#                                                   1024             0.366940
#
#                                                                      262144  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.447413
#                                                   128              0.736633
#                                                   256              0.737073
#                                                   512              0.441573
#                                                   1024             0.459207
# {'name': 'comp', 'type': 'function'}              64               0.095010
#                                                   128              0.114000
#                                                   256              0.114338
#                                                   512              0.091820
#                                                   1024             0.107913
# {'name': 'comp_large', 'type': 'function'}        64               0.044821
#                                                   128              0.053728
#                                                   256              0.053758
#                                                   512              0.041683
#                                                   1024             0.043332
# {'name': 'comp_small', 'type': 'function'}        64               0.050147
#                                                   128              0.060232
#                                                   256              0.060538
#                                                   512              0.050100
#                                                   1024             0.064538
# {'name': 'correctness_check', 'type': 'function'} 64               0.000114
#                                                   128              0.000110
#                                                   256              0.000090
#                                                   512              0.000082
#                                                   1024             0.000104
# {'name': 'data_init', 'type': 'function'}         64               0.346377
#                                                   128              0.617117
#                                                   256              0.617047
#                                                   512              0.344294
#                                                   1024             0.345796
#
#                                                                     1048576  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.970032
#                                                   128              0.952758
#                                                   256              0.941002
#                                                   512              0.993052
#                                                   1024             0.743201
# {'name': 'comp', 'type': 'function'}              64               0.347631
#                                                   128              0.336063
#                                                   256              0.321125
#                                                   512              0.350093
#                                                   1024             0.384677
# {'name': 'comp_large', 'type': 'function'}        64               0.135680
#                                                   128              0.110758
#                                                   256              0.115393
#                                                   512              0.129117
#                                                   1024             0.115066
# {'name': 'comp_small', 'type': 'function'}        64               0.211909
#                                                   128              0.225259
#                                                   256              0.205683
#                                                   512              0.220933
#                                                   1024             0.269568
# {'name': 'correctness_check', 'type': 'function'} 64               0.000089
#                                                   128              0.000092
#                                                   256              0.000087
#                                                   512              0.000092
#                                                   1024             0.000080
# {'name': 'data_init', 'type': 'function'}         64               0.606453
#                                                   128              0.611015
#                                                   256              0.614362
#                                                   512              0.573608
#                                                   1024             0.353011
#
#                                                                     4194304  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               1.761996
#                                                   128              1.940736
#                                                   256              1.915305
#                                                   512              1.889541
#                                                   1024             1.667966
# {'name': 'comp', 'type': 'function'}              64               1.137569
#                                                   128              1.314296
#                                                   256              1.310943
#                                                   512              1.288724
#                                                   1024             1.308737
# {'name': 'comp_large', 'type': 'function'}        64               0.447885
#                                                   128              0.443846
#                                                   256              0.444605
#                                                   512              0.449840
#                                                   1024             0.450418
# {'name': 'comp_small', 'type': 'function'}        64               0.689626
#                                                   128              0.870396
#                                                   256              0.866282
#                                                   512              0.838828
#                                                   1024             0.858251
# {'name': 'correctness_check', 'type': 'function'} 64               0.000155
#                                                   128              0.000133
#                                                   256              0.000110
#                                                   512              0.000122
#                                                   1024             0.000121
# {'name': 'data_init', 'type': 'function'}         64               0.618807
#                                                   128              0.620666
#                                                   256              0.594049
#                                                   512              0.595008
#                                                   1024             0.353599
#
#                                                                    16777216  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64              10.716097
#                                                   128             10.401376
#                                                   256             10.533626
#                                                   512             10.214669
#                                                   1024            10.536911
# {'name': 'comp', 'type': 'function'}              64              10.092978
#                                                   128              9.775054
#                                                   256             10.173767
#                                                   512              9.835780
#                                                   1024            10.148863
# {'name': 'comp_large', 'type': 'function'}        64               3.262943
#                                                   128              3.248413
#                                                   256              3.214994
#                                                   512              3.237577
#                                                   1024             3.297064
# {'name': 'comp_small', 'type': 'function'}        64               6.829969
#                                                   128              6.526573
#                                                   256              6.958687
#                                                   512              6.598117
#                                                   1024             6.851707
# {'name': 'correctness_check', 'type': 'function'} 64               0.000449
#                                                   128              0.000371
#                                                   256              0.000372
#                                                   512              0.000391
#                                                   1024             0.000428
# {'name': 'data_init', 'type': 'function'}         64               0.616946
#                                                   128              0.619785
#                                                   256              0.353751
#                                                   512              0.372347
#                                                   1024             0.381797
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                        main
#                                                   128                       main
#                                                   256                       main
#                                                   512                       main
#                                                   1024                      main
# {'name': 'comp', 'type': 'function'}              64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
# {'name': 'comp_large', 'type': 'function'}        64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
# {'name': 'comp_small', 'type': 'function'}        64                  comp_small
#                                                   128                 comp_small
#                                                   256                 comp_small
#                                                   512                 comp_small
#                                                   1024                comp_small
# {'name': 'correctness_check', 'type': 'function'} 64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %%
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
# Out:
# /sw/hprc/sw/Python/virtualenvs/Python/3.8.2/default_jupyter_notebook/lib/python3.8/site-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

# %%
for name in function_names:
     #for size in input_sizes:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"CUDA Weak Scaling - Sample Sort, {name}, Random", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Sample Sort, main, Random", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Sample Sort, comp_large, Random", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
#speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
#plot_mpl(
#    df=speedup,
#    title=f"CUDA - Merge Sort, comm, Random Array", 
#    xlabel="Number of Threads",
#    ylabel="Speed Up",
#)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'CUDA - Sample Sort, comp_large, Random'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %% [markdown]
# # Weak Scaling for Sorted

# %%
tk = th.Thicket.from_caliperreader(glob("*-i1*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
gb = tk.groupby("InputSize")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
ctk.dataframe = ctk.dataframe.drop([268435456,67108864], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

for name in function_names:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"CUDA Weak Scaling - Sample Sort, {name}, Sorted", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Sample Sort, main, Sorted", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Sample Sort, comp_large, Sorted", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
#speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
#plot_mpl(
#    df=speedup,
#    title=f"CUDA - Merge Sort, comm, Sorted Array", 
#    xlabel="Number of Threads",
#    ylabel="Speed Up",
#)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ac8316297c0>, 262144: <thicket.thicket.Thicket object at 0x2ac82f0568b0>, 1048576: <thicket.thicket.Thicket object at 0x2ac8313ecdc0>, 4194304: <thicket.thicket.Thicket object at 0x2ac831410040>, 16777216: <thicket.thicket.Thicket object at 0x2ac82f04ea00>, 67108864: <thicket.thicket.Thicket object at 0x2ac82edff7c0>, 268435456: <thicket.thicket.Thicket object at 0x2ac831625190>}
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'CUDA - Sample Sort, comp_large, Sorted'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %% [markdown]
# # Weak Scaling for Reverse Sorted

# %%
tk = th.Thicket.from_caliperreader(glob("*-i2*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
gb = tk.groupby("InputSize")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
ctk.dataframe = ctk.dataframe.drop([268435456,67108864], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

for name in function_names:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"Cuda Weak Scaling - Sample Sort, {name}, ReverseSorted", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Sample Sort, main, ReverseSorted", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Sample Sort, comp_large, ReverseSorted", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
#speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
#plot_mpl(
#    df=speedup,
#    title=f"CUDA - Merge Sort, comm, Reverse Sorted Array", 
#    xlabel="Number of Threads",
#    ylabel="Speed Up",
#)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ac82ee8ffd0>, 262144: <thicket.thicket.Thicket object at 0x2ac8314620d0>, 1048576: <thicket.thicket.Thicket object at 0x2ac82ee1d670>, 4194304: <thicket.thicket.Thicket object at 0x2ac82f026bb0>, 16777216: <thicket.thicket.Thicket object at 0x2ac82eef3460>, 67108864: <thicket.thicket.Thicket object at 0x2ac8313872b0>, 268435456: <thicket.thicket.Thicket object at 0x2ac82f04e910>}
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'CUDA - Sample Sort, comp_large, ReverseSorted'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %% [markdown]
# # Weak Scaling for 1% Perturbed

# %%
tk = th.Thicket.from_caliperreader(glob("*-i3*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
gb = tk.groupby("InputSize")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
ctk.dataframe = ctk.dataframe.drop([268435456,67108864], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

for name in function_names:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"Cuda Weak Scaling- Sample Sort, {name}, 1%Perturbed", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Sample Sort, Main, 1%Perturbed", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Sample Sort, comp_large, 1%Perturbed", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
#speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
#plot_mpl(
#    df=speedup,
#    title=f"CUDA - Merge Sort, comm, 1% Perturbed", 
#    xlabel="Number of Threads",
#    ylabel="Speed Up",
#)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ac8316683d0>, 262144: <thicket.thicket.Thicket object at 0x2ac831370580>, 1048576: <thicket.thicket.Thicket object at 0x2ac831302dc0>, 4194304: <thicket.thicket.Thicket object at 0x2ac8313ec910>, 16777216: <thicket.thicket.Thicket object at 0x2ac831457940>, 67108864: <thicket.thicket.Thicket object at 0x2ac831421970>, 268435456: <thicket.thicket.Thicket object at 0x2ac82f051940>}
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'CUDA - Sample Sort, comp_large, 1%Perturbed'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %%
for name in function_names:
    print(ctk.dataframe.loc[name])
# Out:
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.014638      0.050951      0.197868      0.724111
# 128              0.014590      0.057108      0.174902      0.812623
# 256              0.012662      0.032954      0.169557      0.844609
# 512              0.008616      0.052998      0.238511      0.782157
# 1024             0.015389      0.061117      0.296983      0.859631
#
#                  16777216
#             Avg time/rank
# num_threads
# 64               6.627639
# 128              6.681354
# 256              7.046120
# 512              6.655886
# 1024             7.116395
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.602667      0.331733      0.354616      0.351414
# 128              0.615580      0.493496      0.336143      0.346099
# 256              0.323333      0.489594      0.331809      0.335125
# 512              0.219269      0.328071      0.340951      0.335943
# 1024             0.332681      0.335605      0.341468      0.338324
#
#                  16777216
#             Avg time/rank
# num_threads
# 64               0.348353
# 128              0.348104
# 256              0.352202
# 512              0.336158
# 1024             0.336405
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.028361      0.094476      0.307102      1.170204
# 128              0.027382      0.104903      0.290549      1.253451
# 256              0.023413      0.060425      0.278543      1.285769
# 512              0.015130      0.093767      0.347090      1.226313
# 1024             0.025700      0.097381      0.408085      1.307047
#
#                  16777216
#             Avg time/rank
# num_threads
# 64               9.839877
# 128              9.883876
# 256             10.238481
# 512              9.852203
# 1024            10.657381
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000086      0.000097      0.000110      0.000140
# 128              0.000089      0.000087      0.000095      0.000119
# 256              0.000079      0.000085      0.000086      0.000102
# 512              0.000081      0.000094      0.000098      0.000092
# 1024             0.000080      0.000089      0.000116      0.000105
#
#                  16777216
#             Avg time/rank
# num_threads
# 64               0.000465
# 128              0.000362
# 256              0.000349
# 512              0.000340
# 1024             0.000352
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.636604      0.431828      0.667823      1.527246
# 128              0.648684      0.654328      0.632386      1.605298
# 256              0.352313      0.555659      0.616024      1.626602
# 512              0.240130      0.427435      0.694036      1.567815
# 1024             0.363949      0.438598      0.755451      1.651139
#
#                  16777216
#             Avg time/rank
# num_threads
# 64              10.194601
# 128             10.238053
# 256             10.596929
# 512             10.194616
# 1024            10.999904
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.013688      0.043483      0.109190      0.446039
# 128              0.012756      0.047759      0.115597      0.440778
# 256              0.010715      0.027426      0.108940      0.441110
# 512              0.006477      0.040727      0.108536      0.444109
# 1024             0.010277      0.036222      0.111049      0.447360
#
#                  16777216
#             Avg time/rank
# num_threads
# 64               3.212165
# 128              3.202444
# 256              3.192283
# 512              3.196239
# 1024             3.540906

# %%
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
speedup
# Out:
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               1.000000      1.000000      1.000000      1.000000
# 128              0.981378      0.659956      1.056037      0.951378
# 256              1.806927      0.777146      1.084086      0.938918
# 512              2.651081      1.010278      0.962231      0.974124
# 1024             1.749157      0.984564      0.884006      0.924965
#
#                  16777216
#             Avg time/rank
# num_threads
# 64               1.000000
# 128              0.995756
# 256              0.962034
# 512              0.999999
# 1024             0.926790

# %%
plot_mpl(
    df=speedup,
    title=f"CUDA - Sample Sort, Main", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'CUDA - Sample Sort, Main'}, xlabel='Number of Threads', ylabel='Speed Up'>)
