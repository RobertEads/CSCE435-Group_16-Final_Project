# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
all_files = glob("*.cali")
print(all_files)
tk = th.Thicket.from_caliperreader(all_files)
# Out:
# ['SS-CUDA-i1-t256-s1048576.cali', 'SS-CUDA-i1-t1024-s262144.cali', 'SS-CUDA-i1-t256-s262144.cali', 'SS-CUDA-i1-t512-s1048576.cali', 'SS-CUDA-i1-t128-s1048576.cali', 'SS-CUDA-i1-t256-s65536.cali', 'SS-CUDA-i1-t1024-s1048576.cali', 'SS-CUDA-i1-t64-s1048576.cali', 'SS-CUDA-i1-t1024-s65536.cali', 'SS-CUDA-i1-t512-s65536.cali', 'SS-CUDA-i1-t128-s262144.cali', 'SS-CUDA-i1-t64-s65536.cali', 'SS-CUDA-i1-t128-s65536.cali', 'SS-CUDA-i1-t64-s262144.cali', 'SS-CUDA-i1-t512-s262144.cali']

# %%
tk.profile_mapping
# Out:
# OrderedDict([(6318664, 'SS-CUDA-i1-t512-s262144.cali'),
#              (925675111, 'SS-CUDA-i1-t512-s1048576.cali'),
#              (1074393378, 'SS-CUDA-i1-t64-s1048576.cali'),
#              (1354738133, 'SS-CUDA-i1-t128-s262144.cali'),
#              (1534088367, 'SS-CUDA-i1-t512-s65536.cali'),
#              (1805720230, 'SS-CUDA-i1-t1024-s65536.cali'),
#              (2597104869, 'SS-CUDA-i1-t256-s1048576.cali'),
#              (3099896238, 'SS-CUDA-i1-t128-s1048576.cali'),
#              (3276735306, 'SS-CUDA-i1-t64-s65536.cali'),
#              (3317981574, 'SS-CUDA-i1-t1024-s1048576.cali'),
#              (3760525145, 'SS-CUDA-i1-t256-s262144.cali'),
#              (3909383082, 'SS-CUDA-i1-t256-s65536.cali'),
#              (4067219679, 'SS-CUDA-i1-t128-s65536.cali'),
#              (4106490612, 'SS-CUDA-i1-t64-s262144.cali'),
#              (4142598652, 'SS-CUDA-i1-t1024-s262144.cali')])

# %%
tk.dataframe
# Out:
#                                                                nid  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               6318664       1
#                                                    925675111     1
#                                                    1074393378    1
#                                                    1354738133    1
#                                                    1534088367    1
#                                                    1805720230    1
#                                                    2597104869    1
#                                                    3099896238    1
#                                                    3276735306    1
#                                                    3317981574    1
#                                                    3760525145    1
#                                                    3909383082    1
# ...

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 6318664              2.11.0-dev
# 925675111            2.11.0-dev
# 1074393378           2.11.0-dev
# 1354738133           2.11.0-dev
# 1534088367           2.11.0-dev
# 1805720230           2.11.0-dev
# 2597104869           2.11.0-dev
# 3099896238           2.11.0-dev
# 3276735306           2.11.0-dev
# 3317981574           2.11.0-dev
# 3760525145           2.11.0-dev
# 3909383082           2.11.0-dev
# 4067219679           2.11.0-dev
# 4106490612           2.11.0-dev
# 4142598652           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 6318664     min#inclusive#sum#time.duration,max#inclusive#...
# 925675111   min#inclusive#sum#time.duration,max#inclusive#...
# 1074393378  min#inclusive#sum#time.duration,max#inclusive#...
# 1354738133  min#inclusive#sum#time.duration,max#inclusive#...
# 1534088367  min#inclusive#sum#time.duration,max#inclusive#...
# ...

# %%
#tk.statsframe.dataframe["time"] = 1

# %%
#print(tk.tree())

# %%
gb = tk.groupby("InputSize")
# Out:
# 3  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2abf0e5ecdf0>, 262144: <thicket.thicket.Thicket object at 0x2abf0e5e0fa0>, 1048576: <thicket.thicket.Thicket object at 0x2abf0e4fdd60>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                                65536  \
#                                                                  nid
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64              1
#                                                    128             1
#                                                    256             1
#                                                    512             1
#                                                    1024            1
# {'name': 'comm', 'type': 'function'}               64              6
#                                                    128             6
#                                                    256             6
#                                                    512             6
#                                                    1024            6
# {'name': 'comm_large', 'type': 'function'}         64              7
# ...

# %%
ctk.metadata
# Out:
#                          65536    \
#             cali.caliper.version
# num_threads
# 64                    2.11.0-dev
# 128                   2.11.0-dev
# 256                   2.11.0-dev
# 512                   2.11.0-dev
# 1024                  2.11.0-dev
#
#                                                                 \
#                                                   spot.metrics
# num_threads
# 64           min#inclusive#sum#time.duration,max#inclusive#...
# 128          min#inclusive#sum#time.duration,max#inclusive#...
# 256          min#inclusive#sum#time.duration,max#inclusive#...
# 512          min#inclusive#sum#time.duration,max#inclusive#...
# 1024         min#inclusive#sum#time.duration,max#inclusive#...
#
#                                                          \
#             spot.timeseries.metrics spot.format.version
# num_threads
# 64                                                    2
# 128                                                   2
# ...

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (65536, "nid"), (1048576, "nid"), (262144, "nid"),(65536, "spot.channel"), (1048576, "spot.channel"), (262144, "spot.channel"), (65536, "Avg time/rank"), (1048576, "Avg time/rank"), (262144, "Avg time/rank")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([(65536, "Min time/rank"), (1048576, "Min time/rank"), (262144, "Min time/rank"),(65536, "Max time/rank"), (1048576, "Max time/rank"), (262144, "Max time/rank")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

# %%
ctk.dataframe
# Out:
#                                index      65536                    \
#                                      Total time Avg GPU time/rank
# name               num_threads
# main               64              0   0.360051          0.016714
#                    128             1   0.379349          0.021549
#                    256             2   0.360171          0.020134
#                    512             3   0.483371          0.026071
#                    1024            4   0.470092          0.064415
# comm               64              5   0.000294          0.000024
#                    128             6   0.000307          0.000025
#                    256             7   0.000338          0.000023
#                    512             8   0.000292          0.000024
#                    1024            9   0.000358          0.000025
# comm_large         64             10   0.000280          0.000024
#                    128            11   0.000295          0.000025
# ...

# %%
# Define common variables
function_names = ["main","comm","comp","data_init","correctness_check "]
threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
sizes = [65536, 262144, 1048576]
dataType = "Sorted"

# %%
def plot_mpl(df, df2, df3, title, xlabel, ylabel, columns):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.plot(
        df2,
        marker='o',
    )
    ax.plot(
        df3,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(columns)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %%
for name in function_names:
    plot_mpl(
            df=ctk.dataframe.loc[name][65536]["Total time"],
            df2=ctk.dataframe.loc[name][262144]["Total time"],
            df3=ctk.dataframe.loc[name][1048576]["Total time"],
            title="Total time-" + name + "-" + dataType + "-Strong_Scaling",
            xlabel="Number of Threads",
            ylabel="Time (seconds)",
            columns=sizes
        )
