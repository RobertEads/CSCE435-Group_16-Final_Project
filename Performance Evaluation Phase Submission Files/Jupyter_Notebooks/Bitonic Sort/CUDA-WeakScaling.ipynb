# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd
import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Weak Scaling for Random

# %%
tk = th.Thicket.from_caliperreader(glob("*-i0*.cali"))

# %%
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
tk.dataframe
# Out:
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              35315638         0.362953
#                                                   144236697        0.555353
#                                                   259993179        2.192658
#                                                   270436343        0.652572
#                                                   449932661        2.274526
#                                                   491594397        0.339570
#                                                   582169192        0.350288
#                                                   634432550        0.450722
#                                                   716173700        0.966267
#                                                   739759273        2.414272
#                                                   755306632        0.454518
#                                                   915797722        7.860891
#                                                   1062882091       0.948096
#                                                   1304038302       0.798670
#                                                   1362388260       7.701983
#                                                   1420917730       0.660462
#                                                   1527210753       0.324653
#                                                   1625124236       0.383517
#                                                   1743274927       2.188431
#                                                   1778166758       7.691412
#                                                   1854910549       0.801843
#                                                   1864944667       0.609353
#                                                   2047687356       0.597807
#                                                   2507080258       0.352637
#                                                   2550841583       0.348154
#                                                   2628230475       0.361038
#                                                   2666890565       0.798679
#                                                   3031851456       2.182511
#                                                   3120172595       0.456940
#                                                   3286526640       0.336050
#                                                   3332783031       0.337816
#                                                   3849530958       0.583328
#                                                   3854198508       8.449979
#                                                   4137322965       0.602607
#                                                   4270114402       7.684462
# {'name': 'comm', 'type': 'function'}              35315638         0.002023
#                                                   144236697        0.000698
#                                                   259993179        0.116910
#                                                   270436343        0.007522
#                                                   449932661        0.113833
#                                                   491594397        0.000703
#                                                   582169192        0.000301
#                                                   634432550        0.007316
#                                                   716173700        0.029179
#                                                   739759273        0.117206
#                                                   755306632        0.007403
#                                                   915797722        0.468803
#                                                   1062882091       0.029191
#                                                   1304038302       0.028364
#                                                   1362388260       0.453716
#                                                   1420917730       0.007438
#                                                   1527210753       0.000247
#                                                   1625124236       0.001987
#                                                   1743274927       0.113769
#                                                   1778166758       0.455091
#                                                   1854910549       0.028326
#                                                   1864944667       0.002059
#                                                   2047687356       0.002013
#                                                   2507080258       0.000687
#                                                   2550841583       0.000265
#                                                   2628230475       0.002023
#                                                   2666890565       0.029161
#                                                   3031851456       0.113124
#                                                   3120172595       0.007198
#                                                   3286526640       0.000649
#                                                   3332783031       0.000300
#                                                   3849530958       0.000266
#                                                   3854198508       0.452479
#                                                   4137322965       0.000710
#                                                   4270114402       0.452045
# {'name': 'comm_large', 'type': 'function'}        35315638         0.001980
#                                                   144236697        0.000659
#                                                   259993179        0.116862
#                                                   270436343        0.007478
#                                                   449932661        0.113770
#                                                   491594397        0.000660
#                                                   582169192        0.000256
#                                                   634432550        0.007278
#                                                   716173700        0.029136
#                                                   739759273        0.117141
#                                                   755306632        0.007361
#                                                   915797722        0.468747
#                                                   1062882091       0.029134
#                                                   1304038302       0.028324
#                                                   1362388260       0.453666
#                                                   1420917730       0.007399
#                                                   1527210753       0.000208
#                                                   1625124236       0.001948
#                                                   1743274927       0.113728
#                                                   1778166758       0.455039
#                                                   1854910549       0.028274
#                                                   1864944667       0.002020
#                                                   2047687356       0.001970
#                                                   2507080258       0.000646
#                                                   2550841583       0.000226
#                                                   2628230475       0.001981
#                                                   2666890565       0.029117
#                                                   3031851456       0.113083
#                                                   3120172595       0.007158
#                                                   3286526640       0.000613
#                                                   3332783031       0.000257
#                                                   3849530958       0.000229
#                                                   3854198508       0.452426
#                                                   4137322965       0.000666
#                                                   4270114402       0.451995
# {'name': 'cudaMemcpy', 'type': 'function'}        35315638         0.001938
#                                                   144236697        0.000620
#                                                   259993179        0.116807
#                                                   270436343        0.007434
#                                                   449932661        0.113726
#                                                   491594397        0.000618
#                                                   582169192        0.000224
#                                                   634432550        0.007240
#                                                   716173700        0.029079
#                                                   739759273        0.117094
#                                                   755306632        0.007318
#                                                   915797722        0.468694
#                                                   1062882091       0.029085
#                                                   1304038302       0.028284
#                                                   1362388260       0.453617
#                                                   1420917730       0.007354
#                                                   1527210753       0.000183
#                                                   1625124236       0.001912
#                                                   1743274927       0.113670
#                                                   1778166758       0.454990
#                                                   1854910549       0.028236
#                                                   1864944667       0.001977
#                                                   2047687356       0.001930
#                                                   2507080258       0.000608
#                                                   2550841583       0.000197
#                                                   2628230475       0.001939
#                                                   2666890565       0.029068
#                                                   3031851456       0.113028
#                                                   3120172595       0.007118
#                                                   3286526640       0.000581
#                                                   3332783031       0.000217
#                                                   3849530958       0.000200
#                                                   3854198508       0.452377
#                                                   4137322965       0.000626
#                                                   4270114402       0.451941
# {'name': 'comp', 'type': 'function'}              35315638         0.001252
#                                                   144236697        0.001106
#                                                   259993179        0.002080
#                                                   270436343        0.001445
#                                                   449932661        0.001560
#                                                   491594397        0.001037
#                                                   582169192        0.000891
#                                                   634432550        0.001210
#                                                   716173700        0.001646
#                                                   739759273        0.001862
#                                                   755306632        0.001479
#                                                   915797722        0.002218
#                                                   1062882091       0.001696
#                                                   1304038302       0.001356
#                                                   1362388260       0.001826
#                                                   1420917730       0.001430
#                                                   1527210753       0.000649
#                                                   1625124236       0.000992
#                                                   1743274927       0.001614
#                                                   1778166758       0.001925
#                                                   1854910549       0.001474
#                                                   1864944667       0.001204
#                                                   2047687356       0.001087
#                                                   2507080258       0.001043
#                                                   2550841583       0.000808
#                                                   2628230475       0.001220
#                                                   2666890565       0.001686
#                                                   3031851456       0.001655
#                                                   3120172595       0.001224
#                                                   3286526640       0.000818
#                                                   3332783031       0.000827
#                                                   3849530958       0.000805
#                                                   3854198508       0.001841
#                                                   4137322965       0.001059
#                                                   4270114402       0.001875
# {'name': 'comp_large', 'type': 'function'}        35315638         0.001234
#                                                   144236697        0.001089
#                                                   259993179        0.002062
#                                                   270436343        0.001425
#                                                   449932661        0.001542
#                                                   491594397        0.001018
#                                                   582169192        0.000873
#                                                   634432550        0.001195
#                                                   716173700        0.001626
#                                                   739759273        0.001843
#                                                   755306632        0.001461
#                                                   915797722        0.002198
#                                                   1062882091       0.001678
#                                                   1304038302       0.001339
#                                                   1362388260       0.001806
#                                                   1420917730       0.001412
#                                                   1527210753       0.000635
#                                                   1625124236       0.000977
#                                                   1743274927       0.001597
#                                                   1778166758       0.001905
#                                                   1854910549       0.001459
#                                                   1864944667       0.001186
#                                                   2047687356       0.001069
#                                                   2507080258       0.001025
#                                                   2550841583       0.000794
#                                                   2628230475       0.001201
#                                                   2666890565       0.001667
#                                                   3031851456       0.001638
#                                                   3120172595       0.001207
#                                                   3286526640       0.000803
#                                                   3332783031       0.000810
#                                                   3849530958       0.000791
#                                                   3854198508       0.001823
#                                                   4137322965       0.001040
#                                                   4270114402       0.001853
# {'name': 'correctness_check', 'type': 'function'} 35315638         0.003036
#                                                   144236697        0.000757
#                                                   259993179        0.191914
#                                                   270436343        0.011958
#                                                   449932661        0.191400
#                                                   491594397        0.000778
#                                                   582169192        0.000240
#                                                   634432550        0.011989
#                                                   716173700        0.047802
#                                                   739759273        0.191508
#                                                   755306632        0.011948
#                                                   915797722        0.764573
#                                                   1062882091       0.047868
#                                                   1304038302       0.048005
#                                                   1362388260       0.765600
#                                                   1420917730       0.013802
#                                                   1527210753       0.000214
#                                                   1625124236       0.003009
#                                                   1743274927       0.192235
#                                                   1778166758       0.764372
#                                                   1854910549       0.048004
#                                                   1864944667       0.003004
#                                                   2047687356       0.003014
#                                                   2507080258       0.000770
#                                                   2550841583       0.000204
#                                                   2628230475       0.003003
#                                                   2666890565       0.047914
#                                                   3031851456       0.191843
#                                                   3120172595       0.011983
#                                                   3286526640       0.000771
#                                                   3332783031       0.000207
#                                                   3849530958       0.000205
#                                                   3854198508       0.766443
#                                                   4137322965       0.000763
#                                                   4270114402       0.766570
# {'name': 'data_init', 'type': 'function'}         35315638         0.349543
#                                                   144236697        0.546447
#                                                   259993179        1.726426
#                                                   270436343        0.619254
#                                                   449932661        1.774018
#                                                   491594397        0.330170
#                                                   582169192        0.342369
#                                                   634432550        0.414762
#                                                   716173700        0.828150
#                                                   739759273        1.736147
#                                                   755306632        0.421941
#                                                   915797722        5.899514
#                                                   1062882091       0.772362
#                                                   1304038302       0.685579
#                                                   1362388260       5.897889
#                                                   1420917730       0.593096
#                                                   1527210753       0.317638
#                                                   1625124236       0.369461
#                                                   1743274927       1.725228
#                                                   1778166758       5.897368
#                                                   1854910549       0.684916
#                                                   1864944667       0.593816
#                                                   2047687356       0.578182
#                                                   2507080258       0.343640
#                                                   2550841583       0.340920
#                                                   2628230475       0.347782
#                                                   2666890565       0.683267
#                                                   3031851456       1.721065
#                                                   3120172595       0.425619
#                                                   3286526640       0.327606
#                                                   3332783031       0.330402
#                                                   3849530958       0.575898
#                                                   3854198508       5.894746
#                                                   4137322965       0.593546
#                                                   4270114402       5.876910
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              35315638                 main
#                                                   144236697                main
#                                                   259993179                main
#                                                   270436343                main
#                                                   449932661                main
#                                                   491594397                main
#                                                   582169192                main
#                                                   634432550                main
#                                                   716173700                main
#                                                   739759273                main
#                                                   755306632                main
#                                                   915797722                main
#                                                   1062882091               main
#                                                   1304038302               main
#                                                   1362388260               main
#                                                   1420917730               main
#                                                   1527210753               main
#                                                   1625124236               main
#                                                   1743274927               main
#                                                   1778166758               main
#                                                   1854910549               main
#                                                   1864944667               main
#                                                   2047687356               main
#                                                   2507080258               main
#                                                   2550841583               main
#                                                   2628230475               main
#                                                   2666890565               main
#                                                   3031851456               main
#                                                   3120172595               main
#                                                   3286526640               main
#                                                   3332783031               main
#                                                   3849530958               main
#                                                   3854198508               main
#                                                   4137322965               main
#                                                   4270114402               main
# {'name': 'comm', 'type': 'function'}              35315638                 comm
#                                                   144236697                comm
#                                                   259993179                comm
#                                                   270436343                comm
#                                                   449932661                comm
#                                                   491594397                comm
#                                                   582169192                comm
#                                                   634432550                comm
#                                                   716173700                comm
#                                                   739759273                comm
#                                                   755306632                comm
#                                                   915797722                comm
#                                                   1062882091               comm
#                                                   1304038302               comm
#                                                   1362388260               comm
#                                                   1420917730               comm
#                                                   1527210753               comm
#                                                   1625124236               comm
#                                                   1743274927               comm
#                                                   1778166758               comm
#                                                   1854910549               comm
#                                                   1864944667               comm
#                                                   2047687356               comm
#                                                   2507080258               comm
#                                                   2550841583               comm
#                                                   2628230475               comm
#                                                   2666890565               comm
#                                                   3031851456               comm
#                                                   3120172595               comm
#                                                   3286526640               comm
#                                                   3332783031               comm
#                                                   3849530958               comm
#                                                   3854198508               comm
#                                                   4137322965               comm
#                                                   4270114402               comm
# {'name': 'comm_large', 'type': 'function'}        35315638           comm_large
#                                                   144236697          comm_large
#                                                   259993179          comm_large
#                                                   270436343          comm_large
#                                                   449932661          comm_large
#                                                   491594397          comm_large
#                                                   582169192          comm_large
#                                                   634432550          comm_large
#                                                   716173700          comm_large
#                                                   739759273          comm_large
#                                                   755306632          comm_large
#                                                   915797722          comm_large
#                                                   1062882091         comm_large
#                                                   1304038302         comm_large
#                                                   1362388260         comm_large
#                                                   1420917730         comm_large
#                                                   1527210753         comm_large
#                                                   1625124236         comm_large
#                                                   1743274927         comm_large
#                                                   1778166758         comm_large
#                                                   1854910549         comm_large
#                                                   1864944667         comm_large
#                                                   2047687356         comm_large
#                                                   2507080258         comm_large
#                                                   2550841583         comm_large
#                                                   2628230475         comm_large
#                                                   2666890565         comm_large
#                                                   3031851456         comm_large
#                                                   3120172595         comm_large
#                                                   3286526640         comm_large
#                                                   3332783031         comm_large
#                                                   3849530958         comm_large
#                                                   3854198508         comm_large
#                                                   4137322965         comm_large
#                                                   4270114402         comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}        35315638           cudaMemcpy
#                                                   144236697          cudaMemcpy
#                                                   259993179          cudaMemcpy
#                                                   270436343          cudaMemcpy
#                                                   449932661          cudaMemcpy
#                                                   491594397          cudaMemcpy
#                                                   582169192          cudaMemcpy
#                                                   634432550          cudaMemcpy
#                                                   716173700          cudaMemcpy
#                                                   739759273          cudaMemcpy
#                                                   755306632          cudaMemcpy
#                                                   915797722          cudaMemcpy
#                                                   1062882091         cudaMemcpy
#                                                   1304038302         cudaMemcpy
#                                                   1362388260         cudaMemcpy
#                                                   1420917730         cudaMemcpy
#                                                   1527210753         cudaMemcpy
#                                                   1625124236         cudaMemcpy
#                                                   1743274927         cudaMemcpy
#                                                   1778166758         cudaMemcpy
#                                                   1854910549         cudaMemcpy
#                                                   1864944667         cudaMemcpy
#                                                   2047687356         cudaMemcpy
#                                                   2507080258         cudaMemcpy
#                                                   2550841583         cudaMemcpy
#                                                   2628230475         cudaMemcpy
#                                                   2666890565         cudaMemcpy
#                                                   3031851456         cudaMemcpy
#                                                   3120172595         cudaMemcpy
#                                                   3286526640         cudaMemcpy
#                                                   3332783031         cudaMemcpy
#                                                   3849530958         cudaMemcpy
#                                                   3854198508         cudaMemcpy
#                                                   4137322965         cudaMemcpy
#                                                   4270114402         cudaMemcpy
# {'name': 'comp', 'type': 'function'}              35315638                 comp
#                                                   144236697                comp
#                                                   259993179                comp
#                                                   270436343                comp
#                                                   449932661                comp
#                                                   491594397                comp
#                                                   582169192                comp
#                                                   634432550                comp
#                                                   716173700                comp
#                                                   739759273                comp
#                                                   755306632                comp
#                                                   915797722                comp
#                                                   1062882091               comp
#                                                   1304038302               comp
#                                                   1362388260               comp
#                                                   1420917730               comp
#                                                   1527210753               comp
#                                                   1625124236               comp
#                                                   1743274927               comp
#                                                   1778166758               comp
#                                                   1854910549               comp
#                                                   1864944667               comp
#                                                   2047687356               comp
#                                                   2507080258               comp
#                                                   2550841583               comp
#                                                   2628230475               comp
#                                                   2666890565               comp
#                                                   3031851456               comp
#                                                   3120172595               comp
#                                                   3286526640               comp
#                                                   3332783031               comp
#                                                   3849530958               comp
#                                                   3854198508               comp
#                                                   4137322965               comp
#                                                   4270114402               comp
# {'name': 'comp_large', 'type': 'function'}        35315638           comp_large
#                                                   144236697          comp_large
#                                                   259993179          comp_large
#                                                   270436343          comp_large
#                                                   449932661          comp_large
#                                                   491594397          comp_large
#                                                   582169192          comp_large
#                                                   634432550          comp_large
#                                                   716173700          comp_large
#                                                   739759273          comp_large
#                                                   755306632          comp_large
#                                                   915797722          comp_large
#                                                   1062882091         comp_large
#                                                   1304038302         comp_large
#                                                   1362388260         comp_large
#                                                   1420917730         comp_large
#                                                   1527210753         comp_large
#                                                   1625124236         comp_large
#                                                   1743274927         comp_large
#                                                   1778166758         comp_large
#                                                   1854910549         comp_large
#                                                   1864944667         comp_large
#                                                   2047687356         comp_large
#                                                   2507080258         comp_large
#                                                   2550841583         comp_large
#                                                   2628230475         comp_large
#                                                   2666890565         comp_large
#                                                   3031851456         comp_large
#                                                   3120172595         comp_large
#                                                   3286526640         comp_large
#                                                   3332783031         comp_large
#                                                   3849530958         comp_large
#                                                   3854198508         comp_large
#                                                   4137322965         comp_large
#                                                   4270114402         comp_large
# {'name': 'correctness_check', 'type': 'function'} 35315638    correctness_check
#                                                   144236697   correctness_check
#                                                   259993179   correctness_check
#                                                   270436343   correctness_check
#                                                   449932661   correctness_check
#                                                   491594397   correctness_check
#                                                   582169192   correctness_check
#                                                   634432550   correctness_check
#                                                   716173700   correctness_check
#                                                   739759273   correctness_check
#                                                   755306632   correctness_check
#                                                   915797722   correctness_check
#                                                   1062882091  correctness_check
#                                                   1304038302  correctness_check
#                                                   1362388260  correctness_check
#                                                   1420917730  correctness_check
#                                                   1527210753  correctness_check
#                                                   1625124236  correctness_check
#                                                   1743274927  correctness_check
#                                                   1778166758  correctness_check
#                                                   1854910549  correctness_check
#                                                   1864944667  correctness_check
#                                                   2047687356  correctness_check
#                                                   2507080258  correctness_check
#                                                   2550841583  correctness_check
#                                                   2628230475  correctness_check
#                                                   2666890565  correctness_check
#                                                   3031851456  correctness_check
#                                                   3120172595  correctness_check
#                                                   3286526640  correctness_check
#                                                   3332783031  correctness_check
#                                                   3849530958  correctness_check
#                                                   3854198508  correctness_check
#                                                   4137322965  correctness_check
#                                                   4270114402  correctness_check
# {'name': 'data_init', 'type': 'function'}         35315638            data_init
#                                                   144236697           data_init
#                                                   259993179           data_init
#                                                   270436343           data_init
#                                                   449932661           data_init
#                                                   491594397           data_init
#                                                   582169192           data_init
#                                                   634432550           data_init
#                                                   716173700           data_init
#                                                   739759273           data_init
#                                                   755306632           data_init
#                                                   915797722           data_init
#                                                   1062882091          data_init
#                                                   1304038302          data_init
#                                                   1362388260          data_init
#                                                   1420917730          data_init
#                                                   1527210753          data_init
#                                                   1625124236          data_init
#                                                   1743274927          data_init
#                                                   1778166758          data_init
#                                                   1854910549          data_init
#                                                   1864944667          data_init
#                                                   2047687356          data_init
#                                                   2507080258          data_init
#                                                   2550841583          data_init
#                                                   2628230475          data_init
#                                                   2666890565          data_init
#                                                   3031851456          data_init
#                                                   3120172595          data_init
#                                                   3286526640          data_init
#                                                   3332783031          data_init
#                                                   3849530958          data_init
#                                                   3854198508          data_init
#                                                   4137322965          data_init
#                                                   4270114402          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 35315638             2.11.0-dev
# 144236697            2.11.0-dev
# 259993179            2.11.0-dev
# 270436343            2.11.0-dev
# 449932661            2.11.0-dev
# 491594397            2.11.0-dev
# 582169192            2.11.0-dev
# 634432550            2.11.0-dev
# 716173700            2.11.0-dev
# 739759273            2.11.0-dev
# 755306632            2.11.0-dev
# 915797722            2.11.0-dev
# 1062882091           2.11.0-dev
# 1304038302           2.11.0-dev
# 1362388260           2.11.0-dev
# 1420917730           2.11.0-dev
# 1527210753           2.11.0-dev
# 1625124236           2.11.0-dev
# 1743274927           2.11.0-dev
# 1778166758           2.11.0-dev
# 1854910549           2.11.0-dev
# 1864944667           2.11.0-dev
# 2047687356           2.11.0-dev
# 2507080258           2.11.0-dev
# 2550841583           2.11.0-dev
# 2628230475           2.11.0-dev
# 2666890565           2.11.0-dev
# 3031851456           2.11.0-dev
# 3120172595           2.11.0-dev
# 3286526640           2.11.0-dev
# 3332783031           2.11.0-dev
# 3849530958           2.11.0-dev
# 3854198508           2.11.0-dev
# 4137322965           2.11.0-dev
# 4270114402           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 35315638    min#inclusive#sum#time.duration,max#inclusive#...
# 144236697   min#inclusive#sum#time.duration,max#inclusive#...
# 259993179   min#inclusive#sum#time.duration,max#inclusive#...
# 270436343   min#inclusive#sum#time.duration,max#inclusive#...
# 449932661   min#inclusive#sum#time.duration,max#inclusive#...
# 491594397   min#inclusive#sum#time.duration,max#inclusive#...
# 582169192   min#inclusive#sum#time.duration,max#inclusive#...
# 634432550   min#inclusive#sum#time.duration,max#inclusive#...
# 716173700   min#inclusive#sum#time.duration,max#inclusive#...
# 739759273   min#inclusive#sum#time.duration,max#inclusive#...
# 755306632   min#inclusive#sum#time.duration,max#inclusive#...
# 915797722   min#inclusive#sum#time.duration,max#inclusive#...
# 1062882091  min#inclusive#sum#time.duration,max#inclusive#...
# 1304038302  min#inclusive#sum#time.duration,max#inclusive#...
# 1362388260  min#inclusive#sum#time.duration,max#inclusive#...
# 1420917730  min#inclusive#sum#time.duration,max#inclusive#...
# 1527210753  min#inclusive#sum#time.duration,max#inclusive#...
# 1625124236  min#inclusive#sum#time.duration,max#inclusive#...
# 1743274927  min#inclusive#sum#time.duration,max#inclusive#...
# 1778166758  min#inclusive#sum#time.duration,max#inclusive#...
# 1854910549  min#inclusive#sum#time.duration,max#inclusive#...
# 1864944667  min#inclusive#sum#time.duration,max#inclusive#...
# 2047687356  min#inclusive#sum#time.duration,max#inclusive#...
# 2507080258  min#inclusive#sum#time.duration,max#inclusive#...
# 2550841583  min#inclusive#sum#time.duration,max#inclusive#...
# 2628230475  min#inclusive#sum#time.duration,max#inclusive#...
# 2666890565  min#inclusive#sum#time.duration,max#inclusive#...
# 3031851456  min#inclusive#sum#time.duration,max#inclusive#...
# 3120172595  min#inclusive#sum#time.duration,max#inclusive#...
# 3286526640  min#inclusive#sum#time.duration,max#inclusive#...
# 3332783031  min#inclusive#sum#time.duration,max#inclusive#...
# 3849530958  min#inclusive#sum#time.duration,max#inclusive#...
# 3854198508  min#inclusive#sum#time.duration,max#inclusive#...
# 4137322965  min#inclusive#sum#time.duration,max#inclusive#...
# 4270114402  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 35315638                                              2
# 144236697                                             2
# 259993179                                             2
# 270436343                                             2
# 449932661                                             2
# 491594397                                             2
# 582169192                                             2
# 634432550                                             2
# 716173700                                             2
# 739759273                                             2
# 755306632                                             2
# 915797722                                             2
# 1062882091                                            2
# 1304038302                                            2
# 1362388260                                            2
# 1420917730                                            2
# 1527210753                                            2
# 1625124236                                            2
# 1743274927                                            2
# 1778166758                                            2
# 1854910549                                            2
# 1864944667                                            2
# 2047687356                                            2
# 2507080258                                            2
# 2550841583                                            2
# 2628230475                                            2
# 2666890565                                            2
# 3031851456                                            2
# 3120172595                                            2
# 3286526640                                            2
# 3332783031                                            2
# 3849530958                                            2
# 3854198508                                            2
# 4137322965                                            2
# 4270114402                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 35315638    cuda.gputime,node.order  regionprofile         spot
# 144236697   cuda.gputime,node.order  regionprofile         spot
# 259993179   cuda.gputime,node.order  regionprofile         spot
# 270436343   cuda.gputime,node.order  regionprofile         spot
# 449932661   cuda.gputime,node.order  regionprofile         spot
# 491594397   cuda.gputime,node.order  regionprofile         spot
# 582169192   cuda.gputime,node.order  regionprofile         spot
# 634432550   cuda.gputime,node.order  regionprofile         spot
# 716173700   cuda.gputime,node.order  regionprofile         spot
# 739759273   cuda.gputime,node.order  regionprofile         spot
# 755306632   cuda.gputime,node.order  regionprofile         spot
# 915797722   cuda.gputime,node.order  regionprofile         spot
# 1062882091  cuda.gputime,node.order  regionprofile         spot
# 1304038302  cuda.gputime,node.order  regionprofile         spot
# 1362388260  cuda.gputime,node.order  regionprofile         spot
# 1420917730  cuda.gputime,node.order  regionprofile         spot
# 1527210753  cuda.gputime,node.order  regionprofile         spot
# 1625124236  cuda.gputime,node.order  regionprofile         spot
# 1743274927  cuda.gputime,node.order  regionprofile         spot
# 1778166758  cuda.gputime,node.order  regionprofile         spot
# 1854910549  cuda.gputime,node.order  regionprofile         spot
# 1864944667  cuda.gputime,node.order  regionprofile         spot
# 2047687356  cuda.gputime,node.order  regionprofile         spot
# 2507080258  cuda.gputime,node.order  regionprofile         spot
# 2550841583  cuda.gputime,node.order  regionprofile         spot
# 2628230475  cuda.gputime,node.order  regionprofile         spot
# 2666890565  cuda.gputime,node.order  regionprofile         spot
# 3031851456  cuda.gputime,node.order  regionprofile         spot
# 3120172595  cuda.gputime,node.order  regionprofile         spot
# 3286526640  cuda.gputime,node.order  regionprofile         spot
# 3332783031  cuda.gputime,node.order  regionprofile         spot
# 3849530958  cuda.gputime,node.order  regionprofile         spot
# 3854198508  cuda.gputime,node.order  regionprofile         spot
# 4137322965  cuda.gputime,node.order  regionprofile         spot
# 4270114402  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order               spot:output  \
# profile
# 35315638                true            true     t256-s1048576-i0.cali
# 144236697               true            true      t512-s262144-i0.cali
# 259993179               true            true    t512-s67108864-i0.cali
# 270436343               true            true     t256-s4194304-i0.cali
# 449932661               true            true    t128-s67108864-i0.cali
# 491594397               true            true       t64-s262144-i0.cali
# 582169192               true            true        t64-s65536-i0.cali
# 634432550               true            true     t128-s4194304-i0.cali
# 716173700               true            true    t128-s16777216-i0.cali
# 739759273               true            true     t64-s67108864-i0.cali
# 755306632               true            true     t512-s4194304-i0.cali
# 915797722               true            true   t128-s268435456-i0.cali
# 1062882091              true            true     t64-s16777216-i0.cali
# 1304038302              true            true    t512-s16777216-i0.cali
# 1362388260              true            true   t512-s268435456-i0.cali
# 1420917730              true            true      t64-s4194304-i0.cali
# 1527210753              true            true      t1024-s65536-i0.cali
# 1625124236              true            true     t128-s1048576-i0.cali
# 1743274927              true            true   t1024-s67108864-i0.cali
# 1778166758              true            true   t256-s268435456-i0.cali
# 1854910549              true            true    t256-s16777216-i0.cali
# 1864944667              true            true    t1024-s1048576-i0.cali
# 2047687356              true            true      t64-s1048576-i0.cali
# 2507080258              true            true      t256-s262144-i0.cali
# 2550841583              true            true       t256-s65536-i0.cali
# 2628230475              true            true     t512-s1048576-i0.cali
# 2666890565              true            true   t1024-s16777216-i0.cali
# 3031851456              true            true    t256-s67108864-i0.cali
# 3120172595              true            true    t1024-s4194304-i0.cali
# 3286526640              true            true      t128-s262144-i0.cali
# 3332783031              true            true       t128-s65536-i0.cali
# 3849530958              true            true       t512-s65536-i0.cali
# 3854198508              true            true    t64-s268435456-i0.cali
# 4137322965              true            true     t1024-s262144-i0.cali
# 4270114402              true            true  t1024-s268435456-i0.cali
#
#             launchdate                                          libraries  \
# profile
# 35315638    1701574816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 144236697   1701574792  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 259993179   1701574939  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 270436343   1701574853  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 449932661   1701574916  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 491594397   1701574758  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 582169192   1701574697  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 634432550   1701574853  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 716173700   1701574878  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 739759273   1701574916  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 755306632   1701574853  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 915797722   1701574960  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1062882091  1701574878  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1304038302  1701574897  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1362388260  1701574959  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1420917730  1701574836  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1527210753  1701574758  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1625124236  1701574816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1743274927  1701574939  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1778166758  1701574959  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1854910549  1701574897  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1864944667  1701574836  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2047687356  1701574796  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2507080258  1701574792  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2550841583  1701574737  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2628230475  1701574836  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2666890565  1701574897  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3031851456  1701574918  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3120172595  1701574878  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3286526640  1701574775  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3332783031  1701574700  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3849530958  1701574737  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3854198508  1701574939  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4137322965  1701574792  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4270114402  1701574977  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                     cmdline cluster     Algorithm  \
# profile
# 35315638       [./bitonic, 0, 256, 1048576]       g  Bitonic Sort
# 144236697       [./bitonic, 0, 512, 262144]       g  Bitonic Sort
# 259993179     [./bitonic, 0, 512, 67108864]       g  Bitonic Sort
# 270436343      [./bitonic, 0, 256, 4194304]       g  Bitonic Sort
# 449932661     [./bitonic, 0, 128, 67108864]       g  Bitonic Sort
# 491594397        [./bitonic, 0, 64, 262144]       g  Bitonic Sort
# 582169192         [./bitonic, 0, 64, 65536]       g  Bitonic Sort
# 634432550      [./bitonic, 0, 128, 4194304]       g  Bitonic Sort
# 716173700     [./bitonic, 0, 128, 16777216]       g  Bitonic Sort
# 739759273      [./bitonic, 0, 64, 67108864]       g  Bitonic Sort
# 755306632      [./bitonic, 0, 512, 4194304]       g  Bitonic Sort
# 915797722    [./bitonic, 0, 128, 268435456]       g  Bitonic Sort
# 1062882091     [./bitonic, 0, 64, 16777216]       g  Bitonic Sort
# 1304038302    [./bitonic, 0, 512, 16777216]       g  Bitonic Sort
# 1362388260   [./bitonic, 0, 512, 268435456]       g  Bitonic Sort
# 1420917730      [./bitonic, 0, 64, 4194304]       g  Bitonic Sort
# 1527210753      [./bitonic, 0, 1024, 65536]       g  Bitonic Sort
# 1625124236     [./bitonic, 0, 128, 1048576]       g  Bitonic Sort
# 1743274927   [./bitonic, 0, 1024, 67108864]       g  Bitonic Sort
# 1778166758   [./bitonic, 0, 256, 268435456]       g  Bitonic Sort
# 1854910549    [./bitonic, 0, 256, 16777216]       g  Bitonic Sort
# 1864944667    [./bitonic, 0, 1024, 1048576]       g  Bitonic Sort
# 2047687356      [./bitonic, 0, 64, 1048576]       g  Bitonic Sort
# 2507080258      [./bitonic, 0, 256, 262144]       g  Bitonic Sort
# 2550841583       [./bitonic, 0, 256, 65536]       g  Bitonic Sort
# 2628230475     [./bitonic, 0, 512, 1048576]       g  Bitonic Sort
# 2666890565   [./bitonic, 0, 1024, 16777216]       g  Bitonic Sort
# 3031851456    [./bitonic, 0, 256, 67108864]       g  Bitonic Sort
# 3120172595    [./bitonic, 0, 1024, 4194304]       g  Bitonic Sort
# 3286526640      [./bitonic, 0, 128, 262144]       g  Bitonic Sort
# 3332783031       [./bitonic, 0, 128, 65536]       g  Bitonic Sort
# 3849530958       [./bitonic, 0, 512, 65536]       g  Bitonic Sort
# 3854198508    [./bitonic, 0, 64, 268435456]       g  Bitonic Sort
# 4137322965     [./bitonic, 0, 1024, 262144]       g  Bitonic Sort
# 4270114402  [./bitonic, 0, 1024, 268435456]       g  Bitonic Sort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize   InputType  \
# profile
# 35315638               CUDA      int               4    1048576  Randomized
# 144236697              CUDA      int               4     262144  Randomized
# 259993179              CUDA      int               4   67108864  Randomized
# 270436343              CUDA      int               4    4194304  Randomized
# 449932661              CUDA      int               4   67108864  Randomized
# 491594397              CUDA      int               4     262144  Randomized
# 582169192              CUDA      int               4      65536  Randomized
# 634432550              CUDA      int               4    4194304  Randomized
# 716173700              CUDA      int               4   16777216  Randomized
# 739759273              CUDA      int               4   67108864  Randomized
# 755306632              CUDA      int               4    4194304  Randomized
# 915797722              CUDA      int               4  268435456  Randomized
# 1062882091             CUDA      int               4   16777216  Randomized
# 1304038302             CUDA      int               4   16777216  Randomized
# 1362388260             CUDA      int               4  268435456  Randomized
# 1420917730             CUDA      int               4    4194304  Randomized
# 1527210753             CUDA      int               4      65536  Randomized
# 1625124236             CUDA      int               4    1048576  Randomized
# 1743274927             CUDA      int               4   67108864  Randomized
# 1778166758             CUDA      int               4  268435456  Randomized
# 1854910549             CUDA      int               4   16777216  Randomized
# 1864944667             CUDA      int               4    1048576  Randomized
# 2047687356             CUDA      int               4    1048576  Randomized
# 2507080258             CUDA      int               4     262144  Randomized
# 2550841583             CUDA      int               4      65536  Randomized
# 2628230475             CUDA      int               4    1048576  Randomized
# 2666890565             CUDA      int               4   16777216  Randomized
# 3031851456             CUDA      int               4   67108864  Randomized
# 3120172595             CUDA      int               4    4194304  Randomized
# 3286526640             CUDA      int               4     262144  Randomized
# 3332783031             CUDA      int               4      65536  Randomized
# 3849530958             CUDA      int               4      65536  Randomized
# 3854198508             CUDA      int               4  268435456  Randomized
# 4137322965             CUDA      int               4     262144  Randomized
# 4270114402             CUDA      int               4  268435456  Randomized
#
#             num_threads  num_blocks  group_num      implementation_source
# profile
# 35315638            256        4096         16  Handwritten, AI, & Online
# 144236697           512         512         16  Handwritten, AI, & Online
# 259993179           512      131072         16  Handwritten, AI, & Online
# 270436343           256       16384         16  Handwritten, AI, & Online
# 449932661           128      524288         16  Handwritten, AI, & Online
# 491594397            64        4096         16  Handwritten, AI, & Online
# 582169192            64        1024         16  Handwritten, AI, & Online
# 634432550           128       32768         16  Handwritten, AI, & Online
# 716173700           128      131072         16  Handwritten, AI, & Online
# 739759273            64     1048576         16  Handwritten, AI, & Online
# 755306632           512        8192         16  Handwritten, AI, & Online
# 915797722           128     2097152         16  Handwritten, AI, & Online
# 1062882091           64      262144         16  Handwritten, AI, & Online
# 1304038302          512       32768         16  Handwritten, AI, & Online
# 1362388260          512      524288         16  Handwritten, AI, & Online
# 1420917730           64       65536         16  Handwritten, AI, & Online
# 1527210753         1024          64         16  Handwritten, AI, & Online
# 1625124236          128        8192         16  Handwritten, AI, & Online
# 1743274927         1024       65536         16  Handwritten, AI, & Online
# 1778166758          256     1048576         16  Handwritten, AI, & Online
# 1854910549          256       65536         16  Handwritten, AI, & Online
# 1864944667         1024        1024         16  Handwritten, AI, & Online
# 2047687356           64       16384         16  Handwritten, AI, & Online
# 2507080258          256        1024         16  Handwritten, AI, & Online
# 2550841583          256         256         16  Handwritten, AI, & Online
# 2628230475          512        2048         16  Handwritten, AI, & Online
# 2666890565         1024       16384         16  Handwritten, AI, & Online
# 3031851456          256      262144         16  Handwritten, AI, & Online
# 3120172595         1024        4096         16  Handwritten, AI, & Online
# 3286526640          128        2048         16  Handwritten, AI, & Online
# 3332783031          128         512         16  Handwritten, AI, & Online
# 3849530958          512         128         16  Handwritten, AI, & Online
# 3854198508           64     4194304         16  Handwritten, AI, & Online
# 4137322965         1024         256         16  Handwritten, AI, & Online
# 4270114402         1024      262144         16  Handwritten, AI, & Online

# %%
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# │     └─ 1.000 cudaMemcpy
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
gb = tk.groupby("InputSize")
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2af097356760>, 262144: <thicket.thicket.Thicket object at 0x2af0972d83d0>, 1048576: <thicket.thicket.Thicket object at 0x2af097384bb0>, 4194304: <thicket.thicket.Thicket object at 0x2af09732c910>, 16777216: <thicket.thicket.Thicket object at 0x2af0972e15e0>, 67108864: <thicket.thicket.Thicket object at 0x2af0973aeb50>, 268435456: <thicket.thicket.Thicket object at 0x2af09743e3a0>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                                       65536  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.350288
#                                                   128              0.337816
#                                                   256              0.348154
#                                                   512              0.583328
#                                                   1024             0.324653
# {'name': 'comm', 'type': 'function'}              64               0.000301
#                                                   128              0.000300
#                                                   256              0.000265
#                                                   512              0.000266
#                                                   1024             0.000247
# {'name': 'comm_large', 'type': 'function'}        64               0.000256
#                                                   128              0.000257
#                                                   256              0.000226
#                                                   512              0.000229
#                                                   1024             0.000208
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000224
#                                                   128              0.000217
#                                                   256              0.000197
#                                                   512              0.000200
#                                                   1024             0.000183
# {'name': 'comp', 'type': 'function'}              64               0.000891
#                                                   128              0.000827
#                                                   256              0.000808
#                                                   512              0.000805
#                                                   1024             0.000649
# {'name': 'comp_large', 'type': 'function'}        64               0.000873
#                                                   128              0.000810
#                                                   256              0.000794
#                                                   512              0.000791
#                                                   1024             0.000635
# {'name': 'correctness_check', 'type': 'function'} 64               0.000240
#                                                   128              0.000207
#                                                   256              0.000204
#                                                   512              0.000205
#                                                   1024             0.000214
# {'name': 'data_init', 'type': 'function'}         64               0.342369
#                                                   128              0.330402
#                                                   256              0.340920
#                                                   512              0.575898
#                                                   1024             0.317638
#
#                                                                      262144  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.339570
#                                                   128              0.336050
#                                                   256              0.352637
#                                                   512              0.555353
#                                                   1024             0.602607
# {'name': 'comm', 'type': 'function'}              64               0.000703
#                                                   128              0.000649
#                                                   256              0.000687
#                                                   512              0.000698
#                                                   1024             0.000710
# {'name': 'comm_large', 'type': 'function'}        64               0.000660
#                                                   128              0.000613
#                                                   256              0.000646
#                                                   512              0.000659
#                                                   1024             0.000666
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000618
#                                                   128              0.000581
#                                                   256              0.000608
#                                                   512              0.000620
#                                                   1024             0.000626
# {'name': 'comp', 'type': 'function'}              64               0.001037
#                                                   128              0.000818
#                                                   256              0.001043
#                                                   512              0.001106
#                                                   1024             0.001059
# {'name': 'comp_large', 'type': 'function'}        64               0.001018
#                                                   128              0.000803
#                                                   256              0.001025
#                                                   512              0.001089
#                                                   1024             0.001040
# {'name': 'correctness_check', 'type': 'function'} 64               0.000778
#                                                   128              0.000771
#                                                   256              0.000770
#                                                   512              0.000757
#                                                   1024             0.000763
# {'name': 'data_init', 'type': 'function'}         64               0.330170
#                                                   128              0.327606
#                                                   256              0.343640
#                                                   512              0.546447
#                                                   1024             0.593546
#
#                                                                     1048576  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.597807
#                                                   128              0.383517
#                                                   256              0.362953
#                                                   512              0.361038
#                                                   1024             0.609353
# {'name': 'comm', 'type': 'function'}              64               0.002013
#                                                   128              0.001987
#                                                   256              0.002023
#                                                   512              0.002023
#                                                   1024             0.002059
# {'name': 'comm_large', 'type': 'function'}        64               0.001970
#                                                   128              0.001948
#                                                   256              0.001980
#                                                   512              0.001981
#                                                   1024             0.002020
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.001930
#                                                   128              0.001912
#                                                   256              0.001938
#                                                   512              0.001939
#                                                   1024             0.001977
# {'name': 'comp', 'type': 'function'}              64               0.001087
#                                                   128              0.000992
#                                                   256              0.001252
#                                                   512              0.001220
#                                                   1024             0.001204
# {'name': 'comp_large', 'type': 'function'}        64               0.001069
#                                                   128              0.000977
#                                                   256              0.001234
#                                                   512              0.001201
#                                                   1024             0.001186
# {'name': 'correctness_check', 'type': 'function'} 64               0.003014
#                                                   128              0.003009
#                                                   256              0.003036
#                                                   512              0.003003
#                                                   1024             0.003004
# {'name': 'data_init', 'type': 'function'}         64               0.578182
#                                                   128              0.369461
#                                                   256              0.349543
#                                                   512              0.347782
#                                                   1024             0.593816
#
#                                                                     4194304  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.660462
#                                                   128              0.450722
#                                                   256              0.652572
#                                                   512              0.454518
#                                                   1024             0.456940
# {'name': 'comm', 'type': 'function'}              64               0.007438
#                                                   128              0.007316
#                                                   256              0.007522
#                                                   512              0.007403
#                                                   1024             0.007198
# {'name': 'comm_large', 'type': 'function'}        64               0.007399
#                                                   128              0.007278
#                                                   256              0.007478
#                                                   512              0.007361
#                                                   1024             0.007158
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.007354
#                                                   128              0.007240
#                                                   256              0.007434
#                                                   512              0.007318
#                                                   1024             0.007118
# {'name': 'comp', 'type': 'function'}              64               0.001430
#                                                   128              0.001210
#                                                   256              0.001445
#                                                   512              0.001479
#                                                   1024             0.001224
# {'name': 'comp_large', 'type': 'function'}        64               0.001412
#                                                   128              0.001195
#                                                   256              0.001425
#                                                   512              0.001461
#                                                   1024             0.001207
# {'name': 'correctness_check', 'type': 'function'} 64               0.013802
#                                                   128              0.011989
#                                                   256              0.011958
#                                                   512              0.011948
#                                                   1024             0.011983
# {'name': 'data_init', 'type': 'function'}         64               0.593096
#                                                   128              0.414762
#                                                   256              0.619254
#                                                   512              0.421941
#                                                   1024             0.425619
#
#                                                                    16777216  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.948096
#                                                   128              0.966267
#                                                   256              0.801843
#                                                   512              0.798670
#                                                   1024             0.798679
# {'name': 'comm', 'type': 'function'}              64               0.029191
#                                                   128              0.029179
#                                                   256              0.028326
#                                                   512              0.028364
#                                                   1024             0.029161
# {'name': 'comm_large', 'type': 'function'}        64               0.029134
#                                                   128              0.029136
#                                                   256              0.028274
#                                                   512              0.028324
#                                                   1024             0.029117
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.029085
#                                                   128              0.029079
#                                                   256              0.028236
#                                                   512              0.028284
#                                                   1024             0.029068
# {'name': 'comp', 'type': 'function'}              64               0.001696
#                                                   128              0.001646
#                                                   256              0.001474
#                                                   512              0.001356
#                                                   1024             0.001686
# {'name': 'comp_large', 'type': 'function'}        64               0.001678
#                                                   128              0.001626
#                                                   256              0.001459
#                                                   512              0.001339
#                                                   1024             0.001667
# {'name': 'correctness_check', 'type': 'function'} 64               0.047868
#                                                   128              0.047802
#                                                   256              0.048004
#                                                   512              0.048005
#                                                   1024             0.047914
# {'name': 'data_init', 'type': 'function'}         64               0.772362
#                                                   128              0.828150
#                                                   256              0.684916
#                                                   512              0.685579
#                                                   1024             0.683267
#
#                                                                    67108864  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               2.414272
#                                                   128              2.274526
#                                                   256              2.182511
#                                                   512              2.192658
#                                                   1024             2.188431
# {'name': 'comm', 'type': 'function'}              64               0.117206
#                                                   128              0.113833
#                                                   256              0.113124
#                                                   512              0.116910
#                                                   1024             0.113769
# {'name': 'comm_large', 'type': 'function'}        64               0.117141
#                                                   128              0.113770
#                                                   256              0.113083
#                                                   512              0.116862
#                                                   1024             0.113728
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.117094
#                                                   128              0.113726
#                                                   256              0.113028
#                                                   512              0.116807
#                                                   1024             0.113670
# {'name': 'comp', 'type': 'function'}              64               0.001862
#                                                   128              0.001560
#                                                   256              0.001655
#                                                   512              0.002080
#                                                   1024             0.001614
# {'name': 'comp_large', 'type': 'function'}        64               0.001843
#                                                   128              0.001542
#                                                   256              0.001638
#                                                   512              0.002062
#                                                   1024             0.001597
# {'name': 'correctness_check', 'type': 'function'} 64               0.191508
#                                                   128              0.191400
#                                                   256              0.191843
#                                                   512              0.191914
#                                                   1024             0.192235
# {'name': 'data_init', 'type': 'function'}         64               1.736147
#                                                   128              1.774018
#                                                   256              1.721065
#                                                   512              1.726426
#                                                   1024             1.725228
#
#                                                                   268435456  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               8.449979
#                                                   128              7.860891
#                                                   256              7.691412
#                                                   512              7.701983
#                                                   1024             7.684462
# {'name': 'comm', 'type': 'function'}              64               0.452479
#                                                   128              0.468803
#                                                   256              0.455091
#                                                   512              0.453716
#                                                   1024             0.452045
# {'name': 'comm_large', 'type': 'function'}        64               0.452426
#                                                   128              0.468747
#                                                   256              0.455039
#                                                   512              0.453666
#                                                   1024             0.451995
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.452377
#                                                   128              0.468694
#                                                   256              0.454990
#                                                   512              0.453617
#                                                   1024             0.451941
# {'name': 'comp', 'type': 'function'}              64               0.001841
#                                                   128              0.002218
#                                                   256              0.001925
#                                                   512              0.001826
#                                                   1024             0.001875
# {'name': 'comp_large', 'type': 'function'}        64               0.001823
#                                                   128              0.002198
#                                                   256              0.001905
#                                                   512              0.001806
#                                                   1024             0.001853
# {'name': 'correctness_check', 'type': 'function'} 64               0.766443
#                                                   128              0.764573
#                                                   256              0.764372
#                                                   512              0.765600
#                                                   1024             0.766570
# {'name': 'data_init', 'type': 'function'}         64               5.894746
#                                                   128              5.899514
#                                                   256              5.897368
#                                                   512              5.897889
#                                                   1024             5.876910
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                        main
#                                                   128                       main
#                                                   256                       main
#                                                   512                       main
#                                                   1024                      main
# {'name': 'comm', 'type': 'function'}              64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
# {'name': 'comm_large', 'type': 'function'}        64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}        64                  cudaMemcpy
#                                                   128                 cudaMemcpy
#                                                   256                 cudaMemcpy
#                                                   512                 cudaMemcpy
#                                                   1024                cudaMemcpy
# {'name': 'comp', 'type': 'function'}              64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
# {'name': 'comp_large', 'type': 'function'}        64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
# {'name': 'correctness_check', 'type': 'function'} 64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %%
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
# Out:
# <ipython-input-9-9853eafaa581>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)

# %%
function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

# %%
for name in function_names:
     #for size in input_sizes:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"CUDA Weak Scaling - Merge Sort, {name}, Random Array", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, main, Random Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comp_large, Random Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comm, Random Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, comm, Random Array'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %% [markdown]
# # Weak Scaling for Sorted

# %%
tk = th.Thicket.from_caliperreader(glob("*-i1*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
gb = tk.groupby("InputSize")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

for name in function_names:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"CUDA Weak Scaling - Merge Sort, {name}, Sorted Array", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, main, Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comp_large, Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comm, Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2af097fdfa90>, 262144: <thicket.thicket.Thicket object at 0x2af09e1260a0>, 1048576: <thicket.thicket.Thicket object at 0x2af09e0299d0>, 4194304: <thicket.thicket.Thicket object at 0x2af09e20cac0>, 16777216: <thicket.thicket.Thicket object at 0x2af09e3a9a30>, 67108864: <thicket.thicket.Thicket object at 0x2af09e3744f0>, 268435456: <thicket.thicket.Thicket object at 0x2af097f47250>}
# <ipython-input-13-ff5036333978>:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, comm, Sorted Array'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %% [markdown]
# # Weak Scaling for Reverse Sorted

# %%
tk = th.Thicket.from_caliperreader(glob("*-i2*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
gb = tk.groupby("InputSize")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

for name in function_names:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"Cuda Weak Scaling - Merge Sort, {name}, Reverse Sorted", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, main, Reverse Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comp_large, Reverse Sorteed Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comm, Reverse Sorted Array", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2af09e0c78e0>, 262144: <thicket.thicket.Thicket object at 0x2af09e1a10a0>, 1048576: <thicket.thicket.Thicket object at 0x2af09e3237c0>, 4194304: <thicket.thicket.Thicket object at 0x2af09e01ebe0>, 16777216: <thicket.thicket.Thicket object at 0x2af09e0ba940>, 67108864: <thicket.thicket.Thicket object at 0x2af09e38ce50>, 268435456: <thicket.thicket.Thicket object at 0x2af0973234f0>}
# <ipython-input-14-ef183992d294>:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, comm, Reverse Sorted Array'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %% [markdown]
# # Weak Scaling for 1% Perturbed

# %%
tk = th.Thicket.from_caliperreader(glob("*-i2*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
gb = tk.groupby("InputSize")
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    lines = ax.plot(
        df,
        marker='o',
    )
    legend_labels = [label[0] for label in df.columns]
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(lines, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(df.index)  
    plt.show()
    return fig, ax

for name in function_names:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"Cuda Weak Scaling- Merge Sort, {name}, 1% Perturbed", 
            xlabel="Number of Threads",
            ylabel="Time (s)",
        )
        
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, Main, 1% Perturbed", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comp_large, 1% Perturbed", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, comm, 1% Perturbed", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2af09e3fcb80>, 262144: <thicket.thicket.Thicket object at 0x2af09e46c730>, 1048576: <thicket.thicket.Thicket object at 0x2af09e07b4f0>, 4194304: <thicket.thicket.Thicket object at 0x2af09e26f970>, 16777216: <thicket.thicket.Thicket object at 0x2af09e431ca0>, 67108864: <thicket.thicket.Thicket object at 0x2af09e3e0c70>, 268435456: <thicket.thicket.Thicket object at 0x2af097fc57c0>}
# <ipython-input-15-9b047bf86966>:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, comm, 1% Perturbed'}, xlabel='Number of Threads', ylabel='Speed Up'>)

# %%
for name in function_names:
    print(ctk.dataframe.loc[name])
# Out:
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000680      0.000979      0.001018      0.001475
# 128              0.000692      0.001044      0.001047      0.001134
# 256              0.000632      0.000777      0.000945      0.001485
# 512              0.000796      0.001010      0.000958      0.001414
# 1024             0.000810      0.001031      0.001208      0.001127
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.001747      0.001574      0.002339
# 128              0.001722      0.001985      0.001779
# 256              0.001363      0.001991      0.002211
# 512              0.001410      0.001618      0.001974
# 1024             0.001650      0.001940      0.002335
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000694      0.000997      0.001033      0.001492
# 128              0.000705      0.001061      0.001064      0.001151
# 256              0.000645      0.000797      0.000961      0.001503
# 512              0.000811      0.001027      0.000974      0.001432
# 1024             0.000825      0.001051      0.001225      0.001143
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.001765      0.001591      0.002358
# 128              0.001739      0.002005      0.001799
# 256              0.001381      0.002010      0.002232
# 512              0.001427      0.001639      0.001992
# 1024             0.001670      0.001958      0.002355
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000263      0.000717      0.001996      0.007321
# 128              0.000266      0.000703      0.001959      0.007071
# 256              0.000253      0.000676      0.001942      0.007354
# 512              0.000268      0.000686      0.001926      0.007423
# 1024             0.000276      0.000700      0.002008      0.007179
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.029006      0.112200      0.466347
# 128              0.029043      0.116756      0.451883
# 256              0.028342      0.115990      0.469325
# 512              0.028679      0.112444      0.455740
# 1024             0.029067      0.116753      0.469555
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.324933      0.343376      0.337772      0.343029
# 128              0.331827      0.613992      0.622787      0.341765
# 256              0.324514      0.321167      0.549158      0.353812
# 512              0.338861      0.334187      0.321131      0.352669
# 1024             0.587347      0.342845      0.338899      0.332831
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.397882      0.589261      1.370465
# 128              0.392750      0.599273      1.371902
# 256              0.396109      0.605394      1.368302
# 512              0.593856      0.589928      1.362157
# 1024             0.398361      0.600972      1.651413
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000224      0.000675      0.001957      0.007275
# 128              0.000226      0.000663      0.001918      0.007030
# 256              0.000208      0.000637      0.001902      0.007309
# 512              0.000229      0.000637      0.001886      0.007379
# 1024             0.000238      0.000658      0.001963      0.007140
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.028962      0.112156      0.466270
# 128              0.028999      0.116711      0.451830
# 256              0.028302      0.115945      0.469270
# 512              0.028639      0.112402      0.455691
# 1024             0.029022      0.116708      0.469502
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000198      0.000634      0.001921      0.007232
# 128              0.000200      0.000624      0.001879      0.006991
# 256              0.000183      0.000604      0.001867      0.007265
# 512              0.000200      0.000598      0.001850      0.007334
# 1024             0.000209      0.000619      0.001921      0.007102
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.028916      0.112106      0.466216
# 128              0.028951      0.116658      0.451777
# 256              0.028262      0.115893      0.469218
# 512              0.028599      0.112353      0.455642
# 1024             0.028974      0.116660      0.469452
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.332313      0.353080      0.353176      0.389432
# 128              0.338978      0.623113      0.637604      0.379322
# 256              0.331527      0.329585      0.570002      0.385372
# 512              0.346357      0.343071      0.334128      0.384759
# 1024             0.594748      0.351682      0.352131      0.363995
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.560986      1.258808      3.946656
# 128              0.522460      1.099589      3.327112
# 256              0.508995      1.043002      3.149090
# 512              0.709210      1.024154      3.124786
# 1024             0.515990      1.080451      3.460866
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.000207      0.000761      0.003030      0.011962
# 128              0.000209      0.000772      0.003003      0.012000
# 256              0.000204      0.000758      0.003010      0.011975
# 512              0.000205      0.000770      0.003004      0.011974
# 1024             0.000203      0.000770      0.003010      0.012004
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.047812      0.191439      0.764704
# 128              0.047842      0.190983      0.765947
# 256              0.047854      0.191296      0.767953
# 512              0.048011      0.191457      0.767354
# 1024             0.047813      0.191473      0.752443

# %%
speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
speedup
# Out:
#                     65536        262144       1048576       4194304  \
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               1.000000      1.000000      1.000000      1.000000
# 128              0.980338      0.566639      0.553911      1.026653
# 256              1.002371      1.071287      0.619605      1.010535
# 512              0.959452      1.029175      1.057008      1.012145
# 1024             0.558746      1.003975      1.002968      1.069883
#
#                  16777216      67108864     268435456
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               1.000000      1.000000      1.000000
# 128              1.073740      1.144799      1.186211
# 256              1.102144      1.206909      1.253269
# 512              0.791001      1.229120      1.263016
# 1024             1.087203      1.165076      1.140367

# %%
plot_mpl(
    df=speedup,
    title=f"CUDA - Merge Sort, Main", 
    xlabel="Number of Threads",
    ylabel="Speed Up",
)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA - Merge Sort, Main'}, xlabel='Number of Threads', ylabel='Speed Up'>)
