# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd
import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

tk = th.Thicket.from_caliperreader(glob("*s65536*.cali"))

tk.dataframe



tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 2304124389           2.11.0-dev               2
# 3483346744           2.11.0-dev               4
# 4060682330           2.11.0-dev               8
#
#                                                  spot.metrics  \
# profile
# 2304124389  min#inclusive#sum#time.duration,max#inclusive#...
# 3483346744  min#inclusive#sum#time.duration,max#inclusive#...
# 4060682330  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 2304124389                                            2
# 3483346744                                            2
# 4060682330                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 2304124389  time.variance,node.order  regionprofile         spot
# 3483346744  time.variance,node.order  regionprofile         spot
# 4060682330  time.variance,node.order  regionprofile         spot
#
#            spot:node.order        spot:output spot:time.variance  launchdate  \
# profile
# 2304124389            true  p2-s65536-t1.cali               true  1700110740
# 3483346744            true  p4-s65536-t1.cali               true  1700110740
# 4060682330            true  p8-s65536-t1.cali               true  1700110740
#
#                                                     libraries  \
# profile
# 2304124389  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3483346744  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4060682330  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                     cmdline cluster       Algorithm  \
# profile
# 2304124389  [./Selection_Sort, 1, 2, 65536]       c  Selection Sort
# 3483346744  [./Selection_Sort, 1, 4, 65536]       c  Selection Sort
# 4060682330  [./Selection_Sort, 1, 8, 65536]       c  Selection Sort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 2304124389              MPI      int               4      65536    Sorted
# 3483346744              MPI      int               4      65536    Sorted
# 4060682330              MPI      int               4      65536    Sorted
#
#             num_procs  group_num      implementation_source
# profile
# 2304124389          2         16  Handwritten, AI, & Online
# 3483346744          4         16  Handwritten, AI, & Online
# 4060682330          8         16  Handwritten, AI, & Online

# %%
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
gb = tk.groupby("InputType")
# Out:
# 1  thickets created...
# {'Sorted': <thicket.thicket.Thicket object at 0x2ad063e82940>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis='columns',
    metadata_key='num_procs'
)

# %%
ctk.dataframe
# Out:
#                                                             Sorted  \
#                                                                nid
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              1
#                                                   4              1
#                                                   8              1
# {'name': 'comm', 'type': 'function'}              2              3
#                                                   4              3
#                                                   8              3
# {'name': 'comm_large', 'type': 'function'}        2              4
#                                                   4              4
#                                                   8              4
# {'name': 'comp', 'type': 'function'}              2              5
#                                                   4              5
#                                                   8              5
# {'name': 'comp_large', 'type': 'function'}        2              6
#                                                   4              6
#                                                   8              6
# {'name': 'correctness_check', 'type': 'function'} 2              7
#                                                   4              7
#                                                   8              7
# {'name': 'data_init', 'type': 'function'}         2              2
#                                                   4              2
#                                                   8              2
#
#                                                                             \
#                                                               spot.channel
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
# {'name': 'comm', 'type': 'function'}              2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
# {'name': 'comm_large', 'type': 'function'}        2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
# {'name': 'comp', 'type': 'function'}              2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
# {'name': 'comp_large', 'type': 'function'}        2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
# {'name': 'correctness_check', 'type': 'function'} 2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
# {'name': 'data_init', 'type': 'function'}         2          regionprofile
#                                                   4          regionprofile
#                                                   8          regionprofile
#
#                                                                            \
#                                                             Min time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              0.008319
#                                                   4              0.031720
#                                                   8              0.029942
# {'name': 'comm', 'type': 'function'}              2              0.000182
#                                                   4              0.000132
#                                                   8              0.000107
# {'name': 'comm_large', 'type': 'function'}        2              0.000169
#                                                   4              0.000118
#                                                   8              0.000093
# {'name': 'comp', 'type': 'function'}              2              0.000216
#                                                   4              0.000211
#                                                   8              0.000212
# {'name': 'comp_large', 'type': 'function'}        2              0.000207
#                                                   4              0.000201
#                                                   8              0.000203
# {'name': 'correctness_check', 'type': 'function'} 2              0.000005
#                                                   4              0.000005
#                                                   8              0.000005
# {'name': 'data_init', 'type': 'function'}         2              0.000713
#                                                   4              0.000363
#                                                   8              0.000189
#
#                                                                            \
#                                                             Max time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2             11.864023
#                                                   4             23.700060
#                                                   8             47.531330
# {'name': 'comm', 'type': 'function'}              2              0.022595
#                                                   4              0.041438
#                                                   8              0.047598
# {'name': 'comm_large', 'type': 'function'}        2              0.022532
#                                                   4              0.041399
#                                                   8              0.047569
# {'name': 'comp', 'type': 'function'}              2             11.824505
#                                                   4             23.647571
#                                                   8             47.395182
# {'name': 'comp_large', 'type': 'function'}        2             11.824450
#                                                   4             23.647520
#                                                   8             47.395130
# {'name': 'correctness_check', 'type': 'function'} 2              0.000813
#                                                   4              0.000412
#                                                   8              0.010243
# {'name': 'data_init', 'type': 'function'}         2              0.000726
#                                                   4              0.026056
#                                                   8              0.000199
#
#                                                                            \
#                                                             Avg time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              5.936171
#                                                   4              5.956217
#                                                   8              5.994606
# {'name': 'comm', 'type': 'function'}              2              0.011388
#                                                   4              0.010463
#                                                   8              0.010824
# {'name': 'comm_large', 'type': 'function'}        2              0.011350
#                                                   4              0.010442
#                                                   8              0.010806
# {'name': 'comp', 'type': 'function'}              2              5.912361
#                                                   4              5.921195
#                                                   8              5.924588
# {'name': 'comp_large', 'type': 'function'}        2              5.912328
#                                                   4              5.921170
#                                                   8              5.924572
# {'name': 'correctness_check', 'type': 'function'} 2              0.000409
#                                                   4              0.000109
#                                                   8              0.001285
# {'name': 'data_init', 'type': 'function'}         2              0.000719
#                                                   4              0.006790
#                                                   8              0.000192
#
#                                                                         \
#                                                             Total time
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2          11.872342
#                                                   4          23.824868
#                                                   8          47.956850
# {'name': 'comm', 'type': 'function'}              2           0.022776
#                                                   4           0.041852
#                                                   8           0.086593
# {'name': 'comm_large', 'type': 'function'}        2           0.022701
#                                                   4           0.041766
#                                                   8           0.086445
# {'name': 'comp', 'type': 'function'}              2          11.824721
#                                                   4          23.684780
#                                                   8          47.396701
# {'name': 'comp_large', 'type': 'function'}        2          11.824657
#                                                   4          23.684680
#                                                   8          47.396577
# {'name': 'correctness_check', 'type': 'function'} 2           0.000818
#                                                   4           0.000435
#                                                   8           0.010279
# {'name': 'data_init', 'type': 'function'}         2           0.001439
#                                                   4           0.027160
#                                                   8           0.001536
#
#                                                                                 \
#                                                             Variance time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                  35.139425
#                                                   4                 104.948038
#                                                   8                 246.471678
# {'name': 'comm', 'type': 'function'}              2                   0.000126
#                                                   4                   0.000320
#                                                   8                   0.000349
# {'name': 'comm_large', 'type': 'function'}        2                   0.000125
#                                                   4                   0.000319
#                                                   8                   0.000349
# {'name': 'comp', 'type': 'function'}              2                  34.953456
#                                                   4                 104.741689
#                                                   8                 245.687165
# {'name': 'comp_large', 'type': 'function'}        2                  34.953185
#                                                   4                 104.741388
#                                                   8                 245.686744
# {'name': 'correctness_check', 'type': 'function'} 2                   0.000000
#                                                   4                   0.000000
#                                                   8                   0.000011
# {'name': 'data_init', 'type': 'function'}         2                   0.000000
#                                                   4                   0.000124
#                                                   8                   0.000000
#
#                                                                           name
#
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                       main
#                                                   4                       main
#                                                   8                       main
# {'name': 'comm', 'type': 'function'}              2                       comm
#                                                   4                       comm
#                                                   8                       comm
# {'name': 'comm_large', 'type': 'function'}        2                 comm_large
#                                                   4                 comm_large
#                                                   8                 comm_large
# {'name': 'comp', 'type': 'function'}              2                       comp
#                                                   4                       comp
#                                                   8                       comp
# {'name': 'comp_large', 'type': 'function'}        2                 comp_large
#                                                   4                 comp_large
#                                                   8                 comp_large
# {'name': 'correctness_check', 'type': 'function'} 2          correctness_check
#                                                   4          correctness_check
#                                                   8          correctness_check
# {'name': 'data_init', 'type': 'function'}         2                  data_init
#                                                   4                  data_init
#                                                   8                  data_init

# %%
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), 
                                                 ('Sorted', "nid"), ('Sorted', "spot.channel"),('Sorted', "Min time/rank"), ('Sorted', "Max time/rank"),('Sorted', "Total time"), ('Sorted', "Variance time/rank"),
                                                 
                                                 ], axis=1)

# %%
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
ctk.dataframe
# Out:
#                                    Sorted
#                             Avg time/rank
# name              num_procs
# main              2              5.936171
#                   4              5.956217
#                   8              5.994606
# comm              2              0.011388
#                   4              0.010463
#                   8              0.010824
# comm_large        2              0.011350
#                   4              0.010442
#                   8              0.010806
# comp              2              5.912361
#                   4              5.921195
#                   8              5.924588
# comp_large        2              5.912328
#                   4              5.921170
#                   8              5.924572
# correctness_check 2              0.000409
#                   4              0.000109
#                   8              0.001285
# data_init         2              0.000719
#                   4              0.006790
#                   8              0.000192

# %%
main = ctk.dataframe.loc["main"]
main
# Out:
#                  Sorted
#           Avg time/rank
# num_procs
# 2              5.936171
# 4              5.956217
# 8              5.994606

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
legend_labels = []
for column in main.columns:
    first_index = column[0]  # Extract the first index
    legend_labels.append(first_index)
    plt.plot(main.index, main.xs(column, axis=1), marker='o', label=column)

plt.xlabel('Number of Processors')
plt.ylabel('Avg time per rank (s)')
plt.title('Weak Scaling for 2^16 Elements')
plt.legend(legend_labels)
plt.grid(True)
plt.show()
